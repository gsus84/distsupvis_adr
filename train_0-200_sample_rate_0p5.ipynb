# %%
import os
import random

from collections import Counter
from collections import defaultdict

import dist_sup_lib.rel_ext as rel_ext
import dist_sup_lib.utils as utils

from src.utils import read_json_examples
from src.utils import read_kb_triples
from src.utils import read_kb_triples_json

# %%
# Set all the random seeds for reproducibility. Only the
# system seed is relevant for this notebook.

utils.fix_random_seeds()

# %%
rel_ext_data_sents = os.path.join('data', 'featurized_sentences')
rel_ext_data_kb = os.path.join("data", "knowledge_base")

# %%
example_data = []

# %%
for index in range(1, 200):
    s_i = str(index)
    zeros = "0" * (4 - len(s_i))
    # Files updated constantly and the names changes by year
    # for files downloaded in 2021 file_naming has to be changed to
    # featurized_sents_pubmed21n
    tagged_sent_file = f"featurized_sents_pubmed20n{zeros + s_i}.json"
    file_path = os.path.join(rel_ext_data_sents, tagged_sent_file)
    example_data.extend(read_json_examples(file_path))

# %%
# read data
# example_data = read_examples(os.path.join(rel_ext_data_sents, "tagged_medline_sents_files_1-20.tsv"))

# %%
print(type(example_data))
print(example_data[:3])
print(len(example_data))
# Out:
# <class 'list'>
# [Example(entity_1='weight', entity_2='sodium', left='Determinations of the molecular ', mention_1='weight', middle=' of the enzyme based on its amino acid composition, sedimentation velocity, and ', mention_2='sodium', right=' dodecyl sulfate gel electrophoresis gave values of 17680, 17470 and 18300, respectively.', left_POS='Determinations/NNS of/IN the/DT molecular/JJ', mention_1_POS='weight/NN', middle_POS='of/IN the/DT enzyme/NN based/VBN on/IN its/PRP$ amino/NN acid/NN composition/NN ,/, sedimentation/NN velocity/NN ,/, and/CC', mention_2_POS='sodium/NN', right_POS='dodecyl/NN sulfate/NN gel/JJ electrophoresis/NN gave/VBD values/NNS of/IN 17680/CD ,/, 17470/CD and/CC 18300/CD ,/, respectively/RB ./.'), Example(entity_1='growth', entity_2='neostigmine', left='The enzymes from both species are inhibited by the anti-cholinesterases neostigmine, physostigmine, and 284c51 and by AMO-1618, a plant ', mention_1='growth', middle='', mention_2='neostigmine', right=', physostigmine, and 284c51 and by AMO-1618, a plant growth retardant and they both have pH optima near pH 8.0.', left_POS='The/DT enzymes/NNS from/IN both/DT species/NNS are/VBP inhibited/VBN by/IN the/DT anti-cholinesterases/NNS neostigmine/NN ,/, physostigmine/NN ,/, and/CC 284c51/CD and/CC by/IN AMO-1618/NNP ,/, a/DT plant/NN', mention_1_POS='growth/NN', middle_POS='', mention_2_POS='neostigmine/NN', right_POS=',/, physostigmine/NN ,/, and/CC 284c51/CD and/CC by/IN AMO-1618/NNP ,/, a/DT plant/NN growth/NN retardant/NN and/CC they/PRP both/DT have/VBP pH/VBN optima/JJ near/IN pH/JJ 8.0/CD ./.'), Example(entity_1='growth', entity_2='physostigmine', left='The enzymes from both species are inhibited by the anti-cholinesterases neostigmine, physostigmine, and 284c51 and by AMO-1618, a plant ', mention_1='growth', middle='', mention_2='physostigmine', right=', and 284c51 and by AMO-1618, a plant growth retardant and they both have pH optima near pH 8.0.', left_POS='The/DT enzymes/NNS from/IN both/DT species/NNS are/VBP inhibited/VBN by/IN the/DT anti-cholinesterases/NNS neostigmine/NN ,/, physostigmine/NN ,/, and/CC 284c51/CD and/CC by/IN AMO-1618/NNP ,/, a/DT plant/NN', mention_1_POS='growth/NN', middle_POS='', mention_2_POS='physostigmine/NN', right_POS=',/, and/CC 284c51/CD and/CC by/IN AMO-1618/NNP ,/, a/DT plant/NN growth/NN retardant/NN and/CC they/PRP both/DT have/VBP pH/VBN optima/JJ near/IN pH/JJ 8.0/CD ./.')]
# 884221

# %%
corpus = rel_ext.Corpus(example_data)

# %%
kb_triples = read_kb_triples_json(os.path.join(rel_ext_data_kb, "rel_drug_react_triple_occ_all.json"))
kb = rel_ext.KB(kb_triples)

# %%
dataset = rel_ext.Dataset(corpus, kb)

# %%
splits = dataset.build_splits()

splits
# Out:
# {'tiny': Corpus with 1,428 examples; KB with 674 triples,
#  'train': Corpus with 671,169 examples; KB with 35,548 triples,
#  'dev': Corpus with 211,624 examples; KB with 16,678 triples,
#  'all': Corpus with 884,221 examples; KB with 52,900 triples}

# %% [markdown]
# ### Negative instances
#
# By joining the corpus to the KB, we can obtain abundant positive instances for each relation. But a classifier cannot be trained on positive instances alone. In order to apply the distant supervision paradigm, we will also need some negative instances — that is, entity pairs which do not belong to any known relation. If you like, you can think of these entity pairs as being assigned to a special relation called `NO_RELATION`. We can find plenty of such pairs by searching for examples in the corpus which contain two entities which do not belong to any relation in the KB.

# %%
dataset.find_unrelated_pairs()
# Out:
# {('atypical_fracture', 'concomitant'),
#  ('cardiac', 'hand_deformity'),
#  ('pentoxifylline', 'infertility'),
#  ('seminoma', 'gallium'),
#  ('phenytoin', 'myotonia'),
#  ('vasopressin', 'fluid_replacement'),
#  ('piroxicam', 'colorectal_cancer'),
#  ('potassium', 'renin'),
#  ('caesarean_section', 'pancuronium'),
#  ('verapamil', 'colorectal_cancer'),
#  ('polydipsia', 'adriamycin'),
#  ('saliva', 'phencyclidine'),
#  ('cardiac', 'convalescent'),
#  ('alfentanil', 'colonoscopy'),
#  ('energy', 'mitoxantrone'),
#  ('basal', 'skin_swelling'),
#  ('hyperoxaluria', 'furosemide'),
#  ('dermatosis', 'ammonium'),
#  ('concomitant', 'mammoplasty'),
#  ('chemotherapy', 'chromium'),
#  ('medium', 'thyroglobulin'),
#  ('droperidol', 'infusion'),
#  ('carboplatin', 'nephropathy'),
#  ('streptococcal_endocarditis', 'clostridium'),
#  ('proparacaine', 'growth'),
#  ('anaphylactic_shock', 'polypeptide'),
#  ('monosodium', 'vitamin_a_deficiency'),
#  ('immunoglobulin', 'performance_status'),
#  ('pityriasis', 'potassium'),
#  ('massage', 'acetazolamide'),
#  ('haemolysis', 'peptide'),
#  ('dependence', 'erythromycin'),
#  ('lorazepam', 'delivery'),
#  ('globulin', 'graft_loss'),
#  ('proteus_infection', 'propranolol'),
#  ('cardiac', 'lyme_disease'),
#  ('immunodeficiency', 'lithium'),
#  ('infusion', 'etidronate'),
#  ('streptococcal_sepsis', 'ampicillin'),
#  ('cardiac_index', 'somatostatin'),
#  ('erysipelas', 'teicoplanin'),
#  ('instant', 'laboratory_test'),
#  ('secretin', 'stenosis'),
#  ('muscle_injury', 'nifedipine'),
#  ('mucocutaneous_candidiasis', 'endocrine'),
#  ('elderly', 'carotene'),
#  ('ventricular_dysfunction', 'urapidil'),
#  ('nac', 'obstruction'),
#  ('gastritis', 'concomitant'),
#  ('urine_chloride', 'hydrochlorothiazide'),
#  ('volvulus', 'tinidazole'),
#  ('bumetanide', 'oxygen_consumption'),
#  ('investigation', 'clofibrate'),
#  ('nasal', 'mucosal_ulceration'),
#  ('breast_cancer', 'miconazole'),
#  ('bronchospasm', 'cardiac'),
#  ('cyclosporin', 'pemphigus'),
#  ('instant', 'investigation'),
#  ('diltiazem', 'delivery'),
#  ('carbon_dioxide', 'acetazolamide'),
#  ('paradox', 'pleural_effusion'),
#  ('nasal_irrigation', 'intranasal'),
#  ('thyroidectomy', 'lithium'),
#  ('delayed_sleep_phase', 'double-blind'),
#  ('pancreatic_carcinoma', 'famotidine'),
#  ('cardiac', 'lymphocytic_leukaemia'),
#  ('motion_sickness', 'vasopressin'),
#  ('frusemide', 'vasoconstriction'),
#  ('famotidine', 'fibrosis'),
#  ('thoracotomy', 'double-blind'),
#  ('prednisolone', 'myelofibrosis'),
#  ('droperidol', 'intracranial_pressure'),
#  ('concomitant', 'low_density_lipoprotein'),
#  ('blister', 'ac'),
#  ('thirst', 'basal'),
#  ('epinephrine', 'oxytocin'),
#  ('floxuridine', 'renal_cell_carcinoma'),
#  ('minocycline', 'acne_conglobata'),
#  ('endocrine', 'hyperlipidaemia'),
#  ('neck_surgery', 'clindamycin'),
#  ('oxytetracycline', 'papulopustular_rosacea'),
#  ('myotonia', 'cardiac'),
#  ('cholesterol', 'lipase'),
#  ('platelet_aggregation', 'ciprofibrate'),
#  ('medium', 'coronary_artery_surgery'),
#  ('heart_transplant', 'furosemide'),
#  ('energy', 'sevoflurane'),
#  ('polypeptide', 'hernia'),
#  ('vitreous_haze', 'gentamicin'),
#  ('surgery', 'cortisporin'),
#  ('ranitidine', 'diphtheria'),
#  ('serotonin_syndrome', 'dopamine'),
#  ('methoxyflurane', 'platelet_aggregation'),
#  ('lymphocytosis', 'cholesterol'),
#  ('pulmonary_sarcoidosis', 'thallium'),
#  ('carmustine', 'beta_2_microglobulin'),
#  ('amsacrine', 'investigation'),
#  ('nephrectomy', 'gentamicin'),
#  ('mucormycosis', 'basal'),
#  ('levodopa', 'anaesthesia'),
#  ('cyclosporin', 'thrombotic_thrombocytopenic_purpura'),
#  ('calcinosis', 'concomitant'),
#  ('knee_arthroplasty', 'enoxaparin'),
#  ('urine_sodium', 'calcium'),
#  ('polypeptide', 'tissue_injury'),
#  ('asphyxia', 'reserpine'),
#  ('breast_engorgement', 'double-blind'),
#  ('myocarditis', 'penicillin'),
#  ('crying', 'sufentanil'),
#  ('cholera', 'buserelin'),
#  ('coronary_artery_disease', 'milrinone'),
#  ('debridement', 'ketoconazole'),
#  ('stress', 'technetium'),
#  ('cyclosporin', 'aspiration'),
#  ('ventricular_fibrillation', 'cesium'),
#  ('orthostatic_hypotension', 'esmolol'),
#  ('amantadine', 'amylase'),
#  ('carotid_artery_occlusion', 'minoxidil'),
#  ('flurbiprofen', 'dialysis'),
#  ('chromium', 'herpes_simplex'),
#  ('ataxia', 'phencyclidine'),
#  ('sedation', 'clenbuterol'),
#  ('enzyme_activity', 'surfactant'),
#  ('enflurane', 'urine_flow'),
#  ('urapidil', 'blood_pressure'),
#  ('metabolic_alkalosis', 'tide'),
#  ('erythromycin', 'debridement'),
#  ('hydrochlorothiazide', 'cutaneous_lupus_erythematosus'),
#  ('ketoconazole', 'phagocytosis'),
#  ('pco2', 'droperidol'),
#  ('parenteral_nutrition', 'amiodarone'),
#  ('rhegmatogenous_retinal_detachment', 'ganciclovir'),
#  ('leukaemia', 'vinblastine'),
#  ('oxymetholone', 'leukaemia'),
#  ('ketotifen', 'breast_feeding'),
#  ('myocardial_ischaemia', 'quinapril'),
#  ('elderly', 'arotinolol'),
#  ('hyperplasia', 'finasteride'),
#  ('energy', 'germanium'),
#  ('elective_surgery', 'teicoplanin'),
#  ('medium', 'disability'),
#  ('intranasal', 'pertussis'),
#  ('adenocarcinoma', 'corynebacterium'),
#  ('intensive_care', 'diltiazem'),
#  ('nilutamide', 'oxygen_consumption'),
#  ('exeresis', 'cisplatin'),
#  ('malignant_melanoma', 'endocrine'),
#  ('cerebral_palsy', 'diphenylhydantoin'),
#  ('concomitant', 'vitamin_b1'),
#  ('hypertrophy', 'enalapril'),
#  ('benzbromarone', 'transplant'),
#  ('albendazole', 'cyst_removal'),
#  ('tenderness', 'piroxicam'),
#  ('peptide', 'rhinitis'),
#  ('gadolinium', 'adenocarcinoma'),
#  ('magnesium', 'muscular_dystrophy'),
#  ('timolol', 'urine_potassium'),
#  ('rhabdomyosarcoma', 'topotecan'),
#  ('rev', 'folliculitis'),
#  ('5-fluorouracil', 'dependence'),
#  ('extravasation', 'submucosal'),
#  ('aspiration', 'ornidazole'),
#  ('medium', 'retrograde_ejaculation'),
#  ('quinacrine', 'acidosis'),
#  ('endocrine', 'euthyroid_sick_syndrome'),
#  ('leukaemia', 'mitomycin'),
#  ('temocillin', 'faeces'),
#  ('germ_cell_cancer', 'methotrexate'),
#  ('hepatitis_c', 'peptide'),
#  ('in_vitro_fertilisation', 'dopamine'),
#  ('stanozolol', 'radicular_pain'),
#  ('double-blind', 'hookworm_infection'),
#  ('prophylaxis', 'bleomycin'),
#  ('retinopathy_of_prematurity', 'medium'),
#  ('heart_rate_variability', 'imipramine'),
#  ('cardiopulmonary_bypass', 'enflurane'),
#  ('concomitant', 'sinoatrial_block'),
#  ('nicotine_dependence', 'instant'),
#  ('phagocytosis', 'streptomycin'),
#  ('nisoldipine', 'blood_pressure'),
#  ('ventricular_dysfunction', 'milrinone'),
#  ('urethritis', 'lymecycline'),
#  ('fotemustine', 'malignant_melanoma'),
#  ('edrophonium', 'mean_arterial_pressure'),
#  ('hepatotoxicity', 'albendazole'),
#  ('bite', 'mepivacaine'),
#  ('endocrine', 'intermittent_claudication'),
#  ('mer', 'myocardial_infarction'),
#  ('wound_infection', 'cardiac'),
#  ('vitamin_a_deficiency', 'immunoglobulin'),
#  ('mobility', 'l-dopa'),
#  ('glycosuria', 'gentamicin'),
#  ('subcutaneous_emphysema', 'disinfectant'),
#  ('immunisation', 'nasal'),
#  ('rheumatoid_arthritis', 'endocrine'),
#  ('nasal', 'hepatic_necrosis'),
#  ('barium', 'haemoconcentration'),
#  ('meconium', 'submucosal'),
#  ('submucosal', 'telangiectasia'),
#  ('5-fluorouracil', 'oophorectomy'),
#  ('surgery', 'amoxycillin'),
#  ('neurogenic_bladder', 'norfloxacin'),
#  ('gastritis', 'beta-carotene'),
#  ('disodium', 'manganese'),
#  ('anaesthesia', 'potassium'),
#  ('norfloxacin', 'epinephrine'),
#  ('urine_sodium', 'benzbromarone'),
#  ('oxytetracycline', 'hydrocele'),
#  ('frusemide', 'dependence'),
#  ('astrocytoma', 'medium'),
#  ('mitomycin', 'hysterectomy'),
#  ('physostigmine', 'memory_impairment'),
#  ('bacteriuria', 'cephalosporin'),
#  ('cyanosis', 'somatostatin'),
#  ('drug_clearance', 'lignocaine'),
#  ('biopsy', 'amoxycillin'),
#  ('lidocaine', 'gastric_dilatation'),
#  ('piperacillin', 'meningitis'),
#  ('plasmapheresis', 'beta-carotene'),
#  ('reproductive_toxicity', 'albendazole'),
#  ('chemotherapy', 'ofloxacin'),
#  ('metronidazole', 'oral_infection'),
#  ('immunoglobulin', 'drug_abuse'),
#  ('cellulitis', 'corynebacterium'),
#  ('sneezing', 'nostril'),
#  ('megacolon', 'concomitant'),
#  ('mebendazole', 'dementia'),
#  ('lipase', 'polypeptide'),
#  ('neuroblastoma', 'losartan'),
#  ('librium', 'blood_alcohol'),
#  ('cyproheptadine', 'myopathy'),
#  ('peptide', 'fanconi_syndrome'),
#  ('oophorectomy', 'adriamycin'),
#  ('bacterial_pyelonephritis', 'amikacin'),
#  ('abdominal_pain', 'phenformin'),
#  ('delivery', 'meperidine'),
#  ('goitre', 'medium'),
#  ('titanium', 'dialysis'),
#  ('natamycin', 'oral_candidiasis'),
#  ('polypeptide', 'bladder_cancer'),
#  ('chest_x-ray', 'acebutolol'),
#  ('stereotypy', 'cyproheptadine'),
#  ('acromegaly', 'somatostatin'),
#  ('sodium', 'flow_cytometry'),
#  ('mifepristone', 'general_anaesthesia'),
#  ('submucosal', 'extravasation'),
#  ('atrial_fibrillation', 'bretylium'),
#  ('carotene', 'iron_deficiency'),
#  ('procaine', 'otitis_media'),
#  ('nasal', 'bone_loss'),
#  ('ammonium', 'pyruvate_kinase'),
#  ('growth', 'treosulfan'),
#  ('nizatidine', 'stress'),
#  ('anticoagulant_therapy', 'endocrine'),
#  ('concomitant', 'diabetes_mellitus'),
#  ('ropivacaine', 'death'),
#  ('plasma_cells', 'double-blind'),
#  ('penicillin', 'acquired_immunodeficiency_syndrome'),
#  ('cutaneous_amyloidosis', 'endocrine'),
#  ('menogaril', 'aspartate_aminotransferase'),
#  ('meropenem', 'meningitis'),
#  ('surgery', 'uracil'),
#  ('right_ventricular_dilatation', 'cardiac'),
#  ('metabolic_acidosis', 'dofetilide'),
#  ('drug_resistance', 'mer'),
#  ('bleomycin', 'cytoreductive_surgery'),
#  ('decreased_interest', 'dopamine'),
#  ('arac', 'death'),
#  ('pleural_thickening', 'amiodarone'),
#  ('diclofenac', 'laparotomy'),
#  ('primary_amyloidosis', 'technetium'),
#  ('vanadium', 'hypertension'),
#  ('atrial_fibrillation', 'ac'),
#  ('vomiting', 'peptide'),
#  ('cardiac_monitoring', 'ganciclovir'),
#  ('pindolol', 'sudden_death'),
#  ('submucosal', 'gastroenteritis'),
#  ('adenocarcinoma', 'epirubicin'),
#  ('hypercalciuria', 'potassium'),
#  ('doxofylline', 'forced_expiratory_volume'),
#  ('lipids', 'reserpine'),
#  ('mifepristone', 'depression'),
#  ('human_chorionic_gonadotropin', 'verapamil'),
#  ('acetazolamide', 'glomerular_filtration_rate'),
#  ('electroencephalogram', 'ciprofloxacin'),
#  ('physostigmine', 'respiratory_depression'),
#  ('cardiac', 'obstruction'),
#  ('nitrendipine', 'diastolic_dysfunction'),
#  ('nerve_block', 'ropivacaine'),
#  ('hypercalcaemia', 'cisplatin'),
#  ('ketoconazole', 'transplant'),
#  ('mediastinal_effusion', 'cardiac'),
#  ('methoxyflurane', 'condition'),
#  ('tac', 'condition'),
#  ('hepatomegaly', 'fenofibrate'),
#  ('vasoconstriction', 'methylprednisolone'),
#  ('humulin', 'infusion'),
#  ('endocrine', 'hydrocephalus'),
#  ('mebeverine', 'condition'),
#  ('nitrazepam', 'cortisol'),
#  ('schizophreniform_disorder', 'remoxipride'),
#  ('double-blind', 'sinusitis'),
#  ('thiabendazole', 'macrophages'),
#  ('vasopressin', 'infusion'),
#  ('hepatotoxicity', 'penicillin'),
#  ('rociverine', 'incontinence'),
#  ('gamma-globulin', 'parenteral_nutrition'),
#  ('barium', 'syphilis'),
#  ('arachnoid_cyst', 'concomitant'),
#  ('menstruation', 'ketoprofen'),
#  ('idoxuridine', 'infusion'),
#  ('bacteriuria', 'disinfectant'),
#  ('corynebacterium', 'tumour_necrosis'),
#  ('fatigue', 'flumazenil'),
#  ('injury', 'polypeptide'),
#  ('medium', 'vaginal_discharge'),
#  ('cardiac', 'chorea'),
#  ('platelet_aggregation', 'ketorolac'),
#  ('tachycardia', 'bepridil'),
#  ('systemic_scleroderma', 'prednisolone'),
#  ('injury', 'suxamethonium'),
#  ('lipase', 'kanamycin'),
#  ('exercise_tolerance', 'technetium'),
#  ('glioma', 'pindolol'),
#  ('mebendazole', 'rash'),
#  ('intranasal', 'plethysmography'),
#  ('pericardial_disease', 'nasal'),
#  ('concomitant', 'vascular_occlusion'),
#  ('alclofenac', 'spondylitis'),
#  ('teicoplanin', 'renal_failure'),
#  ('obstruction', 'meperidine'),
#  ('haloperidol', 'erection'),
#  ('fluoxetine', 'elderly'),
#  ('nifedipine', 'coronary_artery_bypass'),
#  ('platelet_aggregation', 'gentamicin'),
#  ('phencyclidine', 'vasoconstriction'),
#  ('endocrine', 'vipoma'),
#  ('sepsis', 'roxithromycin'),
#  ('corynebacterium', 'ulcer'),
#  ('hypoxia', 'sulfamethoxazole-trimethoprim'),
#  ('propranolol', 'beta_2_microglobulin'),
#  ('dehydration', 'concomitant'),
#  ('granulocyte_count', 'ticarcillin'),
#  ('radiotherapy', 'concomitant'),
#  ('norfloxacin', 'growth'),
#  ('netilmicin', 'sepsis'),
#  ('multiple-drug_resistance', 'ampicillin'),
#  ('sarcoidosis', 'globulin'),
#  ('dry_skin', 'double-blind'),
#  ('incontinence', 'somatostatin'),
#  ('diflunisal', 'urine_flow'),
#  ('oestradiol', 'concomitant'),
#  ('trichlormethiazide', 'hypotension'),
#  ('hepatitis', 'cardiac'),
#  ('gadolinium', 'systemic_lupus_erythematosus'),
#  ('bifascicular_block', 'cardiac'),
#  ('menopausal', 'hypogonadism'),
#  ('ofloxacin', 'tuberculosis'),
#  ('infusion', 'reserpine'),
#  ('hypertrophy', 'nitrendipine'),
#  ('granulocytopenia', 'mebendazole'),
#  ('nifedipine', 'prophylaxis'),
#  ('daunomycin', 'alkalosis'),
#  ('paralysis', 'peptide'),
#  ('hyperoxia', 'tobramycin'),
#  ('ankylosing_spondylitis', 'technetium'),
#  ('chorea', 'lithium'),
#  ('desogestrel', 'endometrial_hyperplasia'),
#  ('stress_ulcer', 'cimetidine'),
#  ('vinblastine', 'breast_cancer_metastatic'),
#  ('pain', 'actinomycin'),
#  ('pulmonary_necrosis', 'heparin'),
#  ('testicular_torsion', 'technetium'),
#  ('immunoglobulins', 'basal'),
#  ('cardiomyopathy', 'molsidomine'),
#  ('hypoparathyroidism', 'immunoglobulin'),
#  ('selenium', 'ovarian_cancer'),
#  ('gallium', 'neurosarcoidosis'),
#  ('nasal', 'lymphangioma'),
#  ('penciclovir', 'infusion'),
#  ('hyposomnia', 'peptide'),
#  ('mania', 'somatostatin'),
#  ('ibuprofen', 'right_ventricular_hypertrophy'),
#  ('potassium', 'dental_cleaning'),
#  ('parenteral_nutrition', 'busulfan'),
#  ('obstruction', 'amoxicillin'),
#  ('norfloxacin', 'catheter_removal'),
#  ('allantoin', 'injection'),
#  ('lymphadenitis', 'cardiac'),
#  ('minocycline', 'brucellosis'),
#  ('extracorporeal_circulation', 'captopril'),
#  ('albuterol', 'infusion'),
#  ('mean_arterial_pressure', 'labetalol'),
#  ('tendon_rupture', 'ac'),
#  ('erythromycin', 'bacteriuria'),
#  ('pco2', 'nifedipine'),
#  ('coronary_artery_bypass', 'technetium'),
#  ('diabetic_gastroparesis', 'cisapride'),
#  ('penicillin', 'type_i_hypersensitivity'),
#  ('renal_transplant', 'ofloxacin'),
#  ('barium', 'growth'),
#  ('sinus_rhythm', 'nisoldipine'),
#  ('immunisation', 'acyclovir'),
#  ('globulin', 'thyroiditis'),
#  ('acetorphan', 'withdrawal_syndrome'),
#  ('biliary_sepsis', 'temocillin'),
#  ('pleural_mesothelioma', 'bleomycin'),
#  ('immunoglobulin', 'protein_s'),
#  ('oxytetracycline', 'azotaemia'),
#  ('carcinogenicity', 'omeprazole'),
#  ('insulinoma', 'potassium'),
#  ('dan', 'cardiac_dysfunction'),
#  ('treatment_failure', 'goserelin'),
#  ('injury', 'kanamycin'),
#  ('cephalosporin', 'dissociation'),
#  ('cocaine', 'premature_delivery'),
#  ('haemolysis', 'methyldopa'),
#  ('infection', 'cryoglobulin'),
#  ('conjunctivitis', 'antazoline'),
#  ('double-blind', 'energy'),
#  ('submucosal', 'swelling'),
#  ('macrophages', 'etodolac'),
#  ('transitional_cell_carcinoma', 'nitrofurantoin'),
#  ('vasospasm', 'medium'),
#  ('prednisolone', 'nephrectomy'),
#  ('epinephrine', 'arotinolol'),
#  ('intranasal', 'sepsis'),
#  ('gentamycin', 'hepatorenal_syndrome'),
#  ('prazosin', 'gout'),
#  ('lupus-like_syndrome', 'hydralazine'),
#  ('polypeptide', 'renal_hypertrophy'),
#  ('cocaine', 'vasospasm'),
#  ('pre-eclampsia', 'pindolol'),
#  ('nadolol', 'embolism'),
#  ('fistula', 'heparin'),
#  ('eosinophilia', 'febarbamate'),
#  ('haemorrhage', 'gamma-globulin'),
#  ('diltiazem', 'right_ventricular_hypertrophy'),
#  ('potassium', 'cardioversion'),
#  ('labetalol', 'long_qt_syndrome'),
#  ('mesenteric_vein_thrombosis', 'cardiac'),
#  ('paroxetine', 'elderly'),
#  ('technetium', 'inflammation'),
#  ('buspirone', 'hyperthermia'),
#  ('hyperinsulinaemia', 'thiazide'),
#  ('nadroparin', 'primary_hyperaldosteronism'),
#  ('angiosarcoma', 'concomitant'),
#  ('tonsillitis', 'phenoxymethylpenicillin'),
#  ('pyruvate_kinase', 'chromium'),
#  ('endocrine', 'hiv_infection'),
#  ('endometritis', 'amoxicillin'),
#  ('propafenone', 'epigastric_discomfort'),
#  ('rash', 'bufexamac'),
#  ('neomycin', 'hysterectomy'),
#  ('progesterone', 'econazole'),
#  ('globulin', 'glucocorticoids'),
#  ('polypeptide', 'atrial_tachycardia'),
#  ('cholesterol', 'glaucoma'),
#  ('nortriptyline', 'dissociation'),
#  ('pancreatic_fistula', 'ciprofloxacin'),
#  ('parakeratosis', 'sodium'),
#  ('lymphopenia', 'cholesterol'),
#  ('prazosin', 'coronary_artery_occlusion'),
#  ('thiazide', 'ventricular_hypertrophy'),
#  ('doxycycline', 'lymphocyte_percentage'),
#  ('histology', 'medium'),
#  ('cholesterol', 'emphysema'),
#  ('droperidol', 'accident'),
#  ('osteosclerosis', 'immunoglobulin'),
#  ('respiratory_tract_infection', 'amoxycillin'),
#  ('peptide', 'disability'),
#  ('meprobamate', 'infusion'),
#  ('cocaine', 'stillbirth'),
#  ('sal', 'myeloid_leukaemia'),
#  ('medium', 'bladder_perforation'),
#  ('cyproheptadine', 'progesterone'),
#  ('somatostatin', 'ovarian_cancer'),
#  ('polypeptide', 'telangiectasia'),
#  ('fosinopril', 'fasting'),
#  ('minoxidil', 'bacterial_infection'),
#  ('glucose_tolerance', 'nitrendipine'),
#  ('neurosis', 'clomipramine'),
#  ('carboplatin', 'small_cell_carcinoma'),
#  ('liver_injury', 'double-blind'),
#  ('fat_tissue', 'alfentanil'),
#  ('endocrine', 'ketosis'),
#  ('injection', 'vinblastine'),
#  ('radium', 'malignant_transformation'),
#  ('quality_of_life', 'demethylchlortetracycline'),
#  ('bepridil', 'sinoatrial_block'),
#  ('cardiac', 'traction'),
#  ('prednisolone', 'monoplegia'),
#  ('nitrendipine', 'hyperaldosteronism'),
#  ('tonsillectomy', 'immunoglobulin'),
#  ('endocrine', 'phyllodes_tumour'),
#  ('streptomycin', 'disseminated_intravascular_coagulation'),
#  ('radiotherapy', 'beta-carotene'),
#  ('double-blind', 'saliva'),
#  ('stanozolol', 'thrombolysis'),
#  ('cisapride', 'eructation'),
#  ('indium', 'dissociation'),
#  ('gallium', 'myocarditis'),
#  ('reserpine', 'hypoxia'),
#  ('amitriptyline', 'electroconvulsive_therapy'),
#  ('histology', 'aluminium'),
#  ('quinolone', 'insomnia'),
#  ('cardiac', 'developmental_delay'),
#  ('abortion', 'endocrine'),
#  ('malnutrition', 'octreotide'),
#  ('dialysis', 'sulbactam'),
#  ('optic_neuropathy', 'endocrine'),
#  ('phenytoin', 'neuromuscular_blockade'),
#  ('tension', 'ketoconazole'),
#  ('delirium', 'gamma-globulin'),
#  ('macular_degeneration', 'cardiac'),
#  ('body_mass_index', 'selenium'),
#  ('calcium', 'antiphospholipid_antibodies'),
#  ('corneal_reflex', 'diazepam'),
#  ('ciprofloxacin', 'pelvic_infection'),
#  ('perforation', 'tide'),
#  ('ascites', 'amoxycillin'),
#  ('amoxicillin', 'meningitis'),
#  ('nasal', 'fibrous_histiocytoma'),
#  ('pyelonephritis', 'endocrine'),
#  ('technetium', 'echocardiogram'),
#  ('asbestosis', 'immunoglobulin'),
#  ('isoflurane', 'elective_surgery'),
#  ('concomitant', 'aplasia'),
#  ('gadolinium', 'renal_failure'),
#  ('renal_tubular_injury', 'magnesium'),
#  ('ketorolac', 'delivery'),
#  ('uracil', 'lipids'),
#  ('interstitial_lung_disease', 'bupivacaine'),
#  ('hypocapnia', 'pancuronium'),
#  ('pneumonitis', 'tetracycline'),
#  ('autoimmune_neutropenia', 'propylthiouracil'),
#  ('anaesthesia', 'flumazenil'),
#  ('immunoglobulin', 'infertility'),
#  ('platelet_aggregation', 'haloperidol'),
#  ('heart_transplant', 'prednisolone'),
#  ('octreotide', 'hepatotoxicity'),
#  ('sputum', 'histidine'),
#  ('polypeptide', 'extravasation'),
#  ('vancomycin', 'adhesion'),
#  ('aneurysm', 'mer'),
#  ('chromium', 'pleural_effusion'),
#  ('pain', 'gamma-globulin'),
#  ('cardiac', 'rubella'),
#  ('dependence', 'reserpine'),
#  ('gallium', 'histology'),
#  ('double-blind', 'yawning'),
#  ('arac', 'elderly'),
#  ('starvation', 'ofloxacin'),
#  ('periodontal_disease', 'tetracycline'),
#  ('dysentery', 'lincomycin'),
#  ('treatment_failure', 'imipenem'),
#  ('pathogen_resistance', 'amikacin'),
#  ('ischaemia', 'cyclosporin'),
#  ('laparoscopy', 'cardiac'),
#  ('rabies', 'gamma-globulin'),
#  ('prolapse', 'cocaine'),
#  ('double-blind', 'local_anaesthesia'),
#  ('ventricular_hypertrophy', 'doxorubicin'),
#  ('hydrothorax', 'tetracycline'),
#  ('performance_status', 'buserelin'),
#  ('obesity', 'cimetidine'),
#  ('heparin', 'cardiac_index'),
#  ('prednisolone', 'angiotensin_converting_enzyme'),
#  ('hepatitis_c', 'methyldopa'),
#  ('clostridium', 'meningitis'),
#  ('medium', 'amoebiasis'),
#  ('cardiac', 'cryptorchism'),
#  ('discharge', 'isoflurane'),
#  ('cryoglobulin', 'flow_cytometry'),
#  ('basal', 'movement_disorder'),
#  ('chemotherapy', 'medium'),
#  ('retinopathy', 'corynebacterium'),
#  ('polypeptide', 'gastroenteritis'),
#  ('secretin', 'total_bile_acids'),
#  ('thallium', 'right_ventricular_hypertrophy'),
#  ('streptococcal_endocarditis', 'teicoplanin'),
#  ('cortisol', 'trenbolone'),
#  ('sal', 'immunosuppression'),
#  ('globulin', 'abdominal_operation'),
#  ('investigation', 'amantadine'),
#  ('l-dopa', 'hyperplasia'),
#  ('hyperemesis_gravidarum', 'sodium'),
#  ('polypeptide', 'delivery'),
#  ('carboplatin', 'injury'),
#  ('medium', 'vascular_calcification'),
#  ('flurazepam', 'perforation'),
#  ('technetium', 'duodenogastric_reflux'),
#  ('trichomoniasis', 'concomitant'),
#  ('pac', 'adrenalectomy'),
#  ('cardiac', 'vitreous_opacities'),
#  ('captopril', 'injury'),
#  ('belgium', 'endocarditis'),
#  ('concomitant', 'tryptase'),
#  ('cardiac', 'osteoporosis'),
#  ('levodopa', 'pregnancy'),
#  ('thymoma', 'vinblastine'),
#  ('adriamycin', 'fasting'),
#  ('epinephrine', 'octocaine'),
#  ('dapsone', 'malaria'),
#  ('mitoxantrone', 'prophylaxis'),
#  ('piroxicam', 'liver_disorder'),
#  ('phencyclidine', 'brain_hypoxia'),
#  ('cyclosporin', 'biopsy'),
#  ('concomitant', 'radical_cystectomy'),
#  ('aortic_surgery', 'cholesterol'),
#  ('milia', 'dapsone'),
#  ('eosinopenia', 'sodium'),
#  ('anaesthesia', 'histidine'),
#  ('adhesion', 'benoxaprofen'),
#  ('medium', 'flushing'),
#  ('bone_formation', 'medium'),
#  ('stress', 'clenbuterol'),
#  ('dinoprost', 'oestradiol'),
#  ('gastroduodenal_ulcer', 'double-blind'),
#  ('nasal', 'globulins'),
#  ('vitamin_d', 'disodium'),
#  ('astrocytoma', '5-fluorouracil'),
#  ('tripeptide', 'depression'),
#  ('hairy_cell_leukaemia', 'immunoglobulin'),
#  ('phagocytosis', 'vancomycin'),
#  ('pulse_pressure', 'felodipine'),
#  ('urine_analysis', 'potassium'),
#  ('medazepam', 'dependence'),
#  ('cisplatin', 'status_epilepticus'),
#  ('biopsy', 'cimetidine'),
#  ('thymoma', 'mitomycin'),
#  ('gentamicin', 'anoxia'),
#  ('medium', 'ototoxicity'),
#  ('ipratroprium', 'rhinorrhoea'),
#  ('cyclosporin', 'mean_arterial_pressure'),
#  ('condition', 'pregnenolone'),
#  ('methylprednisolone', 'laryngoscopy'),
#  ('mass', 'nac'),
#  ('hammer', 'soliloquy'),
#  ('peptic_ulcer', 'trimipramine'),
#  ('serum_sickness', 'cyclosporin'),
#  ('heparin', 'fibrinolysis'),
#  ('tetracosactide', 'skin_reaction'),
#  ('coronary_artery_disease', 'esmolol'),
#  ('flurazepam', 'enzyme_induction'),
#  ('prednisolone', 'neonatal_respiratory_distress'),
#  ('fatigue', 'desflurane'),
#  ('blast_cells', 'cytarabine'),
#  ('haemoglobin', 'econazole'),
#  ('respiratory_alkalosis', 'propranolol'),
#  ('bone_formation', 'aluminium'),
#  ('thyroglobulin', 'clostridium'),
#  ('tonsillitis', 'ticarcillin'),
#  ('menopausal', 'mastectomy'),
#  ('nifedipine', 'meningioma'),
#  ('concomitant', 'neutrophil_count'),
#  ('potassium', 'end-tidal_co2'),
#  ('clindamycin', 'obstruction'),
#  ('pregnancy', 'chlorthiazide'),
#  ('diclofenac', 'endoscopy'),
#  ('abortion', 'ammonium'),
#  ('sotalol', 'bundle_branch_block'),
#  ('instant', 'carcinogenicity'),
#  ('endocrine', 'dysmorphism'),
#  ('acidosis', 'mepacrine'),
#  ('perforation', 'cocaine'),
#  ('stress', 'stim'),
#  ('hydralazine', 'pulmonary_hypertension'),
#  ('lymphocytic_leukaemia', 'prednisolone'),
#  ('respiratory_acidosis', 'enflurane'),
#  ('pyelonephritis', 'ammonium'),
#  ('acrivastine', 'depression'),
#  ('miconazole', 'growth'),
#  ('metabolic_disorder', 'dopamine'),
#  ('actinomycin', 'mass'),
#  ('diclofenac', 'agranulocytosis'),
#  ('nasal', 'dementia'),
#  ('cardiopulmonary_bypass', 'medium'),
#  ('benoxaprofen', 'cholestasis'),
#  ('cardiac_index', 'methylprednisolone'),
#  ('sodium', 'growth_retardation'),
#  ('neomycin', 'intestinal_mass'),
#  ('carbon_dioxide', 'procaine'),
#  ('hyperthermia', 'pancuronium'),
#  ('ketoconazole', 'disability'),
#  ('milrinone', 'arrhythmia'),
#  ('sinus_rhythm', 'cocaine'),
#  ('endocrine', 'organ_failure'),
#  ('infection', 'mitomycin'),
#  ('sulfamethoxazole-trimethoprim', 'stress'),
#  ('radiation_injury', 'bleomycin'),
#  ('nifedipine', 'muscle_fatigue'),
#  ('medium', 'acute_myocardial_infarction'),
#  ('etofylline', 'vascular_insufficiency'),
#  ('pneumonia', 'methicillin'),
#  ('chronic_myeloid_leukaemia', 'tobramycin'),
#  ('lymphadenectomy', 'heparin'),
#  ('double-blind', 'arteriovenous_fistula'),
#  ('concomitant', 'pyoderma'),
#  ('streptomycin', 'enzyme_activity'),
#  ('cocaine', 'alcohol_use'),
#  ('praziquantel', 'dialysis'),
#  ('minoxidil', 'mobility'),
#  ('staphylococcal_sepsis', 'doxycycline'),
#  ('aspiration', 'nac'),
#  ('phencyclidine', 'fall'),
#  ('death', 'bupivacaine'),
#  ('bradypnoea', 'cocaine'),
#  ('ocular_myasthenia', 'edrophonium'),
#  ('somatostatin', 'urine_output'),
#  ('ventricular_dysfunction', 'esmolol'),
#  ('carbenoxolone', 'diuretic_therapy'),
#  ('endocrine', 'adrenalectomy'),
#  ('mass', 'isoflurane'),
#  ('miconazole', 'catheter_removal'),
#  ('discharge', 'globulin'),
#  ('l-dopa', 'miosis'),
#  ('life_expectancy', 'dapsone'),
#  ('progesterone', 'droperidol'),
#  ('disodium', 'proctitis'),
#  ('investigation', 'imipramine'),
#  ('pelvic_infection', 'ampicillin'),
#  ('hypervitaminosis', 'penicillin'),
#  ('double-blind', 'amylase'),
#  ('leukopenia', 'menogaril'),
#  ('blood_pressure', 'medium'),
#  ('endoscopy', 'peptide'),
#  ('vasopressin', 'thyroidectomy'),
#  ('gallium', 'magnetic_resonance_imaging'),
#  ('bile_acid_malabsorption', 'neomycin'),
#  ('thallium', 'renal_impairment'),
#  ('splenomegaly', 'praziquantel'),
#  ('polypeptide', 'swelling'),
#  ('dysplasia', 'peptide'),
#  ('concomitant', 'hyperthermia'),
#  ('mobility', 'pindolol'),
#  ('anaesthesia', 'nadolol'),
#  ('inflammatory_bowel_disease', 'disodium'),
#  ('pac', 'cardiogenic_shock'),
#  ('medium', 'visual_analogue_scale'),
#  ('alveolitis', 'tetracycline'),
#  ('medium', 'stenosis'),
#  ('occupational_asthma', 'hydralazine'),
#  ('renal_tubular_injury', 'carboplatin'),
#  ('carbon_dioxide', 'allantoin'),
#  ('globulin', 'insulin-like_growth_factor'),
#  ('cardiac', 'anaemia'),
#  ('flunitrazepam', 'heart_rate'),
#  ('methotrexate', 'elderly'),
#  ('bepridil', 'weight'),
#  ('vinblastine', 'neurofibrosarcoma'),
#  ('life_expectancy', 'menopausal'),
#  ('carnitine_deficiency', 'medium'),
#  ('erythema', 'peptide'),
#  ('hypertrophic_cardiomyopathy', 'medium'),
#  ('triamcinolone', 'lipids'),
#  ('clostridium', 'urethritis'),
#  ('ganciclovir', 'pregnancy'),
#  ('antibiotic_therapy', 'doxycycline'),
#  ('hyperaemia', 'vasopressin'),
#  ('concomitant', 'personality_disorder'),
#  ('ototoxicity', 'cardiac'),
#  ('paradox', 'condition'),
#  ('aortic_valve_calcification', 'cardiac'),
#  ('mass', 'iodipamide'),
#  ('hypercholesterolaemia', 'sitosterol'),
#  ('sodium', 'blood_selenium'),
#  ('ac', 'wound'),
#  ('pseudocyst', 'barium'),
#  ('vecuronium', 'phaeochromocytoma'),
#  ('ac', 'autoimmune_hypothyroidism'),
#  ('sodium', 'macrophages'),
#  ('tetracaine', 'fluoride'),
#  ('timolol', 'diuretic_therapy'),
#  ('amlodipine', 'dependence'),
#  ('acute_lung_injury', 'medium'),
#  ('isoflurane', 'fistula'),
#  ('fasting', 'secretin'),
#  ('bumetanide', 'malignant_hypertension'),
#  ('carnitine_deficiency', 'aluminium'),
#  ('blood_ph', 'ammonium'),
#  ('clostridium', 'diverticulitis'),
#  ('oxandrolone', 'prealbumin'),
#  ('systemic_lupus_erythematosus', 'timolol'),
#  ('palpitations', 'urapidil'),
#  ('perforation', 'ticarcillin'),
#  ('starvation', 'disodium'),
#  ('mixed_dementia', 'double-blind'),
#  ('vecuronium', 'elective_surgery'),
#  ('5-fluorouracil', 'peritonitis'),
#  ('doxorubicin', 'carcinoembryonic_antigen'),
#  ('meprobamate', 'respiratory_failure'),
#  ('sarcoma', 'rifamycin'),
#  ('arthritis', 'oxytocin'),
#  ('human_chorionic_gonadotropin', 'dopamine'),
#  ('natamycin', 'ulcer'),
#  ('gadolinium', 'sarcoma'),
#  ('concomitant', 'pyonephrosis'),
#  ('pco2', 'domperidone'),
#  ('edentulous', 'menopausal'),
#  ('vinblastine', 'cell_death'),
#  ('double-blind', 'acne'),
#  ('tetracaine', 'surgery'),
#  ('cardiac', 'retinitis_pigmentosa'),
#  ('nephropathy', 'lovastatin'),
#  ('exercise_tolerance', 'clenbuterol'),
#  ('methylprednisolone', 'glucocorticoids'),
#  ('polypeptide', 'ascites'),
#  ('defibrotide', 'reperfusion_injury'),
#  ('renal_injury', 'lovastatin'),
#  ('anticoagulant_therapy', 'sodium'),
#  ('cyproheptadine', 'serum_serotonin'),
#  ('weight', 'defibrotide'),
#  ('endotracheal_intubation', 'cardiac'),
#  ('acidosis', 'acebutolol'),
#  ('cholestasis', 'peptide'),
#  ('plague', 'lithium'),
#  ('ear_discomfort', 'nasal'),
#  ('ammonium', 'proteus_infection'),
#  ('vasospasm', '5-fluorouracil'),
#  ('cephalosporin', 'renal_injury'),
#  ('zidovudine', 'malabsorption'),
#  ('depression', 'thiabendazole'),
#  ('basal', 'nervousness'),
#  ('gonorrhoea', 'doxycycline'),
#  ('nasal', 'renin'),
#  ('erythromycin', 'manganese'),
#  ('granuloma', 'doxycycline'),
#  ('transaminases', 'mithramycin'),
#  ('ac', 'astigmatism'),
#  ('ovarian_cancer', 'thiotepa'),
#  ('diltiazem', 'manganese'),
#  ('piroxicam', 'ammonia'),
#  ('verapamil', 'ammonia'),
#  ('oxytocin', 'erection'),
#  ('rifamycin', 'tuberculosis'),
#  ('ticarcillin', 'tonsillectomy'),
#  ('proxymetacaine', 'local_anaesthesia'),
#  ('mastoiditis', 'endocrine'),
#  ('intranasal', 'shigella_infection'),
#  ('mycelium', 'enzyme_activity'),
#  ('chronic_respiratory_disease', 'cephalosporin'),
#  ('heparin', 'cholera'),
#  ('cardiac', 'troponin_i'),
#  ('enalapril', 'ventricular_failure'),
#  ('cystitis', 'corynebacterium'),
#  ('subdural_hygroma', 'ac'),
#  ('basal', 'malabsorption'),
#  ('histology', '5-fluorouracil'),
#  ('haemoglobin', 'droperidol'),
#  ('bupivacaine', 'myopathy'),
#  ('cardiac_failure', 'lignocaine'),
#  ('blood_test', 'calcium'),
#  ('oxytetracycline', 'endometritis'),
#  ('propafenone', 'ejection_fraction'),
#  ('acute_myocardial_infarction', 'defibrotide'),
#  ('tenosynovitis', 'oxytocin'),
#  ('clostridium', 'paralysis'),
#  ('shock', 'alfentanil'),
#  ('osteopenia', 'buserelin'),
#  ('medium', 'enterocutaneous_fistula'),
#  ('eosinophil_count', 'dopamine'),
#  ('cardiac', 'aortic_surgery'),
#  ('carbenicillin', 'glomerular_filtration_rate'),
#  ('elderly', 'isoflurane'),
#  ('fosfomycin', 'fasting'),
#  ('clemastine', 'anaphylactic_reaction'),
#  ('acetonide', 'cleft_palate'),
#  ('nitrendipine', 'lipids'),
#  ('buspirone', 'parkinsonism'),
#  ('ammonium', 'adenovirus_infection'),
#  ('cholesterol', 'lordosis'),
#  ('retinal_detachment', 'basal'),
#  ('microcephaly', 'cocaine'),
#  ('tac', 'lichen_planus'),
#  ('gastric_cancer', 'actinomycin'),
#  ('antidepressant_therapy', 'basal'),
#  ('neurotoxicity', 'cytoxan'),
#  ('cholecystectomy', 'dopamine'),
#  ('ketosis', 'vasopressin'),
#  ('teicoplanin', 'phagocytosis'),
#  ('infarction', 'cimetidine'),
#  ('haemostasis', 'lignocaine'),
#  ('dehydroepiandrosterone', 'barium'),
#  ('hypersensitivity', 'itraconazole'),
#  ('barium', 'colonoscopy'),
#  ('hypertrophy', 'quinapril'),
#  ('infusion', 'nedocromil'),
#  ('neurosis', 'l-dopa'),
#  ('basal', 'myocardial_depression'),
#  ('menopausal', 'lymphoedema'),
#  ('tobramycin', 'physiotherapy'),
#  ('senile_dementia', 'amantadine'),
#  ('nasal', 'mucosal_inflammation'),
#  ('tremor', 'endocrine'),
#  ('reserpine', 'enzyme_inhibition'),
#  ('fasting', 'mesasal'),
#  ('bronchial_carcinoma', 'polypeptide'),
#  ('cell_death', 'chromium'),
#  ('renal_replacement_therapy', 'heparin'),
#  ('zidovudine', 'leukoencephalopathy'),
#  ('tobramycin', 'abdominal_sepsis'),
#  ('famotidine', 'dissociation'),
#  ('fibrosis', 'furantoin'),
#  ('concomitant', 'myokymia'),
#  ('peptide', 'flushing'),
#  ('dipotassium', 'ejaculation'),
#  ('intraocular_pressure', 'dopamine'),
#  ('blood_viscosity', 'dopamine'),
#  ('anaesthesia', 'articaine'),
#  ('vasopressin', 'cardiotoxicity'),
#  ('cardiac', 'toxic_shock_syndrome'),
#  ('prostate_cancer', 'cholesterol'),
#  ('gliosis', 'mitomycin'),
#  ('frusemide', 'fluid_overload'),
#  ('propranolol', 'energy'),
#  ('oliguria', 'tolazoline'),
#  ('double-blind', 'cutaneous_vasculitis'),
#  ('autoimmune_neutropenia', 'gamma-globulin'),
#  ('blood_aldosterone', 'vasopressin'),
#  ('glioma', 'endocrine'),
#  ('extracorporeal_circulation', 'nifedipine'),
#  ('hepatic_cirrhosis', 'peptide'),
#  ('oxymetazoline', 'epistaxis'),
#  ('erection', 'nimodipine'),
#  ('left_ventricular_failure', 'medium'),
#  ('tension', 'urapidil'),
#  ('labetalol', 'aortic_aneurysm'),
#  ('vascular_malformation', 'barium'),
#  ('corynebacterium', 'drug_abuser'),
#  ('cancer_surgery', 'esmolol'),
#  ('endocarditis', 'doxycycline'),
#  ('basal', 'leukoencephalopathy'),
#  ('chondrosarcoma', 'peptide'),
#  ('benazepril', 'ejection_fraction'),
#  ('laryngoscopy', 'intranasal'),
#  ('chemotherapy', '5-fluorouracil'),
#  ('foreign_body', 'peptide'),
#  ('enteritis', 'gamma-globulin'),
#  ('nitrendipine', 'tension'),
#  ('5-hydroxyindolacetic_acid', 'dopamine'),
#  ('adriamycin', 'chemotherapy'),
#  ('thallium', 'manganese'),
#  ('ciclosporin', 'bone_formation'),
#  ('cholesterol', 'bradykinesia'),
#  ('lethargy', 'ipecac'),
#  ('chest_pain', 'edrophonium'),
#  ('submucosal', 'bladder_injury'),
#  ('pindolol', 'ventricular_hypertrophy'),
#  ('carbon_dioxide', 'concomitant'),
#  ('dermatomyositis', 'cyclosporin'),
#  ('renal_tubular_injury', 'nitrendipine'),
#  ('fungal_sepsis', 'concomitant'),
#  ('cimetidine', 'lymphoma'),
#  ('submucosal', 'arachnoid_cyst'),
#  ('tripeptide', 'necrosis'),
#  ('water_intoxication', 'clofibrate'),
#  ('hepatomegaly', 'mitomycin'),
#  ('progesterone', 'nifedipine'),
#  ('felodipine', 'injection'),
#  ('oxytetracycline', 'investigation'),
#  ('polypeptide', 'strabismus'),
#  ('hyponatraemia', 'atracurium'),
#  ('concomitant', 'functional_residual_capacity'),
#  ('pac', 'sudden_death'),
#  ('haemodialysis', 'fucidin'),
#  ('medium', 'gastric_bypass'),
#  ('cisplatin', 'nephrostomy'),
#  ('ac', 'laparotomy'),
#  ('investigation', 'pentostatin'),
#  ('phenytoin', 'elderly'),
#  ('strontium', 'renal_failure'),
#  ('sinus_arrest', 'phenytoin'),
#  ('hypertension', 'phencyclidine'),
#  ('timolol', 'ventricular_hypertrophy'),
#  ('glomerulonephritis', 'prednisolone'),
#  ('hydralazine', 'fistula'),
#  ('pyruvate_kinase', 'medium'),
#  ('metaplasia', 'immunoglobulin'),
#  ('menstrual_disorder', 'basal'),
#  ('infant', 'calcium'),
#  ('oxytetracycline', 'thyroxine'),
#  ('concomitant', 'dysentery'),
#  ('ventricular_hypertrophy', 'octreotide'),
#  ('actinomycin', 'oedema'),
#  ('erythromycin', 'bronchiolitis'),
#  ('hepatectomy', 'clofibrate'),
#  ('thiazide', 'lethargy'),
#  ('propranolol', 'saliva'),
#  ('beta-carotene', 'dehydroepiandrosterone'),
#  ('arthritis', 'stanozolol'),
#  ('aluminium', 'environmental_exposure'),
#  ('practolol', 'arthralgia'),
#  ('eustachian_tube_dysfunction', 'intranasal'),
#  ('intracranial_aneurysm', 'medium'),
#  ('cardiac', 'glucocorticoid_deficiency'),
#  ('peptide', 'acute_myocardial_infarction'),
#  ('arterial_thrombosis', 'argatroban'),
#  ('disodium', 'anaphylactic_shock'),
#  ('ventricular_failure', 'lidocaine'),
#  ...}

# %% [markdown]
# Let's determine how many examples we have for each triple in the KB. We'll compute averages per relation.

# %%
dataset.count_examples()
# Out:
#                                              examples
# relation               examples    triples    /triple
# --------               --------    -------    -------
# accelerated                  44          1      44.00
# acquired                     23         25       0.92
# aggravated                 2226        421       5.29
# altered                    1014        120       8.45
# caused                   220957      44243       4.99
# changed                     142         92       1.54
# decreased                 56771       3628      15.65
# delayed                      39         47       0.83
# discoloured                 487        149       3.27
# impaired                    332         77       4.31
# improved                      0          1       0.00
# increased                 63399       3720      17.04
# infected                     99         29       3.41
# lowered                       1          2       0.50
# prolonged                   365        112       3.26
# reduced                     174         73       2.38
# ruptured                     79         17       4.65
# shortened                   358        143       2.50

# %%
print(dir(dataset))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'build_dataset', 'build_splits', 'corpus', 'count_examples', 'count_relation_combinations', 'featurize', 'find_unrelated_pairs', 'kb']

# %%
for key, val in dataset.kb.kb_triples_by_relation.items():
    print(key, len(val))
# Out:
# accelerated 1
# acquired 25
# aggravated 421
# altered 120
# caused 44243
# changed 92
# decreased 3628
# delayed 47
# discoloured 149
# impaired 77
# improved 1
# increased 3720
# infected 29
# lowered 2
# prolonged 112
# reduced 73
# ruptured 17
# shortened 143

# %%
for key, val in dataset.kb.kb_triples_by_relation.items():
    print(key, len(val))
# Out:
# accelerated 1
# acquired 25
# aggravated 421
# altered 120
# caused 44243
# changed 92
# decreased 3628
# delayed 47
# discoloured 149
# impaired 77
# improved 1
# increased 3720
# infected 29
# lowered 2
# prolonged 112
# reduced 73
# ruptured 17
# shortened 143

# %%
print(len(dataset.corpus.examples_by_entities))
# Out:
# 4454

# %%
print(dataset.corpus.examples_by_entities.keys())
# Out:
# dict_keys(['weight', 'growth', 'dependence', 'fluoride', 'cardiac', 'cardiac_output', 'anaesthesia', 'fall', 'stress', 'adrenalectomy', 'gastric_ulcer', 'ulcer', 'sodium', 'acidosis', 'metabolic_acidosis', 'extracorporeal_circulation', 'investigation', 'influenza', 'hypertension', 'minoxidil', 'fluid_retention', 'death', 'infection', 'infusion', 'pco2', 'epinephrine', 'glucocorticoids', 'mass', 'parathyroidectomy', 'surgery', 'lorazepam', 'dissociation', 'vasospasm', 'tachycardia', 'hypothermia', 'renin', 'injection', 'histology', 'necrosis', 'dialysis', 'haemodialysis', 'laparotomy', 'intranasal', 'double-blind', 'penicillin', 'schizophrenia', 'l-dopa', 'blunted_affect', 'anxiety', 'shock', 'psychotherapy', 'blood_pressure', 'heart_rate', 'propranolol', 'blood_ph', 'hypotension', 'hypertrophy', 'cardiac_arrest', 'manganese', 'hypoxia', 'pyelonephritis', 'alkalosis', 'respiratory_acidosis', 'ischaemia', 'body_temperature', 'enzyme_activity', 'tension', 'myocardial_ischaemia', 'sedation', 'diazepam', 'agitation', 'rash', 'energy', 'fibrin', 'intraocular_pressure', 'starvation', 'hypoprothrombinaemia', 'poisoning', 'resuscitation', 'carbon_dioxide', 'hyperventilation', 'dopamine', 'timolol', 'essential_hypertension', 'bradycardia', 'respiratory_distress', 'potassium', 'depression', 'lipase', 'urine_flow', 'fistula', 'pancreatic_fistula', 'withdrawal_syndrome', 'delivery', 'sinusitis', 'chest_x-ray', 'blood_glucose', 'glucose_tolerance', 'haemorrhage', 'measles', 'ventricular_tachycardia', 'bundle_branch_block', 'nortriptyline', 'electric_shock', 'arrhythmia', 'bronchospasm', 'pain', 'anileridine', 'angina_pectoris', 'cardiac_failure', 'stool_ph', 'medium', 'ammonium', 'cortisol', 'polypeptide', 'haemoglobin', 'platelet_aggregation', 'sluggishness', 'nausea', 'vomiting', 'amnesia', 'hyperthyroidism', 'meningitis', 'neuroblastoma', 'eosinophil_count', 'sotalol', 'lipids', 'calcium', 'ototoxicity', 'glomerular_filtration_rate', 'fasting', 'hypersensitivity', 'cimetidine', 'infarction', 'myocardial_infarction', 'anoxia', 'concomitant', 'coronary_artery_disease', 'discomfort', 'thyroxine', 'metoprolol', 'acute_myocardial_infarction', 'chest_pain', 'nephrectomy', 'massage', 'hyperthermia', 'oxygen_consumption', 'acne', 'cholera', 'endotoxic_shock', 'cholesterol', 'gamma-glutamyltransferase', 'nadolol', 'ventricular_fibrillation', 'infertility', 'polycystic_ovaries', 'progesterone', 'pulmonary_arterial_pressure', 'adhesion', 'hypothyroidism', 'vitamin_d', 'fluid_intake', 'encephalopathy', 'hepatic_encephalopathy', 'status_epilepticus', 'exercise_tolerance', 'syncope', 'renal_tubular_acidosis', 'po2', 'aspiration', 'biopsy', 'chronic_gastritis', 'gastritis', 'oestradiol', 'dehydroepiandrosterone', 'acebutolol', 'grip_strength', 'atrioventricular_block', 'electrocardiogram', 'human_chorionic_gonadotropin', 'ammonia', 'pregnenolone', 'plasma_cells', 'hyperparathyroidism', 'asthma', 'rhinitis', 'cardiac_index', 'gastric_fistula', 'metabolic_alkalosis', 'myocardial_depression', 'cardiogenic_shock', 'accident', 'cyanosis', 'intracranial_pressure', 'irritability', 'neurosurgery', 'ampicillin', 'arthritis', 'thyroglobulin', 'megacolon', 'obstruction', 'dysponesis', 'epilepsy', 'phagocytosis', 'dental_caries', 'respiratory_depression', 'bronchoscopy', 'vasoconstriction', 'cardiac_hypertrophy', 'hypocapnia', 'duodenal_ulcer', 'autopsy', 'orthostatic_hypotension', 'apnoea', 'amitriptyline', 'immunoglobulins', 'nasal', 'discharge', 'sinus_rhythm', 'loss_of_consciousness', 'cardiac_perforation', 'perforation', 'macrophages', 'ac', 'pyruvate_kinase', 'enzyme_level', 'practolol', 'pindolol', 'methyldopa', 'peritoneal_adhesions', 'duchenne_muscular_dystrophy', 'imipramine', 'muscle_necrosis', 'diarrhoea', 'tremor', 'crystalluria', 'tachyphylaxis', 'coma', 'pertussis', 'ipecac', 'antazoline', 'diuretic_therapy', 'condition', 'enzyme_inhibition', 'flunitrazepam', 'psychomotor_skills', 'hydrochlorothiazide', 'disodium', 'blood_bicarbonate', 'lithium', 'b ...

# %%
dataset.count_relation_combinations()
# Out:
# The most common relation combinations are:
#       1737 ('decreased', 'increased')
#        102 ('caused', 'decreased', 'increased')
#         51 ('caused', 'increased')
#         48 ('discoloured', 'increased')
#         39 ('caused', 'decreased')
#         30 ('prolonged', 'shortened')
#         30 ('decreased', 'shortened')
#         29 ('caused', 'infected')
#         26 ('changed', 'decreased', 'shortened')
#         15 ('changed', 'decreased', 'increased')
#         15 ('caused', 'ruptured')
#         12 ('changed', 'decreased')
#          9 ('changed', 'decreased', 'delayed', 'shortened')
#          8 ('changed', 'decreased', 'increased', 'shortened')
#          7 ('changed', 'decreased', 'delayed', 'increased', 'shortened')
#          7 ('acquired', 'caused')
#          5 ('changed', 'decreased', 'delayed', 'increased', 'prolonged', 'shortened')
#          3 ('decreased', 'delayed', 'shortened')
#          3 ('decreased', 'delayed')
#          2 ('decreased', 'increased', 'shortened')
#          2 ('changed', 'decreased', 'prolonged', 'shortened')
#          2 ('changed', 'decreased', 'delayed', 'prolonged', 'shortened')
#          1 ('delayed', 'shortened')
#          1 ('decreased', 'prolonged', 'shortened')
#          1 ('decreased', 'prolonged')
#          1 ('decreased', 'increased', 'prolonged', 'shortened')
#          1 ('decreased', 'increased', 'prolonged')
#          1 ('decreased', 'delayed', 'prolonged', 'shortened')
#          1 ('changed', 'shortened')
#          1 ('changed', 'decreased', 'increased', 'prolonged', 'shortened')
#          1 ('changed', 'decreased', 'delayed')

# %% [markdown]
# ### Featurizers
#
# Featurizers are functions which define the feature representation for our model. The primary input to a featurizer will be the `KBTriple` for which we are generating features. But since our features will be derived from corpus examples containing the entities of the `KBTriple`, we must also pass in a reference to a `Corpus`. And in order to make it easy to combine different featurizers, we'll also pass in a feature counter to hold the results.
#
# Here's an implementation for a very simple bag-of-words featurizer. It finds all the corpus examples containing the two entities in the `KBTriple`, breaks the phrase appearing between the two entity mentions into words, and counts the words. Note that it makes no distinction between "forward" and "reverse" examples.

# %%
def simple_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        for word in ex.middle.split(' '):
            feature_counter[word] += 1
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        for word in ex.middle.split(' '):
            feature_counter[word] += 1
    return feature_counter

def count_words(sent_part: str, feature_counter: Counter):
    for word in sent_part.split(" "):
        feature_counter[word] += 1

def middle_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        count_words(ex.middle, feature_counter)
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        count_words(ex.middle, feature_counter)
    return feature_counter

def start_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        count_words(ex.left, feature_counter)
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        count_words(ex.left, feature_counter)
    return feature_counter

def end_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        count_words(ex.right, feature_counter)
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        count_words(ex.right, feature_counter)
    return feature_counter

# %%
kbt = kb.kb_triples[5]

kbt
# Out:
# KBTriple(rel='acquired', sbj='metformin', obj='lipodystrophy')

# %%
corpus.get_examples_for_entities(kbt.sbj, kbt.obj)
# Out:
# []

# %%
print(len(corpus.examples_by_entities))
# Out:
# 4454

# %%
print(corpus.examples_by_entities.keys())
# Out:
# dict_keys(['weight', 'growth', 'dependence', 'fluoride', 'cardiac', 'cardiac_output', 'anaesthesia', 'fall', 'stress', 'adrenalectomy', 'gastric_ulcer', 'ulcer', 'sodium', 'acidosis', 'metabolic_acidosis', 'extracorporeal_circulation', 'investigation', 'influenza', 'hypertension', 'minoxidil', 'fluid_retention', 'death', 'infection', 'infusion', 'pco2', 'epinephrine', 'glucocorticoids', 'mass', 'parathyroidectomy', 'surgery', 'lorazepam', 'dissociation', 'vasospasm', 'tachycardia', 'hypothermia', 'renin', 'injection', 'histology', 'necrosis', 'dialysis', 'haemodialysis', 'laparotomy', 'intranasal', 'double-blind', 'penicillin', 'schizophrenia', 'l-dopa', 'blunted_affect', 'anxiety', 'shock', 'psychotherapy', 'blood_pressure', 'heart_rate', 'propranolol', 'blood_ph', 'hypotension', 'hypertrophy', 'cardiac_arrest', 'manganese', 'hypoxia', 'pyelonephritis', 'alkalosis', 'respiratory_acidosis', 'ischaemia', 'body_temperature', 'enzyme_activity', 'tension', 'myocardial_ischaemia', 'sedation', 'diazepam', 'agitation', 'rash', 'energy', 'fibrin', 'intraocular_pressure', 'starvation', 'hypoprothrombinaemia', 'poisoning', 'resuscitation', 'carbon_dioxide', 'hyperventilation', 'dopamine', 'timolol', 'essential_hypertension', 'bradycardia', 'respiratory_distress', 'potassium', 'depression', 'lipase', 'urine_flow', 'fistula', 'pancreatic_fistula', 'withdrawal_syndrome', 'delivery', 'sinusitis', 'chest_x-ray', 'blood_glucose', 'glucose_tolerance', 'haemorrhage', 'measles', 'ventricular_tachycardia', 'bundle_branch_block', 'nortriptyline', 'electric_shock', 'arrhythmia', 'bronchospasm', 'pain', 'anileridine', 'angina_pectoris', 'cardiac_failure', 'stool_ph', 'medium', 'ammonium', 'cortisol', 'polypeptide', 'haemoglobin', 'platelet_aggregation', 'sluggishness', 'nausea', 'vomiting', 'amnesia', 'hyperthyroidism', 'meningitis', 'neuroblastoma', 'eosinophil_count', 'sotalol', 'lipids', 'calcium', 'ototoxicity', 'glomerular_filtration_rate', 'fasting', 'hypersensitivity', 'cimetidine', 'infarction', 'myocardial_infarction', 'anoxia', 'concomitant', 'coronary_artery_disease', 'discomfort', 'thyroxine', 'metoprolol', 'acute_myocardial_infarction', 'chest_pain', 'nephrectomy', 'massage', 'hyperthermia', 'oxygen_consumption', 'acne', 'cholera', 'endotoxic_shock', 'cholesterol', 'gamma-glutamyltransferase', 'nadolol', 'ventricular_fibrillation', 'infertility', 'polycystic_ovaries', 'progesterone', 'pulmonary_arterial_pressure', 'adhesion', 'hypothyroidism', 'vitamin_d', 'fluid_intake', 'encephalopathy', 'hepatic_encephalopathy', 'status_epilepticus', 'exercise_tolerance', 'syncope', 'renal_tubular_acidosis', 'po2', 'aspiration', 'biopsy', 'chronic_gastritis', 'gastritis', 'oestradiol', 'dehydroepiandrosterone', 'acebutolol', 'grip_strength', 'atrioventricular_block', 'electrocardiogram', 'human_chorionic_gonadotropin', 'ammonia', 'pregnenolone', 'plasma_cells', 'hyperparathyroidism', 'asthma', 'rhinitis', 'cardiac_index', 'gastric_fistula', 'metabolic_alkalosis', 'myocardial_depression', 'cardiogenic_shock', 'accident', 'cyanosis', 'intracranial_pressure', 'irritability', 'neurosurgery', 'ampicillin', 'arthritis', 'thyroglobulin', 'megacolon', 'obstruction', 'dysponesis', 'epilepsy', 'phagocytosis', 'dental_caries', 'respiratory_depression', 'bronchoscopy', 'vasoconstriction', 'cardiac_hypertrophy', 'hypocapnia', 'duodenal_ulcer', 'autopsy', 'orthostatic_hypotension', 'apnoea', 'amitriptyline', 'immunoglobulins', 'nasal', 'discharge', 'sinus_rhythm', 'loss_of_consciousness', 'cardiac_perforation', 'perforation', 'macrophages', 'ac', 'pyruvate_kinase', 'enzyme_level', 'practolol', 'pindolol', 'methyldopa', 'peritoneal_adhesions', 'duchenne_muscular_dystrophy', 'imipramine', 'muscle_necrosis', 'diarrhoea', 'tremor', 'crystalluria', 'tachyphylaxis', 'coma', 'pertussis', 'ipecac', 'antazoline', 'diuretic_therapy', 'condition', 'enzyme_inhibition', 'flunitrazepam', 'psychomotor_skills', 'hydrochlorothiazide', 'disodium', 'blood_bicarbonate', 'lithium', 'b ...

# %%
print(len(corpus.examples_by_entities["sodium"]))
# Out:
# 617

# %%
simple_bag_of_words_featurizer(kb.kb_triples[0], corpus, Counter())
# Out:
# Counter({'': 61,
#          'treatment': 4,
#          'by': 5,
#          'daily': 2,
#          'injections': 2,
#          'did': 3,
#          'not': 3,
#          'suppress': 2,
#          'levels': 3,
#          'of': 12,
#          'growth': 2,
#          'hormone,': 1,
#          'prolactin,': 1,
#          'or': 2,
#          'epidermal': 1,
#          'in': 5,
#          'this': 1,
#          'tumor': 2,
#          'model': 1,
#          'had': 1,
#          'no': 2,
#          'direct': 1,
#          'inhibitory': 2,
#          'effect': 2,
#          'and': 9,
#          'cause': 1,
#          'an': 2,
#          'endocrine': 1,
#          'inhibition': 1,
#          'mammary': 1,
#          'represents': 1,
#          'a': 3,
#          'significant': 2,
#          'advance': 1,
#          'the': 5,
#          'hormone-releasing': 2,
#          'hormone': 4,
#          '(GHRH)': 2,
#          'syndrome,': 2,
#          'Sandostatin': 1,
#          'is': 1,
#          'unequivocally': 1,
#          'effective': 1,
#          'and,': 1,
#          'ectopic': 1,
#          'corticotropin': 1,
#          'syndrome': 1,
#          'selected': 1,
#          'cases': 1,
#          'can': 1,
#          'be': 1,
#          'treated': 1,
#          'successfully': 1,
#          'with': 3,
#          '1/3': 1,
#          'SSR': 1,
#          'positive': 2,
#          'SCLC': 1,
#          'cell': 1,
#          'lines': 1,
#          'was': 3,
#          'significantly': 1,
#          'inhibited': 2,
#          'long-acting': 3,
#          'somatostatin': 5,
#          'analogue': 4,
#          'octreotide': 1,
#          '(SMS': 1,
#          '201-995,': 1,
#          'effects': 1,
#          'estradiol': 1,
#          '(E2)': 1,
#          'receptor': 1,
#          'antagonist,': 1,
#          'tamoxifen,': 1,
#          'somatostatin,': 1,
#          'SKI': 2,
#          'tumors,': 1,
#          'since': 1,
#          'for': 1,
#          'binding': 1,
#          'sites;': 1,
#          'it': 1,
#          'appears': 1,
#          'less': 2,
#          'likely': 1,
#          'that': 2,
#          'secretion': 1,
#          'SMS': 1,
#          '201-995': 1,
#          '(': 1,
#          'factor': 1,
#          'type': 1,
#          '1': 1,
#          '(IGF-1),': 1,
#          'numerous': 1,
#          'gastrointestinal': 1,
#          'peptides,': 1,
#          'addition': 1,
#          'its': 1,
#          'long-lasting': 1,
#          'analogue,': 1,
#          'at': 1,
#          'sharply': 1,
#          'defined': 1,
#          'amount': 1,
#          'somatomedin-C': 1,
#          'untreated': 1,
#          'acromegaly,': 1,
#          'after': 2,
#          'surgery': 1,
#          'radiotherapy': 1,
#          'during': 2,
#          'medical': 1,
#          'therapy': 1,
#          'transplanted': 1,
#          'dunning': 1,
#          'rat': 1,
#          'prostate': 1,
#          'tumors': 1,
#          'markedly': 1,
#          'than': 1,
#          'intact': 1,
#          'rats,': 1,
#          'rate': 1,
#          'demonstrated': 1,
#          'hormone-': 1,
#          'prolactin-producing': 1,
#          'adenoma': 1})

# %% [markdown]
# ### Experiments

# %%
train_result = rel_ext.train_models(
    splits, 
    featurizers=[start_bag_of_words_featurizer, middle_bag_of_words_featurizer, end_bag_of_words_featurizer],
    sampling_rate=0.5
)
# Out:
# #####################
# relation: accelerated
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='accelerated', sbj='sandostatin', obj='growth')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: acquired
# number positive examples: 16
# relation examples:
#  [KBTriple(rel='acquired', sbj='ranitidine', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='metformin', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='lamivudine', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='nasal', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='lamivudine', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='ritonavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='raltegravir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='cholesterol', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='stavudine', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='darunavir', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: aggravated
# number positive examples: 300
# relation examples:
#  [KBTriple(rel='aggravated', sbj='ibuprofen', obj='condition'), KBTriple(rel='aggravated', sbj='psyllium', obj='condition'), KBTriple(rel='aggravated', sbj='procyclidine', obj='condition'), KBTriple(rel='aggravated', sbj='ozogamicin', obj='condition'), KBTriple(rel='aggravated', sbj='caspofungin', obj='condition'), KBTriple(rel='aggravated', sbj='lanreotide', obj='condition'), KBTriple(rel='aggravated', sbj='oxytocin', obj='condition'), KBTriple(rel='aggravated', sbj='argatroban', obj='condition'), KBTriple(rel='aggravated', sbj='ritonavir', obj='condition'), KBTriple(rel='aggravated', sbj='metoprolol', obj='condition')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: altered
# number positive examples: 84
# relation examples:
#  [KBTriple(rel='altered', sbj='pembrolizumab', obj='mood'), KBTriple(rel='altered', sbj='ibuprofen', obj='mood'), KBTriple(rel='altered', sbj='bromazepam', obj='mood'), KBTriple(rel='altered', sbj='dapsone', obj='mood'), KBTriple(rel='altered', sbj='metoprolol', obj='mood'), KBTriple(rel='altered', sbj='amitriptyline', obj='saliva'), KBTriple(rel='altered', sbj='ranitidine', obj='saliva'), KBTriple(rel='altered', sbj='oxazepam', obj='saliva'), KBTriple(rel='altered', sbj='quetiapine', obj='mood'), KBTriple(rel='altered', sbj='venlafaxine', obj='mood')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: caused
# number positive examples: 29719
# relation examples:
#  [KBTriple(rel='caused', sbj='tolvaptan', obj='abdominal_distension'), KBTriple(rel='caused', sbj='furosemide', obj='pyelonephritis'), KBTriple(rel='caused', sbj='emtricitabine', obj='prostate_cancer'), KBTriple(rel='caused', sbj='calcium', obj='sinus_rhythm'), KBTriple(rel='caused', sbj='brodalumab', obj='infection'), KBTriple(rel='caused', sbj='cisplatin', obj='febrile_neutropenia'), KBTriple(rel='caused', sbj='immunoglobulin', obj='influenza'), KBTriple(rel='caused', sbj='tipranavir', obj='haemorrhage'), KBTriple(rel='caused', sbj='cytarabine', obj='cerebellar_syndrome'), KBTriple(rel='caused', sbj='doxycycline', obj='drug-induced_liver_injury')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: changed
# number positive examples: 62
# relation examples:
#  [KBTriple(rel='changed', sbj='levetiracetam', obj='therapeutic_response'), KBTriple(rel='changed', sbj='verapamil', obj='therapeutic_response'), KBTriple(rel='changed', sbj='terazosin', obj='therapeutic_response'), KBTriple(rel='changed', sbj='paroxetine', obj='therapeutic_response'), KBTriple(rel='changed', sbj='atomoxetine', obj='therapeutic_response'), KBTriple(rel='changed', sbj='atorvastatin', obj='therapeutic_response'), KBTriple(rel='changed', sbj='carbidopa', obj='therapeutic_response'), KBTriple(rel='changed', sbj='magnesium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='haloperidol', obj='therapeutic_response'), KBTriple(rel='changed', sbj='penicillin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: decreased
# number positive examples: 2442
# relation examples:
#  [KBTriple(rel='decreased', sbj='radium', obj='weight'), KBTriple(rel='decreased', sbj='nasal', obj='blood_pressure'), KBTriple(rel='decreased', sbj='telmisartan', obj='glomerular_filtration_rate'), KBTriple(rel='decreased', sbj='tamoxifen', obj='quality_of_life'), KBTriple(rel='decreased', sbj='calcium', obj='blood_bilirubin'), KBTriple(rel='decreased', sbj='metoprolol', obj='exercise_tolerance'), KBTriple(rel='decreased', sbj='calcium', obj='prostatic_specific_antigen'), KBTriple(rel='decreased', sbj='ciprofloxacin', obj='oxygen_consumption'), KBTriple(rel='decreased', sbj='disodium', obj='mobility'), KBTriple(rel='decreased', sbj='magnesium', obj='grip_strength')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: delayed
# number positive examples: 32
# relation examples:
#  [KBTriple(rel='delayed', sbj='secukinumab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='adalimumab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='venlafaxine', obj='ejaculation'), KBTriple(rel='delayed', sbj='cholesterol', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sildenafil', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='calcium', obj='menstruation'), KBTriple(rel='delayed', sbj='calcium', obj='callus_formation'), KBTriple(rel='delayed', sbj='diclofenac', obj='menstruation'), KBTriple(rel='delayed', sbj='rituximab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='lorazepam', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: discoloured
# number positive examples: 103
# relation examples:
#  [KBTriple(rel='discoloured', sbj='valsartan', obj='faeces'), KBTriple(rel='discoloured', sbj='nasal', obj='faeces'), KBTriple(rel='discoloured', sbj='immunoglobulin', obj='sputum'), KBTriple(rel='discoloured', sbj='penicillin', obj='sputum'), KBTriple(rel='discoloured', sbj='prednisolone', obj='sputum'), KBTriple(rel='discoloured', sbj='nac', obj='sputum'), KBTriple(rel='discoloured', sbj='cholesterol', obj='faeces'), KBTriple(rel='discoloured', sbj='sildenafil', obj='faeces'), KBTriple(rel='discoloured', sbj='nasal', obj='sputum'), KBTriple(rel='discoloured', sbj='cholesterol', obj='sputum')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: impaired
# number positive examples: 58
# relation examples:
#  [KBTriple(rel='impaired', sbj='penicillin', obj='judgement'), KBTriple(rel='impaired', sbj='risperidone', obj='judgement'), KBTriple(rel='impaired', sbj='ciprofloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='celecoxib', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='haloperidol', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='exemestane', obj='judgement'), KBTriple(rel='impaired', sbj='amitriptyline', obj='psychomotor_skills'), KBTriple(rel='impaired', sbj='metoprolol', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='quetiapine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='ramipril', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: improved
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='improved', sbj='cocaine', obj='pre-existing_condition')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: increased
# number positive examples: 2478
# relation examples:
#  [KBTriple(rel='increased', sbj='dapsone', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='quinapril', obj='heart_rate'), KBTriple(rel='increased', sbj='infliximab', obj='alanine_aminotransferase'), KBTriple(rel='increased', sbj='nortriptyline', obj='intraocular_pressure'), KBTriple(rel='increased', sbj='verapamil', obj='intraocular_pressure'), KBTriple(rel='increased', sbj='carboplatin', obj='blood_pressure'), KBTriple(rel='increased', sbj='magnesium', obj='fat_tissue'), KBTriple(rel='increased', sbj='metoprolol', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='nizatidine', obj='heart_rate'), KBTriple(rel='increased', sbj='sal', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: infected
# number positive examples: 22
# relation examples:
#  [KBTriple(rel='infected', sbj='metoprolol', obj='dermatitis'), KBTriple(rel='infected', sbj='calcium', obj='eczema'), KBTriple(rel='infected', sbj='ciprofloxacin', obj='blister'), KBTriple(rel='infected', sbj='ramipril', obj='dermatitis'), KBTriple(rel='infected', sbj='esomeprazole', obj='dermatitis'), KBTriple(rel='infected', sbj='calcium', obj='dermatitis'), KBTriple(rel='infected', sbj='metoprolol', obj='blister'), KBTriple(rel='infected', sbj='infliximab', obj='blister'), KBTriple(rel='infected', sbj='atorvastatin', obj='dermatitis'), KBTriple(rel='infected', sbj='furosemide', obj='eczema')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='ranitidine', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: prolonged
# number positive examples: 71
# relation examples:
#  [KBTriple(rel='prolonged', sbj='ibuprofen', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='quetiapine', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='phenylbutazone', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='furosemide', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='atenolol', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='levofloxacin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='furosemide', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='lidocaine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='metformin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='fluconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: reduced
# number positive examples: 47
# relation examples:
#  [KBTriple(rel='reduced', sbj='acetonide', obj='visual_acuity'), KBTriple(rel='reduced', sbj='ibuprofen', obj='visual_acuity'), KBTriple(rel='reduced', sbj='furosemide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='bevacizumab', obj='visual_acuity'), KBTriple(rel='reduced', sbj='verteporfin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='brinzolamide', obj='visual_acuity'), KBTriple(rel='reduced', sbj='lorazepam', obj='visual_acuity'), KBTriple(rel='reduced', sbj='azithromycin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='exemestane', obj='visual_acuity'), KBTriple(rel='reduced', sbj='fingolimod', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: ruptured
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='ruptured', sbj='calcium', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='enalapril', obj='aneurysm'), KBTriple(rel='ruptured', sbj='atorvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='furosemide', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='tolvaptan', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='calcium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='lorazepam', obj='aneurysm'), KBTriple(rel='ruptured', sbj='letrozole', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='calcium', obj='ovarian_cyst')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: shortened
# number positive examples: 102
# relation examples:
#  [KBTriple(rel='shortened', sbj='pioglitazone', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='aripiprazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rizatriptan', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='vancomycin', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='diltiazem', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='lisinopril', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='calcium', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='aluminium', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='alemtuzumab', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='bupivacaine', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# /home/gerhard/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %% [markdown]
# Next comes `predict()`. This function takes as arguments a dictionary of data splits, the outputs of `train_models()`, and the name of the split for which to make predictions. It returns two parallel dictionaries: one holding the predictions (grouped by relation), the other holding the true labels (again, grouped by prediction).

# %%
predictions, true_labels, predict_setup = rel_ext.predict(
    splits, train_result, split_name='dev',
    sampling_rate=0.5
)
# Out:
# #####################
# relation: acquired
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='acquired', sbj='indinavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='sodium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='efavirenz', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='potassium', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='abacavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='potassium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='abacavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='methylprednisolone', obj='spinal_fusion'), KBTriple(rel='acquired', sbj='zidovudine', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: aggravated
# number positive examples: 117
# relation examples:
#  [KBTriple(rel='aggravated', sbj='fluocinolone', obj='condition'), KBTriple(rel='aggravated', sbj='octreotide', obj='condition'), KBTriple(rel='aggravated', sbj='desmopressin', obj='condition'), KBTriple(rel='aggravated', sbj='amlodipine', obj='condition'), KBTriple(rel='aggravated', sbj='acetanilide', obj='condition'), KBTriple(rel='aggravated', sbj='gentamicin', obj='condition'), KBTriple(rel='aggravated', sbj='valacyclovir', obj='condition'), KBTriple(rel='aggravated', sbj='technetium', obj='condition'), KBTriple(rel='aggravated', sbj='phenytoin', obj='condition'), KBTriple(rel='aggravated', sbj='labetalol', obj='condition')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: altered
# number positive examples: 36
# relation examples:
#  [KBTriple(rel='altered', sbj='methylprednisolone', obj='mood'), KBTriple(rel='altered', sbj='nifedipine', obj='mood'), KBTriple(rel='altered', sbj='losartan', obj='mood'), KBTriple(rel='altered', sbj='prozac', obj='mood'), KBTriple(rel='altered', sbj='levonorgestrel', obj='mood'), KBTriple(rel='altered', sbj='potassium', obj='mood'), KBTriple(rel='altered', sbj='clonazepam', obj='saliva'), KBTriple(rel='altered', sbj='omeprazole', obj='saliva'), KBTriple(rel='altered', sbj='propranolol', obj='mood'), KBTriple(rel='altered', sbj='acyclovir', obj='mood')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: caused
# number positive examples: 13953
# relation examples:
#  [KBTriple(rel='caused', sbj='methylprednisolone', obj='nausea'), KBTriple(rel='caused', sbj='losartan', obj='sudden_cardiac_death'), KBTriple(rel='caused', sbj='liraglutide', obj='constipation'), KBTriple(rel='caused', sbj='gentamicin', obj='infection'), KBTriple(rel='caused', sbj='technetium', obj='hepatomegaly'), KBTriple(rel='caused', sbj='fenofibrate', obj='colitis'), KBTriple(rel='caused', sbj='losartan', obj='necrosis'), KBTriple(rel='caused', sbj='denosumab', obj='osteosclerosis'), KBTriple(rel='caused', sbj='sodium', obj='pericarditis'), KBTriple(rel='caused', sbj='sodium', obj='starvation')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: changed
# number positive examples: 28
# relation examples:
#  [KBTriple(rel='changed', sbj='hydrochlorothiazide', obj='drug_level'), KBTriple(rel='changed', sbj='domperidone', obj='therapeutic_response'), KBTriple(rel='changed', sbj='clonazepam', obj='drug_level'), KBTriple(rel='changed', sbj='acyclovir', obj='therapeutic_response'), KBTriple(rel='changed', sbj='phenytoin', obj='drug_level'), KBTriple(rel='changed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='changed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='changed', sbj='imatinib', obj='therapeutic_response'), KBTriple(rel='changed', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='sodium', obj='drug_level')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: decreased
# number positive examples: 1143
# relation examples:
#  [KBTriple(rel='decreased', sbj='propranolol', obj='oxygen_saturation'), KBTriple(rel='decreased', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='decreased', sbj='sodium', obj='drug_level'), KBTriple(rel='decreased', sbj='irinotecan', obj='platelet_count'), KBTriple(rel='decreased', sbj='omeprazole', obj='serum_ferritin'), KBTriple(rel='decreased', sbj='potassium', obj='blood_phosphorus'), KBTriple(rel='decreased', sbj='potassium', obj='weight'), KBTriple(rel='decreased', sbj='domperidone', obj='body_temperature'), KBTriple(rel='decreased', sbj='potassium', obj='prothrombin_level'), KBTriple(rel='decreased', sbj='potassium', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: delayed
# number positive examples: 14
# relation examples:
#  [KBTriple(rel='delayed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='hydrochlorothiazide', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sodium', obj='menstruation'), KBTriple(rel='delayed', sbj='metronidazole', obj='menstruation'), KBTriple(rel='delayed', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='levonorgestrel', obj='menstruation'), KBTriple(rel='delayed', sbj='potassium', obj='menstruation'), KBTriple(rel='delayed', sbj='methylprednisolone', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: discoloured
# number positive examples: 45
# relation examples:
#  [KBTriple(rel='discoloured', sbj='clarithromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='bicalutamide', obj='faeces'), KBTriple(rel='discoloured', sbj='mepolizumab', obj='sputum'), KBTriple(rel='discoloured', sbj='omeprazole', obj='faeces'), KBTriple(rel='discoloured', sbj='abatacept', obj='sputum'), KBTriple(rel='discoloured', sbj='clarithromycin', obj='sputum'), KBTriple(rel='discoloured', sbj='erythromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='dopamine', obj='sputum'), KBTriple(rel='discoloured', sbj='piperacillin', obj='sputum'), KBTriple(rel='discoloured', sbj='methylprednisolone', obj='sputum')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: impaired
# number positive examples: 19
# relation examples:
#  [KBTriple(rel='impaired', sbj='clarithromycin', obj='judgement'), KBTriple(rel='impaired', sbj='hydrochlorothiazide', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='moxifloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='methylprednisolone', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='nifedipine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='levonorgestrel', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='potassium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='judgement'), KBTriple(rel='impaired', sbj='methotrexate', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: increased
# number positive examples: 1194
# relation examples:
#  [KBTriple(rel='increased', sbj='prozac', obj='libido'), KBTriple(rel='increased', sbj='epirubicin', obj='heart_rate'), KBTriple(rel='increased', sbj='hydrochlorothiazide', obj='haemoglobin'), KBTriple(rel='increased', sbj='clonazepam', obj='neutrophil_count'), KBTriple(rel='increased', sbj='liraglutide', obj='lipase'), KBTriple(rel='increased', sbj='omeprazole', obj='ammonia'), KBTriple(rel='increased', sbj='propranolol', obj='eosinophil_count'), KBTriple(rel='increased', sbj='candesartan', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='methotrexate', obj='transaminases'), KBTriple(rel='increased', sbj='desmopressin', obj='weight')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: infected
# number positive examples: 6
# relation examples:
#  [KBTriple(rel='infected', sbj='methylprednisolone', obj='dermatitis'), KBTriple(rel='infected', sbj='hydrochlorothiazide', obj='dermatitis'), KBTriple(rel='infected', sbj='methotrexate', obj='dermatitis'), KBTriple(rel='infected', sbj='amlodipine', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='blister')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='clonazepam', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: prolonged
# number positive examples: 39
# relation examples:
#  [KBTriple(rel='prolonged', sbj='gentamicin', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='heparin', obj='immobilisation'), KBTriple(rel='prolonged', sbj='dopamine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='piperacillin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='sodium', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='gentamicin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='heparin', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='potassium', obj='bleeding_time'), KBTriple(rel='prolonged', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='ketoconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: reduced
# number positive examples: 25
# relation examples:
#  [KBTriple(rel='reduced', sbj='propranolol', obj='visual_acuity'), KBTriple(rel='reduced', sbj='methotrexate', obj='visual_acuity'), KBTriple(rel='reduced', sbj='phenytoin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='hydrochlorothiazide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='sodium', obj='fluid_intake'), KBTriple(rel='reduced', sbj='propranolol', obj='fluid_intake'), KBTriple(rel='reduced', sbj='moxifloxacin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='raloxifene', obj='visual_acuity'), KBTriple(rel='reduced', sbj='sodium', obj='visual_acuity'), KBTriple(rel='reduced', sbj='latanoprost', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: ruptured
# number positive examples: 8
# relation examples:
#  [KBTriple(rel='ruptured', sbj='methotrexate', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='sodium', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='methylprednisolone', obj='aneurysm'), KBTriple(rel='ruptured', sbj='methotrexate', obj='aneurysm'), KBTriple(rel='ruptured', sbj='potassium', obj='liver_carcinoma'), KBTriple(rel='ruptured', sbj='rosuvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='sodium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='heparin', obj='aneurysm')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: shortened
# number positive examples: 41
# relation examples:
#  [KBTriple(rel='shortened', sbj='methylprednisolone', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='sodium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sirolimus', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='metronidazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='octreotide', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='potassium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sodium', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rosuvastatin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]

# %% [markdown]
# Now `evaluate_predictions()`. This function takes as arguments the parallel dictionaries of predictions and true labels produced by `predict()`. It prints summary statistics for each relation, including precision, recall, and F<sub>0.5</sub>-score, and it returns the macro-averaged F<sub>0.5</sub>-score.

# %%
rel_ext.evaluate_predictions(predictions, true_labels)
# Out:
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      0.778      0.875          9      12078
# aggravated                0.000      0.000      0.000        117      12186
# altered                   0.500      0.056      0.100         36      12105
# caused                    0.471      0.096      0.159      13953      26022
# changed                   0.565      0.464      0.510         28      12097
# decreased                 0.636      0.073      0.132       1143      13212
# delayed                   1.000      0.429      0.600         14      12083
# discoloured               0.118      0.044      0.065         45      12114
# impaired                  0.000      0.000      0.000         19      12088
# increased                 0.649      0.042      0.079       1194      13263
# infected                  0.000      0.000      0.000          6      12075
# lowered                   0.000      0.000      0.000          1      12070
# prolonged                 0.792      0.487      0.603         39      12108
# reduced                   1.000      0.640      0.780         25      12094
# ruptured                  0.000      0.000      0.000          8      12077
# shortened                 0.719      0.561      0.630         41      12110
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.466      0.229      0.283      16678     209782
# /home/gerhard/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.2832997106706182

# %% [markdown]
# Finally, we introduce `rel_ext.experiment()`, which basically chains together `rel_ext.train_models()`, `rel_ext.predict()`, and `rel_ext.evaluate_predictions()`. For convenience, this function returns the output of `rel_ext.train_models()` as its result.

# %%
_ = rel_ext.experiment(
    splits,
    featurizers=[
        start_bag_of_words_featurizer, middle_bag_of_words_featurizer, 
        end_bag_of_words_featurizer],
    train_sampling_rate=0.5,
    test_sampling_rate=0.5
)  # [simple_bag_of_words_featurizer])
# Out:
# =========== Train Models ===========
# #####################
# relation: accelerated
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='accelerated', sbj='sandostatin', obj='growth')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: acquired
# number positive examples: 16
# relation examples:
#  [KBTriple(rel='acquired', sbj='ranitidine', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='metformin', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='lamivudine', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='nasal', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='lamivudine', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='ritonavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='raltegravir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='cholesterol', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='stavudine', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='darunavir', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: aggravated
# number positive examples: 300
# relation examples:
#  [KBTriple(rel='aggravated', sbj='ibuprofen', obj='condition'), KBTriple(rel='aggravated', sbj='psyllium', obj='condition'), KBTriple(rel='aggravated', sbj='procyclidine', obj='condition'), KBTriple(rel='aggravated', sbj='ozogamicin', obj='condition'), KBTriple(rel='aggravated', sbj='caspofungin', obj='condition'), KBTriple(rel='aggravated', sbj='lanreotide', obj='condition'), KBTriple(rel='aggravated', sbj='oxytocin', obj='condition'), KBTriple(rel='aggravated', sbj='argatroban', obj='condition'), KBTriple(rel='aggravated', sbj='ritonavir', obj='condition'), KBTriple(rel='aggravated', sbj='metoprolol', obj='condition')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: altered
# number positive examples: 84
# relation examples:
#  [KBTriple(rel='altered', sbj='pembrolizumab', obj='mood'), KBTriple(rel='altered', sbj='ibuprofen', obj='mood'), KBTriple(rel='altered', sbj='bromazepam', obj='mood'), KBTriple(rel='altered', sbj='dapsone', obj='mood'), KBTriple(rel='altered', sbj='metoprolol', obj='mood'), KBTriple(rel='altered', sbj='amitriptyline', obj='saliva'), KBTriple(rel='altered', sbj='ranitidine', obj='saliva'), KBTriple(rel='altered', sbj='oxazepam', obj='saliva'), KBTriple(rel='altered', sbj='quetiapine', obj='mood'), KBTriple(rel='altered', sbj='venlafaxine', obj='mood')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: caused
# number positive examples: 29719
# relation examples:
#  [KBTriple(rel='caused', sbj='tolvaptan', obj='abdominal_distension'), KBTriple(rel='caused', sbj='furosemide', obj='pyelonephritis'), KBTriple(rel='caused', sbj='emtricitabine', obj='prostate_cancer'), KBTriple(rel='caused', sbj='calcium', obj='sinus_rhythm'), KBTriple(rel='caused', sbj='brodalumab', obj='infection'), KBTriple(rel='caused', sbj='cisplatin', obj='febrile_neutropenia'), KBTriple(rel='caused', sbj='immunoglobulin', obj='influenza'), KBTriple(rel='caused', sbj='tipranavir', obj='haemorrhage'), KBTriple(rel='caused', sbj='cytarabine', obj='cerebellar_syndrome'), KBTriple(rel='caused', sbj='doxycycline', obj='drug-induced_liver_injury')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: changed
# number positive examples: 62
# relation examples:
#  [KBTriple(rel='changed', sbj='levetiracetam', obj='therapeutic_response'), KBTriple(rel='changed', sbj='verapamil', obj='therapeutic_response'), KBTriple(rel='changed', sbj='terazosin', obj='therapeutic_response'), KBTriple(rel='changed', sbj='paroxetine', obj='therapeutic_response'), KBTriple(rel='changed', sbj='atomoxetine', obj='therapeutic_response'), KBTriple(rel='changed', sbj='atorvastatin', obj='therapeutic_response'), KBTriple(rel='changed', sbj='carbidopa', obj='therapeutic_response'), KBTriple(rel='changed', sbj='magnesium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='haloperidol', obj='therapeutic_response'), KBTriple(rel='changed', sbj='penicillin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: decreased
# number positive examples: 2442
# relation examples:
#  [KBTriple(rel='decreased', sbj='radium', obj='weight'), KBTriple(rel='decreased', sbj='nasal', obj='blood_pressure'), KBTriple(rel='decreased', sbj='telmisartan', obj='glomerular_filtration_rate'), KBTriple(rel='decreased', sbj='tamoxifen', obj='quality_of_life'), KBTriple(rel='decreased', sbj='calcium', obj='blood_bilirubin'), KBTriple(rel='decreased', sbj='metoprolol', obj='exercise_tolerance'), KBTriple(rel='decreased', sbj='calcium', obj='prostatic_specific_antigen'), KBTriple(rel='decreased', sbj='ciprofloxacin', obj='oxygen_consumption'), KBTriple(rel='decreased', sbj='disodium', obj='mobility'), KBTriple(rel='decreased', sbj='magnesium', obj='grip_strength')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: delayed
# number positive examples: 32
# relation examples:
#  [KBTriple(rel='delayed', sbj='secukinumab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='adalimumab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='venlafaxine', obj='ejaculation'), KBTriple(rel='delayed', sbj='cholesterol', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sildenafil', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='calcium', obj='menstruation'), KBTriple(rel='delayed', sbj='calcium', obj='callus_formation'), KBTriple(rel='delayed', sbj='diclofenac', obj='menstruation'), KBTriple(rel='delayed', sbj='rituximab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='lorazepam', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: discoloured
# number positive examples: 103
# relation examples:
#  [KBTriple(rel='discoloured', sbj='valsartan', obj='faeces'), KBTriple(rel='discoloured', sbj='nasal', obj='faeces'), KBTriple(rel='discoloured', sbj='immunoglobulin', obj='sputum'), KBTriple(rel='discoloured', sbj='penicillin', obj='sputum'), KBTriple(rel='discoloured', sbj='prednisolone', obj='sputum'), KBTriple(rel='discoloured', sbj='nac', obj='sputum'), KBTriple(rel='discoloured', sbj='cholesterol', obj='faeces'), KBTriple(rel='discoloured', sbj='sildenafil', obj='faeces'), KBTriple(rel='discoloured', sbj='nasal', obj='sputum'), KBTriple(rel='discoloured', sbj='cholesterol', obj='sputum')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: impaired
# number positive examples: 58
# relation examples:
#  [KBTriple(rel='impaired', sbj='penicillin', obj='judgement'), KBTriple(rel='impaired', sbj='risperidone', obj='judgement'), KBTriple(rel='impaired', sbj='ciprofloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='celecoxib', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='haloperidol', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='exemestane', obj='judgement'), KBTriple(rel='impaired', sbj='amitriptyline', obj='psychomotor_skills'), KBTriple(rel='impaired', sbj='metoprolol', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='quetiapine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='ramipril', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: improved
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='improved', sbj='cocaine', obj='pre-existing_condition')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: increased
# number positive examples: 2478
# relation examples:
#  [KBTriple(rel='increased', sbj='dapsone', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='quinapril', obj='heart_rate'), KBTriple(rel='increased', sbj='infliximab', obj='alanine_aminotransferase'), KBTriple(rel='increased', sbj='nortriptyline', obj='intraocular_pressure'), KBTriple(rel='increased', sbj='verapamil', obj='intraocular_pressure'), KBTriple(rel='increased', sbj='carboplatin', obj='blood_pressure'), KBTriple(rel='increased', sbj='magnesium', obj='fat_tissue'), KBTriple(rel='increased', sbj='metoprolol', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='nizatidine', obj='heart_rate'), KBTriple(rel='increased', sbj='sal', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: infected
# number positive examples: 22
# relation examples:
#  [KBTriple(rel='infected', sbj='metoprolol', obj='dermatitis'), KBTriple(rel='infected', sbj='calcium', obj='eczema'), KBTriple(rel='infected', sbj='ciprofloxacin', obj='blister'), KBTriple(rel='infected', sbj='ramipril', obj='dermatitis'), KBTriple(rel='infected', sbj='esomeprazole', obj='dermatitis'), KBTriple(rel='infected', sbj='calcium', obj='dermatitis'), KBTriple(rel='infected', sbj='metoprolol', obj='blister'), KBTriple(rel='infected', sbj='infliximab', obj='blister'), KBTriple(rel='infected', sbj='atorvastatin', obj='dermatitis'), KBTriple(rel='infected', sbj='furosemide', obj='eczema')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='ranitidine', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: prolonged
# number positive examples: 71
# relation examples:
#  [KBTriple(rel='prolonged', sbj='ibuprofen', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='quetiapine', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='phenylbutazone', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='furosemide', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='atenolol', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='levofloxacin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='furosemide', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='lidocaine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='metformin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='fluconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: reduced
# number positive examples: 47
# relation examples:
#  [KBTriple(rel='reduced', sbj='acetonide', obj='visual_acuity'), KBTriple(rel='reduced', sbj='ibuprofen', obj='visual_acuity'), KBTriple(rel='reduced', sbj='furosemide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='bevacizumab', obj='visual_acuity'), KBTriple(rel='reduced', sbj='verteporfin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='brinzolamide', obj='visual_acuity'), KBTriple(rel='reduced', sbj='lorazepam', obj='visual_acuity'), KBTriple(rel='reduced', sbj='azithromycin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='exemestane', obj='visual_acuity'), KBTriple(rel='reduced', sbj='fingolimod', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: ruptured
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='ruptured', sbj='calcium', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='enalapril', obj='aneurysm'), KBTriple(rel='ruptured', sbj='atorvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='furosemide', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='tolvaptan', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='calcium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='lorazepam', obj='aneurysm'), KBTriple(rel='ruptured', sbj='letrozole', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='calcium', obj='ovarian_cyst')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: shortened
# number positive examples: 102
# relation examples:
#  [KBTriple(rel='shortened', sbj='pioglitazone', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='aripiprazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rizatriptan', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='vancomycin', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='diltiazem', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='lisinopril', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='calcium', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='aluminium', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='alemtuzumab', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='bupivacaine', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 39715
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# /home/gerhard/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ============= Predict =============
# #####################
# relation: acquired
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='acquired', sbj='indinavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='sodium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='efavirenz', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='potassium', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='abacavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='potassium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='abacavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='methylprednisolone', obj='spinal_fusion'), KBTriple(rel='acquired', sbj='zidovudine', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: aggravated
# number positive examples: 117
# relation examples:
#  [KBTriple(rel='aggravated', sbj='fluocinolone', obj='condition'), KBTriple(rel='aggravated', sbj='octreotide', obj='condition'), KBTriple(rel='aggravated', sbj='desmopressin', obj='condition'), KBTriple(rel='aggravated', sbj='amlodipine', obj='condition'), KBTriple(rel='aggravated', sbj='acetanilide', obj='condition'), KBTriple(rel='aggravated', sbj='gentamicin', obj='condition'), KBTriple(rel='aggravated', sbj='valacyclovir', obj='condition'), KBTriple(rel='aggravated', sbj='technetium', obj='condition'), KBTriple(rel='aggravated', sbj='phenytoin', obj='condition'), KBTriple(rel='aggravated', sbj='labetalol', obj='condition')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: altered
# number positive examples: 36
# relation examples:
#  [KBTriple(rel='altered', sbj='methylprednisolone', obj='mood'), KBTriple(rel='altered', sbj='nifedipine', obj='mood'), KBTriple(rel='altered', sbj='losartan', obj='mood'), KBTriple(rel='altered', sbj='prozac', obj='mood'), KBTriple(rel='altered', sbj='levonorgestrel', obj='mood'), KBTriple(rel='altered', sbj='potassium', obj='mood'), KBTriple(rel='altered', sbj='clonazepam', obj='saliva'), KBTriple(rel='altered', sbj='omeprazole', obj='saliva'), KBTriple(rel='altered', sbj='propranolol', obj='mood'), KBTriple(rel='altered', sbj='acyclovir', obj='mood')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: caused
# number positive examples: 13953
# relation examples:
#  [KBTriple(rel='caused', sbj='methylprednisolone', obj='nausea'), KBTriple(rel='caused', sbj='losartan', obj='sudden_cardiac_death'), KBTriple(rel='caused', sbj='liraglutide', obj='constipation'), KBTriple(rel='caused', sbj='gentamicin', obj='infection'), KBTriple(rel='caused', sbj='technetium', obj='hepatomegaly'), KBTriple(rel='caused', sbj='fenofibrate', obj='colitis'), KBTriple(rel='caused', sbj='losartan', obj='necrosis'), KBTriple(rel='caused', sbj='denosumab', obj='osteosclerosis'), KBTriple(rel='caused', sbj='sodium', obj='pericarditis'), KBTriple(rel='caused', sbj='sodium', obj='starvation')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: changed
# number positive examples: 28
# relation examples:
#  [KBTriple(rel='changed', sbj='hydrochlorothiazide', obj='drug_level'), KBTriple(rel='changed', sbj='domperidone', obj='therapeutic_response'), KBTriple(rel='changed', sbj='clonazepam', obj='drug_level'), KBTriple(rel='changed', sbj='acyclovir', obj='therapeutic_response'), KBTriple(rel='changed', sbj='phenytoin', obj='drug_level'), KBTriple(rel='changed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='changed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='changed', sbj='imatinib', obj='therapeutic_response'), KBTriple(rel='changed', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='sodium', obj='drug_level')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: decreased
# number positive examples: 1143
# relation examples:
#  [KBTriple(rel='decreased', sbj='propranolol', obj='oxygen_saturation'), KBTriple(rel='decreased', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='decreased', sbj='sodium', obj='drug_level'), KBTriple(rel='decreased', sbj='irinotecan', obj='platelet_count'), KBTriple(rel='decreased', sbj='omeprazole', obj='serum_ferritin'), KBTriple(rel='decreased', sbj='potassium', obj='blood_phosphorus'), KBTriple(rel='decreased', sbj='potassium', obj='weight'), KBTriple(rel='decreased', sbj='domperidone', obj='body_temperature'), KBTriple(rel='decreased', sbj='potassium', obj='prothrombin_level'), KBTriple(rel='decreased', sbj='potassium', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: delayed
# number positive examples: 14
# relation examples:
#  [KBTriple(rel='delayed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='hydrochlorothiazide', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sodium', obj='menstruation'), KBTriple(rel='delayed', sbj='metronidazole', obj='menstruation'), KBTriple(rel='delayed', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='levonorgestrel', obj='menstruation'), KBTriple(rel='delayed', sbj='potassium', obj='menstruation'), KBTriple(rel='delayed', sbj='methylprednisolone', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: discoloured
# number positive examples: 45
# relation examples:
#  [KBTriple(rel='discoloured', sbj='clarithromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='bicalutamide', obj='faeces'), KBTriple(rel='discoloured', sbj='mepolizumab', obj='sputum'), KBTriple(rel='discoloured', sbj='omeprazole', obj='faeces'), KBTriple(rel='discoloured', sbj='abatacept', obj='sputum'), KBTriple(rel='discoloured', sbj='clarithromycin', obj='sputum'), KBTriple(rel='discoloured', sbj='erythromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='dopamine', obj='sputum'), KBTriple(rel='discoloured', sbj='piperacillin', obj='sputum'), KBTriple(rel='discoloured', sbj='methylprednisolone', obj='sputum')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: impaired
# number positive examples: 19
# relation examples:
#  [KBTriple(rel='impaired', sbj='clarithromycin', obj='judgement'), KBTriple(rel='impaired', sbj='hydrochlorothiazide', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='moxifloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='methylprednisolone', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='nifedipine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='levonorgestrel', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='potassium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='judgement'), KBTriple(rel='impaired', sbj='methotrexate', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: increased
# number positive examples: 1194
# relation examples:
#  [KBTriple(rel='increased', sbj='prozac', obj='libido'), KBTriple(rel='increased', sbj='epirubicin', obj='heart_rate'), KBTriple(rel='increased', sbj='hydrochlorothiazide', obj='haemoglobin'), KBTriple(rel='increased', sbj='clonazepam', obj='neutrophil_count'), KBTriple(rel='increased', sbj='liraglutide', obj='lipase'), KBTriple(rel='increased', sbj='omeprazole', obj='ammonia'), KBTriple(rel='increased', sbj='propranolol', obj='eosinophil_count'), KBTriple(rel='increased', sbj='candesartan', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='methotrexate', obj='transaminases'), KBTriple(rel='increased', sbj='desmopressin', obj='weight')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: infected
# number positive examples: 6
# relation examples:
#  [KBTriple(rel='infected', sbj='methylprednisolone', obj='dermatitis'), KBTriple(rel='infected', sbj='hydrochlorothiazide', obj='dermatitis'), KBTriple(rel='infected', sbj='methotrexate', obj='dermatitis'), KBTriple(rel='infected', sbj='amlodipine', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='blister')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='clonazepam', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: prolonged
# number positive examples: 39
# relation examples:
#  [KBTriple(rel='prolonged', sbj='gentamicin', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='heparin', obj='immobilisation'), KBTriple(rel='prolonged', sbj='dopamine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='piperacillin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='sodium', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='gentamicin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='heparin', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='potassium', obj='bleeding_time'), KBTriple(rel='prolonged', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='ketoconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: reduced
# number positive examples: 25
# relation examples:
#  [KBTriple(rel='reduced', sbj='propranolol', obj='visual_acuity'), KBTriple(rel='reduced', sbj='methotrexate', obj='visual_acuity'), KBTriple(rel='reduced', sbj='phenytoin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='hydrochlorothiazide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='sodium', obj='fluid_intake'), KBTriple(rel='reduced', sbj='propranolol', obj='fluid_intake'), KBTriple(rel='reduced', sbj='moxifloxacin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='raloxifene', obj='visual_acuity'), KBTriple(rel='reduced', sbj='sodium', obj='visual_acuity'), KBTriple(rel='reduced', sbj='latanoprost', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: ruptured
# number positive examples: 8
# relation examples:
#  [KBTriple(rel='ruptured', sbj='methotrexate', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='sodium', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='methylprednisolone', obj='aneurysm'), KBTriple(rel='ruptured', sbj='methotrexate', obj='aneurysm'), KBTriple(rel='ruptured', sbj='potassium', obj='liver_carcinoma'), KBTriple(rel='ruptured', sbj='rosuvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='sodium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='heparin', obj='aneurysm')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: shortened
# number positive examples: 41
# relation examples:
#  [KBTriple(rel='shortened', sbj='methylprednisolone', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='sodium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sirolimus', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='metronidazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='octreotide', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='potassium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sodium', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rosuvastatin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# ============ Evaluate =============
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      0.778      0.875          9      12078
# aggravated                0.000      0.000      0.000        117      12186
# altered                   0.500      0.056      0.100         36      12105
# caused                    0.471      0.096      0.159      13953      26022
# changed                   0.565      0.464      0.510         28      12097
# decreased                 0.636      0.073      0.132       1143      13212
# delayed                   1.000      0.429      0.600         14      12083
# discoloured               0.118      0.044      0.065         45      12114
# impaired                  0.000      0.000      0.000         19      12088
# increased                 0.649      0.042      0.079       1194      13263
# infected                  0.000      0.000      0.000          6      12075
# lowered                   0.000      0.000      0.000          1      12070
# prolonged                 0.792      0.487      0.603         39      12108
# reduced                   1.000      0.640      0.780         25      12094
# ruptured                  0.000      0.000      0.000          8      12077
# shortened                 0.719      0.561      0.630         41      12110
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.466      0.229      0.283      16678     209782

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Examining the trained models
#
# One important way to gain understanding of our trained model is to inspect the model weights. What features are strong positive indicators for each relation, and what features are strong negative indicators?

# %%
rel_ext.examine_model_weights(train_result)
# Out:
# Highest and lowest feature weights for relation accelerated:
#
#      1.193 growth
#      0.957 somatostatin
#      0.943 pancreatic
#      ..... .....
#     -0.412 with
#     -0.578 ,
#     -1.486
#
# Highest and lowest feature weights for relation acquired:
#
#      0.910 mucous
#      0.688 glucosuria
#      0.688 nephrolithiasis,
#      ..... .....
#     -0.681 to
#     -0.899 ,
#     -2.613
#
# Highest and lowest feature weights for relation aggravated:
#
#      0.727 condition
#      0.490 this
#      0.366 condition.
#      ..... .....
#     -0.221 and
#     -0.237 ,
#     -0.285
#
# Highest and lowest feature weights for relation altered:
#
#      2.555 mood
#      1.942 saliva
#      1.518 lithium
#      ..... .....
#     -0.556 patients
#     -0.718 ,
#     -0.811
#
# Highest and lowest feature weights for relation caused:
#
#      0.185 calcium
#      0.136 furosemide
#      0.133 mass
#      ..... .....
#     -0.153 peptide
#     -0.165 basal
#     -0.207 concomitant
#
# Highest and lowest feature weights for relation changed:
#
#      2.570 therapeutic
#      1.945 response.
#      1.370 CSF
#      ..... .....
#     -1.046 by
#     -1.617 ,
#     -1.647
#
# Highest and lowest feature weights for relation decreased:
#
#      0.274 electrophoretic
#      0.269 body
#      0.252 blood
#      ..... .....
#     -0.157 basal
#     -0.158 A
#     -0.199 nitrendipine
#
# Highest and lowest feature weights for relation delayed:
#
#      1.412 CSF
#      1.165 largest
#      1.099 familial
#      ..... .....
#     -0.893 (
#     -1.317 ,
#     -2.105
#
# Highest and lowest feature weights for relation discoloured:
#
#      3.602 sputum
#      2.543 faeces
#      1.374 blood,
#      ..... .....
#     -0.945 (
#     -1.157 ,
#     -1.367
#
# Highest and lowest feature weights for relation impaired:
#
#      1.736 test
#      1.680 insulin
#      1.677 glucose
#      ..... .....
#     -0.896 ,
#     -0.910 )
#     -1.353
#
# Highest and lowest feature weights for relation improved:
#
#      0.000 (CO)
#      0.000 (SV),
#      0.000 Fick
#      ..... .....
#     -0.573 of
#     -0.686 and
#     -2.378
#
# Highest and lowest feature weights for relation increased:
#
#      0.255 calcium
#      0.227 weight
#      0.192 blood
#      ..... .....
#     -0.131 A
#     -0.142 with
#     -0.169 patients
#
# Highest and lowest feature weights for relation infected:
#
#      1.791 atopic
#      1.372 fluid
#      1.335 penetration
#      ..... .....
#     -0.715 (
#     -0.895 .
#     -1.847
#
# Highest and lowest feature weights for relation lowered:
#
#      0.000 (CO)
#      0.000 (SV),
#      0.000 Fick
#      ..... .....
#     -0.573 of
#     -0.686 and
#     -2.378
#
# Highest and lowest feature weights for relation prolonged:
#
#      1.801 prolongation
#      1.483 prolonged
#      1.442 prothrombin
#      ..... .....
#     -1.033 (
#     -1.290 ,
#     -1.810
#
# Highest and lowest feature weights for relation reduced:
#
#      2.454 visual
#      2.318 acuity
#      1.667 oxalate
#      ..... .....
#     -1.010 .
#     -1.120 ,
#     -1.931
#
# Highest and lowest feature weights for relation ruptured:
#
#      1.565 calcium
#      1.310 aneurysm
#      1.212 aortic
#      ..... .....
#     -0.773 and
#     -0.920 ,
#     -2.064
#
# Highest and lowest feature weights for relation shortened:
#
#      2.632 therapeutic
#      1.739 levodopa
#      1.606 good
#      ..... .....
#     -1.156 )
#     -1.559
#     -1.580 ,

# %% [markdown]
# ### Discovering new relation instances
#
# Another way to gain insight into our trained models is to use them to discover new relation instances that don't currently appear in the KB. In fact, this is the whole point of building a relation extraction system: to extend an existing KB (or build a new one) using knowledge extracted from natural language text at scale. Can the models we've trained do this effectively?
#
# Because the goal is to discover new relation instances which are _true_ but _absent from the KB_, we can't evaluate this capability automatically. But we can generate candidate KB triples and manually evaluate them for correctness.
#
# To do this, we'll start from corpus examples containing pairs of entities which do not belong to any relation in the KB (earlier, we described these as "negative examples"). We'll then apply our trained models to each pair of entities, and sort the results by probability assigned by the model, in order to find the most likely new instances for each relation.

# %%
rel_ext.find_new_relation_instances(
    dataset,
    featurizers=[simple_bag_of_words_featurizer])
# Out:
# #####################
# relation: accelerated
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='accelerated', sbj='sandostatin', obj='growth')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: acquired
# number positive examples: 16
# relation examples:
#  [KBTriple(rel='acquired', sbj='ranitidine', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='metformin', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='lamivudine', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='nasal', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='lamivudine', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='ritonavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='raltegravir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='cholesterol', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='stavudine', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='darunavir', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: aggravated
# number positive examples: 300
# relation examples:
#  [KBTriple(rel='aggravated', sbj='ibuprofen', obj='condition'), KBTriple(rel='aggravated', sbj='psyllium', obj='condition'), KBTriple(rel='aggravated', sbj='procyclidine', obj='condition'), KBTriple(rel='aggravated', sbj='ozogamicin', obj='condition'), KBTriple(rel='aggravated', sbj='caspofungin', obj='condition'), KBTriple(rel='aggravated', sbj='lanreotide', obj='condition'), KBTriple(rel='aggravated', sbj='oxytocin', obj='condition'), KBTriple(rel='aggravated', sbj='argatroban', obj='condition'), KBTriple(rel='aggravated', sbj='ritonavir', obj='condition'), KBTriple(rel='aggravated', sbj='metoprolol', obj='condition')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: altered
# number positive examples: 84
# relation examples:
#  [KBTriple(rel='altered', sbj='pembrolizumab', obj='mood'), KBTriple(rel='altered', sbj='ibuprofen', obj='mood'), KBTriple(rel='altered', sbj='bromazepam', obj='mood'), KBTriple(rel='altered', sbj='dapsone', obj='mood'), KBTriple(rel='altered', sbj='metoprolol', obj='mood'), KBTriple(rel='altered', sbj='amitriptyline', obj='saliva'), KBTriple(rel='altered', sbj='ranitidine', obj='saliva'), KBTriple(rel='altered', sbj='oxazepam', obj='saliva'), KBTriple(rel='altered', sbj='quetiapine', obj='mood'), KBTriple(rel='altered', sbj='venlafaxine', obj='mood')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: caused
# number positive examples: 29719
# relation examples:
#  [KBTriple(rel='caused', sbj='tolvaptan', obj='abdominal_distension'), KBTriple(rel='caused', sbj='furosemide', obj='pyelonephritis'), KBTriple(rel='caused', sbj='emtricitabine', obj='prostate_cancer'), KBTriple(rel='caused', sbj='calcium', obj='sinus_rhythm'), KBTriple(rel='caused', sbj='brodalumab', obj='infection'), KBTriple(rel='caused', sbj='cisplatin', obj='febrile_neutropenia'), KBTriple(rel='caused', sbj='immunoglobulin', obj='influenza'), KBTriple(rel='caused', sbj='tipranavir', obj='haemorrhage'), KBTriple(rel='caused', sbj='cytarabine', obj='cerebellar_syndrome'), KBTriple(rel='caused', sbj='doxycycline', obj='drug-induced_liver_injury')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: changed
# number positive examples: 62
# relation examples:
#  [KBTriple(rel='changed', sbj='levetiracetam', obj='therapeutic_response'), KBTriple(rel='changed', sbj='verapamil', obj='therapeutic_response'), KBTriple(rel='changed', sbj='terazosin', obj='therapeutic_response'), KBTriple(rel='changed', sbj='paroxetine', obj='therapeutic_response'), KBTriple(rel='changed', sbj='atomoxetine', obj='therapeutic_response'), KBTriple(rel='changed', sbj='atorvastatin', obj='therapeutic_response'), KBTriple(rel='changed', sbj='carbidopa', obj='therapeutic_response'), KBTriple(rel='changed', sbj='magnesium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='haloperidol', obj='therapeutic_response'), KBTriple(rel='changed', sbj='penicillin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: decreased
# number positive examples: 2442
# relation examples:
#  [KBTriple(rel='decreased', sbj='radium', obj='weight'), KBTriple(rel='decreased', sbj='nasal', obj='blood_pressure'), KBTriple(rel='decreased', sbj='telmisartan', obj='glomerular_filtration_rate'), KBTriple(rel='decreased', sbj='tamoxifen', obj='quality_of_life'), KBTriple(rel='decreased', sbj='calcium', obj='blood_bilirubin'), KBTriple(rel='decreased', sbj='metoprolol', obj='exercise_tolerance'), KBTriple(rel='decreased', sbj='calcium', obj='prostatic_specific_antigen'), KBTriple(rel='decreased', sbj='ciprofloxacin', obj='oxygen_consumption'), KBTriple(rel='decreased', sbj='disodium', obj='mobility'), KBTriple(rel='decreased', sbj='magnesium', obj='grip_strength')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: delayed
# number positive examples: 32
# relation examples:
#  [KBTriple(rel='delayed', sbj='secukinumab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='adalimumab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='venlafaxine', obj='ejaculation'), KBTriple(rel='delayed', sbj='cholesterol', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sildenafil', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='calcium', obj='menstruation'), KBTriple(rel='delayed', sbj='calcium', obj='callus_formation'), KBTriple(rel='delayed', sbj='diclofenac', obj='menstruation'), KBTriple(rel='delayed', sbj='rituximab', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='lorazepam', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: discoloured
# number positive examples: 103
# relation examples:
#  [KBTriple(rel='discoloured', sbj='valsartan', obj='faeces'), KBTriple(rel='discoloured', sbj='nasal', obj='faeces'), KBTriple(rel='discoloured', sbj='immunoglobulin', obj='sputum'), KBTriple(rel='discoloured', sbj='penicillin', obj='sputum'), KBTriple(rel='discoloured', sbj='prednisolone', obj='sputum'), KBTriple(rel='discoloured', sbj='nac', obj='sputum'), KBTriple(rel='discoloured', sbj='cholesterol', obj='faeces'), KBTriple(rel='discoloured', sbj='sildenafil', obj='faeces'), KBTriple(rel='discoloured', sbj='nasal', obj='sputum'), KBTriple(rel='discoloured', sbj='cholesterol', obj='sputum')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: impaired
# number positive examples: 58
# relation examples:
#  [KBTriple(rel='impaired', sbj='penicillin', obj='judgement'), KBTriple(rel='impaired', sbj='risperidone', obj='judgement'), KBTriple(rel='impaired', sbj='ciprofloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='celecoxib', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='haloperidol', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='exemestane', obj='judgement'), KBTriple(rel='impaired', sbj='amitriptyline', obj='psychomotor_skills'), KBTriple(rel='impaired', sbj='metoprolol', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='quetiapine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='ramipril', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: improved
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='improved', sbj='cocaine', obj='pre-existing_condition')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: increased
# number positive examples: 2478
# relation examples:
#  [KBTriple(rel='increased', sbj='dapsone', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='quinapril', obj='heart_rate'), KBTriple(rel='increased', sbj='infliximab', obj='alanine_aminotransferase'), KBTriple(rel='increased', sbj='nortriptyline', obj='intraocular_pressure'), KBTriple(rel='increased', sbj='verapamil', obj='intraocular_pressure'), KBTriple(rel='increased', sbj='carboplatin', obj='blood_pressure'), KBTriple(rel='increased', sbj='magnesium', obj='fat_tissue'), KBTriple(rel='increased', sbj='metoprolol', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='nizatidine', obj='heart_rate'), KBTriple(rel='increased', sbj='sal', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: infected
# number positive examples: 22
# relation examples:
#  [KBTriple(rel='infected', sbj='metoprolol', obj='dermatitis'), KBTriple(rel='infected', sbj='calcium', obj='eczema'), KBTriple(rel='infected', sbj='ciprofloxacin', obj='blister'), KBTriple(rel='infected', sbj='ramipril', obj='dermatitis'), KBTriple(rel='infected', sbj='esomeprazole', obj='dermatitis'), KBTriple(rel='infected', sbj='calcium', obj='dermatitis'), KBTriple(rel='infected', sbj='metoprolol', obj='blister'), KBTriple(rel='infected', sbj='infliximab', obj='blister'), KBTriple(rel='infected', sbj='atorvastatin', obj='dermatitis'), KBTriple(rel='infected', sbj='furosemide', obj='eczema')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='ranitidine', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: prolonged
# number positive examples: 71
# relation examples:
#  [KBTriple(rel='prolonged', sbj='ibuprofen', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='quetiapine', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='phenylbutazone', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='furosemide', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='atenolol', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='levofloxacin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='furosemide', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='lidocaine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='metformin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='fluconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: reduced
# number positive examples: 47
# relation examples:
#  [KBTriple(rel='reduced', sbj='acetonide', obj='visual_acuity'), KBTriple(rel='reduced', sbj='ibuprofen', obj='visual_acuity'), KBTriple(rel='reduced', sbj='furosemide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='bevacizumab', obj='visual_acuity'), KBTriple(rel='reduced', sbj='verteporfin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='brinzolamide', obj='visual_acuity'), KBTriple(rel='reduced', sbj='lorazepam', obj='visual_acuity'), KBTriple(rel='reduced', sbj='azithromycin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='exemestane', obj='visual_acuity'), KBTriple(rel='reduced', sbj='fingolimod', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: ruptured
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='ruptured', sbj='calcium', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='enalapril', obj='aneurysm'), KBTriple(rel='ruptured', sbj='atorvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='furosemide', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='tolvaptan', obj='renal_cyst'), KBTriple(rel='ruptured', sbj='calcium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='lorazepam', obj='aneurysm'), KBTriple(rel='ruptured', sbj='letrozole', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='calcium', obj='ovarian_cyst')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: shortened
# number positive examples: 102
# relation examples:
#  [KBTriple(rel='shortened', sbj='pioglitazone', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='aripiprazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rizatriptan', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='vancomycin', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='diltiazem', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='lisinopril', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='calcium', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='aluminium', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='alemtuzumab', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='bupivacaine', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 7943
# unrelated examples:
#  [('buspirone', 'ulcer'), ('international_normalised_ratio', 'acenocoumarol'), ('basal', 'choriocarcinoma'), ('ampicillin', 'bile_duct_stone'), ('cholesteatoma', 'medium'), ('disability', 'acetazolamide'), ('pco2', 'acetazolamide'), ('diazepam', 'ischaemia'), ('cephalosporin', 'enterocolitis'), ('urapidil', 'bradycardia')]
# #####################
# relation: acquired
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='acquired', sbj='indinavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='sodium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='efavirenz', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='potassium', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='abacavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='potassium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='abacavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='methylprednisolone', obj='spinal_fusion'), KBTriple(rel='acquired', sbj='zidovudine', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: aggravated
# number positive examples: 117
# relation examples:
#  [KBTriple(rel='aggravated', sbj='fluocinolone', obj='condition'), KBTriple(rel='aggravated', sbj='octreotide', obj='condition'), KBTriple(rel='aggravated', sbj='desmopressin', obj='condition'), KBTriple(rel='aggravated', sbj='amlodipine', obj='condition'), KBTriple(rel='aggravated', sbj='acetanilide', obj='condition'), KBTriple(rel='aggravated', sbj='gentamicin', obj='condition'), KBTriple(rel='aggravated', sbj='valacyclovir', obj='condition'), KBTriple(rel='aggravated', sbj='technetium', obj='condition'), KBTriple(rel='aggravated', sbj='phenytoin', obj='condition'), KBTriple(rel='aggravated', sbj='labetalol', obj='condition')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: altered
# number positive examples: 36
# relation examples:
#  [KBTriple(rel='altered', sbj='methylprednisolone', obj='mood'), KBTriple(rel='altered', sbj='nifedipine', obj='mood'), KBTriple(rel='altered', sbj='losartan', obj='mood'), KBTriple(rel='altered', sbj='prozac', obj='mood'), KBTriple(rel='altered', sbj='levonorgestrel', obj='mood'), KBTriple(rel='altered', sbj='potassium', obj='mood'), KBTriple(rel='altered', sbj='clonazepam', obj='saliva'), KBTriple(rel='altered', sbj='omeprazole', obj='saliva'), KBTriple(rel='altered', sbj='propranolol', obj='mood'), KBTriple(rel='altered', sbj='acyclovir', obj='mood')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: caused
# number positive examples: 13953
# relation examples:
#  [KBTriple(rel='caused', sbj='methylprednisolone', obj='nausea'), KBTriple(rel='caused', sbj='losartan', obj='sudden_cardiac_death'), KBTriple(rel='caused', sbj='liraglutide', obj='constipation'), KBTriple(rel='caused', sbj='gentamicin', obj='infection'), KBTriple(rel='caused', sbj='technetium', obj='hepatomegaly'), KBTriple(rel='caused', sbj='fenofibrate', obj='colitis'), KBTriple(rel='caused', sbj='losartan', obj='necrosis'), KBTriple(rel='caused', sbj='denosumab', obj='osteosclerosis'), KBTriple(rel='caused', sbj='sodium', obj='pericarditis'), KBTriple(rel='caused', sbj='sodium', obj='starvation')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: changed
# number positive examples: 28
# relation examples:
#  [KBTriple(rel='changed', sbj='hydrochlorothiazide', obj='drug_level'), KBTriple(rel='changed', sbj='domperidone', obj='therapeutic_response'), KBTriple(rel='changed', sbj='clonazepam', obj='drug_level'), KBTriple(rel='changed', sbj='acyclovir', obj='therapeutic_response'), KBTriple(rel='changed', sbj='phenytoin', obj='drug_level'), KBTriple(rel='changed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='changed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='changed', sbj='imatinib', obj='therapeutic_response'), KBTriple(rel='changed', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='sodium', obj='drug_level')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: decreased
# number positive examples: 1143
# relation examples:
#  [KBTriple(rel='decreased', sbj='propranolol', obj='oxygen_saturation'), KBTriple(rel='decreased', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='decreased', sbj='sodium', obj='drug_level'), KBTriple(rel='decreased', sbj='irinotecan', obj='platelet_count'), KBTriple(rel='decreased', sbj='omeprazole', obj='serum_ferritin'), KBTriple(rel='decreased', sbj='potassium', obj='blood_phosphorus'), KBTriple(rel='decreased', sbj='potassium', obj='weight'), KBTriple(rel='decreased', sbj='domperidone', obj='body_temperature'), KBTriple(rel='decreased', sbj='potassium', obj='prothrombin_level'), KBTriple(rel='decreased', sbj='potassium', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: delayed
# number positive examples: 14
# relation examples:
#  [KBTriple(rel='delayed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='hydrochlorothiazide', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sodium', obj='menstruation'), KBTriple(rel='delayed', sbj='metronidazole', obj='menstruation'), KBTriple(rel='delayed', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='levonorgestrel', obj='menstruation'), KBTriple(rel='delayed', sbj='potassium', obj='menstruation'), KBTriple(rel='delayed', sbj='methylprednisolone', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: discoloured
# number positive examples: 45
# relation examples:
#  [KBTriple(rel='discoloured', sbj='clarithromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='bicalutamide', obj='faeces'), KBTriple(rel='discoloured', sbj='mepolizumab', obj='sputum'), KBTriple(rel='discoloured', sbj='omeprazole', obj='faeces'), KBTriple(rel='discoloured', sbj='abatacept', obj='sputum'), KBTriple(rel='discoloured', sbj='clarithromycin', obj='sputum'), KBTriple(rel='discoloured', sbj='erythromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='dopamine', obj='sputum'), KBTriple(rel='discoloured', sbj='piperacillin', obj='sputum'), KBTriple(rel='discoloured', sbj='methylprednisolone', obj='sputum')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: impaired
# number positive examples: 19
# relation examples:
#  [KBTriple(rel='impaired', sbj='clarithromycin', obj='judgement'), KBTriple(rel='impaired', sbj='hydrochlorothiazide', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='moxifloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='methylprednisolone', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='nifedipine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='levonorgestrel', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='potassium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='judgement'), KBTriple(rel='impaired', sbj='methotrexate', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: increased
# number positive examples: 1194
# relation examples:
#  [KBTriple(rel='increased', sbj='prozac', obj='libido'), KBTriple(rel='increased', sbj='epirubicin', obj='heart_rate'), KBTriple(rel='increased', sbj='hydrochlorothiazide', obj='haemoglobin'), KBTriple(rel='increased', sbj='clonazepam', obj='neutrophil_count'), KBTriple(rel='increased', sbj='liraglutide', obj='lipase'), KBTriple(rel='increased', sbj='omeprazole', obj='ammonia'), KBTriple(rel='increased', sbj='propranolol', obj='eosinophil_count'), KBTriple(rel='increased', sbj='candesartan', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='methotrexate', obj='transaminases'), KBTriple(rel='increased', sbj='desmopressin', obj='weight')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: infected
# number positive examples: 6
# relation examples:
#  [KBTriple(rel='infected', sbj='methylprednisolone', obj='dermatitis'), KBTriple(rel='infected', sbj='hydrochlorothiazide', obj='dermatitis'), KBTriple(rel='infected', sbj='methotrexate', obj='dermatitis'), KBTriple(rel='infected', sbj='amlodipine', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='blister')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='clonazepam', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: prolonged
# number positive examples: 39
# relation examples:
#  [KBTriple(rel='prolonged', sbj='gentamicin', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='heparin', obj='immobilisation'), KBTriple(rel='prolonged', sbj='dopamine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='piperacillin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='sodium', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='gentamicin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='heparin', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='potassium', obj='bleeding_time'), KBTriple(rel='prolonged', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='ketoconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: reduced
# number positive examples: 25
# relation examples:
#  [KBTriple(rel='reduced', sbj='propranolol', obj='visual_acuity'), KBTriple(rel='reduced', sbj='methotrexate', obj='visual_acuity'), KBTriple(rel='reduced', sbj='phenytoin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='hydrochlorothiazide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='sodium', obj='fluid_intake'), KBTriple(rel='reduced', sbj='propranolol', obj='fluid_intake'), KBTriple(rel='reduced', sbj='moxifloxacin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='raloxifene', obj='visual_acuity'), KBTriple(rel='reduced', sbj='sodium', obj='visual_acuity'), KBTriple(rel='reduced', sbj='latanoprost', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: ruptured
# number positive examples: 8
# relation examples:
#  [KBTriple(rel='ruptured', sbj='methotrexate', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='sodium', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='methylprednisolone', obj='aneurysm'), KBTriple(rel='ruptured', sbj='methotrexate', obj='aneurysm'), KBTriple(rel='ruptured', sbj='potassium', obj='liver_carcinoma'), KBTriple(rel='ruptured', sbj='rosuvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='sodium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='heparin', obj='aneurysm')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: shortened
# number positive examples: 41
# relation examples:
#  [KBTriple(rel='shortened', sbj='methylprednisolone', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='sodium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sirolimus', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='metronidazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='octreotide', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='potassium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sodium', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rosuvastatin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 24138
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# Highest probability examples for relation accelerated:
#
# Highest probability examples for relation acquired:
#
#      0.799 KBTriple(rel='acquired', sbj='impetigo', obj='clarithromycin')
#      0.799 KBTriple(rel='acquired', sbj='clarithromycin', obj='impetigo')
#      0.699 KBTriple(rel='acquired', sbj='tracheal_injury', obj='submucosal')
#      0.699 KBTriple(rel='acquired', sbj='submucosal', obj='tracheal_injury')
#      0.362 KBTriple(rel='acquired', sbj='heparin', obj='paroxysmal_nocturnal_haemoglobinuria')
#      0.362 KBTriple(rel='acquired', sbj='paroxysmal_nocturnal_haemoglobinuria', obj='heparin')
#      0.352 KBTriple(rel='acquired', sbj='belgium', obj='erythema')
#      0.352 KBTriple(rel='acquired', sbj='erythema', obj='belgium')
#      0.201 KBTriple(rel='acquired', sbj='flunitrazepam', obj='progesterone')
#      0.201 KBTriple(rel='acquired', sbj='progesterone', obj='flunitrazepam')
#
# Highest probability examples for relation aggravated:
#
#      0.999 KBTriple(rel='aggravated', sbj='hepatectomy', obj='vasopressin')
#      0.999 KBTriple(rel='aggravated', sbj='vasopressin', obj='hepatectomy')
#      0.999 KBTriple(rel='aggravated', sbj='viomycin', obj='condition')
#      0.999 KBTriple(rel='aggravated', sbj='condition', obj='viomycin')
#      0.976 KBTriple(rel='aggravated', sbj='condition', obj='estramustine')
#      0.976 KBTriple(rel='aggravated', sbj='estramustine', obj='condition')
#      0.941 KBTriple(rel='aggravated', sbj='pco2', obj='cimetidine')
#      0.941 KBTriple(rel='aggravated', sbj='cimetidine', obj='pco2')
#      0.936 KBTriple(rel='aggravated', sbj='bleomycin', obj='adverse_reaction')
#      0.936 KBTriple(rel='aggravated', sbj='adverse_reaction', obj='bleomycin')
#
# Highest probability examples for relation altered:
#
#      0.410 KBTriple(rel='altered', sbj='zidovudine', obj='saliva')
#      0.410 KBTriple(rel='altered', sbj='saliva', obj='zidovudine')
#      0.313 KBTriple(rel='altered', sbj='nitrazepam', obj='cortisol')
#      0.313 KBTriple(rel='altered', sbj='cortisol', obj='nitrazepam')
#      0.282 KBTriple(rel='altered', sbj='vasopressin', obj='adhesion')
#      0.282 KBTriple(rel='altered', sbj='adhesion', obj='vasopressin')
#      0.262 KBTriple(rel='altered', sbj='mood', obj='vasopressin')
#      0.262 KBTriple(rel='altered', sbj='vasopressin', obj='mood')
#      0.139 KBTriple(rel='altered', sbj='enzyme_activity', obj='mitomycin')
#      0.139 KBTriple(rel='altered', sbj='mitomycin', obj='enzyme_activity')
#
# Highest probability examples for relation caused:
#
#      0.998 KBTriple(rel='caused', sbj='bleomycin', obj='fibrosis')
#      0.998 KBTriple(rel='caused', sbj='fibrosis', obj='bleomycin')
#      0.995 KBTriple(rel='caused', sbj='nifedipine', obj='pertussis')
#      0.995 KBTriple(rel='caused', sbj='pertussis', obj='nifedipine')
#      0.994 KBTriple(rel='caused', sbj='febrile_convulsion', obj='sodium')
#      0.994 KBTriple(rel='caused', sbj='sodium', obj='febrile_convulsion')
#      0.994 KBTriple(rel='caused', sbj='potassium', obj='diuretic_therapy')
#      0.994 KBTriple(rel='caused', sbj='diuretic_therapy', obj='potassium')
#      0.993 KBTriple(rel='caused', sbj='ocular_hypertension', obj='levobunolol')
#      0.993 KBTriple(rel='caused', sbj='levobunolol', obj='ocular_hypertension')
#
# Highest probability examples for relation changed:
#
#      1.000 KBTriple(rel='changed', sbj='dialysis', obj='clofibrate')
#      1.000 KBTriple(rel='changed', sbj='clofibrate', obj='dialysis')
#      0.981 KBTriple(rel='changed', sbj='tuberculosis', obj='viomycin')
#      0.981 KBTriple(rel='changed', sbj='viomycin', obj='tuberculosis')
#      0.528 KBTriple(rel='changed', sbj='nosocomial_infection', obj='neomycin')
#      0.528 KBTriple(rel='changed', sbj='neomycin', obj='nosocomial_infection')
#      0.524 KBTriple(rel='changed', sbj='vasopressin', obj='craniopharyngioma')
#      0.524 KBTriple(rel='changed', sbj='craniopharyngioma', obj='vasopressin')
#      0.524 KBTriple(rel='changed', sbj='nosocomial_infection', obj='norfloxacin')
#      0.524 KBTriple(rel='changed', sbj='norfloxacin', obj='nosocomial_infection')
#
# Highest probability examples for relation decreased:
#
#      1.000 KBTriple(rel='decreased', sbj='potassium', obj='infusion')
#      1.000 KBTriple(rel='decreased', sbj='infusion', obj='potassium')
#      1.000 KBTriple(rel='decreased', sbj='heart_rate', obj='nisoldipine')
#      1.000 KBTriple(rel='decreased', sbj='nisoldipine', obj='heart_rate')
#      1.000 KBTriple(rel='decreased', sbj='metronidazole', obj='injection')
#      1.000 KBTriple(rel='decreased', sbj='injection', obj='metronidazole')
#      1.000 KBTriple(rel='decreased', sbj='praziquantel', obj='weight')
#      1.000 KBTriple(rel='decreased', sbj='weight', obj='praziquantel')
#      1.000 KBTriple(rel='decreased', sbj='vasopressin', obj='weight')
#      1.000 KBTriple(rel='decreased', sbj='weight', obj='vasopressin')
#
# Highest probability examples for relation delayed:
#
#      0.836 KBTriple(rel='delayed', sbj='pertussis', obj='alprenolol')
#      0.836 KBTriple(rel='delayed', sbj='alprenolol', obj='pertussis')
#      0.782 KBTriple(rel='delayed', sbj='single_umbilical_artery', obj='pac')
#      0.782 KBTriple(rel='delayed', sbj='pac', obj='single_umbilical_artery')
#      0.526 KBTriple(rel='delayed', sbj='levonorgestrel', obj='protein_s')
#      0.526 KBTriple(rel='delayed', sbj='protein_s', obj='levonorgestrel')
#      0.399 KBTriple(rel='delayed', sbj='oxymetholone', obj='elderly')
#      0.399 KBTriple(rel='delayed', sbj='elderly', obj='oxymetholone')
#      0.342 KBTriple(rel='delayed', sbj='technetium', obj='chronic_hepatitis')
#      0.342 KBTriple(rel='delayed', sbj='chronic_hepatitis', obj='technetium')
#
# Highest probability examples for relation discoloured:
#
#      1.000 KBTriple(rel='discoloured', sbj='sputum', obj='methicillin')
#      1.000 KBTriple(rel='discoloured', sbj='methicillin', obj='sputum')
#      0.998 KBTriple(rel='discoloured', sbj='diarrhoea', obj='oxytetracycline')
#      0.998 KBTriple(rel='discoloured', sbj='oxytetracycline', obj='diarrhoea')
#      0.958 KBTriple(rel='discoloured', sbj='obstruction', obj='cilastatin')
#      0.958 KBTriple(rel='discoloured', sbj='cilastatin', obj='obstruction')
#      0.925 KBTriple(rel='discoloured', sbj='wound', obj='submucosal')
#      0.925 KBTriple(rel='discoloured', sbj='submucosal', obj='wound')
#      0.865 KBTriple(rel='discoloured', sbj='prophylaxis', obj='cilastatin')
#      0.865 KBTriple(rel='discoloured', sbj='cilastatin', obj='prophylaxis')
#
# Highest probability examples for relation impaired:
#
#      1.000 KBTriple(rel='impaired', sbj='glucose_tolerance', obj='propranolol')
#      1.000 KBTriple(rel='impaired', sbj='propranolol', obj='glucose_tolerance')
#      0.999 KBTriple(rel='impaired', sbj='levonorgestrel', obj='blood_glucose')
#      0.999 KBTriple(rel='impaired', sbj='blood_glucose', obj='levonorgestrel')
#      0.931 KBTriple(rel='impaired', sbj='fasting', obj='indapamide')
#      0.931 KBTriple(rel='impaired', sbj='indapamide', obj='fasting')
#      0.925 KBTriple(rel='impaired', sbj='medazepam', obj='psychomotor_skills')
#      0.925 KBTriple(rel='impaired', sbj='psychomotor_skills', obj='medazepam')
#      0.840 KBTriple(rel='impaired', sbj='forced_expiratory_volume', obj='cimetidine')
#      0.840 KBTriple(rel='impaired', sbj='cimetidine', obj='forced_expiratory_volume')
#
# Highest probability examples for relation improved:
#
# Highest probability examples for relation increased:
#
#      1.000 KBTriple(rel='increased', sbj='potassium', obj='renin')
#      1.000 KBTriple(rel='increased', sbj='renin', obj='potassium')
#      1.000 KBTriple(rel='increased', sbj='renin', obj='sodium')
#      1.000 KBTriple(rel='increased', sbj='sodium', obj='renin')
#      1.000 KBTriple(rel='increased', sbj='heart_rate', obj='nisoldipine')
#      1.000 KBTriple(rel='increased', sbj='nisoldipine', obj='heart_rate')
#      1.000 KBTriple(rel='increased', sbj='propranolol', obj='venous_pressure')
#      1.000 KBTriple(rel='increased', sbj='venous_pressure', obj='propranolol')
#      1.000 KBTriple(rel='increased', sbj='praziquantel', obj='weight')
#      1.000 KBTriple(rel='increased', sbj='weight', obj='praziquantel')
#
# Highest probability examples for relation infected:
#      0.250 KBTriple(rel='infected', sbj='technetium', obj='chronic_hepatitis')
#      0.250 KBTriple(rel='infected', sbj='chronic_hepatitis', obj='technetium')
#      0.230 KBTriple(rel='infected', sbj='technetium', obj='hepatitis')
#      0.230 KBTriple(rel='infected', sbj='hepatitis', obj='technetium')
#      0.121 KBTriple(rel='infected', sbj='lithiasis', obj='technetium')
#      0.121 KBTriple(rel='infected', sbj='technetium', obj='lithiasis')
#      0.077 KBTriple(rel='infected', sbj='sulindac', obj='urine_output')
#      0.077 KBTriple(rel='infected', sbj='urine_output', obj='sulindac')
#      0.072 KBTriple(rel='infected', sbj='aspiration', obj='oxytetracycline')
#      0.072 KBTriple(rel='infected', sbj='oxytetracycline', obj='aspiration')
#
# Highest probability examples for relation lowered:
#
#      0.045 KBTriple(rel='lowered', sbj='tracheal_injury', obj='submucosal')
#      0.045 KBTriple(rel='lowered', sbj='submucosal', obj='tracheal_injury')
#      0.040 KBTriple(rel='lowered', sbj='autopsy', obj='nisoldipine')
#      0.040 KBTriple(rel='lowered', sbj='nisoldipine', obj='autopsy')
#      0.039 KBTriple(rel='lowered', sbj='colon_cancer', obj='proleukin')
#      0.039 KBTriple(rel='lowered', sbj='proleukin', obj='colon_cancer')
#      0.031 KBTriple(rel='lowered', sbj='flunitrazepam', obj='mechanical_ventilation')
#      0.031 KBTriple(rel='lowered', sbj='mechanical_ventilation', obj='flunitrazepam')
#      0.026 KBTriple(rel='lowered', sbj='flunitrazepam', obj='progesterone')
#      0.026 KBTriple(rel='lowered', sbj='progesterone', obj='flunitrazepam')
#
# Highest probability examples for relation prolonged:
#
#      0.903 KBTriple(rel='prolonged', sbj='nitrazepam', obj='cortisol')
#      0.903 KBTriple(rel='prolonged', sbj='cortisol', obj='nitrazepam')
#      0.803 KBTriple(rel='prolonged', sbj='triptorelin', obj='pregnancy')
#      0.803 KBTriple(rel='prolonged', sbj='pregnancy', obj='triptorelin')
#      0.718 KBTriple(rel='prolonged', sbj='neomycin', obj='wound_sepsis')
#      0.718 KBTriple(rel='prolonged', sbj='wound_sepsis', obj='neomycin')
#      0.694 KBTriple(rel='prolonged', sbj='ivermectin', obj='prothrombin_time')
#      0.694 KBTriple(rel='prolonged', sbj='prothrombin_time', obj='ivermectin')
#      0.688 KBTriple(rel='prolonged', sbj='thrombin_time', obj='propranolol')
#      0.688 KBTriple(rel='prolonged', sbj='propranolol', obj='thrombin_time')
#
# Highest probability examples for relation reduced:
#
#      0.477 KBTriple(rel='reduced', sbj='sodium', obj='central_cord_syndrome')
#      0.477 KBTriple(rel='reduced', sbj='central_cord_syndrome', obj='sodium')
#      0.440 KBTriple(rel='reduced', sbj='hyperparathyroidism', obj='chlorothiazide')
#      0.440 KBTriple(rel='reduced', sbj='chlorothiazide', obj='hyperparathyroidism')
#      0.300 KBTriple(rel='reduced', sbj='cetrorelix', obj='erythema')
#      0.300 KBTriple(rel='reduced', sbj='erythema', obj='cetrorelix')
#      0.286 KBTriple(rel='reduced', sbj='vasopressin', obj='forced_expiratory_volume')
#      0.286 KBTriple(rel='reduced', sbj='forced_expiratory_volume', obj='vasopressin')
#      0.265 KBTriple(rel='reduced', sbj='cardiomyopathy', obj='neomycin')
#      0.265 KBTriple(rel='reduced', sbj='neomycin', obj='cardiomyopathy')
#
# Highest probability examples for relation ruptured:
#
#      0.144 KBTriple(rel='ruptured', sbj='arteriosclerosis', obj='nimodipine')
#      0.144 KBTriple(rel='ruptured', sbj='nimodipine', obj='arteriosclerosis')
#      0.131 KBTriple(rel='ruptured', sbj='infusion', obj='thromboglobulin')
#      0.131 KBTriple(rel='ruptured', sbj='thromboglobulin', obj='infusion')
#      0.040 KBTriple(rel='ruptured', sbj='intraocular_pressure', obj='desmopressin')
#      0.040 KBTriple(rel='ruptured', sbj='desmopressin', obj='intraocular_pressure')
#      0.030 KBTriple(rel='ruptured', sbj='pertussis', obj='alprenolol')
#      0.030 KBTriple(rel='ruptured', sbj='alprenolol', obj='pertussis')
#      0.030 KBTriple(rel='ruptured', sbj='minocycline', obj='pneumonectomy')
#      0.030 KBTriple(rel='ruptured', sbj='pneumonectomy', obj='minocycline')
#
# Highest probability examples for relation shortened:
#
#      1.000 KBTriple(rel='shortened', sbj='dialysis', obj='clofibrate')
#      1.000 KBTriple(rel='shortened', sbj='clofibrate', obj='dialysis')
#      0.977 KBTriple(rel='shortened', sbj='erythromycin', obj='gastrointestinal_toxicity')
#      0.977 KBTriple(rel='shortened', sbj='gastrointestinal_toxicity', obj='erythromycin')
#      0.976 KBTriple(rel='shortened', sbj='pain', obj='nisoldipine')
#      0.976 KBTriple(rel='shortened', sbj='nisoldipine', obj='pain')
#      0.925 KBTriple(rel='shortened', sbj='potassium', obj='critical_illness')
#      0.925 KBTriple(rel='shortened', sbj='critical_illness', obj='potassium')
#      0.884 KBTriple(rel='shortened', sbj='osteochondrosis', obj='propranolol')
#      0.884 KBTriple(rel='shortened', sbj='propranolol', obj='osteochondrosis')

# %% [markdown]
# ### Evaluating a random-guessing strategy
#
# In order to validate our evaluation framework, and to set a floor under expected results for future evaluations, let's implement and evaluate a random-guessing strategy. The random guesser is a classifier which completely ignores its input, and simply flips a coin.

# %%
def lift(f):
    return lambda xs: [f(x) for x in xs]

def make_random_classifier(p=0.50):
    def random_classify(kb_triple):
        return random.random() < p
    return lift(random_classify)

# %%
rel_ext.evaluate(splits, make_random_classifier(), sampling_rate=0.5)
# Out:
# #####################
# relation: acquired
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='acquired', sbj='indinavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='sodium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='efavirenz', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='potassium', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='abacavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='potassium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='abacavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='methylprednisolone', obj='spinal_fusion'), KBTriple(rel='acquired', sbj='zidovudine', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: aggravated
# number positive examples: 117
# relation examples:
#  [KBTriple(rel='aggravated', sbj='fluocinolone', obj='condition'), KBTriple(rel='aggravated', sbj='octreotide', obj='condition'), KBTriple(rel='aggravated', sbj='desmopressin', obj='condition'), KBTriple(rel='aggravated', sbj='amlodipine', obj='condition'), KBTriple(rel='aggravated', sbj='acetanilide', obj='condition'), KBTriple(rel='aggravated', sbj='gentamicin', obj='condition'), KBTriple(rel='aggravated', sbj='valacyclovir', obj='condition'), KBTriple(rel='aggravated', sbj='technetium', obj='condition'), KBTriple(rel='aggravated', sbj='phenytoin', obj='condition'), KBTriple(rel='aggravated', sbj='labetalol', obj='condition')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: altered
# number positive examples: 36
# relation examples:
#  [KBTriple(rel='altered', sbj='methylprednisolone', obj='mood'), KBTriple(rel='altered', sbj='nifedipine', obj='mood'), KBTriple(rel='altered', sbj='losartan', obj='mood'), KBTriple(rel='altered', sbj='prozac', obj='mood'), KBTriple(rel='altered', sbj='levonorgestrel', obj='mood'), KBTriple(rel='altered', sbj='potassium', obj='mood'), KBTriple(rel='altered', sbj='clonazepam', obj='saliva'), KBTriple(rel='altered', sbj='omeprazole', obj='saliva'), KBTriple(rel='altered', sbj='propranolol', obj='mood'), KBTriple(rel='altered', sbj='acyclovir', obj='mood')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: caused
# number positive examples: 13953
# relation examples:
#  [KBTriple(rel='caused', sbj='methylprednisolone', obj='nausea'), KBTriple(rel='caused', sbj='losartan', obj='sudden_cardiac_death'), KBTriple(rel='caused', sbj='liraglutide', obj='constipation'), KBTriple(rel='caused', sbj='gentamicin', obj='infection'), KBTriple(rel='caused', sbj='technetium', obj='hepatomegaly'), KBTriple(rel='caused', sbj='fenofibrate', obj='colitis'), KBTriple(rel='caused', sbj='losartan', obj='necrosis'), KBTriple(rel='caused', sbj='denosumab', obj='osteosclerosis'), KBTriple(rel='caused', sbj='sodium', obj='pericarditis'), KBTriple(rel='caused', sbj='sodium', obj='starvation')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: changed
# number positive examples: 28
# relation examples:
#  [KBTriple(rel='changed', sbj='hydrochlorothiazide', obj='drug_level'), KBTriple(rel='changed', sbj='domperidone', obj='therapeutic_response'), KBTriple(rel='changed', sbj='clonazepam', obj='drug_level'), KBTriple(rel='changed', sbj='acyclovir', obj='therapeutic_response'), KBTriple(rel='changed', sbj='phenytoin', obj='drug_level'), KBTriple(rel='changed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='changed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='changed', sbj='imatinib', obj='therapeutic_response'), KBTriple(rel='changed', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='sodium', obj='drug_level')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: decreased
# number positive examples: 1143
# relation examples:
#  [KBTriple(rel='decreased', sbj='propranolol', obj='oxygen_saturation'), KBTriple(rel='decreased', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='decreased', sbj='sodium', obj='drug_level'), KBTriple(rel='decreased', sbj='irinotecan', obj='platelet_count'), KBTriple(rel='decreased', sbj='omeprazole', obj='serum_ferritin'), KBTriple(rel='decreased', sbj='potassium', obj='blood_phosphorus'), KBTriple(rel='decreased', sbj='potassium', obj='weight'), KBTriple(rel='decreased', sbj='domperidone', obj='body_temperature'), KBTriple(rel='decreased', sbj='potassium', obj='prothrombin_level'), KBTriple(rel='decreased', sbj='potassium', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: delayed
# number positive examples: 14
# relation examples:
#  [KBTriple(rel='delayed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='hydrochlorothiazide', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sodium', obj='menstruation'), KBTriple(rel='delayed', sbj='metronidazole', obj='menstruation'), KBTriple(rel='delayed', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='levonorgestrel', obj='menstruation'), KBTriple(rel='delayed', sbj='potassium', obj='menstruation'), KBTriple(rel='delayed', sbj='methylprednisolone', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: discoloured
# number positive examples: 45
# relation examples:
#  [KBTriple(rel='discoloured', sbj='clarithromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='bicalutamide', obj='faeces'), KBTriple(rel='discoloured', sbj='mepolizumab', obj='sputum'), KBTriple(rel='discoloured', sbj='omeprazole', obj='faeces'), KBTriple(rel='discoloured', sbj='abatacept', obj='sputum'), KBTriple(rel='discoloured', sbj='clarithromycin', obj='sputum'), KBTriple(rel='discoloured', sbj='erythromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='dopamine', obj='sputum'), KBTriple(rel='discoloured', sbj='piperacillin', obj='sputum'), KBTriple(rel='discoloured', sbj='methylprednisolone', obj='sputum')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: impaired
# number positive examples: 19
# relation examples:
#  [KBTriple(rel='impaired', sbj='clarithromycin', obj='judgement'), KBTriple(rel='impaired', sbj='hydrochlorothiazide', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='moxifloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='methylprednisolone', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='nifedipine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='levonorgestrel', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='potassium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='judgement'), KBTriple(rel='impaired', sbj='methotrexate', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: increased
# number positive examples: 1194
# relation examples:
#  [KBTriple(rel='increased', sbj='prozac', obj='libido'), KBTriple(rel='increased', sbj='epirubicin', obj='heart_rate'), KBTriple(rel='increased', sbj='hydrochlorothiazide', obj='haemoglobin'), KBTriple(rel='increased', sbj='clonazepam', obj='neutrophil_count'), KBTriple(rel='increased', sbj='liraglutide', obj='lipase'), KBTriple(rel='increased', sbj='omeprazole', obj='ammonia'), KBTriple(rel='increased', sbj='propranolol', obj='eosinophil_count'), KBTriple(rel='increased', sbj='candesartan', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='methotrexate', obj='transaminases'), KBTriple(rel='increased', sbj='desmopressin', obj='weight')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: infected
# number positive examples: 6
# relation examples:
#  [KBTriple(rel='infected', sbj='methylprednisolone', obj='dermatitis'), KBTriple(rel='infected', sbj='hydrochlorothiazide', obj='dermatitis'), KBTriple(rel='infected', sbj='methotrexate', obj='dermatitis'), KBTriple(rel='infected', sbj='amlodipine', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='blister')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='clonazepam', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: prolonged
# number positive examples: 39
# relation examples:
#  [KBTriple(rel='prolonged', sbj='gentamicin', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='heparin', obj='immobilisation'), KBTriple(rel='prolonged', sbj='dopamine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='piperacillin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='sodium', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='gentamicin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='heparin', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='potassium', obj='bleeding_time'), KBTriple(rel='prolonged', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='ketoconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: reduced
# number positive examples: 25
# relation examples:
#  [KBTriple(rel='reduced', sbj='propranolol', obj='visual_acuity'), KBTriple(rel='reduced', sbj='methotrexate', obj='visual_acuity'), KBTriple(rel='reduced', sbj='phenytoin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='hydrochlorothiazide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='sodium', obj='fluid_intake'), KBTriple(rel='reduced', sbj='propranolol', obj='fluid_intake'), KBTriple(rel='reduced', sbj='moxifloxacin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='raloxifene', obj='visual_acuity'), KBTriple(rel='reduced', sbj='sodium', obj='visual_acuity'), KBTriple(rel='reduced', sbj='latanoprost', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: ruptured
# number positive examples: 8
# relation examples:
#  [KBTriple(rel='ruptured', sbj='methotrexate', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='sodium', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='methylprednisolone', obj='aneurysm'), KBTriple(rel='ruptured', sbj='methotrexate', obj='aneurysm'), KBTriple(rel='ruptured', sbj='potassium', obj='liver_carcinoma'), KBTriple(rel='ruptured', sbj='rosuvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='sodium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='heparin', obj='aneurysm')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: shortened
# number positive examples: 41
# relation examples:
#  [KBTriple(rel='shortened', sbj='methylprednisolone', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='sodium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sirolimus', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='metronidazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='octreotide', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='potassium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sodium', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rosuvastatin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 12069
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# accelerated               0.000      0.000      0.000          0          0
# acquired                  0.001      0.556      0.002          9      12078
# aggravated                0.010      0.513      0.019        117      12186
# altered                   0.003      0.528      0.006         36      12105
# caused                    0.536      0.500      0.517      13953      26022
# changed                   0.002      0.393      0.004         28      12097
# decreased                 0.084      0.492      0.144       1143      13212
# delayed                   0.001      0.357      0.002         14      12083
# discoloured               0.003      0.444      0.007         45      12114
# impaired                  0.002      0.737      0.005         19      12088
# improved                  0.000      0.000      0.000          0          0
# increased                 0.089      0.493      0.151       1194      13263
# infected                  0.000      0.500      0.001          6      12075
# lowered                   0.000      0.000      0.000          1      12070
# prolonged                 0.003      0.513      0.007         39      12108
# reduced                   0.003      0.680      0.006         25      12094
# ruptured                  0.001      0.750      0.002          8      12077
# shortened                 0.004      0.512      0.007         41      12110
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.041      0.443      0.049      16678     209782
# 0.048778928430296374

# %% [markdown]
# ## A simple baseline model
#
# It shouldn't be too hard to do better than random guessing. But for now, let's aim low — let's use the data we have in the easiest and most obvious way, and see how far that gets us.
#
# We start from the intuition that the words between two entity mentions frequently tell us how they're related. For example, in the phrase "SpaceX was founded by Elon Musk", the words "was founded by" indicate that the `founders` relation holds between the first entity mentioned and the second. Likewise, in the phrase "Elon Musk established SpaceX", the word "established" indicates the `founders` relation holds between the second entity mentioned and the first.
#
# So let's write some code to find the most common phrases that appear between the two entity mentions for each relation. As the examples illustrate, we need to make sure to consider both directions: that is, where the subject of the relation appears as the first mention, and where it appears as the second.

# %%
def find_common_middles(split, top_k=5, show_output=False):
    corpus = split.corpus
    kb = split.kb
    mids_by_rel = {
        'fwd': defaultdict(lambda: defaultdict(int)),
        'rev': defaultdict(lambda: defaultdict(int))}
    for rel in kb.all_relations:
        for kbt in kb.get_triples_for_relation(rel):
            for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
                mids_by_rel['fwd'][rel][ex.middle] += 1
            for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
                mids_by_rel['rev'][rel][ex.middle] += 1
    def most_frequent(mid_counter):
        return sorted([(cnt, mid) for mid, cnt in mid_counter.items()], reverse=True)[:top_k]
    for rel in kb.all_relations:
        for dir in ['fwd', 'rev']:
            top = most_frequent(mids_by_rel[dir][rel])
            if show_output:
                for cnt, mid in top:
                    print('{:20s} {:5s} {:10d} {:s}'.format(rel, dir, cnt, mid))
            mids_by_rel[dir][rel] = set([mid for cnt, mid in top])
    return mids_by_rel

_ = find_common_middles(splits['train'], show_output=False)

# %%
def train_top_k_middles_classifier(top_k=100):
    split = splits['train']
    corpus = split.corpus
    top_k_mids_by_rel = find_common_middles(split=split, top_k=top_k)
    def classify(kb_triple):
        fwd_mids = top_k_mids_by_rel['fwd'][kb_triple.rel]
        rev_mids = top_k_mids_by_rel['rev'][kb_triple.rel]
        for ex in corpus.get_examples_for_entities(kb_triple.sbj, kb_triple.obj):
            if ex.middle in fwd_mids:
                return True
        for ex in corpus.get_examples_for_entities(kb_triple.obj, kb_triple.sbj):
            if ex.middle in rev_mids:
                return True
        return False
    return lift(classify)

# %%
rel_ext.evaluate(splits, train_top_k_middles_classifier())
# Out:
# #####################
# relation: acquired
# number positive examples: 9
# relation examples:
#  [KBTriple(rel='acquired', sbj='indinavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='sodium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='efavirenz', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='potassium', obj='dacryostenosis'), KBTriple(rel='acquired', sbj='abacavir', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='potassium', obj='fanconi_syndrome'), KBTriple(rel='acquired', sbj='abacavir', obj='lipodystrophy'), KBTriple(rel='acquired', sbj='methylprednisolone', obj='spinal_fusion'), KBTriple(rel='acquired', sbj='zidovudine', obj='lipodystrophy')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: aggravated
# number positive examples: 117
# relation examples:
#  [KBTriple(rel='aggravated', sbj='fluocinolone', obj='condition'), KBTriple(rel='aggravated', sbj='octreotide', obj='condition'), KBTriple(rel='aggravated', sbj='desmopressin', obj='condition'), KBTriple(rel='aggravated', sbj='amlodipine', obj='condition'), KBTriple(rel='aggravated', sbj='acetanilide', obj='condition'), KBTriple(rel='aggravated', sbj='gentamicin', obj='condition'), KBTriple(rel='aggravated', sbj='valacyclovir', obj='condition'), KBTriple(rel='aggravated', sbj='technetium', obj='condition'), KBTriple(rel='aggravated', sbj='phenytoin', obj='condition'), KBTriple(rel='aggravated', sbj='labetalol', obj='condition')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: altered
# number positive examples: 36
# relation examples:
#  [KBTriple(rel='altered', sbj='methylprednisolone', obj='mood'), KBTriple(rel='altered', sbj='nifedipine', obj='mood'), KBTriple(rel='altered', sbj='losartan', obj='mood'), KBTriple(rel='altered', sbj='prozac', obj='mood'), KBTriple(rel='altered', sbj='levonorgestrel', obj='mood'), KBTriple(rel='altered', sbj='potassium', obj='mood'), KBTriple(rel='altered', sbj='clonazepam', obj='saliva'), KBTriple(rel='altered', sbj='omeprazole', obj='saliva'), KBTriple(rel='altered', sbj='propranolol', obj='mood'), KBTriple(rel='altered', sbj='acyclovir', obj='mood')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: caused
# number positive examples: 13953
# relation examples:
#  [KBTriple(rel='caused', sbj='methylprednisolone', obj='nausea'), KBTriple(rel='caused', sbj='losartan', obj='sudden_cardiac_death'), KBTriple(rel='caused', sbj='liraglutide', obj='constipation'), KBTriple(rel='caused', sbj='gentamicin', obj='infection'), KBTriple(rel='caused', sbj='technetium', obj='hepatomegaly'), KBTriple(rel='caused', sbj='fenofibrate', obj='colitis'), KBTriple(rel='caused', sbj='losartan', obj='necrosis'), KBTriple(rel='caused', sbj='denosumab', obj='osteosclerosis'), KBTriple(rel='caused', sbj='sodium', obj='pericarditis'), KBTriple(rel='caused', sbj='sodium', obj='starvation')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: changed
# number positive examples: 28
# relation examples:
#  [KBTriple(rel='changed', sbj='hydrochlorothiazide', obj='drug_level'), KBTriple(rel='changed', sbj='domperidone', obj='therapeutic_response'), KBTriple(rel='changed', sbj='clonazepam', obj='drug_level'), KBTriple(rel='changed', sbj='acyclovir', obj='therapeutic_response'), KBTriple(rel='changed', sbj='phenytoin', obj='drug_level'), KBTriple(rel='changed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='changed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='changed', sbj='imatinib', obj='therapeutic_response'), KBTriple(rel='changed', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='changed', sbj='sodium', obj='drug_level')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: decreased
# number positive examples: 1143
# relation examples:
#  [KBTriple(rel='decreased', sbj='propranolol', obj='oxygen_saturation'), KBTriple(rel='decreased', sbj='potassium', obj='therapeutic_response'), KBTriple(rel='decreased', sbj='sodium', obj='drug_level'), KBTriple(rel='decreased', sbj='irinotecan', obj='platelet_count'), KBTriple(rel='decreased', sbj='omeprazole', obj='serum_ferritin'), KBTriple(rel='decreased', sbj='potassium', obj='blood_phosphorus'), KBTriple(rel='decreased', sbj='potassium', obj='weight'), KBTriple(rel='decreased', sbj='domperidone', obj='body_temperature'), KBTriple(rel='decreased', sbj='potassium', obj='prothrombin_level'), KBTriple(rel='decreased', sbj='potassium', obj='blood_glucose')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: delayed
# number positive examples: 14
# relation examples:
#  [KBTriple(rel='delayed', sbj='montelukast', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='hydrochlorothiazide', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='sodium', obj='menstruation'), KBTriple(rel='delayed', sbj='metronidazole', obj='menstruation'), KBTriple(rel='delayed', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='delayed', sbj='levonorgestrel', obj='menstruation'), KBTriple(rel='delayed', sbj='potassium', obj='menstruation'), KBTriple(rel='delayed', sbj='methylprednisolone', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: discoloured
# number positive examples: 45
# relation examples:
#  [KBTriple(rel='discoloured', sbj='clarithromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='bicalutamide', obj='faeces'), KBTriple(rel='discoloured', sbj='mepolizumab', obj='sputum'), KBTriple(rel='discoloured', sbj='omeprazole', obj='faeces'), KBTriple(rel='discoloured', sbj='abatacept', obj='sputum'), KBTriple(rel='discoloured', sbj='clarithromycin', obj='sputum'), KBTriple(rel='discoloured', sbj='erythromycin', obj='faeces'), KBTriple(rel='discoloured', sbj='dopamine', obj='sputum'), KBTriple(rel='discoloured', sbj='piperacillin', obj='sputum'), KBTriple(rel='discoloured', sbj='methylprednisolone', obj='sputum')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: impaired
# number positive examples: 19
# relation examples:
#  [KBTriple(rel='impaired', sbj='clarithromycin', obj='judgement'), KBTriple(rel='impaired', sbj='hydrochlorothiazide', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='moxifloxacin', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='methylprednisolone', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='nifedipine', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='levonorgestrel', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='potassium', obj='glucose_tolerance'), KBTriple(rel='impaired', sbj='sodium', obj='judgement'), KBTriple(rel='impaired', sbj='methotrexate', obj='glucose_tolerance')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: increased
# number positive examples: 1194
# relation examples:
#  [KBTriple(rel='increased', sbj='prozac', obj='libido'), KBTriple(rel='increased', sbj='epirubicin', obj='heart_rate'), KBTriple(rel='increased', sbj='hydrochlorothiazide', obj='haemoglobin'), KBTriple(rel='increased', sbj='clonazepam', obj='neutrophil_count'), KBTriple(rel='increased', sbj='liraglutide', obj='lipase'), KBTriple(rel='increased', sbj='omeprazole', obj='ammonia'), KBTriple(rel='increased', sbj='propranolol', obj='eosinophil_count'), KBTriple(rel='increased', sbj='candesartan', obj='c-reactive_protein'), KBTriple(rel='increased', sbj='methotrexate', obj='transaminases'), KBTriple(rel='increased', sbj='desmopressin', obj='weight')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: infected
# number positive examples: 6
# relation examples:
#  [KBTriple(rel='infected', sbj='methylprednisolone', obj='dermatitis'), KBTriple(rel='infected', sbj='hydrochlorothiazide', obj='dermatitis'), KBTriple(rel='infected', sbj='methotrexate', obj='dermatitis'), KBTriple(rel='infected', sbj='amlodipine', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='dermatitis'), KBTriple(rel='infected', sbj='sodium', obj='blister')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: lowered
# number positive examples: 1
# relation examples:
#  [KBTriple(rel='lowered', sbj='clonazepam', obj='convulsive_threshold')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: prolonged
# number positive examples: 39
# relation examples:
#  [KBTriple(rel='prolonged', sbj='gentamicin', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='heparin', obj='immobilisation'), KBTriple(rel='prolonged', sbj='dopamine', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='piperacillin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='sodium', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='gentamicin', obj='prothrombin_time'), KBTriple(rel='prolonged', sbj='heparin', obj='coagulation_time'), KBTriple(rel='prolonged', sbj='potassium', obj='bleeding_time'), KBTriple(rel='prolonged', sbj='sodium', obj='therapeutic_response'), KBTriple(rel='prolonged', sbj='ketoconazole', obj='prothrombin_time')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: reduced
# number positive examples: 25
# relation examples:
#  [KBTriple(rel='reduced', sbj='propranolol', obj='visual_acuity'), KBTriple(rel='reduced', sbj='methotrexate', obj='visual_acuity'), KBTriple(rel='reduced', sbj='phenytoin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='hydrochlorothiazide', obj='fluid_intake'), KBTriple(rel='reduced', sbj='sodium', obj='fluid_intake'), KBTriple(rel='reduced', sbj='propranolol', obj='fluid_intake'), KBTriple(rel='reduced', sbj='moxifloxacin', obj='visual_acuity'), KBTriple(rel='reduced', sbj='raloxifene', obj='visual_acuity'), KBTriple(rel='reduced', sbj='sodium', obj='visual_acuity'), KBTriple(rel='reduced', sbj='latanoprost', obj='visual_acuity')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: ruptured
# number positive examples: 8
# relation examples:
#  [KBTriple(rel='ruptured', sbj='methotrexate', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='sodium', obj='ovarian_cyst'), KBTriple(rel='ruptured', sbj='methylprednisolone', obj='aneurysm'), KBTriple(rel='ruptured', sbj='methotrexate', obj='aneurysm'), KBTriple(rel='ruptured', sbj='potassium', obj='liver_carcinoma'), KBTriple(rel='ruptured', sbj='rosuvastatin', obj='aneurysm'), KBTriple(rel='ruptured', sbj='sodium', obj='aneurysm'), KBTriple(rel='ruptured', sbj='heparin', obj='aneurysm')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# #####################
# relation: shortened
# number positive examples: 41
# relation examples:
#  [KBTriple(rel='shortened', sbj='methylprednisolone', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='sodium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sirolimus', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='clonazepam', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='metronidazole', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='octreotide', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='potassium', obj='coagulation_time'), KBTriple(rel='shortened', sbj='sodium', obj='prothrombin_time'), KBTriple(rel='shortened', sbj='alendronate', obj='therapeutic_response'), KBTriple(rel='shortened', sbj='rosuvastatin', obj='therapeutic_response')]
# -----------------------
# number unrelated pairs: 2413
# unrelated examples:
#  [('dopamine', 'renal_artery_occlusion'), ('nifedipine', 'hiccups'), ('hypotension', 'frusemide'), ('phenytoin', 'diabetic_foot'), ('stress', 'desipramine'), ('discharge', 'methicillin'), ('enzyme_activity', 'calcium-magnesium'), ('bleomycin', 'resuscitation'), ('polyuria', 'enflurane'), ('alendronate', 'fasting')]
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# accelerated               0.000      0.000      0.000          0          0
# acquired                  0.000      0.000      0.000          9       2422
# aggravated                0.000      0.000      0.000        117       2530
# altered                   0.000      0.000      0.000         36       2449
# caused                    0.000      0.000      0.000      13953      16366
# changed                   0.000      0.000      0.000         28       2441
# decreased                 0.000      0.000      0.000       1143       3556
# delayed                   0.000      0.000      0.000         14       2427
# discoloured               0.000      0.000      0.000         45       2458
# impaired                  0.000      0.000      0.000         19       2432
# improved                  0.000      0.000      0.000          0          0
# increased                 0.000      0.000      0.000       1194       3607
# infected                  0.000      0.000      0.000          6       2419
# lowered                   0.000      0.000      0.000          1       2414
# prolonged                 0.000      0.000      0.000         39       2452
# reduced                   0.000      0.000      0.000         25       2438
# ruptured                  0.000      0.000      0.000          8       2421
# shortened                 0.000      0.000      0.000         41       2454
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.000      0.000      0.000      16678      55286
# 0.0
