# %%
import os
import random

from collections import Counter
from collections import defaultdict

import dist_sup_lib.rel_ext as rel_ext
import dist_sup_lib.utils as utils

from src.rel_extract_extend.experiment import get_new_relation_instances

from src.utils import read_json_examples
from src.utils import read_kb_triples
from src.utils import read_kb_triples_json

# %%
# Set all the random seeds for reproducibility. Only the
# system seed is relevant for this notebook.

utils.fix_random_seeds()

# %%
rel_ext_data_sents = os.path.join('data', 'featurized_sentences')
rel_ext_data_kb = os.path.join("data", "knowledge_base")

# %%
example_data = []

# %%
for index in range(1, 200):
    s_i = str(index)
    zeros = "0" * (4 - len(s_i))
    # Files updated constantly and the names changes by year
    # for files downloaded in 2021 file_naming has to be changed to
    # featurized_sents_pubmed21n
    tagged_sent_file = f"featurized_sents_pubmed20n{zeros + s_i}.json"
    file_path = os.path.join(rel_ext_data_sents, tagged_sent_file)
    example_data.extend(read_json_examples(file_path))

# %%
corpus = rel_ext.Corpus(example_data)

# %%
kb_triples = read_kb_triples_json(os.path.join(rel_ext_data_kb, "rel_drug_react_triple_occ_all.json"))

# %%
random.seed(100)
num_list = random.sample(range(0, len(kb_triples)), len(kb_triples))
split_n = int(len(kb_triples)/4) * 3

# kb_train_idxs = set(kb_triples[:split_n])
kb_eval_idxs = set(num_list[split_n:])

kb_train = []
kb_eval = []

for i, kb_triple in enumerate(kb_triples):
    if i in kb_eval_idxs:
        kb_eval.append(kb_triple)
    else:
        kb_train.append(kb_triple)
print(len(kb_train))
print(len(kb_eval))
# Out:
# 41298
# 13769

# %%
kb = rel_ext.KB(kb_train)

# %%
dataset = rel_ext.Dataset(corpus, kb)

# %%
splits = dataset.build_splits()

splits
# Out:
# {'tiny': Corpus with 4,007 examples; KB with 745 triples,
#  'train': Corpus with 669,482 examples; KB with 28,380 triples,
#  'dev': Corpus with 210,732 examples; KB with 12,173 triples,
#  'all': Corpus with 884,221 examples; KB with 41,298 triples}

# %% [markdown]
# ### Negative instances
#
# By joining the corpus to the KB, we can obtain abundant positive instances for each relation. But a classifier cannot be trained on positive instances alone. In order to apply the distant supervision paradigm, we will also need some negative instances — that is, entity pairs which do not belong to any known relation. If you like, you can think of these entity pairs as being assigned to a special relation called `NO_RELATION`. We can find plenty of such pairs by searching for examples in the corpus which contain two entities which do not belong to any relation in the KB.

# %%
dataset.find_unrelated_pairs()
# Out:
# {('dextromethorphan', 'poisoning'),
#  ('cardiac_output', 'diazepam'),
#  ('metronidazole', 'superinfection'),
#  ('surgery', 'lignocaine'),
#  ('obesity', 'beta-carotene'),
#  ('gammopathy', 'concomitant'),
#  ('injection', 'concomitant'),
#  ('phagocytosis', 'mycelium'),
#  ('brain_death', 'methotrexate'),
#  ('pain', 'ornidazole'),
#  ('dopamine', 'neurogenic_shock'),
#  ('arachnoid_cyst', 'submucosal'),
#  ('ear_infection', 'tetracycline'),
#  ('sodium', 'vitamin_b1'),
#  ('nortriptyline', 'paresis'),
#  ('endoscopy', 'nasal'),
#  ('vitamin_d', 'cardiac'),
#  ('renal_failure', 'urapidil'),
#  ('adverse_event', 'lovastatin'),
#  ('intranasal', 'q_fever'),
#  ('visual_analogue_scale', 'concomitant'),
#  ('blood_gases', 'alfentanil'),
#  ('propranolol', 'radioactive_iodine_therapy'),
#  ('portal_hypertension', 'prednisolone'),
#  ('angina_pectoris', 'diphenylhydantoin'),
#  ('glucose_tolerance', 'medium'),
#  ('hepatitis', 'corynebacterium'),
#  ('immunoglobulin', 'colon_cancer'),
#  ('magnetic_resonance_imaging', 'tamoxifen'),
#  ('polyhydramnios', 'potassium'),
#  ('roxatidine', 'ulcer'),
#  ('retinopathy', 'nasal'),
#  ('pain', 'sotalol'),
#  ('ventricular_hypertrophy', 'doxazosin'),
#  ('hexacetonide', 'granuloma'),
#  ('scleroderma', 'gallium'),
#  ('mithramycin', 'herpes_simplex'),
#  ('magnesium', 'thoracotomy'),
#  ('adams-stokes_syndrome', 'potassium'),
#  ('herpes_zoster', 'procaine'),
#  ('acidosis', 'vecuronium'),
#  ('vitamin_a', 'actinomycin'),
#  ('carboplatin', 'radiotherapy'),
#  ('perindopril', 'vasodilatation'),
#  ('enflurane', 'urine_output'),
#  ('penicillin', 'thrombosis'),
#  ('carcinogenicity', 'busulfan'),
#  ('somatostatin', 'intestinal_resection'),
#  ('pyrexia', 'reassortant'),
#  ('cardiac', 'syphilis'),
#  ('ramipril', 'elderly'),
#  ('hypoprothrombinaemia', 'phenylbutazone'),
#  ('imipenem', 'neutropenic_infection'),
#  ('injury', 'meperidine'),
#  ('meningitis', 'acetazolamide'),
#  ('accessory_spleen', 'nasal'),
#  ('ciprofibrate', 'metastasis'),
#  ('benzocaine', 'local_anaesthesia'),
#  ('familial_hypocalciuric_hypercalcaemia', 'magnesium'),
#  ('lyme_disease', 'belgium'),
#  ('carbon_dioxide', 'bifidobacterium'),
#  ('frusemide', 'dermatosis'),
#  ('radical_mastectomy', 'adriamycin'),
#  ('epinastine', 'hypersensitivity'),
#  ('infusion', 'valium'),
#  ('triamcinolone', 'tracheostomy'),
#  ('tonic_convulsion', 'concomitant'),
#  ('cell_death', 'selenium'),
#  ('investigation', 'vanadium'),
#  ('necrosis', 'roxithromycin'),
#  ('urine_osmolarity', 'globulin'),
#  ('stomatitis', 'lidocaine'),
#  ('colitis', 'potassium'),
#  ('infant', 'ranitidine'),
#  ('nandrolone', 'rheumatoid_arthritis'),
#  ('prednisolone', 'physiotherapy'),
#  ('furosemide', 'autopsy'),
#  ('magnesium', 'nephritis'),
#  ('ophthalmoplegia', 'cardiac'),
#  ('azotaemia', 'thromboglobulin'),
#  ('somatostatin', 'alcoholism'),
#  ('miosis', 'prazosin'),
#  ('carnitine', 'ammonium'),
#  ('furosemide', 'hypercalciuria'),
#  ('acne', 'metronidazole'),
#  ('furosemide', 'hyperoxaluria'),
#  ('pregnancy', 'diphenylhydantoin'),
#  ('thiotepa', 'endoscopy'),
#  ('enalapril', 'fistula'),
#  ('lymphoedema', 'menopausal'),
#  ('corynebacterium', 'prophylaxis'),
#  ('prophylaxis', 'octreotide'),
#  ('ulcer', 'prazepam'),
#  ('endocrine', 'chronic_respiratory_failure'),
#  ('biopsy', 'indium'),
#  ('oxygen_saturation', 'cardiac'),
#  ('headache', 'amitriptyline'),
#  ('platelet_aggregation', 'ketotifen'),
#  ('cortisol', 'propranolol'),
#  ('histology', 'premium'),
#  ('tacrine', 'agitation'),
#  ('haloperidol', 'ejaculation'),
#  ('enalapril', 'bradycardia'),
#  ('fluconazole', 'investigation'),
#  ('prostatectomy', 'double-blind'),
#  ('5-fluorouracil', 'chemotherapy'),
#  ('gastric_ph', 'polypeptide'),
#  ('vinblastine', 'immobile'),
#  ('nasal', 'type_i_hypersensitivity'),
#  ('oxymetholone', 'investigation'),
#  ('rhodococcus_infection', 'concomitant'),
#  ('methylprednisolone', 'fluoride'),
#  ('procaine', 'infection'),
#  ('injection', 'neostigmine'),
#  ('diabetic_foot', 'ciprofloxacin'),
#  ('cardiac', 'growth'),
#  ('hypotension', 'domperidone'),
#  ('mobility', 'histidine'),
#  ('synovitis', 'aceclofenac'),
#  ('basal', 'jaundice'),
#  ('captopril', 'atrophy'),
#  ('cimetidine', 'infarction'),
#  ('minoxidil', 'coronary_artery_disease'),
#  ('heart_valve_replacement', 'cardiac'),
#  ('chronic_hepatitis_c', 'cyclosporin'),
#  ('ac', 'sputum'),
#  ('cardiac_death', 'haloperidol'),
#  ('growth', 'cisplatin'),
#  ('netilmicin', 'neuromuscular_blockade'),
#  ('medium', 'erysipelas'),
#  ('gouty_arthritis', 'piroxicam'),
#  ('gastroenteritis', 'quinolone'),
#  ('lymphocytic_infiltration', 'endocrine'),
#  ('bulimia_nervosa', 'fluoxetine'),
#  ('dystonia', 'remoxipride'),
#  ('corynebacterium', 'coagulopathy'),
#  ('increased_steroid_activity', 'prednisolone'),
#  ('immobile', 'nasal'),
#  ('inadequate_analgesia', 'isoflurane'),
#  ('globulin', 'phagocytosis'),
#  ('prophylaxis', 'atenolol'),
#  ('magnesium', 'hypertrophy'),
#  ('lymphoma', 'epirubicin'),
#  ('adriamycin', 'albuminuria'),
#  ('surfactant', 'agitation'),
#  ('procaine', 'lymphoma'),
#  ('droperidol', 'vertigo'),
#  ('prednisolone', 'actinomycosis'),
#  ('peptide', 'bacterial_infection'),
#  ('transaminases', 'concomitant'),
#  ('primus', 'osteoarthropathy'),
#  ('tripeptide', 'osteogenesis_imperfecta'),
#  ('basal', 'immunodeficiency'),
#  ('practolol', 'arrhythmia'),
#  ('factor_vii_deficiency', 'peptide'),
#  ('chemotherapy', 'carmustine'),
#  ('dopamine', 'arterial_injury'),
#  ('ejection_fraction', 'frusemide'),
#  ('migraine', 'sal'),
#  ('pseudoporphyria', 'dapsone'),
#  ('adhesion', 'cisplatin'),
#  ('cytarabine', 'bone_marrow_transplant'),
#  ('endocrine', 'starvation'),
#  ('hypotension', 'concomitant'),
#  ('pleural_adhesion', 'tetracycline'),
#  ('right_atrial_pressure', 'cardiac'),
#  ('vasodilatation', 'doxazosin'),
#  ('meperidine', 'inguinal_hernia_repair'),
#  ('nifedipine', 'renal_colic'),
#  ('hyperaldosteronism', 'endocrine'),
#  ('mastectomy', 'doxorubicin'),
#  ('histidine', 'hyperplasia'),
#  ('immunoglobulin', 'dependence'),
#  ('lipase', 'kanamycin'),
#  ('proteinuria', 'phenylbutazone'),
#  ('tenoxicam', 'elderly'),
#  ('urine_output', 'bumetanide'),
#  ('cholesterol', 'disseminated_intravascular_coagulation'),
#  ('energy', 'meperidine'),
#  ('polypeptide', 'secondary_immunodeficiency'),
#  ('effusion', 'trimethoprim'),
#  ('fat_tissue', 'medium'),
#  ('basal', 'folliculitis'),
#  ('pustular_psoriasis', 'acitretin'),
#  ('verapamil', 'cerebral_artery_occlusion'),
#  ('oliguria', 'immunoglobulin'),
#  ('flucloxacillin', 'condition'),
#  ('pain', 'etidronate'),
#  ('doxycycline', 'q_fever'),
#  ('cardiac_output', 'rubidium'),
#  ('dissociation', 'ketotifen'),
#  ('ventricular_hypertrophy', 'urapidil'),
#  ('ovarium', 'ascites'),
#  ('carcinogenicity', 'ciprofibrate'),
#  ('phenformin', 'cutaneous_vasculitis'),
#  ('gastrointestinal_haemorrhage', 'tolazoline'),
#  ('acetazolamide', 'growth_retardation'),
#  ('ataxia', 'magnesium'),
#  ('cardiac', 'neurofibromatosis'),
#  ('amoxicillin', 'laparoscopy'),
#  ('renal_failure', 'frusemide'),
#  ('double-blind', 'back_pain'),
#  ('radium', 'rhabdomyosarcoma'),
#  ('minoxidil', 'lichen_sclerosus'),
#  ('trimethoprim', 'thyroxine'),
#  ('papaverine', 'oxygen_consumption'),
#  ('medium', 'cardiopulmonary_bypass'),
#  ('cortisol', 'simvastatin'),
#  ('polypeptide', 'varicella'),
#  ('doxycycline', 'culture_negative'),
#  ('albuterol', 'elderly'),
#  ('cholesterol', 'performance_status'),
#  ('transplant', 'antazoline'),
#  ('abscess_rupture', 'cardiac'),
#  ('alkalosis', 'pancuronium'),
#  ('asthma', 'dopamine'),
#  ('alpha_1_globulin', 'globulin'),
#  ('double-blind', 'normal_tension_glaucoma'),
#  ('sulindac', 'spondylitis'),
#  ('hypothyroidism', 'thallium'),
#  ('praziquantel', 'injection'),
#  ('methotrexate', 'investigation'),
#  ('double-blind', 'histology'),
#  ('corynebacterium', 'granuloma'),
#  ('pac', 'coronary_artery_bypass'),
#  ('magnesium', 'heart_transplant'),
#  ('left_ventricular_failure', 'verapamil'),
#  ('vasopressin', 'cell_death'),
#  ('methylprednisolone', 'microembolism'),
#  ('nystatin', 'infusion'),
#  ('tendon_rupture', 'calcium'),
#  ('rifamycin', 'c-reactive_protein'),
#  ('ticarcillin', 'platelet_aggregation'),
#  ('infarction', 'bupivacaine'),
#  ('lymphoma', 'barium'),
#  ('oxytocin', 'haemorrhage'),
#  ('nifedipine', 'diastolic_dysfunction'),
#  ('otorrhoea', 'aluminium'),
#  ('cholesterol', 'hypomagnesaemia'),
#  ('mechanical_ventilation', 'basal'),
#  ('thrombectomy', 'concomitant'),
#  ('bupivacaine', 'acute_abdomen'),
#  ('arthritis', 'imipenem'),
#  ('cardiac', 'porcelain_gallbladder'),
#  ('selenium', 'neurodegenerative_disorder'),
#  ('echocardiogram', 'technetium'),
#  ('pancuronium', 'tachycardia'),
#  ('mucosal_erosion', 'uracil'),
#  ('double-blind', 'catatonia'),
#  ('modafinil', 'physiotherapy'),
#  ('actinomycin', 'enzyme_activity'),
#  ('liver_carcinoma', 'cardiac'),
#  ('concomitant', 'pneumoperitoneum'),
#  ('mycin', 'hepatitis'),
#  ('acenocoumarol', 'embolism'),
#  ('flushing', 'helium'),
#  ('concomitant', 'carnitine'),
#  ('flatulence', 'hydrochlorothiazide'),
#  ('calcium', 'vitamin_b1'),
#  ('dibucaine', 'acidosis'),
#  ('peptide', 'premenstrual_syndrome'),
#  ('extravasation', 'nisoldipine'),
#  ('flurbiprofen', 'nephritis'),
#  ('elderly', 'pregnenolone'),
#  ('prazosin', 'leukopenia'),
#  ('uterine_prolapse', 'cholesterol'),
#  ('bed_rest', 'labetalol'),
#  ('perforation', 'oxazepam'),
#  ('reserpine', 'glucocorticoids'),
#  ('acute_myocardial_infarction', 'prazosin'),
#  ('spinal_fusion', 'double-blind'),
#  ('venous_occlusion', 'captopril'),
#  ('renal_hypertension', 'felodipine'),
#  ('brain_abscess', 'clostridium'),
#  ('growth', 'triptorelin'),
#  ('tac', 'meningocele'),
#  ('nasal_congestion', 'intranasal'),
#  ('perforation', 'tobramycin'),
#  ('isoflurane', 'renal_failure'),
#  ('discharge', 'enoxaparin'),
#  ('blood_gases', 'diazepam'),
#  ('basal', 'carcinoid_tumour'),
#  ('penicillin', 'relapsing_fever'),
#  ('concomitant', 'chest_x-ray'),
#  ('phagocytosis', 'diazepam'),
#  ('chronic_myeloid_leukaemia', 'reserpine'),
#  ('diabetic_retinopathy', 'medium'),
#  ('isoflurane', 'hypothermia'),
#  ('histidine', 'malabsorption'),
#  ('alveolitis', 'lidocaine'),
#  ('enzyme_inhibition', 'furosemide'),
#  ('felodipine', 'echocardiogram'),
#  ('growth', 'calprotectin'),
#  ('intranasal', 'acne'),
#  ('hypoglycaemia', 'immunoglobulin'),
#  ('retinopathy', 'ganciclovir'),
#  ('concomitant', 'partial_seizures'),
#  ('l-dopa', 'hypercapnia'),
#  ('electroencephalogram', 'papaverine'),
#  ('benazepril', 'exercise_tolerance'),
#  ('infarction', 'neomycin'),
#  ('clostridium', 'rabies'),
#  ('betaxolol', 'systolic_dysfunction'),
#  ('disofenin', 'accessory_spleen'),
#  ('pyelonephritis', 'clostridium'),
#  ('fosinopril', 'dissociation'),
#  ('hepatocellular_carcinoma', 'mitomycin'),
#  ('concomitant', 'vitamin_d'),
#  ('cervicitis', 'immunoglobulin'),
#  ('macrophages', 'submucosal'),
#  ('cholera', 'cesium'),
#  ('bone_pain', 'cardiac'),
#  ('malnutrition', 'cholesterol'),
#  ('drug_resistance', 'thiazide'),
#  ('barium', 'appendiceal_abscess'),
#  ('submucosal', 'perforation'),
#  ('cardiac', 'bone_pain'),
#  ('anorexia_nervosa', 'tamoxifen'),
#  ('ventricular_fibrillation', 'metoprolol'),
#  ('labetalol', 'lipids'),
#  ('cardiac', 'compartment_syndrome'),
#  ('chemotherapy', 'sodium'),
#  ('tension', 'metronidazole'),
#  ('methylprednisolone', 'status_asthmaticus'),
#  ('globulin', 'macrophages'),
#  ('renal_failure', 'phencyclidine'),
#  ('cyclosporin', 'pulmonary_eosinophilia'),
#  ('atenolol', 'mean_arterial_pressure'),
#  ('pulmonary_resection', 'cardiac'),
#  ('tardive_dyskinesia', 'concomitant'),
#  ('csf_protein', 'haloperidol'),
#  ('pneumonia', 'chlorpropamide'),
#  ('amikacin', 'pyelonephritis'),
#  ('fasting', 'lansoprazole'),
#  ('penicillin', 'pyoderma'),
#  ('diabetic_neuropathy', 'nortriptyline'),
#  ('cardiopulmonary_bypass', 'ammonium'),
#  ('fall', 'roxatidine'),
#  ('vitamin_d', 'ciprofibrate'),
#  ('prophylaxis', 'cocaine'),
#  ('gentamycin', 'hepatorenal_syndrome'),
#  ('surgery', 'praziquantel'),
#  ('spondylitis', 'lithium'),
#  ('cisplatin', 'nausea'),
#  ('haemodialysis', 'nisoldipine'),
#  ('medium', 'colposcopy'),
#  ('vancomycin', 'sexually_transmitted_disease'),
#  ('histidine', 'inflammatory_bowel_disease'),
#  ('fibrinolysis', 'levonorgestrel'),
#  ('cardiac', 'adenocarcinoma'),
#  ('peptide', 'hyperadrenocorticism'),
#  ('mepacrine', 'platelet_aggregation'),
#  ('concomitant', 'salmonellosis'),
#  ('glossoptosis', 'cardiac'),
#  ('hepatic_encephalopathy', 'neomycin'),
#  ('acupuncture', 'amitriptyline'),
#  ('biopsy', 'pancuronium'),
#  ('poisoning', 'atenolol'),
#  ('amiodarone', 'epinephrine'),
#  ('arterial_spasm', 'magnesium'),
#  ('ciprofloxacin', 'typhoid_fever'),
#  ('neomycin', 'hypotension'),
#  ('endocrine', 'haemoglobinopathy'),
#  ('gout', 'tenoxicam'),
#  ('medium', 'autopsy'),
#  ('tinea_pedis', 'ketoconazole'),
#  ('pneumonia', 'tolazoline'),
#  ('cryoglobulin', 'visceral_leishmaniasis'),
#  ('carboplatin', 'nephritis'),
#  ('performance_status', 'mitomycin'),
#  ('nimodipine', 'dizziness'),
#  ('basal', 'psoriasis'),
#  ('labetalol', 'plastic_surgery'),
#  ('haemorrhage', 'felodipine'),
#  ('obesity', 'atracurium'),
#  ('glycopyrronium', 'caesarean_section'),
#  ('obesity', 'indapamide'),
#  ('adjuvant_therapy', 'fosfomycin'),
#  ('acetazolamide', 'visual_acuity'),
#  ('cisplatin', 'obstruction'),
#  ('oral_surgery', 'temazepam'),
#  ('aspartate_aminotransferase', 'polypeptide'),
#  ('q_fever', 'globulin'),
#  ('obesity', 'sal'),
#  ('dependence', 'radium'),
#  ('erythromycin', 'growth'),
#  ('swelling', 'enalapril'),
#  ('primus', 'arthritis'),
#  ('dopamine', 'parenteral_nutrition'),
#  ('glioblastoma', 'adriamycin'),
#  ('heparin', 'venous_oxygen_saturation'),
#  ('nifedipine', 'hyperaldosteronism'),
#  ('enflurane', 'general_anaesthesia'),
#  ('gentamicin', 'renal_artery_occlusion'),
#  ('neurotoxicity', 'modafinil'),
#  ('carotene', 'elderly'),
#  ('histology', 'heparin'),
#  ('sodium', 'lung_adenocarcinoma'),
#  ('basal', 'breath_holding'),
#  ('neuroblastoma', 'epirubicin'),
#  ('laryngitis', 'ac'),
#  ('concomitant', 'aortic_dissection'),
#  ('energy', 'dibucaine'),
#  ('phenytoin', 'dehydroepiandrosterone'),
#  ('propranolol', 'vital_capacity'),
#  ('fall', 'erythromycin'),
#  ('oxytocin', 'forceps_delivery'),
#  ('cetylpyridinium', 'tuberculosis'),
#  ('streptomycin', 'brucellosis'),
#  ('adrenal_insufficiency', 'diphenylhydantoin'),
#  ('arterial_stenosis', 'cardiac'),
#  ('polyp', 'nostril'),
#  ('cardiac', 'judgement'),
#  ('floxuridine', 'hepatitis'),
#  ('verapamil', 'macrophages'),
#  ('thyroglobulin', 'endocrine'),
#  ('pancuronium', 'asphyxia'),
#  ('imipramine', 'restlessness'),
#  ('hydronephrosis', 'cesium'),
#  ('buspirone', 'shock'),
#  ('liver_abscess', 'concomitant'),
#  ('sodium', 'renal_dysplasia'),
#  ('pharyngitis', 'flucloxacillin'),
#  ('medium', 'gastric_cancer'),
#  ('lymphocytic_leukaemia', 'verapamil'),
#  ('transplant', 'amantadine'),
#  ('basal', 'accident'),
#  ('basal', 'panniculitis'),
#  ('barium', 'lipids'),
#  ('tetracycline', 'bone_densitometry'),
#  ('congenital_hypothyroidism', 'immunoglobulin'),
#  ('cytoxan', 'lymphocytic_lymphoma'),
#  ('pancreatic_pseudocyst', 'polypeptide'),
#  ('aluminium', 'environmental_exposure'),
#  ('dissociation', 'cyclosporin'),
#  ('basal', 'colectomy'),
#  ('methicillin', 'vitamin_b12'),
#  ('actinomycin', 'pyruvate_kinase'),
#  ('enoxaparin', 'injection'),
#  ('reserpine', 'vasodilatation'),
#  ('vanadium', 'mass'),
#  ('acetazolamide', 'haematocrit'),
#  ('pulmonary_contusion', 'bupivacaine'),
#  ('medium', 'mastitis'),
#  ('renal_artery_stenosis', 'enalaprilat'),
#  ('hyperprolactinaemia', 'medium'),
#  ('prostatectomy', 'somatostatin'),
#  ('defibrotide', 'arterial_thrombosis'),
#  ('uracil', 'hyperthermia'),
#  ('echocardiogram', 'bleomycin'),
#  ('tetracycline', 'thyroidectomy'),
#  ('double-blind', 'chorea'),
#  ('hyperplasia', 'ibuprofen'),
#  ('immunoglobulins', 'cimetidine'),
#  ('imipenem', 'alanine_aminotransferase'),
#  ('menopausal', 'lymphocytic_hypophysitis'),
#  ('headache', 'medium'),
#  ('dapsone', 'iridocyclitis'),
#  ('concomitant', 'rectal_cancer'),
#  ('titanium', 'perforation'),
#  ('mesothelioma', 'methotrexate'),
#  ('somatostatin', 'jaundice'),
#  ('gastroenteritis', 'submucosal'),
#  ('idoxuridine', 'herpes_zoster'),
#  ('monosodium', 'headache'),
#  ('cardiac', 'petechiae'),
#  ('dopamine', 'lipodystrophy'),
#  ('transferrin', 'carotene'),
#  ('pancuronium', 'atrophy'),
#  ('meconium', 'concomitant'),
#  ('saliva', 'pyridostigmine'),
#  ('portal_hypertension', 'terlipressin'),
#  ('cardiopulmonary_bypass', 'globulin'),
#  ('electrocardiogram', 'diltiazem'),
#  ('desmopressin', 'telangiectasia'),
#  ('medium', 'schistosomiasis'),
#  ('diphenylhydantoin', 'hepatic_failure'),
#  ('quinolone', 'headache'),
#  ('acute_phase_reaction', 'instant'),
#  ('sufentanil', 'bradypnoea'),
#  ('liver_injury', 'polypeptide'),
#  ('heparin', 'metastasis'),
#  ('alanine_aminotransferase', 'desflurane'),
#  ('methotrexate', 'squamous_cell_carcinoma'),
#  ('immunoglobulins', 'imipramine'),
#  ('prophylaxis', 'prednisolone'),
#  ('carbenicillin', 'indifference'),
#  ('renal_artery_stenosis', 'gentamicin'),
#  ('atrophy', 'dapsone'),
#  ('cocaine', 'essential_hypertension'),
#  ('anticoagulant_therapy', 'diclofenac'),
#  ('infarction', 'gallopamil'),
#  ('glomerular_filtration_rate', 'lacidipine'),
#  ('renal_failure', 'clodronate'),
#  ('neurosurgery', 'rev'),
#  ('fluid_retention', 'medium'),
#  ('somatostatin', 'immunodeficiency'),
#  ('neuroblastoma', 'barium'),
#  ('basal', 'blood_copper'),
#  ('gramicidin', 'neuritis'),
#  ('infant', 'phenytoin'),
#  ('diazepam', 'respiratory_acidosis'),
#  ('inflammation', 'surfactant'),
#  ('lidocaine', 'vascular_occlusion'),
#  ('venous_pressure', 'diazepam'),
#  ('enflurane', 'apnoea'),
#  ('depression', 'polypeptide'),
#  ('keratitis', 'belgium'),
#  ('methyldopa', 'mutagenic_effect'),
#  ('metformin', 'fall'),
#  ('haemolytic_anaemia', 'cardiac'),
#  ('cardiac', 'cryptococcosis'),
#  ('fibrosis', 'thallium'),
#  ('belgium', 'mitral_valve_replacement'),
#  ('cardiac', 'libido'),
#  ('oxygen_consumption', 'mitomycin'),
#  ('proguanil', 'saliva'),
#  ('molsidomine', 'angioplasty'),
#  ('thyroid_hormones', 'propylthiouracil'),
#  ('bupivacaine', 'peritonitis'),
#  ('peptic_ulcer', 'basal'),
#  ('coagulopathy', 'concomitant'),
#  ('anticipatory_anxiety', 'sodium'),
#  ('pregnancy', 'monosodium'),
#  ('memory_impairment', 'vasopressin'),
#  ('buserelin', 'delivery'),
#  ('fluoxetine', 'weight_control'),
#  ('nac', 'detoxification'),
#  ('cardiac', 'cardiac_dysfunction'),
#  ('imipramine', 'electroencephalogram'),
#  ('cholestasis', 'cyclosporin'),
#  ('transurethral_prostatectomy', 'lignocaine'),
#  ('essential_hypertension', 'betaxolol'),
#  ('ischaemic_stroke', 'thallium'),
#  ('acyclovir', 'infusion'),
#  ('crush_injury', 'sal'),
#  ('nasal', 'blood_gases'),
#  ('oxyphenbutazone', 'osteotomy'),
#  ('benzocaine', 'endoscopy'),
#  ('elderly', 'enflurane'),
#  ('submucosal', 'intestinal_metaplasia'),
#  ('heparin', 'encephalopathy'),
#  ('endocrine', 'anencephaly'),
#  ('basal', 'mitral_valve_prolapse'),
#  ('belgium', 'atopy'),
#  ('sodium', 'hyperglycaemia'),
#  ('instant', 'stenosis'),
#  ('clenbuterol', 'energy'),
#  ('poisoning', 'cocaine'),
#  ('suxamethonium', 'transfusion'),
#  ('thallium', 'infusion'),
#  ('roxatidine', 'duodenal_ulcer'),
#  ('verapamil', 'atrial_enlargement'),
#  ('tetracycline', 'wound'),
#  ('ciprofloxacin', 'infusion'),
#  ('ac', 'chronic_tonsillitis'),
#  ('muscle_mass', 'acetonide'),
#  ('aortic_valve_replacement', 'ciprofloxacin'),
#  ('thyroid_adenoma', 'globulin'),
#  ('peritoneal_dialysis', 'itraconazole'),
#  ('atracurium', 'hysterectomy'),
#  ('immunoglobulin', 'anaphylactic_shock'),
#  ('bronchitis', 'medium'),
#  ('gallium', 'sarcoma'),
#  ('somatostatin', 'myoclonus'),
#  ('ketoconazole', 'mass'),
#  ('weight', 'mebendazole'),
#  ('prophylaxis', 'sibelium'),
#  ('infection', 'surfactant'),
#  ('phagocytosis', 'netilmicin'),
#  ('physostigmine', 'blood_pressure'),
#  ('concomitant', 'hypoaldosteronism'),
#  ('phaeochromocytoma', 'endocrine'),
#  ('body_temperature', 'medium'),
#  ('alprenolol', 'pertussis'),
#  ('indium', 'angina_pectoris'),
#  ('inflammation', 'benzylpenicillin'),
#  ('peptide', 'tuberculosis'),
#  ('investigation', 'carbetocin'),
#  ('intestinal_resection', 'medium'),
#  ('vasopressin', 'blood_gases'),
#  ('l-dopa', 'hyperoxia'),
#  ('cardiac', 'congestive_cardiomyopathy'),
#  ('diazepam', 'drug_abuse'),
#  ('muscle_mass', 'bisoprolol'),
#  ('ventricular_extrasystoles', 'enalapril'),
#  ('oesophageal_rupture', 'submucosal'),
#  ('hepatic_failure', 'aluminium'),
#  ('csf_pressure', 'basal'),
#  ('xylocaine', 'necrosis'),
#  ('surfactant', 'parenteral_nutrition'),
#  ('dermatitis', 'papaverine'),
#  ('pulmonary_fibrosis', 'dactinomycin'),
#  ('norfloxacin', 'liver_injury'),
#  ('lordosis', 'reserpine'),
#  ('prostatitis', 'clostridium'),
#  ('nasal', 'retinitis_pigmentosa'),
#  ('barium', 'tuberculosis'),
#  ('aneurysm', 'actinomycin'),
#  ('edrophonium', 'hyperthyroidism'),
#  ('cimetidine', 'endotracheal_intubation'),
#  ('sumatriptan', 'abortion'),
#  ('intracranial_pressure', 'suxamethonium'),
#  ('verapamil', 'glomerulosclerosis'),
#  ('carotene', 'obesity'),
#  ('enzyme_activity', 'rifamycin'),
#  ('investigation', 'bezafibrate'),
#  ('endocrine', 'rectal_prolapse'),
#  ('coronary_artery_surgery', 'nasal'),
#  ('indium', 'ulcer'),
#  ('cholecystectomy', 'meperidine'),
#  ('indifference', 'quinolone'),
#  ('potassium', 'gonorrhoea'),
#  ('chlorothiazide', 'overdose'),
#  ('anoxia', 'kanamycin'),
#  ('dehydroepiandrosterone', 'surfactant'),
#  ('gastric_ph', 'octreotide'),
#  ('amiodarone', 'mitral_valve_prolapse'),
#  ('lentigo', '5-fluorouracil'),
#  ('tetracycline', 'diphtheria'),
#  ('basal', 'progressive_supranuclear_palsy'),
#  ('nystatin', 'bacterial_infection'),
#  ('l-dopa', 'affective_disorder'),
#  ('calcium', 'disease_progression'),
#  ('somatostatin', 'epinephrine'),
#  ('natamycin', 'surgery'),
#  ('bupivacaine', 'hysterectomy'),
#  ('mass', 'tamoxifen'),
#  ('mass', 'chromium'),
#  ('drug_detoxification', 'sodium'),
#  ('peptide', 'pneumococcal_infection'),
#  ('disodium', 'sputum'),
#  ('diazepam', 'injection'),
#  ('enflurane', 'extracorporeal_circulation'),
#  ('practolol', 'acidosis'),
#  ('clostridium', 'gestational_diabetes'),
#  ('calcium', 'teratoma'),
#  ('5-fluorouracil', 'synovectomy'),
#  ('cocaine', 'major_depression'),
#  ('isoflurane', 'angina_pectoris'),
#  ('technetium', 'cyst'),
#  ('infection', 'benzylpenicillin'),
#  ('osteitis', 'polypeptide'),
#  ('ischaemia', 'bezafibrate'),
#  ('injection', 'physostigmine'),
#  ('keratitis', 'ac'),
#  ('cardiac_dysfunction', 'potassium'),
#  ('infarction', 'enflurane'),
#  ('herpes_simplex', 'concomitant'),
#  ('chemotherapy', 'lithium'),
#  ('calcium', 'renal_dysplasia'),
#  ('lithium', 'acute_respiratory_failure'),
#  ('diltiazem', 'enzyme_activity'),
#  ('carotid_sinus_syndrome', 'amiodarone'),
#  ('macular_degeneration', 'concomitant'),
#  ('asthma', 'pred'),
#  ('squamous_cell_carcinoma', 'ac'),
#  ('nisoldipine', 'headache'),
#  ('surfactant', 'blood_gases'),
#  ('glucocorticoids', 'ampicillin'),
#  ('pertussis', 'surfactant'),
#  ('tamoxifen', 'osteopenia'),
#  ('investigation', 'clomipramine'),
#  ('adjuvant_therapy', 'domperidone'),
#  ('chronic_disease', 'cholesterol'),
#  ('dependence', 'ipratropium'),
#  ('methylprednisolone', 'vitrectomy'),
#  ('myocardial_ischaemia', 'bupivacaine'),
#  ('propanolol', 'injection'),
#  ('dipotassium', 'blood_alcohol'),
#  ('wound', 'rifamycin'),
#  ('granuloma', 'vancomycin'),
#  ('endocrine', 'iron_overload'),
#  ('isoflurane', 'blood_glucose'),
#  ('ventricular_septal_defect', 'nifedipine'),
#  ('encephalitis', 'l-dopa'),
#  ('sodium', 'sedation'),
#  ('atenolol', 'phobia'),
#  ('dysphoria', 'concomitant'),
#  ('acetazolamide', 'dissociation'),
#  ('magnesium', 'anxiety'),
#  ('venous_thrombosis', 'phenformin'),
#  ('benzylpenicillin', 'wound'),
#  ('pancreatic_carcinoma', 'polypeptide'),
#  ('fraxiparin', 'injection'),
#  ('xanthelasma', 'cholesterol'),
#  ('starvation', 'reserpine'),
#  ('lipids', 'oxytetracycline'),
#  ('tracheostomy', 'concomitant'),
#  ('arthritis', 'beta-carotene'),
#  ('domperidone', 'diabetic_neuropathy'),
#  ('laryngoscopy', 'acebutolol'),
#  ('rickets', 'hydrochlorothiazide'),
#  ('hypocholesterolaemia', 'cholesterol'),
#  ('somatostatin', 'psoriasis'),
#  ('diclofenac', 'metaplasia'),
#  ('dopamine', 'microalbuminuria'),
#  ('roxithromycin', 'infection'),
#  ('mithramycin', 'cardiac_arrest'),
#  ('ofloxacin', 'mass'),
#  ('infection', 'papaverine'),
#  ('ovarian_hyperstimulation_syndrome', 'basal'),
#  ('captopril', 'thirst'),
#  ('heparin', 'arrhythmia'),
#  ('energy', 'azithromycin'),
#  ('nasal', 'lymphoma'),
#  ('submucosal', 'fatigue'),
#  ('acquired_immunodeficiency_syndrome', 'cholesterol'),
#  ('arthritis', 'benoxaprofen'),
#  ('concomitant', 'pneumothorax'),
#  ('trimethoprim', 'thrombocytopenia'),
#  ('nasal', 'immunisation'),
#  ('cholesterol', 'blood_lead'),
#  ('histology', 'streptomycin'),
#  ('tremor', 'intranasal'),
#  ('arterial_occlusive_disease', 'double-blind'),
#  ('vital_capacity', 'timolol'),
#  ('celiprolol', 'blood_viscosity'),
#  ('phlebitis', 'menogaril'),
#  ('calcium', 'myofascitis'),
#  ('overweight', 'endocrine'),
#  ('discharge', 'peptide'),
#  ('streptomycin', 'respiratory_paralysis'),
#  ('amoxycillin', 'neurosyphilis'),
#  ('clostridium', 'energy'),
#  ('endocrine', 'discharge'),
#  ('amikacin', 'sinusitis'),
#  ('vasopressin', 'infection'),
#  ('immunoglobulin', 'megaloblasts'),
#  ('end-tidal_co2', 'enflurane'),
#  ('infusion', 'omeprazole'),
#  ('cardiac_index', 'intranasal'),
#  ('ampicillin', 'urticaria'),
#  ('surfactant', 'lipase'),
#  ('pancreatitis', 'globulin'),
#  ('cholera', 'intranasal'),
#  ('basal', 'organic_brain_syndrome'),
#  ('aortic_occlusion', 'pancuronium'),
#  ('squamous_cell_carcinoma', 'mitoxantrone'),
#  ('piroxicam', 'delivery'),
#  ('fluorouracil', 'colorectal_adenocarcinoma'),
#  ('systemic_lupus_erythematosus', 'practolol'),
#  ('erythromycin', 'oestradiol'),
#  ('progesterone', 'buspirone'),
#  ('menopause', 'basal'),
#  ('psychotherapy', 'diazepam'),
#  ('amoxycillin', 'sputum'),
#  ('secretin', 'mobility'),
#  ('frusemide', 'ototoxicity'),
#  ('oxygen_saturation', 'intranasal'),
#  ('concomitant', 'biliary_cirrhosis'),
#  ('dehydroepiandrosterone', 'papaverine'),
#  ('dysplasia', 'ranitidine'),
#  ('nasal', 'basophilia'),
#  ('sedation', 'sodium'),
#  ('somatostatin', 'colectomy'),
#  ('basal_cell_carcinoma', 'endocrine'),
#  ('gliosis', 'basal'),
#  ('renal_cell_carcinoma', 'floxuridine'),
#  ('food_allergy', 'nedocromil'),
#  ('captopril', 'disease_progression'),
#  ('reperfusion_injury', 'buflomedil'),
#  ('parotitis', 'doxycycline'),
#  ('sematilide', 'infarction'),
#  ('double-blind', 'urticaria'),
#  ('double-blind', 'gynaecomastia'),
#  ('nadolol', 'ammonia'),
#  ('cardiac', 'arteriogram'),
#  ('lincomycin', 'malaria'),
#  ('anaphylactoid_reaction', 'medium'),
#  ('concomitant', 'gastric_ulcer'),
#  ('immunodeficiency', 'memantine'),
#  ('appendicitis', 'metronidazole'),
#  ('concomitant', 'psychotherapy'),
#  ('stenosis', 'ramipril'),
#  ('double-blind', 'left_ventricular_hypertrophy'),
#  ('cocaine', 'intensive_care'),
#  ('hair_transplant', 'minoxidil'),
#  ('flunitrazepam', 'general_anaesthesia'),
#  ('meningitis', 'fluorouracil'),
#  ('asphyxia', 'surfactant'),
#  ('proteinuria', 'gamma-globulin'),
#  ('bacterial_vaginosis', 'clostridium'),
#  ('amnesia', 'propranolol'),
#  ('anxiety_disorder', 'cardiac'),
#  ('chorea', 'pancuronium'),
#  ('cystitis', 'norfloxacin'),
#  ('imipenem', 'neutrophil_count'),
#  ('polypeptide', 'peritoneal_dialysis'),
#  ('clomifene', 'anovulatory_cycle'),
#  ('nifedipine', 'hypertrophy'),
#  ('distractibility', 'cardiac'),
#  ('body_temperature', 'amoxycillin'),
#  ('proglumide', 'pain'),
#  ('biliary_cirrhosis', 'cardiac'),
#  ('cholangitis', 'concomitant'),
#  ('tamoxifen', 'fibroma'),
#  ('ketotifen', 'neurofibroma'),
#  ('terazosin', 'elderly'),
#  ('macrophages', 'alprenolol'),
#  ('crepitations', 'cardiac'),
#  ('phenytoin', 'somnolence'),
#  ('cholesterol', 'renal_cell_carcinoma'),
#  ('imipramine', 'dialysis'),
#  ('azithromycin', 'erythema_migrans'),
#  ('basal', 'transferrin_saturation'),
#  ('mobility', 'double-blind'),
#  ('teicoplanin', 'diarrhoea'),
#  ('hypermetabolism', 'sodium'),
#  ('dermoid_cyst', 'peptide'),
#  ('chemotherapy', 'hydralazine'),
#  ('carcinogenicity', 'aluminium'),
#  ('physostigmine', 'renin'),
#  ('tetracycline', 'lacrimation'),
#  ('discharge', 'uracil'),
#  ('metoprolol', 'renin'),
#  ('gramicidin', 'macrophages'),
#  ('eosinophilia', 'tac'),
#  ('arteriosclerosis', 'concomitant'),
#  ('haemopexin', 'medium'),
#  ('sodium', 'macrocytosis'),
#  ('indium', 'deep_vein_thrombosis'),
#  ('cardiac', 'hyperparathyroidism'),
#  ('perforation', 'cardiac'),
#  ('surfactant', 'infection'),
#  ('renin', 'penbutolol'),
#  ('pyoderma', 'concomitant'),
#  ('double-blind', 'androgenetic_alopecia'),
#  ('nitrendipine', 'cardiac_index'),
#  ('antibiotic_therapy', 'strontium'),
#  ('syphilis', 'aluminium'),
#  ('bezafibrate', 'cerebral_ischaemia'),
#  ('nitrazepam', 'dialysis'),
#  ('pancreatitis', 'submucosal'),
#  ('double-blind', 'reflux_gastritis'),
#  ('peptide', 'factor_vii_deficiency'),
#  ('desflurane', 'stenosis'),
#  ('cesium', 'salpingo-oophorectomy'),
#  ('miconazole', 'thrombocytosis'),
#  ('flushing', 'furosemide'),
#  ('endocrine', 'extubation'),
#  ('l-dopa', 'akinesia'),
#  ('cimetidine', 'starvation'),
#  ('enalapril', 'venous_oxygen_saturation'),
#  ('fracture', 'concomitant'),
#  ('cesium', 'sarcoma'),
#  ('measles', 'levodopa'),
#  ('gonorrhoea', 'magnesium'),
#  ('hypoparathyroidism', 'dihydrotachysterol'),
#  ('psoriasis', 'disodium'),
#  ('lipids', 'double-blind'),
#  ('gangrene', 'penicillin'),
#  ('psyllium', 'occupational_asthma'),
#  ('protriptyline', 'uvulopalatopharyngoplasty'),
#  ('ciprofloxacin', 'bite'),
#  ('endocrine', 'herpes_simplex'),
#  ('cisapride', 'intestinal_resection'),
#  ('gallium', 'embolism'),
#  ('plastic_surgery', 'diazepam'),
#  ('concomitant', 'delayed_puberty'),
#  ('infant', 'cytarabine'),
#  ('vinblastine', 'delivery'),
#  ('neuralgia', 'streptomycin'),
#  ('stress_ulcer', 'l-dopa'),
#  ('basal', 'collateral_circulation'),
#  ('myxoedema_coma', 'sodium'),
#  ('illusion', 'nasal'),
#  ('titanium', 'fatigue'),
#  ('ketoconazole', 'respiratory_distress'),
#  ('mitral_valve_replacement', 'potassium'),
#  ('intraocular_pressure', 'vasopressin'),
#  ('sedation', 'phenytoin'),
#  ('nifedipine', 'heart_transplant'),
#  ('cephalosporin', 'investigation'),
#  ('lupus_nephritis', 'captopril'),
#  ('etodolac', 'enzyme_activity'),
#  ('haemodialysis', 'vasopressin'),
#  ('nasal', 'bone_loss'),
#  ('paradox', 'anorexia_nervosa'),
#  ('hyperventilation', 'phenytoin'),
#  ('extravasation', 'diclofenac'),
#  ('heart_rate', 'helium'),
#  ('nephritis', 'furosemide'),
#  ('calcium', 'cachexia'),
#  ('lithium', 'pyoderma_gangrenosum'),
#  ('hyperparathyroidism', 'basal'),
#  ('gadolinium', 'glioma'),
#  ('flunitrazepam', 'apnoea'),
#  ('blood_pressure_measurement', 'captopril'),
#  ('alteplase', 'cardiac_index'),
#  ('kyphoscoliosis', 'nasal'),
#  ('prostatitis', 'carbenicillin'),
#  ('barium_impaction', 'cardiac'),
#  ('myocardial_infarction', 'mer'),
#  ('hypothyroidism', 'thiazide'),
#  ('cardiac', 'muscle_tightness'),
#  ('thrombotic_thrombocytopenic_purpura', 'defibrotide'),
#  ('urate_nephropathy', 'potassium'),
#  ('epinephrine', 'disodium'),
#  ('anxiety', 'double-blind'),
#  ('double-blind', 'perioral_dermatitis'),
#  ('ventricular_fibrillation', 'nadolol'),
#  ('postpericardiotomy_syndrome', 'ibuprofen'),
#  ('desipramine', 'fall'),
#  ('metastatic_malignant_melanoma', 'cimetidine'),
#  ('bacteriuria', 'trimethoprim'),
#  ('arthralgia', 'instant'),
#  ('suxamethonium', 'respiratory_rate'),
#  ('bretylium', 'injection'),
#  ('ranitidine', 'vasoconstriction'),
#  ('caesarean_section', 'nitrazepam'),
#  ('octreotide', 'necrosis'),
#  ('ticarcillin', 'decubitus_ulcer'),
#  ('skin_test_negative', 'penicillin'),
#  ('buserelin', 'bone_pain'),
#  ('anafranil', 'neurosis'),
#  ('5-fluorouracil', 'renal_cell_carcinoma'),
#  ('hyperplasia', 'reserpine'),
#  ('triamcinolone', 'thyroid_hormones'),
#  ('injection', 'statin'),
#  ('urticaria', 'ranitidine'),
#  ('hypersensitivity', 'paroxetine'),
#  ('cardiac_failure', 'cisplatin'),
#  ('barium', 'histology'),
#  ('praziquantel', 'obstruction'),
#  ('local_reaction', 'barium'),
#  ('myocardial_ischaemia', 'gallopamil'),
#  ('prednisolone', 'erythema'),
#  ('cardiac', 'vascular_injury'),
#  ('vinblastine', 'malignant_melanoma'),
#  ('cocaine', 'paralysis'),
#  ('vomiting', 'famotidine'),
#  ('peptide', 'catatonia'),
#  ('hyperinsulinaemia', 'endocrine'),
#  ('electroencephalogram', 'esmolol'),
#  ('lincomycin', 'pneumonia'),
#  ('mycelium', 'fibrin'),
#  ('coronary_artery_disease', 'gadolinium'),
#  ('hysterectomy', 'tinidazole'),
#  ('delivery', 'frusemide'),
#  ('buserelin', 'adenocarcinoma'),
#  ('anaphylactic_reaction', 'mepivacaine'),
#  ('amiodarone', 'thyroglobulin'),
#  ('pregnenolone', 'oophorectomy'),
#  ('pulse_pressure', 'cardiac'),
#  ('metronidazole', 'papulopustular_rosacea'),
#  ('mesothelioma', 'heparin'),
#  ('beta-carotene', 'hyperplasia'),
#  ('cimetidine', 'endoscopy'),
#  ('corium', 'swelling'),
#  ('cholesterol', 'hiatus_hernia'),
#  ('vitamin_d', 'aluminium'),
#  ('piroxicam', 'growth'),
#  ('tardive_dyskinesia', 'physostigmine'),
#  ('clonazepam', 'injection'),
#  ('gastrointestinal_toxicity', 'floxuridine'),
#  ('verapamil', 'growth_retardation'),
#  ('methyldopa', 'necrosis'),
#  ('5-fluorouracil', 'bronchial_carcinoma'),
#  ('detoxification', 'buspirone'),
#  ('muscle_injury', 'basal'),
#  ('double-blind', 'flow_cytometry'),
#  ('cholera', 'vinblastine'),
#  ('urine_bilirubin', 'cholesterol'),
#  ('maculopathy', 'cholesterol'),
#  ('menopausal', 'insomnia'),
#  ('medium', 'arterial_thrombosis'),
#  ('epidermolysis', 'immunoglobulin'),
#  ('selenium', 'hypoxia'),
#  ('energy', 'strontium'),
#  ('cerebral_vasoconstriction', 'calcium'),
#  ('cardiac', 'blood_albumin'),
#  ('helium', 'infusion'),
#  ('tooth_loss', 'basal'),
#  ('laparotomy', 'heparin'),
#  ('pyoderma_gangrenosum', 'methylprednisolone'),
#  ('ac', 'cell_death'),
#  ('cancer_pain', 'oxytocin'),
#  ('enzyme_induction', 'chlorpropamide'),
#  ('lipase', 'barium'),
#  ('selenium', 'peritoneal_dialysis'),
#  ('tolazoline', 'depression'),
#  ('diabetic_coma', 'thiazide'),
#  ('drug_resistance', 'gallium'),
#  ('enflurane', 'cortisol'),
#  ('gastric_cancer', 'submucosal'),
#  ('erythema_migrans', 'doxycycline'),
#  ('epistaxis', 'natamycin'),
#  ('echocardiogram', 'meperidine'),
#  ('miconazole', 'mucocutaneous_candidiasis'),
#  ('arthroscopy', 'technetium'),
#  ('hypervolaemia', 'dopamine'),
#  ('infusion', 'trimethoprim'),
#  ('double-blind', 'ovarian_cancer'),
#  ('stomatitis', 'idarubicin'),
#  ('histidine', 'heart_rate'),
#  ('cardiac', 'flail_chest'),
#  ('electroconvulsive_therapy', 'fluoxetine'),
#  ('concomitant', 'dizziness'),
#  ('adrenal_adenoma', 'captopril'),
#  ...}

# %% [markdown]
# Let's determine how many examples we have for each triple in the KB. We'll compute averages per relation.

# %%
dataset.count_examples()
# Out:
#                                              examples
# relation               examples    triples    /triple
# --------               --------    -------    -------
# acquired                     20         17       1.18
# aggravated                 1392        322       4.32
# altered                     894         97       9.22
# caused                   170646      34601       4.93
# changed                     101         70       1.44
# decreased                 44333       2820      15.72
# delayed                      25         30       0.83
# discoloured                 395        114       3.46
# impaired                    321         71       4.52
# improved                      0          1       0.00
# increased                 48708       2846      17.11
# infected                    155         23       6.74
# lowered                       1          2       0.50
# prolonged                   230         85       2.71
# reduced                      82         63       1.30
# ruptured                     36         14       2.57
# shortened                   308        122       2.52

# %%
for key, val in dataset.kb.kb_triples_by_relation.items():
    print(key, len(val))
# Out:
# acquired 17
# aggravated 322
# altered 97
# caused 34601
# changed 70
# decreased 2820
# delayed 30
# discoloured 114
# impaired 71
# improved 1
# increased 2846
# infected 23
# lowered 2
# prolonged 85
# reduced 63
# ruptured 14
# shortened 122

# %%
for key, val in dataset.kb.kb_triples_by_relation.items():
    print(key, len(val))
# Out:
# acquired 17
# aggravated 322
# altered 97
# caused 34601
# changed 70
# decreased 2820
# delayed 30
# discoloured 114
# impaired 71
# improved 1
# increased 2846
# infected 23
# lowered 2
# prolonged 85
# reduced 63
# ruptured 14
# shortened 122

# %%
print(len(dataset.corpus.examples_by_entities))
# Out:
# 4454

# %%
dataset.count_relation_combinations()
# Out:
# The most common relation combinations are:
#        995 ('decreased', 'increased')
#         59 ('caused', 'decreased', 'increased')
#         42 ('caused', 'increased')
#         42 ('caused', 'decreased')
#         27 ('discoloured', 'increased')
#         22 ('decreased', 'shortened')
#         20 ('prolonged', 'shortened')
#         20 ('changed', 'decreased', 'shortened')
#         17 ('caused', 'infected')
#         11 ('changed', 'decreased')
#          9 ('caused', 'ruptured')
#          8 ('decreased', 'delayed', 'shortened')
#          8 ('changed', 'decreased', 'increased')
#          6 ('acquired', 'caused')
#          4 ('changed', 'shortened')
#          3 ('decreased', 'increased', 'shortened')
#          2 ('changed', 'increased')
#          2 ('changed', 'decreased', 'increased', 'shortened')
#          2 ('changed', 'decreased', 'delayed', 'increased', 'prolonged', 'shortened')
#          1 ('increased', 'prolonged', 'shortened')
#          1 ('decreased', 'prolonged')
#          1 ('decreased', 'increased', 'prolonged')
#          1 ('decreased', 'delayed', 'prolonged', 'shortened')
#          1 ('decreased', 'delayed', 'increased', 'shortened')
#          1 ('decreased', 'delayed')
#          1 ('changed', 'prolonged', 'shortened')
#          1 ('changed', 'prolonged')
#          1 ('changed', 'delayed', 'shortened')
#          1 ('changed', 'delayed', 'increased', 'shortened')
#          1 ('changed', 'decreased', 'prolonged', 'shortened')
#          1 ('changed', 'decreased', 'increased', 'prolonged')
#          1 ('changed', 'decreased', 'delayed', 'prolonged')
#          1 ('changed', 'decreased', 'delayed', 'increased', 'shortened')
#          1 ('changed', 'decreased', 'delayed')

# %% [markdown]
# ### Featurizers
#
# Featurizers are functions which define the feature representation for our model. The primary input to a featurizer will be the `KBTriple` for which we are generating features. But since our features will be derived from corpus examples containing the entities of the `KBTriple`, we must also pass in a reference to a `Corpus`. And in order to make it easy to combine different featurizers, we'll also pass in a feature counter to hold the results.
#
# Here's an implementation for a very simple bag-of-words featurizer. It finds all the corpus examples containing the two entities in the `KBTriple`, breaks the phrase appearing between the two entity mentions into words, and counts the words. Note that it makes no distinction between "forward" and "reverse" examples.

# %%
def simple_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        for word in ex.middle.split(' '):
            feature_counter[word] += 1
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        for word in ex.middle.split(' '):
            feature_counter[word] += 1
    return feature_counter

def count_words(sent_part: str, feature_counter: Counter):
    for word in sent_part.split(" "):
        feature_counter[word] += 1

def middle_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        count_words(ex.middle, feature_counter)
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        count_words(ex.middle, feature_counter)
    return feature_counter

def start_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        count_words(ex.left, feature_counter)
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        count_words(ex.left, feature_counter)
    return feature_counter

def end_bag_of_words_featurizer(kbt, corpus, feature_counter):
    for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
        count_words(ex.right, feature_counter)
    for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
        count_words(ex.right, feature_counter)
    return feature_counter

# %%
kbt = kb.kb_triples[5]

kbt
# Out:
# KBTriple(rel='acquired', sbj='atazanavir', obj='lipodystrophy')

# %%
print(len(corpus.examples_by_entities))
# Out:
# 4454

# %%
print(len(corpus.examples_by_entities["sodium"]))
# Out:
# 617

# %%
for i in range(0, len(kb.kb_triples)):
    res = simple_bag_of_words_featurizer(kb.kb_triples[i], corpus, Counter())
    if res:
        print(res)
# Out:
# Counter({'': 17, 'the': 12, 'in': 10, 'and': 8, 'of': 7, 'with': 6, 'by': 4, 'renal': 4, 'a': 4, 'patients': 3, 'seven': 2, 'isolated': 2, 'injection': 2, 'induced': 2, 'dog,': 2, 'we': 2, 'membrane': 2, 'to': 2, 'minutes': 2, 'after': 2, 'increased': 2, 'all': 2, 'hyperenzymurias': 2, 'rapidly,': 2, 'progressively,': 2, 'maleate': 1, '(200-400': 1, 'mg/kg)': 1, 'into': 1, 'rats': 1, 'produces': 1, 'aminoaciduria': 1, 'along': 1, 'glycosuria': 1, 'phosphaturia,': 1, 'resembling': 1, 'reabsorption': 1, 'proximal': 1, 'distal': 1, 'tubule': 1, 'was': 1, 'evaluated': 1, 'different': 1, 'methods': 1, 'healthy': 1, 'subjects,': 1, 'recurrent': 1, 'calcium': 1, 'nephrolithiasis,': 1, 'five': 1, 'glucosuria': 1, 'three': 1, ',': 1, 'decline': 1, 'intestinal': 1, 'mucosa': 1, '(Na+-K+)-ATPase': 1, 'simultaneous': 1, 'decrease': 1, 'produced': 1, 'single': 1, 'Basenji': 1, 'have': 1, 'used': 1, 'brush': 1, 'border': 1, 'vesicles': 1, 'examine': 1, 'two': 1, 'factors': 1, 'that': 1, 'influence': 1, 'nonelectrolyte': 1, 'transport': 1, 'processes,': 1, 'type': 1, '2': 1, 'tubular': 1, 'acidosis': 1, '(FS/RTA2)': 1, 'maleic': 1, 'acid': 1, 'unanesthetized': 1, 'observed:': 1, '30': 1, 'onset': 1, 'FS/RTA2,': 1, 'urinary': 1, 'excretion': 1, 'lysosomal': 1, 'enzymes,': 1, 'N-acetyl-beta-glucosaminidase': 1, '(NAG),': 1, 'beta-glucuronidase': 1, '(beta-gluc)': 1, 'beta-galactosidase': 1, '(beta-galac),': 1, 'simultaneously': 1, 'anticipated': 1, 'increase': 1, 'clearance': 1, 'lysozyme;': 1, 'severities': 1, 'these': 1, 'parallel,': 1, 'reaching': 1, 'peak': 1, 'some': 1, '60': 1, '80': 1, 'their': 1, 'onset;': 1, 'thereafter,': 1, 'while': 1, 'FS/RTA2': 1, 'continued': 1, 'undiminished': 1, 'severity,': 1, 'severity': 1, 'decreased': 1, 'greatly,': 1, 'parallel;': 1})
# Counter({'': 3, 'which': 1, 'ensued,': 1, 'including': 1, 'excessive': 1, 'loss': 1, 'of': 1})
# Counter({'': 7, 'of': 6, ',': 4, 'in': 4, 'RENAL': 3, 'during': 3, 'degrees': 3, 'hypokalemia,': 3, 'daily': 3, 'urinary': 3, 'excretion': 3, 'a': 2, 'intestinal': 2, 'POTASSIUM': 2, 'WASTING': 2, 'PERSISTED': 2, 'DESPITE': 2, 'SUSTAINED': 2, 'CORRECTION': 2, 'OF': 2, 'ACIDOSIS:': 2, '(a)': 2, 'moderate': 2, 'decline': 1, 'the': 1, 'mucosa': 1, '(Na+-K+)-ATPase': 1, 'with': 1, 'simultaneous': 1, 'decrease': 1, 'sodium': 1, 'transport': 1, 'and': 1, 'an': 1, 'increase': 1, 'potassium': 1, 'exceeded': 1, '80': 1, 'mEq': 1, 'each': 1, 'patient;': 1, '(b)': 1, 'more': 1, 'severe': 1})
# Counter({'': 1})
# Counter({'': 23, 'in': 6, 'the': 5, 'and': 4, 'with': 4, 'of': 4, ',': 3, 'an': 3, 'to': 3, 'patients': 2, 'was': 2, 'either': 2, 'supersensitivity': 2, 'by': 2, 'treated': 2, 'aggravated': 1, 'dextroamphetamine': 1, 'sulfate,': 1, 'levamfetamine': 1, 'succinate,': 1, 'apomorphine,': 1, 'piribedil': 1, 'were': 1, 'studied': 1, 'two': 1, 'Giles': 1, 'de': 1, 'la': 1, "Tourette's": 1, 'disease': 1, 'attempt': 1, 'clarify': 1, 'catecholamine': 1, 'mechanisms': 1, 'involved': 1, 'this': 1, 'sulpiride,': 1, 'benztropine,': 1, 'methyl': 1, 'atropine,': 1, 'phentolamine,': 1, 'prazosin,': 1, 'methiothepin,': 1, 'methysergide,': 1, 'diphenhydramine,': 1, 'pargyline': 1, 'diazepam': 1, 'failed': 1, 'increase': 1, 'response': 1, 'latencies': 1, 'under': 1, 'hind': 1, 'paw': 1, 'lick-only': 1, 'treatment': 1, 'subthreshold': 1, 'for': 1, 'inducing': 1, 'dopamine': 1, 'autoreceptor': 1, 'or': 1, 'postsynaptic': 1, 'as': 1, 'evidenced': 1, 'equivalent': 1, 'metabolic': 1, 'reductions': 1, 'chronically': 1, 'neuroleptic': 1, 'versus': 1, 'vehicle': 1, 'groups,': 1, 'absence': 1, 'stereotypical': 1, 'responding': 1, 'some': 1, 'children': 1, 'unresponsive': 1, 'liver': 1, 'monoxygenase': 1, 'system': 1, 'effects': 1, 'on': 1, 'replacing': 1, 'chlorpromazine': 1, 'which': 1, 'successfully': 1, 'psychoses': 1, '(mainly': 1, 'schizophrenia)': 1, 'when': 1, 'abrupt': 1, 'change': 1, 'from': 1, 'orally': 1, 'administered': 1, 'could': 1, 'be': 1, 'reversed': 1})
# Counter({'': 2})
# Counter({'': 7, 'of': 6, 'been': 2, 'less': 2, 'than': 2, '30': 2, 'micrograms/litre': 2, 'has': 1, 'often': 1, 'assumed': 1, 'to': 1, 'be': 1, 'irreversible,': 1, 'although': 1, 'promising': 1, 'results': 1, 'have': 1, 'achieved': 1, 'recently': 1, 'by': 1, 'using': 1, 'a': 1, 'chelating': 1, 'agent': 1, 'for': 1, 'removal': 1, 'aluminium': 1, 'is': 1, 'dependent': 1, 'on': 1, 'the': 1, 'quantity': 1})
# Counter({'': 20, 'and': 7, 'as': 5, 'a': 5, 'of': 5, ',': 4, 'the': 4, 'be': 3, 'with': 3, 'is': 3, 'was': 3, 'renal': 3, 'were': 3, 'rate': 3, 'by': 3, 'considered': 2, 'in': 2, 'for': 2, 'blood': 2, 'which': 2, 'to': 2, 'administration': 2, 'may': 1, 'useful': 1, 'should': 1, 'patients': 1, 'non-Q-wave': 1, 'infarction': 1, 'along': 1, 'aspirin,': 1, 'no': 1, 'other': 1, 'treatment': 1, 'yet': 1, 'available': 1, 'this': 1, 'conventional': 1, 'tablet': 1, '(2': 1, 'x': 1, '30': 1, 'mg,': 1, 'first': 1, 'group)': 1, 'or': 1, 'slow-release': 1, 'capsule': 1, '(120': 1, 'mg': 1, 'SR,': 1, 'second': 1, 'group),': 1, 'administered': 1, 'fasting': 1, 'on': 1, 'flow': 1, 'function': 1, 'studied': 1, 'under': 1, 'angiotensin': 1, 'II-loaded': 1, 'significantly': 1, 'increased': 1, 'fatigue': 1, 'while': 1, 'dog': 1, 'coronary': 1, 'arteries;': 1, '(2)': 1, 'vasodilation': 1, 'caused': 1, 'ACh': 1, 'mostly': 1, 'endothelium-dependent,': 1, 'mediated': 1, 'muscarinic': 1, 'receptors;': 1, '(3)': 1, 'vascular': 1, 'responses': 1, 'NE,': 1, 'KCl,': 1, ';': 1, 'all': 1, 'three': 1, 'drugs': 1, 'reduced': 1, 'pressure': 1, 'product': 1, 'at': 1, 'submaximal': 1, 'exercise,': 1, 'but': 1, 'significant': 1, 'statistical': 1, 'difference': 1, 'found': 1, 'only': 1, 'verapamil': 1, 'glomerular': 1, 'filtration': 1, 'para-amino-hippuric': 1, 'acid': 1, 'clearance,': 1, 'well': 1, 'flow,': 1, 'markedly': 1, 'reduced,': 1, 'levels': 1, 'recovered': 1, 'intrarenal': 1, 'marked': 1, 'natriuretic': 1, 'effect': 1, 'observed': 1, 'both': 1, 'intravenous': 1, 'intraarterial': 1})
# Counter({'': 2, 'states,': 1, 'especially': 1, 'those': 1, 'in': 1, 'which': 1, 'serum': 1})
# Counter({'': 1})
# Counter({'': 1})
# Counter({'': 1})
# Counter({'': 3})
# Counter({'': 11, 'and': 5, 'the': 4, 'of': 4, 'in': 3, ',': 2, 'to': 2, '+/-': 2, 'with': 2, 'clonidine,': 1, 'indoramin': 1, 'on': 1, 'central': 1, 'regional': 1, 'hemodynamic': 1, 'parameters': 1, 'left': 1, 'ventricular': 1, 'performance': 1, 'were': 1, 'analyzed': 1, 'a': 1, 'congestive': 1, 'heart': 1, 'failure': 1, 'population': 1, 'compare': 1, 'pharmacodynamic': 1, 'responses': 1, 'different': 1, 'levels': 1, 'alpha-adrenergic': 1, 'interruption': 1, 'this': 1, '(12.7': 1, '0.6%': 1, 'versus': 1, '6.9': 1, '0.4%': 1, 'hyperosmolar': 1, 'load': 1, '(after': 1, 'mannitol': 1, 'infusion),': 1, 'following': 1, 'beta-adrenergic': 1, 'beta': 1, '+': 1, 'alpha': 1, '1-adrenergic': 1, 'blockade': 1, 'use': 1, 'propranolol': 1, 'as': 1, 'employed': 1, 'physiological': 1, 'experiments': 1, 'decreased': 1, 'specific': 1, 'binding': 1, '[3H]': 1})
# Counter({'': 4, 'the': 3, 'of': 2, 'and': 2, 'patient': 1, 'diagnostic': 1, 'confirmation': 1, 'liver': 1, 'hydatid': 1, 'disease': 1, 'by': 1, 'CT': 1, 'scan,': 1, 'antiparasitic': 1, 'therapy': 1, 'with': 1, 'that': 1})
# Counter({'': 11, 'the': 8, 'and': 6, 'of': 6, 'at': 5, 'in': 4, 'presence': 4, 'duration': 4, 'Week': 3, '2': 3, 'was': 3, 'slightly': 3, 'greater': 3, 'etodolac': 3, 'SR': 3, 'with': 3, 'about': 3, 'treatment': 2, 'group,': 2, 'suggesting': 2, 'that': 2, 'improvement': 2, 'may': 2, 'occur': 2, 'more': 2, 'rapidly': 2, ',': 2, 'morning': 2, 'stiffness,': 2, 'stiffness': 2, 'rest,': 2, 'finally': 2, "investigator's": 2, 'integrated': 2, 'evaluation': 2, 'effectiveness': 2, 'tolerance': 2, 'than': 1, 'diclofenac': 1, 'SR.': 1, 'With': 1, 'regard': 1, 'to': 1, 'tolerability,': 1, '5': 1, 'patients': 1, "patient's": 1, 'self-evaluation': 1, 'his': 1, 'own': 1, 'condition,': 1})
# Counter({'': 11, 'in': 7, 'the': 6, 'with': 5, 'etodolac': 5, 'SR': 5, 'treatment': 4, 'to': 4, 'a': 3, 'improvement': 3, 'was': 3, 'more': 3, 'patients': 2, 'of': 2, 'at': 2, 'Week': 2, '2': 2, 'slightly': 2, 'greater': 2, 'group,': 2, 'suggesting': 2, 'that': 2, 'may': 2, 'occur': 2, 'rapidly': 2, 'than': 2, 'improved': 1, 'nine': 1, 'following': 1, ',': 1, 'however,': 1, 'trend': 1, 'towards': 1, 'significant': 1, 'discernible,': 1, "investigator's": 1, 'opinion,': 1, 'only': 1, 'response': 1, 'most': 1, 'patients,': 1, 'but': 1, 'clinical': 1, 'impression': 1, 'would': 1, 'appear': 1, 'point': 1, 'marked': 1, 'analgesic': 1, 'effect': 1, 'diclofenac': 1, 'SR.': 1, 'With': 1, 'regard': 1, 'tolerability,': 1, '5': 1, 'group': 1, 'and': 1, '3': 1})
# Counter({'': 3, 'D': 3, 'the': 3, 'at': 2, '-3': 2, 'and': 2, 'a': 1, 'reduction': 1, 'in': 1, 'response': 1, '-5': 1, 'D.': 1, 'Mental': 1, 'effort': 1, 'induced': 1, 'similar': 1, 'responses': 1, 'for': 1, '-1': 1, 'locations': 1, 'when': 1, 'sympathetic': 1, 'innervation': 1, 'to': 1, 'ciliary': 1, 'muscle': 1, 'was': 1, 'blocked': 1, 'with': 1, 'beta-receptor': 1, 'antagonist': 1})
# Counter({'': 2, 'was': 1, 'cured': 1, 'after': 1, 'systemic': 1, 'therapy': 1, 'with': 1, 'metronidazole': 1, 'and': 1})
# Counter({'': 5, 'for': 2, 'of': 2, 'as': 2, 'this': 2, 'thus': 1, 'seems': 1, 'to': 1, 'have': 1, 'certain': 1, 'advantages': 1, 'over': 1, 'gemfibrozil': 1, 'treatment': 1, 'elevated': 1, 'plasma': 1, 'triglyceride': 1, 'levels': 1, 'accompanied': 1, 'by': 1, 'borderline': 1, 'high': 1, 'total': 1, 'cholesterol': 1, 'and': 1, 'raised': 1, 'apolipoprotein': 1, 'B': 1, 'levels;': 1, 'therefore,': 1, 'lovastatin': 1, 'therapy': 1, 'should': 1, 'be': 1, 'considered': 1, 'one': 1, 'approach': 1, 'management': 1, '(Mevacor)': 1, 'has': 1, 'emerged': 1, 'an': 1, 'agent': 1, 'that': 1, 'may': 1, 'effectively': 1, 'manage': 1})
# Counter({'the': 3, '': 2, 'and': 2, 'decarboxylases': 1, '(HisDC)': 1, 'from': 1, 'hypothalamus': 1, 'lungs,': 1, 'was': 1, 'markedly': 1, 'reduced': 1, 'by': 1, 'incubating': 1, 'with': 1, 'ATP.Mg,': 1, 'cAMP': 1, 'cAMP-dependent': 1, 'protein': 1, 'kinase': 1, 'A,': 1, 'whereas': 1, 'activity': 1, 'of': 1, 'crude': 1, 'glandular': 1, 'stomach': 1, 'enzyme': 1, 'changed': 1, 'only': 1, 'slightly': 1, 'under': 1, 'equal': 1})
# Counter({'': 14, 'of': 6, 'in': 5, 'the': 2, 'by': 2, 'studied': 2, 'a': 2, 'not': 2, 'was': 2, '(PHT)': 1, 'on': 1, 'modifications': 1, 'ammonia': 1, '(NH+4)': 1, 'metabolism': 1, 'caused': 1, 'sodium': 1, 'valproate': 1, '(VPA)': 1, 'are': 1, 'here': 1, 'order': 1, 'to': 1, 'identify': 1, 'drug': 1, 'combinations': 1, 'susceptible': 1, 'evoking': 1, 'stuporous': 1, 'states': 1, 'epileptics,': 1, 'rare': 1, 'affecting': 1, 'infants': 1, 'epileptic': 1, 'mothers': 1, '(11': 1, '61,': 1, '18%)': 1, 'but': 1, 'controls': 1, 'The': 1, 'mean': 1, 'cord': 1, 'serum': 1, 'causing': 1, 'no': 1, 'problems': 1, 'over': 1, '90%': 1, 'patients,': 1, 'it': 1, 'is': 1, 'considered': 1, 'that': 1, 'gum': 1, 'hypertrophy': 1, 'per': 1, 'se': 1, 'should': 1, 'deter': 1, 'physician': 1, 'from': 1, 'using': 1, 'characterized': 1, 'increased': 1, 'amounts': 1, 'gingival': 1, 'connective': 1, 'tissue,': 1, 'has': 1, 'most': 1, 'commonly': 1, 'been': 1, 'observed': 1, 'patients': 1, 'receiving': 1})
# Counter({'': 22, 'and': 6, 'the': 6, ',': 4, 'of': 4, 'were': 4, 'in': 3, 'during': 3, 'reduce': 2, 'by': 2, 'restores': 1, 'proximal': 1, 'reabsorption': 1, 'renal': 1, 'functional': 1, 'reserve': 1, 'this': 1, 'can:': 1, 'a)': 1, 'blood': 1, 'pressure;': 1, 'b)': 1, 'cardiac': 1, 'hypertrophy;': 1, 'c)': 1, 'reverse': 1, 'isomyosin': 1, 'enzymes': 1, '(V1': 1, 'V3)': 1, 'previously': 1, 'altered': 1, 'hypertrophy': 1, 'angiotensin': 1, 'II': 1, 'administration': 1, '(60': 1, 'ng.kg-1.min-1': 1, 'iv),': 1, 'CEI': 1, '(': 1, '(T0)': 1, 'after': 1, '60': 1, 'min': 1, 'ruled': 1, 'out,': 1, 'reweighed': 1, 'contents': 1, 'assayed': 1, 'for': 1, 'Brattleboro': 1, 'rats': 1, 'showed': 1, 'a': 1, 'profound': 1, 'progressive': 1, 'hypotension': 1, 'response': 1, 'to': 1, 'an': 1, 'identical': 1, 'decline': 1, 'MAP': 1, '(5': 1, '+/-': 1, '1': 1, 'mmHg)': 1, 'blockade': 1, 'RAS': 1, 'effects': 1, 'ANP': 1, 'compared': 1, 'with': 1, 'those': 1})
# Counter({'': 3, 'for': 2, ':': 1, 'beta-2-agonists': 1, 'intermittent': 1, 'mild': 1, 'wheezing;': 1, 'cromolyn': 1, 'sodium': 1, 'moderate': 1, 'to': 1, 'severe': 1, 'asthma;': 1, 'xanthines,': 1, 'anticholinergic': 1, 'agents,': 1, 'particularly': 1})
# Counter({'': 16, 'in': 7, 'and': 5, 'with': 4, 'to': 4, 'the': 3, 'response': 3, 'little': 2, 'but': 2, 'central': 2, '10': 2, 'control': 2, 'had': 1, 'effect': 1, 'on': 1, 'physiologic': 1, '(on),': 1, "patients'": 1, 'motor': 1, 'time': 1, 'normalized,': 1, 'cognitive': 1, 'processing': 1, 'speed': 1, 'became': 1, 'significantly': 1, 'slower': 1, 'when': 1, 'compared': 1, 'previous': 1, 'performance': 1, 'off': 1, 'nervous': 1, 'system': 1, 'naturally': 1, 'accumulated': 1, 'due': 1, 'a': 1, 'congenital': 1, 'deficiency': 1, 'of': 1, 'aromatic-L-amino': 1, 'acid': 1, 'decarboxylase': 1, 'these': 1, 'were': 1, 'treated': 1, 'pyridoxine': 1, '(which': 1, 'this': 1, 'various': 1, 'inhibiting': 1, 'and/or': 1, 'stimulating': 1, 'agents': 1, '(': 1, 'EEG': 1, 'cleared': 1, 'following': 1, 'lowers': 1, ',': 1, 'most': 1, 'cases': 1, 'having': 1, 'or': 1, 'no': 1, 'where': 1, 'neurotransmission': 1, 'is': 1, 'severely': 1, 'deranged),': 1, 'patients': 1, 'liver': 1, 'cirrhosis': 1, 'without': 1, 'encephalopathy': 1, 'subjects': 1, 'under': 1, 'conditions': 1, 'nomifensine,': 1})
# Counter({'': 102, 'the': 34, 'of': 33, 'and': 22, 'in': 21, 'with': 8, ',': 7, 'to': 6, 'by': 6, 'or': 6, 'an': 6, 'concentration': 5, 'on': 4, 'as': 4, 'sodium': 4, 'is': 4, 'potassium': 4, 'a': 4, 'than': 4, 'increase': 4, 'pH': 3, 'during': 3, 'depletion': 3, 'this': 3, 'mM': 3, 'but': 3, 'was': 3, 'plasma': 3, 'calcium': 3, 'after': 3, 'factors': 3, 'other': 3, 'cell': 3, 'presence': 2, 'across': 2, 'membrane': 2, 'were': 2, 'from': 2, 'such': 2, 'RS': 2, 'possessed': 2, 'bell': 2, 'shaped': 2, 'dose': 2, 'response': 2, 'nature': 2, 'optimal': 2, '10': 2, 'heart': 2, 'failure': 2, 'for': 2, 'due': 2, 'when': 2, 'exchangeable': 2, 'normal': 2, 'have': 2, 'low': 2, 'blood': 2, 'using': 2, 'saline': 2, 'mM)': 2, 'we': 2, 'serum': 2, 'creatinine,': 2, 'increased': 2, 'clinical': 2, 'are': 2, 'important': 2, 'modulating': 2, 'that': 2, 'characteristic': 2, 'positive': 2, 'diagnosis': 2, 'vaginal': 2, 'ions': 1, 'valinomycin': 1, 'gradient': 1, 'determined': 1, 'changes': 1, 'pK': 1, 'observed': 1, 'external': 1, 'medium': 1, 'transition': 1, 'energized': 1, 'respiring': 1, 'state': 1, 'de-engerized': 1, 'resting': 1, 'iodide': 1, 'perchlorate': 1, 'parameters': 1, 'characterizing': 1, 'thypoid': 1, 'hormones': 1, 'secretion,': 1, 'cAMP': 1, 'level': 1, 'gland': 1, 'tissue': 1, 'number': 1, 'intracellular': 1, 'colloid': 1, 'droplets': 1, 'under': 1, 'has': 1, 'been': 1, 'reported': 1, 'condition': 1, '145': 1, '6': 1, 'm': 1, 'may': 1, 'account': 1, 'part': 1, 'high': 1, 'frequency': 1, 'arrhythmias': 1, 'sudden': 1, 'death': 1, 'antidepressant': 1, 'medication': 1, 'she': 1, 'responded': 1, 'promptly': 1, 'cessation': 1, 'spironolactone': 1, 'prescription': 1, 'probably': 1, 'more': 1, 'aldosterone': 1, 'secretion': 1, 'controlled': 1, 'ACTH': 1, 'measured': 1, 'whereas': 1, 'levels': 1, 'marginal': 1, 'found': 1, 'measurements': 1, 'total': 1, 'body': 1, 'reduced': 1, 'chloride': 1, 'elevated': 1, 'together': 1, 'its': 1, 'concomitant': 1, 'severe': 1, 'associated': 1, 'digitalis': 1, 'toxicity,': 1, 'effects': 1, 'described': 1, 'it': 1, 'includes': 1, 'well-known': 1, 'modalities': 1, 'administration': 1, 'salts,': 1, 'NaHCO3,': 1, 'removal': 1, 'combined': 1, 'replacement': 1, 'therapy': 1, 'half': 1, 'strength': 1, 'modest': 1, 'quantities': 1, 'insulin': 1, 'blockade': 1, 'well': 1, 'stimulation': 1, 'excess': 1, '(56': 1, 'analyzed': 1, 'retrospectively': 1, 'pre-dialytic': 1, 'pressure': 1, 'propagated': 1, 'adjacent': 1, 'regions': 1, 'cortex': 1, 'diffusion': 1, 'glial-mediated': 1, 'spread': 1, ')': 1, 'complemented': 1, 'all': 1, 'essential': 1, 'amino': 1, 'acids,': 1, 'CPK,': 1, 'creatine': 1, 'phosphate': 1, 'HEPES': 1, 'buffer': 1, 'containing': 1, 'hepatosomatic': 1, 'indices,': 1, 'chloride,': 1, 'cholesterol,': 1, 'cortisol,': 1, 'glucose,': 1, 'osmolarity,': 1, 'intraerythrocyte': 1, 'OPC-8212': 1, '(0.1': 1, 'inward': 1, 'current': 1, 'decreased': 1, 'delayed': 1, 'outward': 1, 'inward-rectifying': 1, '44': 1, 'calves': 1, 'delivered': 1, 'caesarean': 1, 'section': 1, 'before': 1, 'term': 1, 'monitored': 1, 'repeated': 1, 'laboratory': 1, 'examinations': 1, '(analysis': 1, 'urea,': 1, 'sodium,': 1, 'at': 1, '1-': 1, '2-min': 1, 'point': 1, 'injection': 1, 'epinephrine': 1, 'mean': 1, 'promoting': 1, 'transfer': 1, 'apical': 1, 'visible': 1, 'edema': 1, 'where': 1, 'excessive': 1, 'unbalanced': 1, 'intake': 1, 'rapid': 1, '[K+]': 1, 'exercise': 1, 'indicated': 1, 'addition': 1, 'defined': 1, 'ability': 1, 'kidneys': 1, 'excrete': 1, 'acute': 1, 'infusion': 1, 'therefore': 1, 'conclude': 1, 'picture': 1, 'microscopy': 1, 'constitute': 1, 'safe': 1, 'basis': 1, 'Gardnerella': 1, 'vaginalis': 1, 'syndrome,': 1, 'should': 1, 'be': 1, 'based': 1, 'combination': 1, 'fulfilment': 1, 'three': 1, 'following': 1, 'four': 1, 'criteria:': 1, '1)': 1, 'secretion;': 1, '2)': 1, 'greater': 1, '4.5;': 1, '3)': 1, 'characterized': 1, 'benign': 1, 'hypertension,': 1})
# Counter({'the': 6, 'of': 3, '': 2, 'to': 2, 'anterior': 1, 'chamber': 1, 'eye,': 1, 'carried': 1, 'out': 1, 'in': 1, 'therapy': 1, 'course,': 1, 'allowed': 1, 'establish': 1, 'following': 1, 'order': 1, 'studied': 1, 'drugs,': 1, 'according': 1, 'their': 1, 'therapeutical': 1, 'effectiveness': 1, '(from': 1, 'most': 1, 'effective):': 1, 'indomethacin': 1, 'greater': 1, 'than': 1})
# Counter({'': 60, 'of': 27, 'the': 17, 'in': 10, 'and': 9, ',': 6, 'with': 6, 'a': 6, 'not': 6, 'as': 5, 'should': 5, 'patients': 4, 'serum': 4, 'is': 3, 'its': 3, 'have': 3, 'measured': 3, 'from': 3, 'for': 3, 'to': 3, 'interdict': 3, 'use': 3, 'repetitive': 3, 'doses': 3, 'magnesium': 3, 'deficiency': 2, 'this': 2, 'phosphate,': 2, 'activity': 2, 'bone': 2, 'calcium,': 2, '31': 2, '(type': 2, 'all': 2, 'were': 2, 'was': 2, 'mM': 2, 'low': 2, 'calcium': 2, 'effect': 2, 'which': 2, 'may': 2, 'be': 2, 'unbalanced': 2, 'mineral': 2, 'content': 2, 'Ca': 2, 'normal': 2, 'citrate': 2, 'cathartic,': 2, 'requiring': 2, 'such': 2, 'therapy': 2, 'problematic,': 1, 'since': 1, 'there': 1, 'no': 1, 'test': 1, 'that': 1, 'will': 1, 'reliably': 1, 'consistently': 1, 'detect': 1, 'inorganic': 1, 'total': 1, 'alkaline': 1, 'phosphatase': 1, 'fraction,': 1, 'well': 1, 'urinary': 1, 'excretion': 1, 'hydroxyproline': 1, 'oxalate': 1, 'been': 1, 'insulin-dependent': 1, 'I)': 1, 'diabetes,': 1, 'non-insulin-dependent': 1, 'II)': 1, 'diabetes': 1, '29': 1, 'healthy': 1, 'subjects': 1, 'limitation': 1, 'variables,': 1, 'specific': 1, 'production': 1, 'rates,': 1, 'reduced--apart': 1, 'proteinase--compared': 1, 'magnesium-replete': 1, 'common': 1, 'clinical': 1, 'reduced': 1, 'following': 1, 'pre-operative': 1, 'administration': 1, 'investigation,': 1, '40': 1, '0.4': 1, 'together': 1, 'concomitant': 1, 'blood': 1, 'potassium,': 1, 'rapidly': 1, 'regressed': 1, 'when': 1, 'decreasing': 1, 'glucagon': 1, 'on': 1, 'skin,': 1, 'decreased': 1, 'severity': 1, 'other': 1, 'plasma': 1, 'accurate': 1, 'predicting': 1, 'intracellular': 1, 'levels': 1, 'found': 1, 'soil': 1, 'drinking': 1, 'water': 1, 'samples': 1, 'ALS': 1, 'foci': 1, 'showing': 1, '(Ca)': 1, 'derangement': 1, 'mineralization': 1, 'induced': 1, 'by': 1, 'diets': 1, 'fed': 1, 'experimental': 1, 'rats,': 1, 'Mg': 1, 'mobilized': 1, 'bone,': 1, 'keeping': 1, 'their': 1, 'soft': 1, 'tissues,': 1, 'including': 1, 'CNS': 1, 'tissue,': 1, 'utilization': 1, 'vital': 1, 'activities,': 1, 'thereby': 1, 'resulting': 1, 'deposition': 1, 'while': 1, 'maintaining': 1, 'an': 1, 'almost': 1, 'value': 1, 'fully': 1, 'inhibited': 1, 'phosphoinositide-specific': 1, 'phospholipase': 1, 'C.': 1, 'GTP[S]': 1, 'did': 1, 'stimulate': 1, 'phosphomonoesterase': 1, 'activity,': 1, 'action': 1, 'due': 1, 'binding': 1, ')': 1, 'complemented': 1, 'essential': 1, 'amino': 1, 'acids,': 1, 'CPK,': 1, 'creatine': 1, 'phosphate': 1, 'HEPES': 1, 'buffer': 1, 'containing': 1, 'potassium': 1, 'acetate,': 1, 'PS-VT': 1, 'terminated': 1, 'immediately': 1, 'after': 1, 'half': 1, 'dose': 1, 'stimulatory': 1, 'concentrations': 1, 'serially': 1, 'monitor': 1, 'signs': 1, 'frequently': 1, 'present': 1, 'even': 1})
# Counter({'': 1})
# Counter({'': 8, ',': 3, 'of': 3, 'the': 3, 'caused': 3, 'by': 3, 'improvement': 2, 'in': 2, 'left': 2, 'ventricular': 2, 'pump': 2, 'function': 2, 'that': 2, 'and': 1, 'therapy': 1, 'with': 1, 'intravenous': 1, '20': 1, 'percent': 1, 'patients': 1, 'taking': 1, 'milrinone': 1, 'exceeded': 1, 'nitroprusside,': 1, 'suggesting': 1, 'a': 1, 'significant': 1, 'portion': 1})
# Counter({'': 3, 'allows': 1, 'prompt': 1, 'debridement': 1, 'beyond': 1, 'the': 1, 'margins': 1, 'of': 1, 'involved': 1, 'necrotic': 1, 'fascia,': 1, 'followed': 1, 'by': 1, 'wound': 1, 'inspection': 1, '8-hourly,': 1, 'and': 1, 'treatment': 1, 'with': 1, 'antibiotics,': 1, 'most': 1, 'recently': 1, 'third-generation': 1, 'cephalosporins,': 1, 'piperacillin,': 1})
# Counter({'': 2, 'in': 1})
# Counter({'': 1})
# Counter({'': 25, 'the': 12, 'is': 8, 'with': 7, 'oxytocin': 6, ',': 5, 'of': 4, 'immunoreactivity': 3, 'that': 3, 'released': 3, 'a': 3, 'in': 2, 'women': 2, 'uterine': 2, 'and': 2, 'not': 2, 'movements,': 2, 'cardiotocographic': 2, 'neurophysin': 2, 'novel': 2, 'peptide': 2, 'which': 2, 'antigenically': 2, 'similar': 2, 'to': 2, 'infant': 1, 'normal': 1, 'activity': 1, 'primary': 1, 'inertia': 1, 'treated': 1, 'who': 1, 'did': 1, 'require': 1, 'administration': 1, 'markers': 1, 'fetus': 1, 'uterus': 1, '(fetal': 1, 'fetal': 1, 'breathing': 1, 'amniotic': 1, 'fluid': 1, 'volume,': 1, 'maturity': 1, 'placenta,': 1, 'intestine': 1, 'distension,': 1, '"non': 1, 'stress': 1, 'test",': 1, '"': 1, 'yet': 1, 'concentration-response': 1, 'curves': 1, 'for': 1, 'pharmacological': 1, 'treatment': 1, 'synthetic': 1})
# Counter({'': 1})
# Counter({'': 1})
# Counter({'': 13, 'and': 5, 'in': 4, 'of': 3, 'were': 2, 'from': 2, 'after': 2, 'for': 2, ',': 2, 'the': 2, '0.9%': 1, 'sodium': 1, 'chloride': 1, 'injection': 1, 'placed': 1, '80-ml': 1, 'ethylene': 1, 'vinylacetate': 1, '(EVA)': 1, 'drug': 1, 'reservoirs': 1, 'protected': 1, 'light': 1, '1-ml': 1, 'quantities': 1, 'withdrawn': 1, 'immediately': 1, 'preparation': 1, 'storage': 1, '1,': 1, '2,': 1, '3,': 1, '4,': 1, '7,': 1, '14,': 1, '28': 1, 'days': 1, 'at': 1, '+22': 1, 'or': 1, '+35': 1, 'degrees': 1, 'C.': 1, 'Three': 1, 'samples': 1, 'each': 1, 'bleomycin,': 1, 'methotrexate': 1, 'are': 1, 'active': 1, 'cytostatic': 1, 'drugs': 1, 'penile': 1, 'cancer': 1, 'may': 1, 'have': 1, 'a': 1, 'role': 1, 'multimodality': 1, 'treatment': 1, 'this': 1, 'preexisting': 1, 'ileus,': 1, 'chemotherapy': 1, 'consisting': 1, 'because': 1, 'it': 1, 'had': 1, 'less': 1, 'cytotoxicity': 1, 'retained': 1, 'same': 1, 'antitumor': 1, 'activity': 1, 'compared': 1, 'with': 1, 'experimentally': 1, 'induced': 1, 'polyuric': 1, 'acute': 1, 'renal': 1, 'failure': 1, 'by': 1})
# Counter({'': 284, 'of': 83, 'the': 76, 'and': 52, 'in': 36, 'a': 35, 'with': 26, 'to': 24, 'sodium': 17, 'for': 16, ',': 16, 'was': 15, 'were': 14, 'on': 14, 'by': 13, 'an': 12, 'treatment': 11, 'after': 10, 'is': 8, 'not': 8, 'which': 7, 'under': 7, 'be': 7, 'pyruvate': 7, 'or': 6, 'who': 6, 'increase': 6, '=': 6, 'affinity': 6, 'excretion': 5, 'potassium': 5, 'significant': 5, 'at': 5, 'gel': 5, 'plasma': 5, 'this': 5, 'may': 5, 'increased': 5, 'did': 5, 'transport': 5, 'revealed': 4, 'concentrations': 4, 'degrees': 4, 'dodecyl': 4, 'electrophoresis': 4, 'concentration': 4, 'but': 4, 'showed': 4, 'proteins': 4, 'delta': 4, 'presence': 4, 'mM': 4, 'no': 4, 'DCC': 4, 'addition': 4, 'its': 4, '(Kt': 4, 'intracellular': 3, 'sulfate-polyacrylamide': 3, 'balance': 3, 'has': 3, 'been': 3, 'when': 3, 'into': 3, 'synthesis': 3, 'however,': 3, 'depending': 3, 'clinical': 3, 'that': 3, 'observed': 3, 'intake': 3, 'cells': 3, '2': 3, 'blood': 3, 'warfarin': 3, 'improved': 3, 'response': 3, 'volume': 3, 'aqueous': 3, 'influence': 3, 'both': 3, 'than': 3, 'condition': 3, 'without': 3, 'solution': 3, 'containing': 3, 'one': 3, 'high': 3, 'low': 3, 'known': 2, 'urinary': 2, 'fractional': 2, 'measured': 2, 'as': 2, 'external': 2, 'chloride': 2, 'withdrawn': 2, 'storage': 2, 'days': 2, 'C.': 2, 'purified': 2, 'reduced': 2, 'replacement': 2, 'stimulate': 2, 'diet': 2, 'bicarbonate': 2, 'decreased': 2, 'urine': 2, 'giant': 2, 'used': 2, 'could': 2, 'level': 2, 'only': 2, 'upon': 2, 'also': 2, 'water': 2, 'stored': 2, '4': 2, 'hrs': 2, '0': 2, 'changes': 2, 'cell': 2, 'change': 2, 'seems': 2, 'within': 2, 'abdomen,': 2, 'man': 2, 'ingested': 2, '500': 2, 'mg': 2, 'nurse': 2, 'they': 2, 'are': 2, 'F': 2, 'less': 2, 'nine': 2, 'patients': 2, 'diclofenac': 2, 'have': 2, 'whereas': 2, 'loading': 2, 'simultaneous': 2, 'she': 2, 'where': 2, 'treated': 2, 'initially': 2, 'then': 2, 'renal': 2, 'crystals': 2, 'obtained': 2, 'agent': 2, 'mg.day-1': 2, 'edema': 2, 'preparations': 2, 'their': 2, ':': 2, 'creatinine,': 2, 'protein,': 2, 'raising': 2, 'bathing': 2, 'decrease': 2, 'intraerythrocyte': 2, 'ME': 2, 'structural': 2, 'separated': 2, 'polyacrylamide': 2, 'causes': 2, 'kidneys': 2, '(TSK-gel': 2, 'DEAE-5PW': 2, 'glass': 2, 'column': 2, '8.0': 2, 'mm': 2, 'ID': 2, 'x': 2, '7.5': 2, 'cm': 2, '20': 2, 'psi': 2, '0,': 2, 'initial': 2, 'rates': 2, 'existence': 2, 'two': 2, 'families': 2, 'sites,': 2, '88': 2, 'microM)': 2, 'mM)': 2, 'serum': 2, 'it': 2, 'azide': 1, 'produce': 1, 'alterations': 1, 'mammalian': 1, 'copper': 1, 'proteins,': 1, 'thus': 1, 'rendering': 1, 'them': 1, 'unable': 1, 'bind': 1, 'exogenous': 1, 'metal,': 1, 'remains': 1, '"labile': 1, 'pool"': 1, '(UNaV),': 1, '(UKV),': 1, '(FENa),': 1, '(FEK)': 1, 'evidence': 1, 'genetic': 1, 'variance': 1, 'fluxes': 1, 'changed': 1, 'K-free': 1, 'injection': 1, 'placed': 1, '80-ml': 1, 'ethylene': 1, 'vinylacetate': 1, '(EVA)': 1, 'drug': 1, 'reservoirs': 1, 'protected': 1, 'from': 1, 'light': 1, '1-ml': 1, 'quantities': 1, 'immediately': 1, 'preparation': 1, '1,': 1, '2,': 1, '3,': 1, '4,': 1, '7,': 1, '14,': 1, '28': 1, '+22': 1, '+35': 1, 'Three': 1, 'samples': 1, 'each': 1, 'fibrinogen': 1, 'output': 1, '(urine),': 1, 'input': 1, '(feeding': 1, 'plus': 1, 'supplement)': 1, 'calculate': 1, 'supplement': 1, 'needed': 1, 'maintain': 1, 'hormone': 1, 'fluoride': 1, 'bone': 1, 'formation': 1, 'fully': 1, 'tested': 1, 'saccharin': 1, 'promoter': 1, 'incorporated': 1, 'Wayne': 1, 'AIN': 1, 'diet,': 1, 'ability': 1, 'DNA': 1, 'important': 1, 'insufficient': 1, 'dihydrogen': 1, 'phosphate': 1, 'pH,': 1, 'respectively,': 1, 'affected': 1, 'neither': 1, 'calcium': 1, 'inward': 1, 'currents': 1, '(INa': 1, 'ICa)': 1, 'identifiable': 1, 'neurone,': 1, 'd-RPLN': 1, '(dorsal-right': 1, 'parietal': 1, 'large': 1, 'neurone),': 1, 'African': 1, 'snail': 1, '(Achatina': 1, 'fulica': 1, 'Férussac),': 1, 'separately': 1, 'voltage': 1, 'clamp': 1, 'dichloroisocyanurate': 1, 'soluble': 1, 'water;': 1, 'suitable': 1 ...
# Counter({'': 7, 'of': 6, 'and': 4, 'the': 3, 'induced': 2, 'by': 2, '2': 2, 'was': 2, 'a': 2, 'selective': 1, 'depletion': 1, 'brain': 1, 'amines': 1, 'repeated': 1, 'administrations': 1, 'syrosingopine,': 1, 'mg/kg': 1, 'daily': 1, 'for': 1, 'days,': 1, 'analgesic': 1, 'action': 1, 'morphine': 1, 'not': 1, 'affected,': 1, 'whereas': 1, 'catecholamine': 1, 'exhaustion': 1, 'in': 1, 'nerve': 1, 'endings': 1, 'administration': 1, 'H44/68': 1, 'were': 1, 'standardized': 1, 'compared': 1, 'before': 1, 'after': 1, 'four': 1, 'weeks': 1, 'ambulatory': 1, 'treatment': 1, 'with': 1, 'diisopropylamine': 1, '(3': 1, 'times': 1, '200': 1, 'mg': 1, 'day)': 1})
# Counter({'': 5, 'of': 5, 'the': 3, 'in': 2, 'with': 2, 'a': 2, 'these': 2, 'high': 2, 'patients': 1, 'reflux': 1, 'esophagitis': 1, 'completing': 1, 'trial': 1, 'suggest': 1, 'benefit': 1, 'agents,': 1, 'absence': 1, 'placebo': 1, 'control': 1, 'group': 1, 'and': 1, 'default': 1, 'rates,': 1, 'particularly': 1, 'for': 1, 'those': 1, 'receiving': 1, 'sucralfate,': 1, 'preclude': 1, 'any': 1, 'firm': 1, 'conclusions': 1, 'as': 1, 'to': 1, 'relative': 1, 'or': 1, 'specific': 1, 'efficacy': 1, 'agents': 1, 'this': 1, 'was': 1, 'achieved': 1, 'by': 1, 'treatment': 1, 'omeprazole': 1, 'after': 1, 'failure': 1, 'other': 1, 'therapeutic': 1, 'measures,': 1, 'including': 1, 'doses': 1})
# Counter({'': 1})
# Counter({'': 11, 'awakening,': 2, 'with': 2, 'the': 2, 'following': 1, 'upon': 1, 'whereas': 1, ',': 1, 'producing': 1, 'a': 1, 'dose-dependent': 1, 'shift': 1, 'to': 1, 'right': 1, 'of': 1, 'on': 1, 'awakening': 1, 'was': 1, 'better': 1})
# Counter({'': 9, 'the': 3, 'to': 2, 'with': 2, 'therapy': 1, 'initially': 1, 'produced': 1, 'dramatic': 1, 'improvement,': 1, 'but': 1, 'treatment': 1, 'and': 1, 'neutrophil': 1, 'function': 1, 'improved': 1, 'use': 1, 'of': 1, 'who': 1, 'responded': 1, 'well': 1})
# Counter({'': 2, '10': 1, 'months': 1, 'after': 1, 'diagnosis': 1, 'on': 1, 'a': 1, 'regimen': 1, 'of': 1})
# Counter({'': 4, 'with': 1, 'large': 1, 'oesophageal': 1, 'varices,': 1, 'this': 1, 'study': 1, 'suggests': 1, 'that': 1})
# Counter({'': 9, 'and': 5, 'of': 2, 'with': 2, 'from': 2, 'the': 1, 'intrathoracic': 1, 'organs,': 1, 'radiotherapeutic': 1, 'techniques': 1, 'doses,': 1, 'combined': 1, 'therapy': 1, 'preexisting': 1, 'ileus,': 1, 'chemotherapy': 1, 'consisting': 1, 'cisplatin,': 1, ',': 1, 'responses': 1, 'to': 1, 'prior': 1, 'chemotherapeutic': 1, 'regimens': 1, 'toxic': 1, 'side': 1, 'effects,': 1, 'particularly': 1, 'Adriamycin': 1, 'adenomatous': 1, 'polyposis': 1, 'coli': 1, '(APC)': 1, 'were': 1, 'treated': 1, 'N-methyl-N1-nitro-N-nitrosoguanidine': 1, '(MNNG)': 1})
# Counter({'': 11, 'of': 4, 'was': 3, 'to': 2, 'improved': 2, 'by': 2, 'pulses': 1, 'failed': 1, 'improve': 1, 'the': 1, "patient's": 1, 'each': 1, 'patient': 1, 'notably': 1, 'a': 1, 'series': 1, 'direct': 1, 'injections': 1, 'considered': 1, 'be': 1, 'permeability': 1, 'edema': 1, 'developing': 1, 'adult': 1, 'respiratory': 1, 'distress': 1, 'syndrome': 1, '(ARDS)': 1, 'and': 1, '1': 1, 'g/day': 1})
# Counter({'': 1})
# Counter({'': 11, 'of': 6, 'and': 5, 'the': 5, 'administration': 4, ',': 3, 'was': 3, 'to': 3, 'she': 2, 'a': 2, 'improved': 2, 'following': 2, 'by': 2, 'systemic': 1, 'carbenicillin': 1, 'admitted': 1, 'hospital': 1, 'where': 1, 'treated': 1, 'initially': 1, 'with': 1, 'procaine': 1, 'penicillin': 1, 'G,': 1, 'then': 1, 'methicillin': 1, 'sodium': 1, 'blood': 1, 'cultures': 1, 'became': 1, 'negative': 1, 'usefulness': 1, 'increased': 1, 'urinary': 1, 'amino': 1, 'acid': 1, 'excretion': 1, 'as': 1, 'marker': 1, 'investigated': 1, 'inducing': 1, 'renal': 1, 'tubular': 1, 'necrosis': 1, 'in': 1, 'male': 1, 'Wistar': 1, 'rats': 1, 'led': 1, 'graded': 1, 'additions': 1, 'treatment': 1, 'regimen:': 1, 'lactose-free': 1, 'soya': 1, 'diet,': 1, 'oral': 1, 'rapidly': 1, 'after': 1, 'drainage': 1, 'abscess': 1, 'LMOX': 1})
# Counter({'PRL': 3, '': 3, 'receptor': 2, 'an': 2, 'on': 2, 'secretion': 2, ',': 1, 'GABAb': 1, "don't": 1, 'play': 1, 'obvious': 1, 'role': 1, 'in': 1, 'modulation': 1, 'of': 1, 'secretion;': 1, 'when': 1, 'H2': 1, 'istaminergic': 1, 'inhibition': 1, 'is': 1, 'blocked': 1, '(at': 1, 'hypothalamic': 1, 'site),': 1, 'a': 1, 'GABA': 1, 'inhibition,': 1, 'b': 1, 'mediated,': 1, 'became': 1, 'more': 1, 'clear;': 1, 'the': 1, 'was': 1, 'evaluated': 1, 'one': 1, 'to': 1, 'three': 1, 'years': 1, 'later': 1, 'by': 1, 'TRH,': 1, 'nomifensine,': 1, 'and': 1})
# Counter({'': 1})
# Counter({'': 4, '10': 2, 'a': 2, 'in': 2, 'did': 1, 'not': 1, 'produce': 1, 'any': 1, 'behavioral': 1, 'side': 1, 'effects': 1, 'during': 1, 'either': 1, 'drug': 1, 'mg,': 1, 'as': 1, 'solution': 1, 'soft': 1, 'gelatin': 1, 'capsules,': 1, 'was': 1, 'given': 1, 'to': 1, 'fasting': 1, 'geriatric': 1, 'in-patients': 1, '(mean': 1, 'age': 1, '83': 1, 'years)': 1, 'stable': 1, 'clinical': 1})
# Counter({'': 6, 'of': 3, 'and': 2, 'severe': 2, ',': 2, 'brikanil': 1, 'produces': 1, 'a': 1, 'number': 1, 'favorable': 1, 'ventilatory': 1, 'hemodynamic': 1, 'effects,': 1, 'conducive': 1, 'to': 1, 'the': 1, 'stabilization': 1, 'clinical': 1, 'five': 1, 'patients': 1, 'with': 1, 'or': 1, 'medium': 1, 'asthma': 1, 'was': 1, 'considerably': 1, 'relieved': 1, 'by': 1, 'atenolol': 1, 'and/or': 1, 'verapamil,': 1})
# Counter({'': 3, 'and': 2, 'improving': 1, 'after': 1, 'pericardial': 1, 'drainage': 1, 'parenteral': 1, 'intrapericardial': 1, 'administration': 1, 'of': 1})
# Counter({'': 3, 'and': 3, 'were': 2, 'to': 2, 'of': 2, 'terfenadine': 1, 'significantly': 1, 'superior': 1, 'placebo': 1, '(p': 1, 'less': 1, 'than': 1, 'or': 1, 'equal': 1, '0.004),': 1, 'the': 1, 'two': 1, 'active': 1, 'medications': 1, 'statistically': 1, 'comparable,': 1, 'based': 1, 'on': 1, 'mean': 1, 'totals': 1, 'sign/symptom': 1, 'severity': 1, 'scores': 1, 'ratings': 1, 'overall': 1, 'disease': 1})
# Counter({'': 4, 'in': 2, 'total': 1, 'body': 1, 'clearance': 1, 'was': 1, 'reduced': 1, 'decompensated': 1, 'cirrhosis,': 1, 'indicating': 1, 'that': 1, 'the': 1, 'dose': 1, 'schedule': 1, 'requires': 1, 'modification': 1, 'patients': 1, 'with': 1, 'this': 1})
# Counter({'': 2, 'tolerance': 2, 'where': 1, 'developed': 1, 'rapidly': 1, 'to': 1, 'the': 1, 'depressant': 1, 'activity': 1, 'of': 1, 'benzodiazepines': 1, 'little': 1, 'was': 1, 'seen': 1, 'with': 1})
# Counter({'': 3, 'as': 1, 'mentioned': 1, 'above': 1, 'and': 1, 'significant': 1, 'amount': 1, 'of': 1, '(nesting),': 1, '[3H]': 1})
# Counter({'': 1})
# Counter({'': 1})
# Counter({'': 5})
# Counter({'': 75, 'the': 20, 'of': 20, 'and': 18, 'in': 12, 'a': 9, 'to': 7, ',': 4, 'periods': 4, 'is': 3, 'with': 3, 'for': 3, 'been': 2, 'be': 2, 'effective': 2, 'this': 2, 'patients': 2, 'stimulated': 2, 'incorporation': 2, 'thyroid': 2, 'cells': 2, 'basal': 2, 'on': 2, 'use': 2, 'when': 2, 'patient,': 2, '(2)': 2, 'develops': 2, 'an': 2, 'appropriate': 2, 'blood': 2, 'sampling': 2, 'schedule,': 2, '(3)': 2, 'initiates': 2, 'maintains': 2, 'serial': 2, 'lithium': 2, 'erythrocyte': 2, 'plasma': 2, 'following': 2, 'two': 2, 'weeks': 2, 'maintenance': 2, '0.7': 2, '1.2': 2, 'MEQ/L': 2, 'therapy': 2, 'which': 2, 'relatively': 2, 'euthymic': 2, 'variable': 2, 'duration': 2, 'separate': 2, 'mania': 2, 'depression,': 2, 'specificity': 2, 'that': 2, 'intoxication': 1, 'serious': 1, 'carbonate': 1, 'has': 1, 'shown': 1, 'only': 1, 'reliably': 1, 'treatment': 1, 'chloride': 1, 'was': 1, 'used': 1, 'aversively': 1, 'clearance': 1, "Gordon's": 1, 'syndrome': 1, 'supports': 1, 'hypothesis': 1, 'increased': 1, 'proximal': 1, 'sodium': 1, 'reabsorption': 1, '[3H]thymidine': 1, '[3H]': 1, 'thymidine': 1, '(as': 1, 'chloride,': 1, '0.15': 1, 'mEq/kg,': 1, '6': 1, 'days)': 1, 'counteracted': 1, 'latent': 1, 'inhibition': 1, 'impaired': 1, 'acquisition': 1, 'conditioned': 1, 'response': 1, 'nonpreexposed': 1, 'discharge': 1, 'close': 1, 'clinical,': 1, 'electrocardiographic': 1, 'ionic': 1, 'surveillance,': 1, 'cardiac': 1, 'renal': 1, 'failure': 1, 'neuropsychiatric': 1, 'disturbances': 1, 'do': 1, 'not': 1, 'prevent': 1, 'treated': 1, 'continued': 1, 'lethargy': 1, 'muscle': 1, 'weakness': 1, 'trial': 1, 'patient': 1, 'profile,': 1, '(4)': 1, 'evaluates': 1, 'serum': 1, 'levels': 1, 'relation': 1, 'established': 1, 'criteria': 1, 'provide': 1, 'basis': 1, 'differential': 1, 'diagnosis': 1, '(5)': 1, 'individualizes': 1, ';': 1, 'then': 1, 'condition': 1, 'several': 1, 'forms': 1, 'have': 1, 'developed,': 1, 'ranging': 1, 'from': 1, 'focus': 1, 'therapeutic': 1, 'milieu': 1, 'pharmacologic': 1, 'antidepressants': 1, '(particularly': 1, 'receiving': 1, 'long-term': 1, 'contraindicated': 1, 'tricyclic': 1, 'antidepressants,': 1, 'whom': 1, 'combination': 1, 'mianserin': 1, 'suggests': 1, 'molecular': 1, 'target': 1, 'illness': 1, 'may': 1, 'system': 1, 'bidirectionally': 1, 'influences': 1, 'neurotransmission': 1, 'affected': 1, 'by': 1, 'nu': 1, '=': 1, '(1/2': 1, 'pi)(q/m)Bo,': 1, 'singly': 1, 'charged': 1, 'there': 1, 'no': 1, 'change': 1, 'intracellular': 1, 'potential': 1})
# Counter({'': 16, 'after': 5, 'of': 4, 'and': 4, 'three': 4, 'a': 3, 'with': 3, 'alone,': 2, 'two': 2, 'total': 2, 'dose': 2, '12.25': 2, 'mg/kg': 2, '14': 2, 'mg/kg;': 2, 'others': 2, 'were': 2, 'in': 2, 'poor': 2, 'died': 2, 'five': 1, 'died;': 1, 'CBA': 1, 'mice': 1, 'bone': 1, 'marrow': 1, 'hemopoiesis': 1, 'functional': 1, 'activity': 1, 'adherent': 1, 'cells': 1, '6': 1, 'months': 1, 'single': 1, 'treatment': 1, 'vinblastine': 1, '(VB),': 1, 'for': 1, 'reversing': 1, '4.21': 1, '+/-': 1, '0.2;': 1, 'improved': 1, 'chemotherapy': 1, '(vinblastine': 1})
# Counter({'': 3, 'as': 2, 'to': 2, ',': 1, 'well': 1, 'introduce': 1, 'medication': 1, 'which': 1, 'will': 1, 'also': 1, 'suppress': 1, 'the': 1, 'spasm': 1, '(': 1})
# Counter({'': 2, 'the': 2, 'binding': 1, 'of': 1})
# Counter({'': 1})
# Counter({'': 4, 'a': 2, 'of': 2, 'may': 1, 'be': 1, 'very': 1, 'persistent': 1, 'and': 1, 'recognized': 1, 'treatments': 1, 'include': 1, 'brushing': 1, 'with': 1, 'soft': 1, 'tooth': 1, 'brush': 1, 'which': 1, 'is': 1, 'enhanced': 1, 'by': 1, 'the': 1, 'prior': 1, 'application': 1, '40%': 1, 'solution': 1, 'urea,': 1, 'scraping,': 1, 'topical': 1, 'triamcinolone': 1})
# Counter({'': 9, 'the': 3, 'to': 3, 'has': 2, 'been': 2, 'treatment': 2, 'of': 2, 'she': 2, 'was': 2, 'with': 2, 'advocated': 1, 'in': 1, 'malignant': 1, 'hyperpyrexia,': 1, 'whereas': 1, 'lignocaine': 1, 'shown': 1, 'worsen': 1, ',': 1, 'admitted': 1, 'a': 1, 'hospital': 1, 'where': 1, 'treated': 1, 'initially': 1, 'responded': 1, 'briskly': 1, 'and': 1, 'administration': 1})
# Counter({'': 2, 'or': 1, 'with': 1, 'thrombocytopenia': 1, 'before': 1, 'treatment': 1, 'should': 1, 'have': 1, 'a': 1, 'reduced': 1})
# Counter({'': 1})
# Counter({'': 1})
# Counter({'': 2, 'of': 2, 'infection': 2, 'the': 2, 'Baylisascaris': 1, 'transfuga': 1, 'five': 1, 'polar': 1, 'bears': 1, 'is': 1, 'reported': 1, 'and': 1, 'a': 1, 'control': 1, 'measure': 1, 'programme': 1, 'directed': 1, 'towards': 1, 'limiting': 1, 'under': 1, 'prevailing': 1})
# Counter({'': 4, 'in': 2, 'the': 2, 'of': 2, ',': 2, 'with': 2, '99': 1, 'diphosphonate': 1, 'bone': 1, 'scanning': 1, 'diagnosis': 1, 'this': 1, 'was': 1, 'diagnosed': 1, 'preoperatively': 1, 'a': 1, '4-year-old': 1, 'girl,': 1, 'aid': 1, 'history,': 1, 'physical': 1, 'examination,': 1, 'blood': 1, 'smear': 1, 'findings,': 1, 'splenic': 1, 'scans': 1, 'include': 1, 'good-quality': 1, 'plain': 1, 'radiographs,': 1})
# Counter({'': 6, 'finally': 1, 'responded': 1, 'to': 1})
# Counter({'ng),': 4, '': 2, '(10-100': 2, '(1-10': 2, 'granisetron': 1, 'ICS205-930': 1, 'GR': 1, '65630': 1, 'and': 1, 'MDL72222': 1, '(100-1000': 1, 'ng)': 1, 'all': 1, 'significantly': 1, 'increased': 1, 'SI': 1, 'under': 1, 'the': 1, 'HLU': 1, 'but': 1, 'not': 1, 'LLF': 1})
# Counter({'': 7, 'the': 4, '(DDAVP)': 2, 'in': 2, 'of': 2, 'diabetes': 2, 'as': 2, 'acetate': 2, 'was': 2, 'and': 2, 'with': 2, 'a': 2, 'is': 1, 'used': 1, 'intramuscularly': 1, 'treatment': 1, 'post': 1, 'operative': 1, 'insipidus': 1, 'soon': 1, '(0.3': 1, 'micrograms/kg)': 1, 'infused': 1, 'over': 1, '30': 1, 'min': 1, '9': 1, 'controls': 1, '11': 1, 'subjects': 1, 'mellitus,': 1, 'appropriately': 1, 'managed': 1, 'DI,': 1, 'not': 1, 'associated': 1, 'worsening': 1})
# Counter({'the': 3, '': 2, 'and': 2, 'of': 2, 'with': 1, 'either': 1, 'drug,': 1, 'dose-sparing': 1, 'effect': 1, 'both': 1, 'enteric-coated': 1, 'preparation,': 1})
# Counter({'': 3, 'corrected': 1, 'itself': 1, 'when': 1, 'the': 1})
# Counter({'': 3, 'responded': 1, 'well': 1, 'to': 1, 'penicillin': 1, 'and': 1})
# Counter({'': 12, 'the': 5, 'with': 4, 'of': 3, 'was': 2, 'and': 2, 'after': 2, 'improved': 2, 'treatment': 2, 'given': 1, 'initially': 1, 'intravenously': 1, 'then': 1, 'orally,': 1, 'improvement': 1, 'general': 1, 'administered': 1, 'within': 1, '48': 1, 'hours': 1, 'initial': 1, 'examination,': 1, 'clinical': 1, 'use': 1, 'topical': 1, 'gradually': 1, "legionnaires'": 1, 'disease': 1, ',': 1, 'we': 1, 'suspected': 1, 'legionella': 1, 'pneumonia': 1, 'changed': 1, 'therapy': 1, 'to': 1, 'deteriorates': 1, 'during': 1})
# Counter({'': 6, 'the': 3, 'of': 3, 'ml': 2, 'and': 2, 'doses': 1, 'from': 1, '2.5': 1, 'to': 1, '4.0': 1, 'depending': 1, 'on': 1, 'infants,': 1, 'but': 1, 'did': 1, 'alter': 1, 'acid-base': 1, 'state': 1, 'baby': 1, 'at': 1, 'birth': 1, 'its': 1, 'subsequent': 1, 'behaviour': 1, 'were': 1, 'compared': 1, 'in': 1, 'three': 1, 'groups': 1, 'infants': 1, 'whose': 1, 'mothers': 1, 'received': 1, 'during': 1, 'labour': 1, 'either': 1, 'no': 1, 'drugs,': 1, 'intramuscular': 1, 'pethidine': 1, 'or': 1, 'epidural': 1})
# Counter({'': 1})
# Counter({'': 58, 'the': 29, 'of': 14, 'to': 10, 'and': 9, 'in': 9, 'under': 8, 'with': 6, 'on': 6, 'a': 5, 'training': 5, 'determined': 4, 'were': 4, 'but': 3, ',': 3, 'responding': 3, 'condition': 3, 'treatment': 3, 'day': 3, 'not': 2, 'for': 2, 'session': 2, 'test': 2, 'increase': 2, 'pentobarbital,': 2, 'triazolam,': 2, 'meprobamate,': 2, 'zopiclone': 2, 'occasioned': 2, '100%': 2, 'drug-lever': 2, 'tests': 2, 'both': 2, 'conditions;': 2, 'generalization': 2, 'gradients': 2, 'pentobarbital': 2, 'shifted': 2, 'right': 2, 'those': 2, 'diazepam': 2, 'effect': 2, ':': 2, 'treated': 2, 'then': 2, 'after': 2, '(baboons': 2, 'maintained': 2, '20': 2, 'mg/kg': 2, 'per': 2, 'which': 2, 'be': 2, 'either': 2, 'as': 2, 'transiently': 1, 'reverses': 1, 'component': 1, 'dialysis': 1, 'encephalopathy': 1, 'syndrome,': 1, 'it': 1, 'does': 1, 'appear': 1, 'change': 1, 'ultimate': 1, 'prognosis': 1, 'patients': 1, 'this': 1, 'given': 1, 'before': 1, 'Pavlovian': 1, 'conditioning': 1, 'and/or': 1, 'did': 1, 'prevent': 1, 'response': 1, 'CS': 1, 'presentation;': 1, 'however,': 1, 'temporal': 1, 'pattern': 1, 'differed': 1, 'according': 1, 'drug': 1, 'led': 1, 'return': 1, "patient's": 1, 'usual': 1, 'there': 1, 'increases': 1, 'number': 1, 'infusions': 1, 'deprivation': 1, 'relative': 1, 'satiation': 1, 'had': 1, 'no': 1, 'significant': 1, 'responses': 1, 'carbachol': 1, '22': 1, 'degrees': 1, 'C': 1, 'labour:': 1, 'its': 1, 'metabolism': 1, 'clinical': 1, '(': 1, 'eventually': 1, 'deteriorated': 1, 'despite': 1, 'continued': 1, 'significantly': 1, 'delayed': 1, 'peak': 1, 'CS;': 1, 'pigs': 1, 'an': 1, 'injection': 1, 'appeared': 1, 'acutely,': 1, 'progressed': 1, 'over': 1, 'several': 1, 'hours': 1, 'disappeared': 1, '2-3': 1, 'days': 1, 'diazepam-dependent': 1, 'who': 1, 'received': 1, 'anesthesia': 1, 'fentanyl,': 1, '2.5': 1, 'micrograms/kg-1,': 1, 'can': 1, 'diagnosed': 1, 'NIC': 1, 'or': 1, 'mild': 1, 'form': 1, 'NMS': 1, 'has': 1, 'been': 1, 'successfully': 1, 'combination': 1, 'amantadine': 1, '(600': 1, 'mg/day)': 1, '(i.e.,': 1, 'angular': 1, 'difference': 1, 'orientation': 1, 'between': 1, 'two': 1, 'identical': 1, 'stimulus': 1, 'figures)': 1, 'computed': 1, 'their': 1, 'dose': 1, 'was': 1, 'tapered': 1, 'regime': 1, 'active': 1, '(4': 1, 'ml/kg)': 1, 'benzodiazepine': 1, '(BDZ)': 1, 'agonists': 1})
# Counter({'': 2})
# Counter({'': 6, 'of': 5, 'the': 2, 'to': 1, 'compute': 1, 'conformation': 1, 'normal': 1, 'and': 1, 'inhibited': 1, 'ionic': 1, 'equilibrium': 1, 'has': 1, 'been': 1, 'developed': 1, 'using': 1, 'a': 1, 'combination': 1, 'heat': 1, 'incubation': 1})
# Counter({'': 3, 'of': 1, 'her': 1, 'probation;': 1, 'legislators': 1, 'have': 1, 'proposed': 1, 'that': 1, 'women': 1, 'on': 1, 'welfare': 1, 'be': 1, 'paid': 1, 'to': 1, 'use': 1})
# Counter({'or': 6, 'and': 3, '': 2, 'mg/mL,': 2, '1.25': 2, 'in': 2, 'injection': 2, 'were': 2, 'after': 2, '4,': 2, '50': 1, '10': 1, 'cytarabine': 1, '25': 1, 'doxorubicin': 1, 'hydrochloride': 1, '0.5': 1, 'mg/mL': 1, '0.9%': 1, 'sodium': 1, 'chloride': 1, '5%': 1, 'dextrose': 1, 'placed': 1, '80-mL': 1, 'ethylene': 1, 'vinylacetate': 1, 'drug': 1, 'reservoirs': 1, 'protected': 1, 'from': 1, 'light,': 1, '1-mL': 1, 'quantities': 1, 'withdrawn': 1, 'immediately': 1, 'preparation': 1, 'storage': 1, 'for': 1, '1,': 1, '2,': 1, '3,': 1, '7,': 1, '14,': 1, '28': 1, 'days': 1, 'at': 1, '22,': 1, '35': 1, 'degrees': 1, 'C.': 1, 'For': 1, 'each': 1})
# Counter({'': 3, 'was': 1, 'only': 1, 'partially': 1, 'controlled': 1, 'by': 1, 'a': 1, ',': 1, 'stable': 1, 'expression': 1, 'of': 1})
# Counter({'': 10, 'with': 1, 'the': 1, 'combined': 1, 'administration': 1, 'of': 1, 'chlorpheniramine': 1, '+': 1, '(hypothermia)': 1, 'or': 1, 'drug': 1, '(': 1})
# Counter({'': 4, 'and': 2, 'tested,': 1, 'rifampicin,': 1, 'isoniazid,': 1, 'ethambutol,': 1, 'ethionamide': 1, 'cycloserine': 1, 'did': 1, 'not': 1, 'exhibit': 1, 'any': 1, 'bactericidal': 1, 'activity,': 1, 'only': 1})
# Counter({'': 2, 'was': 1, 'not': 1, 'evident': 1, 'at': 1, 'the': 1, '7-day': 1, 'follow-up': 1, 'visit,': 1, 'a': 1, 'second': 1, 'dose': 1, 'of': 1})
# Counter({'the': 4, 'under': 3, 'training': 3, 'determined': 2, '': 2, ',': 1, 'and': 1, 'zopiclone': 1, 'occasioned': 1, '100%': 1, 'drug-lever': 1, 'responding': 1, 'in': 1, 'tests': 1, 'both': 1, 'conditions;': 1, 'but': 1, 'generalization': 1, 'gradients': 1, 'pentobarbital': 1, 'condition': 1, 'were': 1, 'shifted': 1, 'to': 1, 'right': 1, 'of': 1, 'those': 1, 'diazepam': 1})
# Counter({'': 8, 'of': 3, 'which': 2, 'as': 2, 'a': 2, 'and': 2, 'with': 2, 'was': 2, 'can': 1, 'be': 1, 'diagnosed': 1, 'either': 1, 'NIC': 1, 'or': 1, 'mild': 1, 'form': 1, 'NMS': 1, 'has': 1, 'been': 1, 'treated': 1, 'successfully': 1, 'combination': 1, 'corrected': 1, 'by': 1, 'reintroduction': 1, 'markedly': 1, 'improved': 1, 'pimozide': 1, 'after': 1, 'benztropine': 1, 'mesylate,': 1, 'clonazepam': 1})
# Counter({'': 6, 'with': 2, 'is': 1, 'easily': 1, 'controlled': 1, 'was': 1, 'markedly': 1, 'improved': 1, 'pimozide': 1, 'after': 1, 'benztropine': 1, 'mesylate,': 1})
# Counter({'': 2, 'by': 1, 'increasing': 1, 'inspired': 1})
# ...
# Counter({'': 4, 'was': 3, 'and': 3, 'to': 2, 'of': 2, 'UV': 2, 'reaction': 1, '120': 1, 'sec': 1, 'irradiation': 1, 'assessed': 1, 'after': 1, '1,': 1, '2': 1, '4': 1, 'h.': 1, 'A': 1, 'direct': 1, 'quantitative': 1, 'comparison': 1, 'the': 1, 'anti-erythema': 1, 'effect': 1, 'made': 1, 'between': 1, 'phenylbutazone,': 1, 'induced': 1, 'by': 1, 'irradiation,': 1, 'which': 1, 'equal': 1, '3': 1, 'times': 1, 'stronger': 1, 'than': 1, 'pranoprofen': 1})
# Counter({'': 1})
# Counter({'': 3, 'a': 2, 'as': 2, 'is': 1, 'best': 1, 'treated': 1, 'with': 1, 'combination': 1, 'of': 1, 'thiazide': 1, 'diuretics': 1, 'well': 1, 'diet': 1, 'low': 1, 'in': 1})
# Counter({'': 1})
# Counter({'': 1})
# Counter({'': 76, 'in': 14, 'of': 12, 'with': 11, 'A': 9, 'and': 9, 'a': 8, 'the': 8, 'to': 6, 'were': 5, 'for': 4, 'patients': 4, 'treatment': 4, '(RA)': 4, 'effects': 3, 'study': 3, 'from': 3, 'clinical': 2, 'is': 2, 'decrease': 2, 'effect': 2, '(CyA)': 2, 'was': 2, 'side': 2, 'an': 2, 'open': 2, 'randomized': 2, 'be': 2, 'effective': 2, 'refractory': 2, 'into': 2, 'centres': 2, 'randomised': 2, 'receive': 2, 'have': 2, 'oral': 2, 'treated': 2, 'entered': 2, 'improves': 1, 'markers': 1, 'synovial': 1, 'inflammation': 1, 'useful': 1, 'individual': 1, 'led': 1, 'percentage': 1, 'm5Cyt': 1, 'three': 1, 'on': 1, 'sodium': 1, 'potassium': 1, 'transport': 1, 'across': 1, 'erythrocytes': 1, 'administered': 1, '6': 1, 'cases': 1, 'classical': 1, 'or': 1, 'definite,': 1, 'seropositive': 1, 'A):': 1, 'mode': 1, 'action': 1, 'results': 1, 'severe,': 1, 'treatment-refractory': 1, 'azathioprine': 1, '(Aza)': 1, 'compared': 1, 'respect': 1, 'renal': 1, 'controlled,': 1, 'seems': 1, 'active': 1, 'clinically': 1, 'special': 1, 'reference': 1, 'can': 1, 'classified': 1, 'two': 1, 'categories:': 1, 'typical': 1, 'four': 1, 'Australian': 1, ';': 1, 'beneficial': 1, 'ulcerative': 1, 'colitis;': 1, 'combination': 1, 'drugs,': 1, 'improve': 1, 'skin': 1, 'lesions,': 1, 'lower': 1, 'hyperlipidemia': 1, 'etretinates,': 1, 'toxicity': 1, 'patients,': 1, 'but': 1, 'rebound': 1, 'observed': 1, 'when': 1, 'six': 1, 'double-blind': 1, 'placebo': 1, 'controlled': 1, 'low': 1, 'dose': 1, 'raises': 1, 'questions': 1, 'about': 1, 'their': 1, 'place': 1, 'therapeutic': 1, 'regimens,': 1, 'especially': 1, 'as': 1, 'concerns': 1, 'auranofin,': 1, 'sulphasalazine,': 1, 'methotrexate': 1, 'wide': 1, 'range': 1, 'seronegative': 1, 'spondyloarthritides': 1, '(SN),': 1, 'we': 1, 'demonstrated': 1, 'that': 1, 'this': 1, 'phenomenon': 1, 'is:': 1, '(i)': 1, 'T': 1, 'cell': 1, 'response,': 1, '(ii)': 1, 'inhibited': 1, 'by': 1, 'addition': 1, 'included': 1, '1-year': 1, 'trial': 1, '24-week': 1, 'pilot': 1})
# Counter({'': 2})
# Counter({'': 1})
# Counter({'': 28, 'to': 7, 'reaction': 5, 'the': 4, 'with': 2, 'as': 2, 'analog,': 1, 'amoxicillin,': 1, 'can': 1, 'potentially': 1, 'produce': 1, 'same': 1, ')': 1, 'intravenous': 1, 'of': 1, 'colonic': 1, 'mucosa': 1, 'by': 1, 'skin': 1, 'tests,': 1, 'including': 1, 'penicilloylpolylysine,': 1, 'benzyl-penicillin,': 1, 'is': 1, 'less': 1, 'common': 1, 'penicillin': 1, 'or': 1, 'tetracycline': 1, 'compared': 1, 'mechanism': 1, 'when': 1, 'following': 1, 'drugs': 1, 'have': 1, 'been': 1, 'given:': 1, 'nitrofurantoin,': 1, 'salazopyrine,': 1, 'erythromycin,': 1})
# Counter({'': 1})
# Counter({'': 5, 'was': 1, 'significantly': 1, 'more': 1, 'common': 1, 'than': 1, 'in': 1, 'the': 1, 'and': 1, 'vomiting)': 1, 'when': 1, 'added': 1, 'to': 1})
# Counter({'': 6, 'produced': 3, 'chloride': 2, 'and': 2, 'lidocaine': 2, 'regional': 2, 'was': 2, 'dyskinesia': 1, 'that': 1, 'similar': 1, 'to': 1, 'the': 1, 'in': 1, 'open': 1, 'chest': 1, 'dogs': 1, 'by': 1, 'six': 1, 'repeated': 1, 'intracoronary': 1, 'infusions': 1, 'of': 1, 'either': 1})
# Counter({'': 2, '24': 1, 'hours': 1, 'after': 1, 'a': 1, 'change': 1, 'in': 1, 'antihypertensive': 1, 'medication': 1, 'from': 1, 'atenolol': 1, '50': 1, 'mg/d': 1, 'to': 1})
# Counter({'': 3, 'by': 3, 'a': 3, 'dose': 3, 'was': 2, 'low': 2, 'of': 2, 'in': 1, 'MH-rats': 1, 'blocked': 1, '(1': 1, 'mg/kg)': 1, 'propranolol,': 1, 'which': 1, 'insufficient': 1, 'to': 1, 'cure': 1, 'the': 1, 'Spontanous': 1, 'Hypertensive': 1, 'rats,': 1, 'and': 1, 'very': 1, '(20': 1, 'ng/kg)': 1, '1-dopa': 1, 'with': 1, 'carbidopa': 1, 'treatment,': 1, 'but': 1, 'not': 1})
# Counter({'': 21, 'in': 4, 'and': 4, 'of': 4, 'with': 4, 'the': 3, 'effect': 3, 'on': 3, 'by': 2, 'a': 2, 'calcium': 2, 'to': 2, 'renal': 2, 'modulating': 1, 'smooth': 1, 'muscle': 1, 'contractility': 1, 'is': 1, 'discussed': 1, 'importance': 1, 'checking': 1, 'serum': 1, 'magnesium': 1, 'patients': 1, 'airway': 1, 'silica': 1, 'stones': 1, 'patient': 1, 'taking': 1, 'phosphate': 1, 'microliths,': 1, 'similar': 1, 'that': 1, 'seen': 1, 'underwent': 1, 'combination': 1, 'tocolysis': 1, 'intravenous': 1, 'ritodrine': 1, ',': 1, 'were': 1, 'treated': 1, 'part': 1, 'repeated': 1, 'doses': 1, 'commercially': 1, 'available': 1, 'antacid/cathartic': 1, 'preparation': 1, 'containing': 1, 'appears': 1, 'enhance': 1, 'inhibitory': 1, 'sulfate': 1, 'sodium': 1, 'reabsorption': 1, 'but': 1, 'does': 1, 'not': 1, 'alter': 1, 'ammonium': 1, 'had': 1, 'no': 1, 'rumen': 1, 'sodium,': 1, 'calcium,': 1})
# Counter({'': 1})
# Counter({'': 2})
# Counter({'': 43, 'plus': 12, 'with': 12, 'and': 11, 'cefoxitin': 8, 'of': 7, 'or': 6, 'clinical': 5, 'to': 5, 'clindamycin': 4, 'were': 4, 'treated': 4, 'intravenous': 4, 'in': 3, 'doxycycline': 3, 'response': 3, 'the': 3, 'randomly': 3, '(N': 3, '=': 3, 'treatment': 2, 'parenteral': 2, '(PID)': 2, 'based': 2, 'on': 2, 'criteria': 2, 'gentamicin': 2, '63)': 2, ':': 2, 'comparison': 2, 'cefotetan': 2, 'underwent': 2, 'endocervical': 2, 'endometrial': 2, 'cultures': 2, 'prior': 2, 'random': 2, 'therapy': 2, 'without': 2, '(Vibramycin)': 1, 'demonstrated': 1, 'high': 1, 'rates': 1, 'initial': 1, 'acute': 1, 'laparoscopic': 1, 'diagnosis': 1, 'grading,': 1, 'comparative': 1, 'cefamandole': 1, 'ambulatory': 1, 'setting:': 1, 'trial': 1, 'ampicillin,': 1, 'cefpodoxime,': 1, 'metronidazole,': 1, '67)': 1, 'for': 1, 'at': 1, 'least': 1, '4': 1, 'days,': 1, 'followed': 1, 'by': 1, 'oral': 1, 'either': 1, 'combination': 1, 'doxycycline,': 1, 'ceftizoxime': 1, 'Augmentin,': 1, 'as': 1, 'outpatients': 1, 'Augmentin': 1, ',': 1, 'eight': 1, 'whom': 1, '(2.1%)': 1, 'had': 1, 'received': 1})
# Counter({'': 3, 'and': 2, 'neurologic': 1, 'signs': 1, 'from': 1, 'recurrence': 1, 'of': 1, 'coccidioidomycosis': 1, 'was': 1, 'treated': 1, 'with': 1})
# Counter({'': 1})
# Counter({'': 2, 'in': 1, '10': 1, 'kidney-transplanted': 1, 'patients': 1, 'receiving': 1, 'steroids': 1, '(': 1})
# Counter({'': 1, 'and': 1, 'were': 1, 'found': 1, 'to': 1, 'experience': 1, 'significantly': 1, 'longer': 1, 'postoperative': 1, 'pain': 1, 'than': 1, '20': 1, 'patients': 1, 'who': 1, 'recieved': 1, 'lidocaine': 1, '(': 1})
# Counter({'': 11, 'treatment': 1, 'was': 1, 'effective': 1, 'on': 1, 'the': 1, 'course': 1, 'of': 1, ',': 1, 'improved': 1, 'by': 1, 'and': 1})
# Counter({'': 5, 'the': 3, 'by': 2, 'induced': 1, 'can': 1, 'thus': 1, 'be': 1, 'explained': 1, 'fully': 1, 'effects': 1, 'on': 1, 'autonomic': 1, 'nervous': 1, 'system': 1, 'which': 1, 'are': 1, 'reversed': 1, 'lowering': 1, 'blood': 1, 'pressure,': 1, 'whereas': 1, 'severe': 1, 'reduction': 1, 'of': 1, 'coronary': 1, 'flow': 1, 'did': 1, 'not': 1, 'contribute': 1, 'to': 1, 'vasopressin-induced': 1})
# Counter({'': 4, 'analysis': 1, 'must': 1, 'be': 1, 'performed': 1, 'for': 1, 'unexplained': 1, 'and': 1, 'cerebral': 1, 'electrical': 1, 'silence': 1, 'were': 1, 'observed': 1, 'whereas': 1, 'the': 1})
# Counter({'': 3, 'was': 1, 'evaluated': 1, 'in': 1, '34': 1, 'children': 1, '(mean': 1, 'age:': 1, '8': 1, 'years)': 1, 'presenting': 1, 'with': 1, 'severe': 1, 'infection': 1, '(septicaemia,': 1, 'meningitis,': 1, 'bronchopneumonia,': 1})
# Counter({'': 2, 'on': 1, 'the': 1, '7th': 1, 'day': 1, 'after': 1, 'abrupt': 1, 'discontinuation': 1, 'of': 1})
# Counter({'': 3, 'a': 3, 'were': 1, 'given': 1, 'intravenously': 1, 'to': 1, 'patients': 1, 'with': 1, 'serious': 1, 'underlying': 1, 'disease': 1, 'who': 1, 'presented': 1, 'pulmonary': 1, 'infection': 1, 'or': 1})
# Counter({'': 13, 'with': 3, 'prevents': 1, ':': 1, 'Rats': 1, 'aortic': 1, 'constriction': 1, 'treated': 1, 'a': 1, 'nonantihypertensive': 1, 'dose': 1, 'of': 1, 'under': 1, 'takes': 1, 'place': 1})
# Counter({',': 1, 'was': 1, 'dose': 1, 'limiting': 1, 'at': 1, '2400': 1, 'mg': 1, '': 1})
# Counter({'': 14, 'and': 5, 'in': 4, 'was': 3, 'the': 3, 'with': 2, 'vomiting': 2, 'than': 2, 'sedation': 2, 'well': 1, 'tolerated,': 1, 'minimal': 1, 'alterations': 1, 'consciousness': 1, 'infrequent': 1, 'less': 1, 'MTM': 1, 'morphine': 1, 'or': 1, ',': 1, 'vomiting,': 1, 'prolonged': 1, 'occurred': 1, 'more': 1, 'frequently': 1, 'similar,': 1, 'although': 1, 'patients': 1, 'receiving': 1})
# Counter({'': 104, 'of': 28, 'in': 21, 'the': 19, 'and': 17, 'with': 11, 'by': 10, 'was': 9, 'renal': 8, 'acute': 8, 'to': 7, 'is': 7, '(ARF)': 6, 'patients': 5, ',': 4, 'an': 4, 'greater': 4, 'than': 4, 'induced': 3, 'rats': 3, 'chronic': 3, 'may': 3, 'for': 3, 'increase': 3, 'that': 3, 'or': 3, 'were': 3, 'and/or': 3, 'be': 3, 'soluble': 3, 'course': 2, 'studied': 2, 'ten': 2, 'normal': 2, 'administered': 2, 'urinary': 2, 'dopamine': 2, 'cases': 2, 'it': 2, 'effect': 2, 'urine': 2, 'flow': 2, 'established': 2, 'there': 2, 'this': 2, 'rate': 2, 'control': 2, 'group,': 2, 'developed': 2, '=': 2, 'more': 2, 'a': 2, 'hypotension': 2, 'can': 2, 'prevented': 2, 'crystalloid': 2, '30': 2, 'minutes': 2, 'bilateral': 2, 'artery': 2, 'clamping;': 2, '(c)': 2, 'assess': 2, 'comparative': 2, 'efficacies': 2, 'nitroprusside,': 2, 'activator': 2, 'guanylate': 2, 'cyclase,': 2, 'combined': 2, 'infusions': 2, 'group': 2, '(mean': 2, 'under': 2, 'pharmacologic': 2, 'plasma': 2, 'sensitivity': 2, 'infusion,': 1, 'when': 1, 'commenced': 1, '24': 1, 'h': 1, 'after': 1, 'insult,': 1, 'ineffective': 1, 'modifying': 1, 'uranyl': 1, 'nitrate': 1, 'hydrochloride': 1, 'septic': 1, 'shock': 1, 'myocardial': 1, 'dysfunction': 1, 'function': 1, '(group': 1, '1)': 1, 'at': 1, 'time': 1, 'initiation': 1, 'anoxic': 1, 'their': 1, 'metabolites': 1, 'low': 1, 'doses': 1, 'frequently': 1, 'employed': 1, 'oliguric': 1, 'potentiate': 1, 'vasodilating': 1, 'provide': 1, 'effective': 1, 'therapy': 1, 'developing': 1, 'failure': 1, 'current': 1, 'fashion,': 1, 'but': 1, 'little': 1, 'evidence': 1, 'drug': 1, 'raises': 1, 'glomerular': 1, 'filtration': 1, 'shortens': 1, 'aldosterone': 1, 'secretion': 1, 'end-stage': 1, 'only': 1, 'two': 1, 'transplant': 1, 'operations': 1, '(9.5%)': 1, 'complicated': 1, 'impairment,': 1, 'whereas': 1, 'other': 1, '10': 1, '(67%)': 1, 'impairment': 1, '(p': 1, '0.001);': 1, 'these,': 1, 'four': 1, 'justified': 1, 'where': 1, 'increasing': 1, 'heart': 1, 'desirable,': 1, 'are': 1, 'signs': 1, '(DA)': 1, 'infused': 1, 'dose': 1, '2': 1, 'micrograms/kg/min': 1, '12': 1, 'children': 1, 'adolescents': 1, 'systemic': 1, 'impending': 1, '(plasma': 1, 'creatinine': 1, '100': 1, 'mg/i),': 1, 'effects': 1, 'dosage': 1, 'might': 1, 'develop,': 1, 'advantage': 1, '(study': 1, 'A:': 1, 'colloidal': 1, 'solutions;': 1, 'study': 1, 'B': 1, 'than:': 1, 'solutions': 1, '(ND)': 1, 'including': 1, 'RBF': 1, 'concept': 1, "'oxygen": 1, 'supply': 1, "demand'": 1, 'relation': 1, 'tubular': 1, 'function,': 1, 'suggests': 1, 'former': 1, 'further': 1, 'divided': 1, 'into': 1, 'output,': 1, 'less': 1, '27': 1, 'ml/min)': 1, 'hypoxia': 1, 'arterial': 1, 'oxygen': 1, 'pressure': 1, '56': 1, 'torr': 1, '80%': 1, 'forced': 1, 'inspiratory': 1, 'oxygen),': 1, 'despite': 1, 'maximum': 1, 'support': 1, '(dobutamine,': 1, '16': 1, '18': 1, 'gamma/kg/min;': 1, 'reproduced': 1, 'generation': 1, 'lipofuscins': 1, 'samples': 1, 'incubation': 1, 'mixtures': 1, 'L-dopa,': 1, ';': 1, 'ventilator': 1, 'applied;': 1, 'defined': 1, 'Cr': 1, '0.5': 1, 'mg/dl': 1, 'FeNa': 1, '2%': 1, 'hypoperfusion': 1, 'which': 1, 'considered': 1, 'case': 1, 'resistant': 1, 'volume': 1, 'repletion': 1, 'associated': 1, 'diminished': 1, 'thyrotroph': 1, 'TRH': 1, 'stimulation,': 1, 'blunted': 1, 'dopamine-dependent': 1, 'since': 1, 'abolished': 1, 'without': 1, 'systematic': 1, 'low-dose': 1, 'oliguria': 1, 'present': 1, '(vascular': 1, 'filling,': 1, 'furosemide,': 1, 'hemodialysis': 1, '(CRFh)': 1, 'measuring': 1, 'concentration': 1, 'free,': 1, 'sulfo-': 1, 'glucuroconjugated': 1, 'CA,': 1})
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Experiments

# %%
train_result = rel_ext.train_models(
    splits, 
    featurizers=[start_bag_of_words_featurizer, middle_bag_of_words_featurizer, end_bag_of_words_featurizer],
    split_name="all"
)
# Out:
# /home/gerhard/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %% [markdown]
# Next comes `predict()`. This function takes as arguments a dictionary of data splits, the outputs of `train_models()`, and the name of the split for which to make predictions. It returns two parallel dictionaries: one holding the predictions (grouped by relation), the other holding the true labels (again, grouped by prediction).

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Examining the trained models
#
# One important way to gain understanding of our trained model is to inspect the model weights. What features are strong positive indicators for each relation, and what features are strong negative indicators?

# %%
rel_ext.examine_model_weights(train_result)
# Out:
# Highest and lowest feature weights for relation acquired:
#
#      1.462 renal
#      1.046 transport
#      0.918 Fanconi
#      ..... .....
#     -0.478 (
#     -0.807 ,
#     -2.232
#
# Highest and lowest feature weights for relation aggravated:
#
#      3.993 condition
#      3.640 condition.
#      1.834 this
#      ..... .....
#     -0.725 (
#     -0.762 )
#     -0.896
#
# Highest and lowest feature weights for relation altered:
#
#      2.547 mood
#      1.938 saliva
#      1.749 lithium
#      ..... .....
#     -0.509 patients
#     -0.759 ,
#     -0.949
#
# Highest and lowest feature weights for relation caused:
#
#      0.301 mass
#      0.245 calcium
#      0.234 pain
#      ..... .....
#     -0.274 somatostatin
#     -0.308 endocrine
#     -0.443 concomitant
#
# Highest and lowest feature weights for relation changed:
#
#      2.479 therapeutic
#      1.399 concentration
#      1.357 response.
#      ..... .....
#     -0.850 .
#     -1.113 ,
#     -1.359
#
# Highest and lowest feature weights for relation decreased:
#
#      0.539 immunoglobulins
#      0.466 molecular
#      0.460 immunoglobulin
#      ..... .....
#     -0.247 cerebral
#     -0.260 case
#     -0.330 concomitant
#
# Highest and lowest feature weights for relation delayed:
#
#      1.534 therapeutic
#      0.957 cromoglycate
#      0.854 largest
#      ..... .....
#     -0.926 .
#     -1.333 ,
#     -1.793
#
# Highest and lowest feature weights for relation discoloured:
#
#      3.533 sputum
#      1.539 faeces
#      1.499 urine
#      ..... .....
#     -0.636 )
#     -0.871 ,
#     -1.294
#
# Highest and lowest feature weights for relation impaired:
#
#      2.097 glucose
#      1.796 tolerance
#      1.529 insulin
#      ..... .....
#     -0.821 (
#     -1.134 by
#     -1.287
#
# Highest and lowest feature weights for relation improved:
#
#      0.000 μg
#      0.000 μM
#      0.000 γ-globulin
#      ..... .....
#     -0.504 of
#     -0.608 and
#     -2.063
#
# Highest and lowest feature weights for relation increased:
#
#      0.120 body
#      0.119 blood
#      0.110 calcium
#      ..... .....
#     -0.049 A
#     -0.101 with
#     -0.106 patients
#
# Highest and lowest feature weights for relation infected:
#
#      1.977 atopic
#      1.705 contact
#      1.401 abortion
#      ..... .....
#     -0.646 .
#     -0.737 ,
#     -1.154
#
# Highest and lowest feature weights for relation lowered:
#
#      0.590 control
#      0.451 had
#      0.304 fallen
#      ..... .....
#     -0.545 of
#     -0.750 and
#     -2.000
#
# Highest and lowest feature weights for relation prolonged:
#
#      2.040 prolongation
#      1.836 time
#      1.366 prothrombin
#      ..... .....
#     -0.786 )
#     -1.048 ,
#     -1.507
#
# Highest and lowest feature weights for relation reduced:
#
#      2.215 acuity
#      2.212 visual
#      1.702 urine
#      ..... .....
#     -0.684 ,
#     -0.731 (
#     -1.757
#
# Highest and lowest feature weights for relation ruptured:
#
#      1.529 calcium
#      1.046 ruptured
#      0.986 aneurysm
#      ..... .....
#     -0.716 and
#     -0.822 ,
#     -1.810
#
# Highest and lowest feature weights for relation shortened:
#
#      2.465 therapeutic
#      1.551 time
#      1.422 good
#      ..... .....
#     -0.989 :
#     -1.238 ,
#     -1.279

# %% [markdown]
# ### Discovering new relation instances
#
# Another way to gain insight into our trained models is to use them to discover new relation instances that don't currently appear in the KB. In fact, this is the whole point of building a relation extraction system: to extend an existing KB (or build a new one) using knowledge extracted from natural language text at scale. Can the models we've trained do this effectively?
#
# Because the goal is to discover new relation instances which are _true_ but _absent from the KB_, we can't evaluate this capability automatically. But we can generate candidate KB triples and manually evaluate them for correctness.
#
# To do this, we'll start from corpus examples containing pairs of entities which do not belong to any relation in the KB (earlier, we described these as "negative examples"). We'll then apply our trained models to each pair of entities, and sort the results by probability assigned by the model, in order to find the most likely new instances for each relation.

# %% [markdown]
# # Create and Evaluate New Instances
#
# In 3 Steps we evaluate the top 10, top 50 and top 100
#
# **Attention**: k is set to the double value, because it creates instances for two directions – sbj-obj and obj.sbj

# %%
new_instances = get_new_relation_instances(
    dataset,
    featurizers=[simple_bag_of_words_featurizer],
    k=20
)

eval_relations = defaultdict(set)

for kb_triple in kb_eval:
    eval_relations[kb_triple.rel].add((kb_triple.rel, kb_triple.sbj, kb_triple.obj))
    
suggestions = defaultdict(set)

for rel, rel_inst in new_instances.items():
    for instance in rel_inst:
        suggestions[rel].add((instance[1].rel, instance[1].sbj, instance[1].obj))
# Out:
# WARNING: could not train model for improved
# train_x_rel = None
# train_y_rel = None
# Highest probability examples for relation acquired:
#
#      0.191 KBTriple(rel='acquired', sbj='corynebacterium', obj='faeces')
#      0.191 KBTriple(rel='acquired', sbj='faeces', obj='corynebacterium')
#      0.163 KBTriple(rel='acquired', sbj='tac', obj='toxoplasmosis')
#      0.163 KBTriple(rel='acquired', sbj='toxoplasmosis', obj='tac')
#      0.092 KBTriple(rel='acquired', sbj='microangiopathy', obj='somatostatin')
#      0.092 KBTriple(rel='acquired', sbj='somatostatin', obj='microangiopathy')
#      0.070 KBTriple(rel='acquired', sbj='tac', obj='progesterone')
#      0.070 KBTriple(rel='acquired', sbj='progesterone', obj='tac')
#      0.062 KBTriple(rel='acquired', sbj='stress', obj='ondansetron')
#      0.062 KBTriple(rel='acquired', sbj='ondansetron', obj='stress')
#      0.058 KBTriple(rel='acquired', sbj='econazole', obj='haemoglobin')
#      0.058 KBTriple(rel='acquired', sbj='haemoglobin', obj='econazole')
#      0.057 KBTriple(rel='acquired', sbj='ammonium', obj='nephrocalcinosis')
#      0.057 KBTriple(rel='acquired', sbj='nephrocalcinosis', obj='ammonium')
#      0.042 KBTriple(rel='acquired', sbj='diabetic_neuropathy', obj='cisapride')
#      0.042 KBTriple(rel='acquired', sbj='cisapride', obj='diabetic_neuropathy')
#      0.031 KBTriple(rel='acquired', sbj='pancreatectomy', obj='octreotide')
#      0.031 KBTriple(rel='acquired', sbj='octreotide', obj='pancreatectomy')
#      0.031 KBTriple(rel='acquired', sbj='tryptase', obj='polypeptide')
#      0.031 KBTriple(rel='acquired', sbj='polypeptide', obj='tryptase')
#
# Highest probability examples for relation aggravated:
#
#      0.999 KBTriple(rel='aggravated', sbj='cimetidine', obj='pco2')
#      0.999 KBTriple(rel='aggravated', sbj='pco2', obj='cimetidine')
#      0.979 KBTriple(rel='aggravated', sbj='diazepam', obj='tension')
#      0.979 KBTriple(rel='aggravated', sbj='tension', obj='diazepam')
#      0.887 KBTriple(rel='aggravated', sbj='somatostatin', obj='acidosis')
#      0.887 KBTriple(rel='aggravated', sbj='acidosis', obj='somatostatin')
#      0.886 KBTriple(rel='aggravated', sbj='droperidol', obj='visual_analogue_scale')
#      0.886 KBTriple(rel='aggravated', sbj='visual_analogue_scale', obj='droperidol')
#      0.850 KBTriple(rel='aggravated', sbj='coagulopathy', obj='corynebacterium')
#      0.850 KBTriple(rel='aggravated', sbj='corynebacterium', obj='coagulopathy')
#      0.842 KBTriple(rel='aggravated', sbj='phenytoin', obj='tension')
#      0.842 KBTriple(rel='aggravated', sbj='tension', obj='phenytoin')
#      0.832 KBTriple(rel='aggravated', sbj='metabolic_acidosis', obj='somatostatin')
#      0.832 KBTriple(rel='aggravated', sbj='somatostatin', obj='metabolic_acidosis')
#      0.740 KBTriple(rel='aggravated', sbj='ibuprofen', obj='vitamin_a')
#      0.740 KBTriple(rel='aggravated', sbj='vitamin_a', obj='ibuprofen')
#      0.736 KBTriple(rel='aggravated', sbj='rheumatoid_arthritis', obj='diazepam')
#      0.736 KBTriple(rel='aggravated', sbj='diazepam', obj='rheumatoid_arthritis')
#      0.731 KBTriple(rel='aggravated', sbj='condition', obj='viomycin')
#      0.731 KBTriple(rel='aggravated', sbj='viomycin', obj='condition')
#
# Highest probability examples for relation altered:
#
#      0.878 KBTriple(rel='altered', sbj='protein_c', obj='peptide')
#      0.878 KBTriple(rel='altered', sbj='peptide', obj='protein_c')
#      0.631 KBTriple(rel='altered', sbj='cimetidine', obj='forced_expiratory_volume')
#      0.631 KBTriple(rel='altered', sbj='forced_expiratory_volume', obj='cimetidine')
#      0.542 KBTriple(rel='altered', sbj='tinnitus', obj='phenylbutazone')
#      0.542 KBTriple(rel='altered', sbj='phenylbutazone', obj='tinnitus')
#      0.501 KBTriple(rel='altered', sbj='vital_capacity', obj='lidocaine')
#      0.501 KBTriple(rel='altered', sbj='lidocaine', obj='vital_capacity')
#      0.382 KBTriple(rel='altered', sbj='somatostatin', obj='blood_glucagon')
#      0.382 KBTriple(rel='altered', sbj='blood_glucagon', obj='somatostatin')
#      0.352 KBTriple(rel='altered', sbj='diazepam', obj='extubation')
#      0.352 KBTriple(rel='altered', sbj='extubation', obj='diazepam')
#      0.273 KBTriple(rel='altered', sbj='microangiopathy', obj='somatostatin')
#      0.273 KBTriple(rel='altered', sbj='somatostatin', obj='microangiopathy')
#      0.271 KBTriple(rel='altered', sbj='infusion', obj='betaxolol')
#      0.271 KBTriple(rel='altered', sbj='betaxolol', obj='infusion')
#      0.262 KBTriple(rel='altered', sbj='phenylbutazone', obj='urticaria')
#      0.262 KBTriple(rel='altered', sbj='urticaria', obj='phenylbutazone')
#      0.241 KBTriple(rel='altered', sbj='strontium', obj='salmonellosis')
#      0.241 KBTriple(rel='altered', sbj='salmonellosis', obj='strontium')
#
# Highest probability examples for relation caused:
#
#      1.000 KBTriple(rel='caused', sbj='fall', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='fall')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='blood_pressure')
#      1.000 KBTriple(rel='caused', sbj='blood_pressure', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='enzyme_activity', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='enzyme_activity')
#      1.000 KBTriple(rel='caused', sbj='tachycardia', obj='propranolol')
#      1.000 KBTriple(rel='caused', sbj='propranolol', obj='tachycardia')
#      1.000 KBTriple(rel='caused', sbj='magnesium', obj='infusion')
#      1.000 KBTriple(rel='caused', sbj='infusion', obj='magnesium')
#      1.000 KBTriple(rel='caused', sbj='sodium', obj='hypercalciuria')
#      1.000 KBTriple(rel='caused', sbj='hypercalciuria', obj='sodium')
#      1.000 KBTriple(rel='caused', sbj='headache', obj='sumatriptan')
#      1.000 KBTriple(rel='caused', sbj='sumatriptan', obj='headache')
#      1.000 KBTriple(rel='caused', sbj='ventricular_tachycardia', obj='magnesium')
#      1.000 KBTriple(rel='caused', sbj='magnesium', obj='ventricular_tachycardia')
#      1.000 KBTriple(rel='caused', sbj='sodium', obj='thrombosis')
#      1.000 KBTriple(rel='caused', sbj='thrombosis', obj='sodium')
#      1.000 KBTriple(rel='caused', sbj='salpingitis', obj='gentamicin')
#      1.000 KBTriple(rel='caused', sbj='gentamicin', obj='salpingitis')
#
# Highest probability examples for relation changed:
#
#      0.602 KBTriple(rel='changed', sbj='pain', obj='gamma-globulin')
#      0.602 KBTriple(rel='changed', sbj='gamma-globulin', obj='pain')
#      0.458 KBTriple(rel='changed', sbj='gamma-globulin', obj='cholangitis')
#      0.458 KBTriple(rel='changed', sbj='cholangitis', obj='gamma-globulin')
#      0.302 KBTriple(rel='changed', sbj='carbon_dioxide', obj='methylprednisolone')
#      0.302 KBTriple(rel='changed', sbj='methylprednisolone', obj='carbon_dioxide')
#      0.256 KBTriple(rel='changed', sbj='cardiopulmonary_bypass', obj='fac')
#      0.256 KBTriple(rel='changed', sbj='fac', obj='cardiopulmonary_bypass')
#      0.239 KBTriple(rel='changed', sbj='indium', obj='neoplasm')
#      0.239 KBTriple(rel='changed', sbj='neoplasm', obj='indium')
#      0.212 KBTriple(rel='changed', sbj='fungal_infection', obj='gentamicin')
#      0.212 KBTriple(rel='changed', sbj='gentamicin', obj='fungal_infection')
#      0.202 KBTriple(rel='changed', sbj='sodium', obj='carbohydrate_intolerance')
#      0.202 KBTriple(rel='changed', sbj='carbohydrate_intolerance', obj='sodium')
#      0.164 KBTriple(rel='changed', sbj='gastric_fistula', obj='diazepam')
#      0.164 KBTriple(rel='changed', sbj='diazepam', obj='gastric_fistula')
#      0.162 KBTriple(rel='changed', sbj='nasal', obj='holoprosencephaly')
#      0.162 KBTriple(rel='changed', sbj='holoprosencephaly', obj='nasal')
#      0.148 KBTriple(rel='changed', sbj='concomitant', obj='borderline_personality_disorder')
#      0.148 KBTriple(rel='changed', sbj='borderline_personality_disorder', obj='concomitant')
#
# Highest probability examples for relation decreased:
#
#      1.000 KBTriple(rel='decreased', sbj='renin', obj='terazosin')
#      1.000 KBTriple(rel='decreased', sbj='terazosin', obj='renin')
#      1.000 KBTriple(rel='decreased', sbj='weight', obj='diltiazem')
#      1.000 KBTriple(rel='decreased', sbj='diltiazem', obj='weight')
#      1.000 KBTriple(rel='decreased', sbj='hypotension', obj='betaxolol')
#      1.000 KBTriple(rel='decreased', sbj='betaxolol', obj='hypotension')
#      1.000 KBTriple(rel='decreased', sbj='gentamicin', obj='mass')
#      1.000 KBTriple(rel='decreased', sbj='mass', obj='gentamicin')
#      1.000 KBTriple(rel='decreased', sbj='allantoin', obj='weight')
#      1.000 KBTriple(rel='decreased', sbj='weight', obj='allantoin')
#      0.999 KBTriple(rel='decreased', sbj='cardiac_index', obj='propranolol')
#      0.999 KBTriple(rel='decreased', sbj='propranolol', obj='cardiac_index')
#      0.998 KBTriple(rel='decreased', sbj='magnesium', obj='alanine_aminotransferase')
#      0.998 KBTriple(rel='decreased', sbj='alanine_aminotransferase', obj='magnesium')
#      0.997 KBTriple(rel='decreased', sbj='urine_flow', obj='ammonium')
#      0.997 KBTriple(rel='decreased', sbj='ammonium', obj='urine_flow')
#      0.996 KBTriple(rel='decreased', sbj='terazosin', obj='epinephrine')
#      0.996 KBTriple(rel='decreased', sbj='epinephrine', obj='terazosin')
#      0.996 KBTriple(rel='decreased', sbj='blood_pressure', obj='urapidil')
#      0.996 KBTriple(rel='decreased', sbj='urapidil', obj='blood_pressure')
#
# Highest probability examples for relation delayed:
#
#      0.154 KBTriple(rel='delayed', sbj='gamma-globulin', obj='cholangitis')
#      0.154 KBTriple(rel='delayed', sbj='cholangitis', obj='gamma-globulin')
#      0.133 KBTriple(rel='delayed', sbj='solar_urticaria', obj='cimetidine')
#      0.133 KBTriple(rel='delayed', sbj='cimetidine', obj='solar_urticaria')
#      0.107 KBTriple(rel='delayed', sbj='anaplastic_astrocytoma', obj='methylprednisolone')
#      0.107 KBTriple(rel='delayed', sbj='methylprednisolone', obj='astrocytoma')
#      0.107 KBTriple(rel='delayed', sbj='methylprednisolone', obj='anaplastic_astrocytoma')
#      0.107 KBTriple(rel='delayed', sbj='astrocytoma', obj='methylprednisolone')
#      0.091 KBTriple(rel='delayed', sbj='ejection_fraction', obj='gallopamil')
#      0.091 KBTriple(rel='delayed', sbj='gallopamil', obj='ejection_fraction')
#      0.087 KBTriple(rel='delayed', sbj='azatadine', obj='rhinitis')
#      0.087 KBTriple(rel='delayed', sbj='rhinitis', obj='azatadine')
#      0.083 KBTriple(rel='delayed', sbj='anoxia', obj='nadolol')
#      0.083 KBTriple(rel='delayed', sbj='nadolol', obj='anoxia')
#      0.080 KBTriple(rel='delayed', sbj='intranasal', obj='cachexia')
#      0.080 KBTriple(rel='delayed', sbj='cachexia', obj='intranasal')
#      0.070 KBTriple(rel='delayed', sbj='gamma-globulin', obj='skin_reaction')
#      0.070 KBTriple(rel='delayed', sbj='skin_reaction', obj='gamma-globulin')
#      0.070 KBTriple(rel='delayed', sbj='gastric_fistula', obj='diazepam')
#      0.070 KBTriple(rel='delayed', sbj='diazepam', obj='gastric_fistula')
#
# Highest probability examples for relation discoloured:
#      0.895 KBTriple(rel='discoloured', sbj='diazepam', obj='faeces')
#      0.895 KBTriple(rel='discoloured', sbj='faeces', obj='diazepam')
#      0.810 KBTriple(rel='discoloured', sbj='imipenem', obj='obstruction')
#      0.810 KBTriple(rel='discoloured', sbj='obstruction', obj='imipenem')
#      0.705 KBTriple(rel='discoloured', sbj='diclofenac', obj='urine_flow')
#      0.705 KBTriple(rel='discoloured', sbj='urine_flow', obj='diclofenac')
#      0.667 KBTriple(rel='discoloured', sbj='urine_flow', obj='ammonium')
#      0.667 KBTriple(rel='discoloured', sbj='ammonium', obj='urine_flow')
#      0.556 KBTriple(rel='discoloured', sbj='leprosy', obj='tac')
#      0.556 KBTriple(rel='discoloured', sbj='tac', obj='leprosy')
#      0.434 KBTriple(rel='discoloured', sbj='sodium', obj='urine_calcium')
#      0.434 KBTriple(rel='discoloured', sbj='urine_calcium', obj='sodium')
#      0.343 KBTriple(rel='discoloured', sbj='phenylbutazone', obj='saliva')
#      0.343 KBTriple(rel='discoloured', sbj='saliva', obj='phenylbutazone')
#      0.325 KBTriple(rel='discoloured', sbj='phenylbutazone', obj='faeces')
#      0.325 KBTriple(rel='discoloured', sbj='faeces', obj='phenylbutazone')
#      0.303 KBTriple(rel='discoloured', sbj='mebendazole', obj='investigation')
#      0.303 KBTriple(rel='discoloured', sbj='investigation', obj='mebendazole')
#      0.284 KBTriple(rel='discoloured', sbj='corynebacterium', obj='drug_resistance')
#      0.284 KBTriple(rel='discoloured', sbj='drug_resistance', obj='corynebacterium')
#
# Highest probability examples for relation impaired:
#
#      1.000 KBTriple(rel='impaired', sbj='propranolol', obj='glucose_tolerance')
#      1.000 KBTriple(rel='impaired', sbj='glucose_tolerance', obj='propranolol')
#      1.000 KBTriple(rel='impaired', sbj='desogestrel', obj='blood_glucose')
#      1.000 KBTriple(rel='impaired', sbj='blood_glucose', obj='desogestrel')
#      0.997 KBTriple(rel='impaired', sbj='glucose_tolerance', obj='buserelin')
#      0.997 KBTriple(rel='impaired', sbj='buserelin', obj='glucose_tolerance')
#      0.993 KBTriple(rel='impaired', sbj='gestational_diabetes', obj='somatostatin')
#      0.993 KBTriple(rel='impaired', sbj='somatostatin', obj='gestational_diabetes')
#      0.966 KBTriple(rel='impaired', sbj='alcoholism', obj='polypeptide')
#      0.966 KBTriple(rel='impaired', sbj='polypeptide', obj='alcoholism')
#      0.881 KBTriple(rel='impaired', sbj='clomifene', obj='thyroxine')
#      0.881 KBTriple(rel='impaired', sbj='thyroxine', obj='clomifene')
#      0.875 KBTriple(rel='impaired', sbj='glucose_tolerance', obj='phenytoin')
#      0.875 KBTriple(rel='impaired', sbj='phenytoin', obj='glucose_tolerance')
#      0.837 KBTriple(rel='impaired', sbj='glucose_tolerance', obj='octreotide')
#      0.837 KBTriple(rel='impaired', sbj='octreotide', obj='glucose_tolerance')
#      0.781 KBTriple(rel='impaired', sbj='ammonia', obj='nadolol')
#      0.781 KBTriple(rel='impaired', sbj='nadolol', obj='ammonia')
#      0.763 KBTriple(rel='impaired', sbj='diltiazem', obj='liver_injury')
#      0.763 KBTriple(rel='impaired', sbj='liver_injury', obj='diltiazem')
#
# Highest probability examples for relation increased:
#
#      1.000 KBTriple(rel='increased', sbj='renin', obj='sodium')
#      1.000 KBTriple(rel='increased', sbj='sodium', obj='renin')
#      0.999 KBTriple(rel='increased', sbj='pectin', obj='weight')
#      0.999 KBTriple(rel='increased', sbj='weight', obj='pectin')
#      0.999 KBTriple(rel='increased', sbj='propranolol', obj='venous_pressure')
#      0.999 KBTriple(rel='increased', sbj='venous_pressure', obj='propranolol')
#      0.991 KBTriple(rel='increased', sbj='weight', obj='diltiazem')
#      0.991 KBTriple(rel='increased', sbj='diltiazem', obj='weight')
#      0.986 KBTriple(rel='increased', sbj='cardiac_index', obj='propranolol')
#      0.986 KBTriple(rel='increased', sbj='propranolol', obj='cardiac_index')
#      0.966 KBTriple(rel='increased', sbj='blood_pressure', obj='urapidil')
#      0.966 KBTriple(rel='increased', sbj='urapidil', obj='blood_pressure')
#      0.965 KBTriple(rel='increased', sbj='weight', obj='pyrantel')
#      0.965 KBTriple(rel='increased', sbj='pyrantel', obj='weight')
#      0.959 KBTriple(rel='increased', sbj='allantoin', obj='weight')
#      0.959 KBTriple(rel='increased', sbj='weight', obj='allantoin')
#      0.957 KBTriple(rel='increased', sbj='magnesium', obj='fasting')
#      0.957 KBTriple(rel='increased', sbj='fasting', obj='magnesium')
#      0.957 KBTriple(rel='increased', sbj='renin', obj='terazosin')
#      0.957 KBTriple(rel='increased', sbj='terazosin', obj='renin')
#
# Highest probability examples for relation infected:
#
#      0.057 KBTriple(rel='infected', sbj='lidocaine', obj='debridement')
#      0.057 KBTriple(rel='infected', sbj='debridement', obj='lidocaine')
#      0.027 KBTriple(rel='infected', sbj='cortisol', obj='menopausal')
#      0.027 KBTriple(rel='infected', sbj='menopausal', obj='cortisol')
#      0.027 KBTriple(rel='infected', sbj='urine_output', obj='sulindac')
#      0.027 KBTriple(rel='infected', sbj='sulindac', obj='urine_output')
#      0.027 KBTriple(rel='infected', sbj='thrombosis', obj='delapril')
#      0.027 KBTriple(rel='infected', sbj='delapril', obj='thrombosis')
#      0.022 KBTriple(rel='infected', sbj='laboratory_test', obj='thiazide')
#      0.022 KBTriple(rel='infected', sbj='thiazide', obj='laboratory_test')
#      0.020 KBTriple(rel='infected', sbj='sodium', obj='carbohydrate_intolerance')
#      0.020 KBTriple(rel='infected', sbj='carbohydrate_intolerance', obj='sodium')
#      0.019 KBTriple(rel='infected', sbj='paradox', obj='left_ventricular_failure')
#      0.019 KBTriple(rel='infected', sbj='left_ventricular_failure', obj='paradox')
#      0.019 KBTriple(rel='infected', sbj='portal_hypertension', obj='cimetidine')
#      0.019 KBTriple(rel='infected', sbj='cimetidine', obj='portal_hypertension')
#      0.017 KBTriple(rel='infected', sbj='stress', obj='piperacillin')
#      0.017 KBTriple(rel='infected', sbj='piperacillin', obj='stress')
#      0.017 KBTriple(rel='infected', sbj='eczema', obj='hydralazine')
#      0.017 KBTriple(rel='infected', sbj='hydralazine', obj='eczema')
#
# Highest probability examples for relation lowered:
#
# Highest probability examples for relation prolonged:
#
#      0.999 KBTriple(rel='prolonged', sbj='prothrombin_time', obj='magnesium')
#      0.999 KBTriple(rel='prolonged', sbj='magnesium', obj='prothrombin_time')
#      0.960 KBTriple(rel='prolonged', sbj='progesterone', obj='econazole')
#      0.960 KBTriple(rel='prolonged', sbj='econazole', obj='progesterone')
#      0.941 KBTriple(rel='prolonged', sbj='ammonium', obj='prothrombin_time')
#      0.941 KBTriple(rel='prolonged', sbj='prothrombin_time', obj='ammonium')
#      0.866 KBTriple(rel='prolonged', sbj='propranolol', obj='thrombin_time')
#      0.866 KBTriple(rel='prolonged', sbj='thrombin_time', obj='propranolol')
#      0.845 KBTriple(rel='prolonged', sbj='magnesium', obj='thrombin_time')
#      0.845 KBTriple(rel='prolonged', sbj='thrombin_time', obj='magnesium')
#      0.806 KBTriple(rel='prolonged', sbj='cimetidine', obj='forced_expiratory_flow')
#      0.806 KBTriple(rel='prolonged', sbj='forced_expiratory_flow', obj='cimetidine')
#      0.771 KBTriple(rel='prolonged', sbj='vital_capacity', obj='cimetidine')
#      0.771 KBTriple(rel='prolonged', sbj='cimetidine', obj='vital_capacity')
#      0.771 KBTriple(rel='prolonged', sbj='cimetidine', obj='forced_vital_capacity')
#      0.771 KBTriple(rel='prolonged', sbj='forced_vital_capacity', obj='cimetidine')
#      0.633 KBTriple(rel='prolonged', sbj='hydralazine', obj='body_surface_area')
#      0.633 KBTriple(rel='prolonged', sbj='body_surface_area', obj='hydralazine')
#      0.630 KBTriple(rel='prolonged', sbj='propanolol', obj='cardiac_output')
#      0.630 KBTriple(rel='prolonged', sbj='cardiac_output', obj='propanolol')
#
# Highest probability examples for relation reduced:
#
#      0.948 KBTriple(rel='reduced', sbj='diazepam', obj='central_cord_syndrome')
#      0.948 KBTriple(rel='reduced', sbj='central_cord_syndrome', obj='diazepam')
#      0.946 KBTriple(rel='reduced', sbj='sodium', obj='central_cord_syndrome')
#      0.946 KBTriple(rel='reduced', sbj='central_cord_syndrome', obj='sodium')
#      0.916 KBTriple(rel='reduced', sbj='microangiopathy', obj='somatostatin')
#      0.916 KBTriple(rel='reduced', sbj='somatostatin', obj='microangiopathy')
#      0.903 KBTriple(rel='reduced', sbj='urine_flow', obj='ammonium')
#      0.903 KBTriple(rel='reduced', sbj='ammonium', obj='urine_flow')
#      0.826 KBTriple(rel='reduced', sbj='thiazide', obj='crystalluria')
#      0.826 KBTriple(rel='reduced', sbj='crystalluria', obj='thiazide')
#      0.789 KBTriple(rel='reduced', sbj='ammonium', obj='nephrocalcinosis')
#      0.789 KBTriple(rel='reduced', sbj='nephrocalcinosis', obj='ammonium')
#      0.734 KBTriple(rel='reduced', sbj='pindolol', obj='dry_mouth')
#      0.734 KBTriple(rel='reduced', sbj='dry_mouth', obj='pindolol')
#      0.668 KBTriple(rel='reduced', sbj='allantoin', obj='weight')
#      0.668 KBTriple(rel='reduced', sbj='weight', obj='allantoin')
#      0.494 KBTriple(rel='reduced', sbj='dehydration', obj='pregnenolone')
#      0.494 KBTriple(rel='reduced', sbj='pregnenolone', obj='dehydration')
#      0.478 KBTriple(rel='reduced', sbj='phenylbutazone', obj='dependence')
#      0.478 KBTriple(rel='reduced', sbj='dependence', obj='phenylbutazone')
#
# Highest probability examples for relation ruptured:
#
#      0.861 KBTriple(rel='ruptured', sbj='strontium', obj='osteolysis')
#      0.861 KBTriple(rel='ruptured', sbj='osteolysis', obj='strontium')
#      0.238 KBTriple(rel='ruptured', sbj='renal_hypertrophy', obj='polypeptide')
#      0.238 KBTriple(rel='ruptured', sbj='polypeptide', obj='renal_hypertrophy')
#      0.104 KBTriple(rel='ruptured', sbj='econazole', obj='erythema')
#      0.104 KBTriple(rel='ruptured', sbj='erythema', obj='econazole')
#      0.069 KBTriple(rel='ruptured', sbj='immunglobulin', obj='transplant')
#      0.069 KBTriple(rel='ruptured', sbj='transplant', obj='immunglobulin')
#      0.058 KBTriple(rel='ruptured', sbj='coma', obj='methylprednisolone')
#      0.058 KBTriple(rel='ruptured', sbj='methylprednisolone', obj='coma')
#      0.049 KBTriple(rel='ruptured', sbj='acyclovir', obj='seizure')
#      0.049 KBTriple(rel='ruptured', sbj='seizure', obj='acyclovir')
#      0.045 KBTriple(rel='ruptured', sbj='enzyme_activity', obj='pindolol')
#      0.045 KBTriple(rel='ruptured', sbj='pindolol', obj='enzyme_activity')
#      0.043 KBTriple(rel='ruptured', sbj='concomitant', obj='congestive_cardiomyopathy')
#      0.043 KBTriple(rel='ruptured', sbj='congestive_cardiomyopathy', obj='concomitant')
#      0.040 KBTriple(rel='ruptured', sbj='hyperplasia', obj='budesonide')
#      0.040 KBTriple(rel='ruptured', sbj='budesonide', obj='hyperplasia')
#      0.040 KBTriple(rel='ruptured', sbj='ammonium', obj='proteinuria')
#      0.040 KBTriple(rel='ruptured', sbj='proteinuria', obj='ammonium')
#
# Highest probability examples for relation shortened:
#
#      0.980 KBTriple(rel='shortened', sbj='cystic_fibrosis', obj='roxithromycin')
#      0.980 KBTriple(rel='shortened', sbj='fibrosis', obj='roxithromycin')
#      0.980 KBTriple(rel='shortened', sbj='roxithromycin', obj='fibrosis')
#      0.980 KBTriple(rel='shortened', sbj='roxithromycin', obj='cystic_fibrosis')
#      0.935 KBTriple(rel='shortened', sbj='prothrombin_time', obj='magnesium')
#      0.935 KBTriple(rel='shortened', sbj='magnesium', obj='prothrombin_time')
#      0.931 KBTriple(rel='shortened', sbj='osteochondrosis', obj='propranolol')
#      0.931 KBTriple(rel='shortened', sbj='propranolol', obj='osteochondrosis')
#      0.919 KBTriple(rel='shortened', sbj='strontium', obj='salmonellosis')
#      0.919 KBTriple(rel='shortened', sbj='salmonellosis', obj='strontium')
#      0.866 KBTriple(rel='shortened', sbj='hydralazine', obj='body_surface_area')
#      0.866 KBTriple(rel='shortened', sbj='body_surface_area', obj='hydralazine')
#      0.813 KBTriple(rel='shortened', sbj='prazepam', obj='mood')
#      0.813 KBTriple(rel='shortened', sbj='mood', obj='prazepam')
#      0.767 KBTriple(rel='shortened', sbj='propranolol', obj='thrombin_time')
#      0.767 KBTriple(rel='shortened', sbj='thrombin_time', obj='propranolol')
#      0.754 KBTriple(rel='shortened', sbj='strontium', obj='food_poisoning')
#      0.754 KBTriple(rel='shortened', sbj='food_poisoning', obj='strontium')
#      0.753 KBTriple(rel='shortened', sbj='poisoning', obj='strontium')
#      0.753 KBTriple(rel='shortened', sbj='strontium', obj='poisoning')

# %%
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    '', 'examples', 'examples', 'examples'))
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    'relation', 'eval set', 'suggestions', 'intersection'))
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    '--------', '--------', '-------', '-------'))

for rel, instances in eval_relations.items():
    print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
        rel, str(len(instances)), 
        str(int(len(suggestions[rel])/2)), 
        str(len(instances.intersection(suggestions[rel])))))
# Out:
#                        examples        examples        examples
# relation               eval set     suggestions    intersection
# --------               --------         -------         -------
# accelerated                   1               0               0
# acquired                      9              10               0
# aggravated                  114              10               0
# altered                      29              10               0
# caused                    11426              10               6
# changed                      25              10               0
# decreased                   962              10               1
# delayed                      24              10               0
# discoloured                  40              10               1
# impaired                     16              10               0
# increased                  1031              10               1
# infected                      9              10               0
# prolonged                    30              10               1
# reduced                      18              10               0
# ruptured                      5              10               0
# shortened                    30              10               0

# %%
new_instances = get_new_relation_instances(
    dataset,
    featurizers=[simple_bag_of_words_featurizer],
    k=100
)

eval_relations = defaultdict(set)

for kb_triple in kb_eval:
    eval_relations[kb_triple.rel].add((kb_triple.rel, kb_triple.sbj, kb_triple.obj))
    
suggestions = defaultdict(set)

for rel, rel_inst in new_instances.items():
    for instance in rel_inst:
        suggestions[rel].add((instance[1].rel, instance[1].sbj, instance[1].obj))
# Out:
# WARNING: could not train model for improved
# train_x_rel = None
# train_y_rel = None
# Highest probability examples for relation acquired:
#
#      0.191 KBTriple(rel='acquired', sbj='corynebacterium', obj='faeces')
#      0.191 KBTriple(rel='acquired', sbj='faeces', obj='corynebacterium')
#      0.163 KBTriple(rel='acquired', sbj='tac', obj='toxoplasmosis')
#      0.163 KBTriple(rel='acquired', sbj='toxoplasmosis', obj='tac')
#      0.092 KBTriple(rel='acquired', sbj='microangiopathy', obj='somatostatin')
#      0.092 KBTriple(rel='acquired', sbj='somatostatin', obj='microangiopathy')
#      0.070 KBTriple(rel='acquired', sbj='tac', obj='progesterone')
#      0.070 KBTriple(rel='acquired', sbj='progesterone', obj='tac')
#      0.062 KBTriple(rel='acquired', sbj='stress', obj='ondansetron')
#      0.062 KBTriple(rel='acquired', sbj='ondansetron', obj='stress')
#      0.058 KBTriple(rel='acquired', sbj='econazole', obj='haemoglobin')
#      0.058 KBTriple(rel='acquired', sbj='haemoglobin', obj='econazole')
#      0.057 KBTriple(rel='acquired', sbj='ammonium', obj='nephrocalcinosis')
#      0.057 KBTriple(rel='acquired', sbj='nephrocalcinosis', obj='ammonium')
#      0.042 KBTriple(rel='acquired', sbj='diabetic_neuropathy', obj='cisapride')
#      0.042 KBTriple(rel='acquired', sbj='cisapride', obj='diabetic_neuropathy')
#      0.031 KBTriple(rel='acquired', sbj='pancreatectomy', obj='octreotide')
#      0.031 KBTriple(rel='acquired', sbj='octreotide', obj='pancreatectomy')
#      0.031 KBTriple(rel='acquired', sbj='tryptase', obj='polypeptide')
#      0.031 KBTriple(rel='acquired', sbj='polypeptide', obj='tryptase')
#      0.026 KBTriple(rel='acquired', sbj='ammonium', obj='salmonellosis')
#      0.026 KBTriple(rel='acquired', sbj='salmonellosis', obj='ammonium')
#      0.026 KBTriple(rel='acquired', sbj='head_injury', obj='cocaine')
#      0.026 KBTriple(rel='acquired', sbj='cocaine', obj='head_injury')
#      0.024 KBTriple(rel='acquired', sbj='laparotomy', obj='pac')
#      0.024 KBTriple(rel='acquired', sbj='pac', obj='laparotomy')
#      0.023 KBTriple(rel='acquired', sbj='droperidol', obj='ataxia')
#      0.023 KBTriple(rel='acquired', sbj='ataxia', obj='droperidol')
#      0.022 KBTriple(rel='acquired', sbj='clostridium', obj='systemic_lupus_erythematosus')
#      0.022 KBTriple(rel='acquired', sbj='systemic_lupus_erythematosus', obj='clostridium')
#      0.020 KBTriple(rel='acquired', sbj='corium', obj='panniculitis')
#      0.020 KBTriple(rel='acquired', sbj='panniculitis', obj='corium')
#      0.019 KBTriple(rel='acquired', sbj='dihydrotachysterol', obj='tetany')
#      0.019 KBTriple(rel='acquired', sbj='tetany', obj='dihydrotachysterol')
#      0.016 KBTriple(rel='acquired', sbj='polypeptide', obj='giardiasis')
#      0.016 KBTriple(rel='acquired', sbj='giardiasis', obj='polypeptide')
#      0.016 KBTriple(rel='acquired', sbj='diazepam', obj='prostatitis')
#      0.016 KBTriple(rel='acquired', sbj='prostatitis', obj='diazepam')
#      0.015 KBTriple(rel='acquired', sbj='propranolol', obj='gastric_lavage')
#      0.015 KBTriple(rel='acquired', sbj='gastric_lavage', obj='propranolol')
#      0.015 KBTriple(rel='acquired', sbj='concomitant', obj='lacrimation')
#      0.015 KBTriple(rel='acquired', sbj='lacrimation', obj='concomitant')
#      0.015 KBTriple(rel='acquired', sbj='ammonium', obj='dysentery')
#      0.015 KBTriple(rel='acquired', sbj='dysentery', obj='ammonium')
#      0.014 KBTriple(rel='acquired', sbj='ammonium', obj='proteinuria')
#      0.014 KBTriple(rel='acquired', sbj='proteinuria', obj='ammonium')
#      0.014 KBTriple(rel='acquired', sbj='anaplastic_astrocytoma', obj='methylprednisolone')
#      0.014 KBTriple(rel='acquired', sbj='methylprednisolone', obj='astrocytoma')
#      0.014 KBTriple(rel='acquired', sbj='methylprednisolone', obj='anaplastic_astrocytoma')
#      0.014 KBTriple(rel='acquired', sbj='astrocytoma', obj='methylprednisolone')
#      0.014 KBTriple(rel='acquired', sbj='hypertensive_crisis', obj='pindolol')
#      0.014 KBTriple(rel='acquired', sbj='pindolol', obj='hypertensive_crisis')
#      0.014 KBTriple(rel='acquired', sbj='norfloxacin', obj='pruritus')
#      0.014 KBTriple(rel='acquired', sbj='pruritus', obj='norfloxacin')
#      0.014 KBTriple(rel='acquired', sbj='adrenal_insufficiency', obj='somatostatin')
#      0.014 KBTriple(rel='acquired', sbj='somatostatin', obj='adrenal_insufficiency')
#      0.014 KBTriple(rel='acquired', sbj='progesterone', obj='nafarelin')
#      0.014 KBTriple(rel='acquired', sbj='nafarelin', obj='progesterone')
#      0.014 KBTriple(rel='acquired', sbj='concomitant', obj='ileus')
#      0.014 KBTriple(rel='acquired', sbj='ileus', obj='concomitant')
#      0.013 KBTriple(rel='acquired', sbj='buserelin', obj='investigation')
#      0.013 KBTriple(rel='acquired', sbj='investigation', obj='buserelin')
#      0.013 KBTriple(rel='acquired', sbj='phlebitis', obj='phenylbutazone')
#      0.013 KBTriple(rel='acquired', sbj='phenylbutazone', obj='phlebitis')
#      0.012 KBTriple(rel='acquired', sbj='concomitant', obj='aplastic_anaemia')
#      0.012 KBTriple(rel='acquired', sbj='aplastic_anaemia', obj='concomitant')
#      0.011 KBTriple(rel='acquired', sbj='halcinonide', obj='dermatitis')
#      0.011 KBTriple(rel='acquired', sbj='dermatitis', obj='halcinonide')
#      0.011 KBTriple(rel='acquired', sbj='natamycin', obj='eosinophilia')
#      0.011 KBTriple(rel='acquired', sbj='eosinophilia', obj='natamycin')
#      0.011 KBTriple(rel='acquired', sbj='supraventricular_tachyarrhythmia', obj='diltiazem')
#      0.011 KBTriple(rel='acquired', sbj='diltiazem', obj='supraventricular_tachyarrhythmia')
#      0.011 KBTriple(rel='acquired', sbj='fluorouracil', obj='aphakia')
#      0.011 KBTriple(rel='acquired', sbj='aphakia', obj='fluorouracil')
#      0.010 KBTriple(rel='acquired', sbj='condition', obj='radium')
#      0.010 KBTriple(rel='acquired', sbj='radium', obj='condition')
#      0.010 KBTriple(rel='acquired', sbj='dehydration', obj='pregnenolone')
#      0.010 KBTriple(rel='acquired', sbj='pregnenolone', obj='dehydration')
#      0.009 KBTriple(rel='acquired', sbj='brain_contusion', obj='magnesium')
#      0.009 KBTriple(rel='acquired', sbj='magnesium', obj='brain_contusion')
#      0.009 KBTriple(rel='acquired', sbj='quality_of_life', obj='betaxolol')
#      0.009 KBTriple(rel='acquired', sbj='betaxolol', obj='quality_of_life')
#      0.009 KBTriple(rel='acquired', sbj='cortisol', obj='buserelin')
#      0.009 KBTriple(rel='acquired', sbj='buserelin', obj='cortisol')
#      0.009 KBTriple(rel='acquired', sbj='acute_respiratory_failure', obj='sulindac')
#      0.009 KBTriple(rel='acquired', sbj='sulindac', obj='acute_respiratory_failure')
#      0.009 KBTriple(rel='acquired', sbj='graft_infection', obj='concomitant')
#      0.009 KBTriple(rel='acquired', sbj='concomitant', obj='graft_infection')
#      0.009 KBTriple(rel='acquired', sbj='adrenalectomy', obj='flunitrazepam')
#      0.009 KBTriple(rel='acquired', sbj='flunitrazepam', obj='adrenalectomy')
#      0.009 KBTriple(rel='acquired', sbj='stress_ulcer', obj='sodium')
#      0.009 KBTriple(rel='acquired', sbj='sodium', obj='stress_ulcer')
#      0.009 KBTriple(rel='acquired', sbj='mydriasis', obj='proparacaine')
#      0.009 KBTriple(rel='acquired', sbj='proparacaine', obj='mydriasis')
#      0.009 KBTriple(rel='acquired', sbj='nasal', obj='stevens-johnson_syndrome')
#      0.009 KBTriple(rel='acquired', sbj='stevens-johnson_syndrome', obj='nasal')
#      0.009 KBTriple(rel='acquired', sbj='lymphoma', obj='ovarium')
#      0.009 KBTriple(rel='acquired', sbj='ovarium', obj='lymphoma')
#      0.009 KBTriple(rel='acquired', sbj='hereditary_angioedema', obj='stanozolol')
#      0.009 KBTriple(rel='acquired', sbj='stanozolol', obj='hereditary_angioedema')
#
# Highest probability examples for relation aggravated:
#
#      0.999 KBTriple(rel='aggravated', sbj='cimetidine', obj='pco2')
#      0.999 KBTriple(rel='aggravated', sbj='pco2', obj='cimetidine')
#      0.979 KBTriple(rel='aggravated', sbj='diazepam', obj='tension')
#      0.979 KBTriple(rel='aggravated', sbj='tension', obj='diazepam')
#      0.887 KBTriple(rel='aggravated', sbj='somatostatin', obj='acidosis')
#      0.887 KBTriple(rel='aggravated', sbj='acidosis', obj='somatostatin')
#      0.886 KBTriple(rel='aggravated', sbj='droperidol', obj='visual_analogue_scale')
#      0.886 KBTriple(rel='aggravated', sbj='visual_analogue_scale', obj='droperidol')
#      0.850 KBTriple(rel='aggravated', sbj='coagulopathy', obj='corynebacterium')
#      0.850 KBTriple(rel='aggravated', sbj='corynebacterium', obj='coagulopathy')
#      0.842 KBTriple(rel='aggravated', sbj='phenytoin', obj='tension')
#      0.842 KBTriple(rel='aggravated', sbj='tension', obj='phenytoin')
#      0.832 KBTriple(rel='aggravated', sbj='metabolic_acidosis', obj='somatostatin')
#      0.832 KBTriple(rel='aggravated', sbj='somatostatin', obj='metabolic_acidosis')
#      0.740 KBTriple(rel='aggravated', sbj='ibuprofen', obj='vitamin_a')
#      0.740 KBTriple(rel='aggravated', sbj='vitamin_a', obj='ibuprofen')
#      0.736 KBTriple(rel='aggravated', sbj='rheumatoid_arthritis', obj='diazepam')
#      0.736 KBTriple(rel='aggravated', sbj='diazepam', obj='rheumatoid_arthritis')
#      0.731 KBTriple(rel='aggravated', sbj='condition', obj='viomycin')
#      0.731 KBTriple(rel='aggravated', sbj='viomycin', obj='condition')
#      0.719 KBTriple(rel='aggravated', sbj='forced_expiratory_flow', obj='sodium')
#      0.719 KBTriple(rel='aggravated', sbj='sodium', obj='forced_expiratory_flow')
#      0.701 KBTriple(rel='aggravated', sbj='debridement', obj='piperacillin')
#      0.701 KBTriple(rel='aggravated', sbj='piperacillin', obj='debridement')
#      0.679 KBTriple(rel='aggravated', sbj='teicoplanin', obj='growth')
#      0.679 KBTriple(rel='aggravated', sbj='growth', obj='teicoplanin')
#      0.652 KBTriple(rel='aggravated', sbj='hepatic_lesion', obj='cocaine')
#      0.652 KBTriple(rel='aggravated', sbj='cocaine', obj='hepatic_lesion')
#      0.651 KBTriple(rel='aggravated', sbj='idoxuridine', obj='infection')
#      0.651 KBTriple(rel='aggravated', sbj='infection', obj='idoxuridine')
#      0.617 KBTriple(rel='aggravated', sbj='accident', obj='molsidomine')
#      0.617 KBTriple(rel='aggravated', sbj='molsidomine', obj='accident')
#      0.601 KBTriple(rel='aggravated', sbj='fluid_imbalance', obj='ibuprofen')
#      0.601 KBTriple(rel='aggravated', sbj='ibuprofen', obj='fluid_imbalance')
#      0.600 KBTriple(rel='aggravated', sbj='muscle_mass', obj='bisoprolol')
#      0.600 KBTriple(rel='aggravated', sbj='bisoprolol', obj='muscle_mass')
#      0.594 KBTriple(rel='aggravated', sbj='pulmonary_function_test', obj='helium')
#      0.594 KBTriple(rel='aggravated', sbj='helium', obj='pulmonary_function_test')
#      0.589 KBTriple(rel='aggravated', sbj='concomitant', obj='grip_strength')
#      0.589 KBTriple(rel='aggravated', sbj='grip_strength', obj='concomitant')
#      0.587 KBTriple(rel='aggravated', sbj='neostigmine', obj='ischaemia')
#      0.587 KBTriple(rel='aggravated', sbj='ischaemia', obj='neostigmine')
#      0.582 KBTriple(rel='aggravated', sbj='pain', obj='paradox')
#      0.582 KBTriple(rel='aggravated', sbj='paradox', obj='pain')
#      0.542 KBTriple(rel='aggravated', sbj='alfentanil', obj='neuromuscular_block')
#      0.542 KBTriple(rel='aggravated', sbj='neuromuscular_block', obj='alfentanil')
#      0.528 KBTriple(rel='aggravated', sbj='magnesium', obj='metrorrhagia')
#      0.528 KBTriple(rel='aggravated', sbj='metrorrhagia', obj='magnesium')
#      0.520 KBTriple(rel='aggravated', sbj='sinus_rhythm', obj='terazosin')
#      0.520 KBTriple(rel='aggravated', sbj='terazosin', obj='sinus_rhythm')
#      0.518 KBTriple(rel='aggravated', sbj='intranasal', obj='glioma')
#      0.518 KBTriple(rel='aggravated', sbj='glioma', obj='intranasal')
#      0.503 KBTriple(rel='aggravated', sbj='teicoplanin', obj='vomiting')
#      0.503 KBTriple(rel='aggravated', sbj='vomiting', obj='teicoplanin')
#      0.491 KBTriple(rel='aggravated', sbj='cocaine', obj='oestradiol')
#      0.491 KBTriple(rel='aggravated', sbj='oestradiol', obj='cocaine')
#      0.489 KBTriple(rel='aggravated', sbj='peptide', obj='enteral_nutrition')
#      0.489 KBTriple(rel='aggravated', sbj='enteral_nutrition', obj='peptide')
#      0.488 KBTriple(rel='aggravated', sbj='diazepam', obj='central_cord_syndrome')
#      0.488 KBTriple(rel='aggravated', sbj='central_cord_syndrome', obj='diazepam')
#      0.474 KBTriple(rel='aggravated', sbj='tac', obj='t-cell_lymphoma')
#      0.474 KBTriple(rel='aggravated', sbj='t-cell_lymphoma', obj='tac')
#      0.467 KBTriple(rel='aggravated', sbj='muscle_mass', obj='diltiazem')
#      0.467 KBTriple(rel='aggravated', sbj='diltiazem', obj='muscle_mass')
#      0.466 KBTriple(rel='aggravated', sbj='epinephrine', obj='allantoin')
#      0.466 KBTriple(rel='aggravated', sbj='allantoin', obj='epinephrine')
#      0.461 KBTriple(rel='aggravated', sbj='amsacrine', obj='blast_cells')
#      0.461 KBTriple(rel='aggravated', sbj='blast_cells', obj='amsacrine')
#      0.459 KBTriple(rel='aggravated', sbj='vitamin_b12', obj='gentamicin')
#      0.459 KBTriple(rel='aggravated', sbj='gentamicin', obj='vitamin_b12')
#      0.454 KBTriple(rel='aggravated', sbj='gentamicin', obj='glomerulosclerosis')
#      0.454 KBTriple(rel='aggravated', sbj='glomerulosclerosis', obj='gentamicin')
#      0.452 KBTriple(rel='aggravated', sbj='sputum', obj='thiabendazole')
#      0.452 KBTriple(rel='aggravated', sbj='thiabendazole', obj='sputum')
#      0.451 KBTriple(rel='aggravated', sbj='ischaemia', obj='paradox')
#      0.451 KBTriple(rel='aggravated', sbj='paradox', obj='ischaemia')
#      0.449 KBTriple(rel='aggravated', sbj='hypometabolism', obj='cocaine')
#      0.449 KBTriple(rel='aggravated', sbj='cocaine', obj='hypometabolism')
#      0.448 KBTriple(rel='aggravated', sbj='piloerection', obj='sodium')
#      0.448 KBTriple(rel='aggravated', sbj='sodium', obj='piloerection')
#      0.441 KBTriple(rel='aggravated', sbj='sodium', obj='central_cord_syndrome')
#      0.441 KBTriple(rel='aggravated', sbj='central_cord_syndrome', obj='sodium')
#      0.437 KBTriple(rel='aggravated', sbj='aciclovir', obj='genital_herpes_simplex')
#      0.437 KBTriple(rel='aggravated', sbj='genital_herpes_simplex', obj='aciclovir')
#      0.430 KBTriple(rel='aggravated', sbj='sodium', obj='atrial_hypertrophy')
#      0.430 KBTriple(rel='aggravated', sbj='atrial_hypertrophy', obj='sodium')
#      0.429 KBTriple(rel='aggravated', sbj='hyperammonaemia', obj='sodium')
#      0.429 KBTriple(rel='aggravated', sbj='sodium', obj='hyperammonaemia')
#      0.427 KBTriple(rel='aggravated', sbj='azatadine', obj='rhinitis')
#      0.427 KBTriple(rel='aggravated', sbj='rhinitis', obj='azatadine')
#      0.420 KBTriple(rel='aggravated', sbj='bepridil', obj='troponin')
#      0.420 KBTriple(rel='aggravated', sbj='troponin', obj='bepridil')
#      0.403 KBTriple(rel='aggravated', sbj='polypeptide', obj='lactic_acidosis')
#      0.403 KBTriple(rel='aggravated', sbj='lactic_acidosis', obj='polypeptide')
#      0.403 KBTriple(rel='aggravated', sbj='diazepam', obj='chorea')
#      0.403 KBTriple(rel='aggravated', sbj='chorea', obj='diazepam')
#      0.401 KBTriple(rel='aggravated', sbj='celiprolol', obj='hypertrophy')
#      0.401 KBTriple(rel='aggravated', sbj='hypertrophy', obj='celiprolol')
#      0.397 KBTriple(rel='aggravated', sbj='somatostatin', obj='gastroduodenal_ulcer')
#      0.397 KBTriple(rel='aggravated', sbj='gastroduodenal_ulcer', obj='somatostatin')
#
# Highest probability examples for relation altered:
#
#      0.878 KBTriple(rel='altered', sbj='protein_c', obj='peptide')
#      0.878 KBTriple(rel='altered', sbj='peptide', obj='protein_c')
#      0.631 KBTriple(rel='altered', sbj='cimetidine', obj='forced_expiratory_volume')
#      0.631 KBTriple(rel='altered', sbj='forced_expiratory_volume', obj='cimetidine')
#      0.542 KBTriple(rel='altered', sbj='tinnitus', obj='phenylbutazone')
#      0.542 KBTriple(rel='altered', sbj='phenylbutazone', obj='tinnitus')
#      0.501 KBTriple(rel='altered', sbj='vital_capacity', obj='lidocaine')
#      0.501 KBTriple(rel='altered', sbj='lidocaine', obj='vital_capacity')
#      0.382 KBTriple(rel='altered', sbj='somatostatin', obj='blood_glucagon')
#      0.382 KBTriple(rel='altered', sbj='blood_glucagon', obj='somatostatin')
#      0.352 KBTriple(rel='altered', sbj='diazepam', obj='extubation')
#      0.352 KBTriple(rel='altered', sbj='extubation', obj='diazepam')
#      0.273 KBTriple(rel='altered', sbj='microangiopathy', obj='somatostatin')
#      0.273 KBTriple(rel='altered', sbj='somatostatin', obj='microangiopathy')
#      0.271 KBTriple(rel='altered', sbj='infusion', obj='betaxolol')
#      0.271 KBTriple(rel='altered', sbj='betaxolol', obj='infusion')
#      0.262 KBTriple(rel='altered', sbj='phenylbutazone', obj='urticaria')
#      0.262 KBTriple(rel='altered', sbj='urticaria', obj='phenylbutazone')
#      0.241 KBTriple(rel='altered', sbj='strontium', obj='salmonellosis')
#      0.241 KBTriple(rel='altered', sbj='salmonellosis', obj='strontium')
#      0.230 KBTriple(rel='altered', sbj='cimetidine', obj='forced_expiratory_flow')
#      0.230 KBTriple(rel='altered', sbj='forced_expiratory_flow', obj='cimetidine')
#      0.227 KBTriple(rel='altered', sbj='pindolol', obj='forced_expiratory_volume')
#      0.227 KBTriple(rel='altered', sbj='forced_expiratory_volume', obj='pindolol')
#      0.208 KBTriple(rel='altered', sbj='blood_bicarbonate', obj='ammonium')
#      0.208 KBTriple(rel='altered', sbj='ammonium', obj='blood_bicarbonate')
#      0.198 KBTriple(rel='altered', sbj='poisoning', obj='strontium')
#      0.198 KBTriple(rel='altered', sbj='strontium', obj='poisoning')
#      0.186 KBTriple(rel='altered', sbj='desipramine', obj='amylase')
#      0.186 KBTriple(rel='altered', sbj='amylase', obj='desipramine')
#      0.184 KBTriple(rel='altered', sbj='imipenem', obj='neurotoxicity')
#      0.184 KBTriple(rel='altered', sbj='neurotoxicity', obj='imipenem')
#      0.179 KBTriple(rel='altered', sbj='strontium', obj='food_poisoning')
#      0.179 KBTriple(rel='altered', sbj='food_poisoning', obj='strontium')
#      0.162 KBTriple(rel='altered', sbj='abdominal_pain', obj='magnesium')
#      0.162 KBTriple(rel='altered', sbj='magnesium', obj='abdominal_pain')
#      0.149 KBTriple(rel='altered', sbj='depressed_mood', obj='concomitant')
#      0.149 KBTriple(rel='altered', sbj='concomitant', obj='depressed_mood')
#      0.142 KBTriple(rel='altered', sbj='sneezing', obj='methylprednisolone')
#      0.142 KBTriple(rel='altered', sbj='methylprednisolone', obj='sneezing')
#      0.142 KBTriple(rel='altered', sbj='zidovudine', obj='saliva')
#      0.142 KBTriple(rel='altered', sbj='saliva', obj='zidovudine')
#      0.137 KBTriple(rel='altered', sbj='prazepam', obj='mood')
#      0.137 KBTriple(rel='altered', sbj='mood', obj='prazepam')
#      0.127 KBTriple(rel='altered', sbj='norfloxacin', obj='prothrombin_time')
#      0.127 KBTriple(rel='altered', sbj='prothrombin_time', obj='norfloxacin')
#      0.120 KBTriple(rel='altered', sbj='magnesium', obj='blood_cadmium')
#      0.120 KBTriple(rel='altered', sbj='blood_cadmium', obj='magnesium')
#      0.115 KBTriple(rel='altered', sbj='euthyroid_sick_syndrome', obj='concomitant')
#      0.115 KBTriple(rel='altered', sbj='concomitant', obj='euthyroid_sick_syndrome')
#      0.113 KBTriple(rel='altered', sbj='osteonecrosis', obj='radium')
#      0.113 KBTriple(rel='altered', sbj='radium', obj='osteonecrosis')
#      0.112 KBTriple(rel='altered', sbj='vital_capacity', obj='cimetidine')
#      0.112 KBTriple(rel='altered', sbj='cimetidine', obj='vital_capacity')
#      0.112 KBTriple(rel='altered', sbj='cimetidine', obj='forced_vital_capacity')
#      0.112 KBTriple(rel='altered', sbj='forced_vital_capacity', obj='cimetidine')
#      0.111 KBTriple(rel='altered', sbj='pindolol', obj='forced_vital_capacity')
#      0.111 KBTriple(rel='altered', sbj='pindolol', obj='vital_capacity')
#      0.111 KBTriple(rel='altered', sbj='vital_capacity', obj='pindolol')
#      0.111 KBTriple(rel='altered', sbj='forced_vital_capacity', obj='pindolol')
#      0.106 KBTriple(rel='altered', sbj='cutaneous_vasculitis', obj='propranolol')
#      0.106 KBTriple(rel='altered', sbj='propranolol', obj='cutaneous_vasculitis')
#      0.102 KBTriple(rel='altered', sbj='immunoglobulins', obj='zidovudine')
#      0.102 KBTriple(rel='altered', sbj='zidovudine', obj='immunoglobulins')
#      0.100 KBTriple(rel='altered', sbj='investigation', obj='idoxuridine')
#      0.100 KBTriple(rel='altered', sbj='idoxuridine', obj='investigation')
#      0.100 KBTriple(rel='altered', sbj='diltiazem', obj='mobility')
#      0.100 KBTriple(rel='altered', sbj='mobility', obj='diltiazem')
#      0.096 KBTriple(rel='altered', sbj='carotid_artery_occlusion', obj='bretylium')
#      0.096 KBTriple(rel='altered', sbj='bretylium', obj='carotid_artery_occlusion')
#      0.093 KBTriple(rel='altered', sbj='fatigue', obj='pindolol')
#      0.093 KBTriple(rel='altered', sbj='pindolol', obj='fatigue')
#      0.092 KBTriple(rel='altered', sbj='nasal', obj='urine_flow')
#      0.092 KBTriple(rel='altered', sbj='urine_flow', obj='nasal')
#      0.089 KBTriple(rel='altered', sbj='tension', obj='prazepam')
#      0.089 KBTriple(rel='altered', sbj='prazepam', obj='tension')
#      0.085 KBTriple(rel='altered', sbj='fasting', obj='nizatidine')
#      0.085 KBTriple(rel='altered', sbj='nizatidine', obj='fasting')
#      0.083 KBTriple(rel='altered', sbj='otitis_media', obj='xylometazoline')
#      0.083 KBTriple(rel='altered', sbj='xylometazoline', obj='otitis_media')
#      0.083 KBTriple(rel='altered', sbj='ammonium', obj='prothrombin_time')
#      0.083 KBTriple(rel='altered', sbj='prothrombin_time', obj='ammonium')
#      0.083 KBTriple(rel='altered', sbj='acyclovir', obj='sensory_disturbance')
#      0.083 KBTriple(rel='altered', sbj='sensory_disturbance', obj='acyclovir')
#      0.081 KBTriple(rel='altered', sbj='concomitant', obj='hypocalcaemia')
#      0.081 KBTriple(rel='altered', sbj='hypocalcaemia', obj='concomitant')
#      0.081 KBTriple(rel='altered', sbj='magnesium', obj='duodenal_obstruction')
#      0.081 KBTriple(rel='altered', sbj='duodenal_obstruction', obj='magnesium')
#      0.080 KBTriple(rel='altered', sbj='piperacillin', obj='prostatitis')
#      0.080 KBTriple(rel='altered', sbj='prostatitis', obj='piperacillin')
#      0.080 KBTriple(rel='altered', sbj='metabolic_acidosis', obj='somatostatin')
#      0.080 KBTriple(rel='altered', sbj='somatostatin', obj='metabolic_acidosis')
#      0.077 KBTriple(rel='altered', sbj='magnesium', obj='folate_deficiency')
#      0.077 KBTriple(rel='altered', sbj='folate_deficiency', obj='magnesium')
#      0.077 KBTriple(rel='altered', sbj='amoebiasis', obj='magnesium')
#      0.077 KBTriple(rel='altered', sbj='magnesium', obj='amoebiasis')
#      0.075 KBTriple(rel='altered', sbj='sodium', obj='gastroschisis')
#      0.075 KBTriple(rel='altered', sbj='gastroschisis', obj='sodium')
#      0.073 KBTriple(rel='altered', sbj='somatostatin', obj='acidosis')
#      0.073 KBTriple(rel='altered', sbj='acidosis', obj='somatostatin')
#
# Highest probability examples for relation caused:
#      1.000 KBTriple(rel='caused', sbj='fall', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='fall')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='blood_pressure')
#      1.000 KBTriple(rel='caused', sbj='blood_pressure', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='enzyme_activity', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='enzyme_activity')
#      1.000 KBTriple(rel='caused', sbj='tachycardia', obj='propranolol')
#      1.000 KBTriple(rel='caused', sbj='propranolol', obj='tachycardia')
#      1.000 KBTriple(rel='caused', sbj='magnesium', obj='infusion')
#      1.000 KBTriple(rel='caused', sbj='infusion', obj='magnesium')
#      1.000 KBTriple(rel='caused', sbj='sodium', obj='hypercalciuria')
#      1.000 KBTriple(rel='caused', sbj='hypercalciuria', obj='sodium')
#      1.000 KBTriple(rel='caused', sbj='headache', obj='sumatriptan')
#      1.000 KBTriple(rel='caused', sbj='sumatriptan', obj='headache')
#      1.000 KBTriple(rel='caused', sbj='ventricular_tachycardia', obj='magnesium')
#      1.000 KBTriple(rel='caused', sbj='magnesium', obj='ventricular_tachycardia')
#      1.000 KBTriple(rel='caused', sbj='sodium', obj='thrombosis')
#      1.000 KBTriple(rel='caused', sbj='thrombosis', obj='sodium')
#      1.000 KBTriple(rel='caused', sbj='salpingitis', obj='gentamicin')
#      1.000 KBTriple(rel='caused', sbj='gentamicin', obj='salpingitis')
#      1.000 KBTriple(rel='caused', sbj='propranolol', obj='enzyme_activity')
#      1.000 KBTriple(rel='caused', sbj='enzyme_activity', obj='propranolol')
#      0.999 KBTriple(rel='caused', sbj='magnesium', obj='dialysis')
#      0.999 KBTriple(rel='caused', sbj='dialysis', obj='magnesium')
#      0.999 KBTriple(rel='caused', sbj='hypotension', obj='betaxolol')
#      0.999 KBTriple(rel='caused', sbj='betaxolol', obj='hypotension')
#      0.999 KBTriple(rel='caused', sbj='ulcer', obj='nizatidine')
#      0.999 KBTriple(rel='caused', sbj='nizatidine', obj='ulcer')
#      0.999 KBTriple(rel='caused', sbj='blood_ethanol', obj='cocaine')
#      0.999 KBTriple(rel='caused', sbj='cocaine', obj='blood_ethanol')
#      0.998 KBTriple(rel='caused', sbj='pectin', obj='weight')
#      0.998 KBTriple(rel='caused', sbj='weight', obj='pectin')
#      0.997 KBTriple(rel='caused', sbj='injury', obj='magnesium')
#      0.997 KBTriple(rel='caused', sbj='magnesium', obj='injury')
#      0.997 KBTriple(rel='caused', sbj='ondansetron', obj='radiotherapy')
#      0.997 KBTriple(rel='caused', sbj='radiotherapy', obj='ondansetron')
#      0.996 KBTriple(rel='caused', sbj='cocaine', obj='thrombosis')
#      0.996 KBTriple(rel='caused', sbj='thrombosis', obj='cocaine')
#      0.996 KBTriple(rel='caused', sbj='renin', obj='magnesium')
#      0.996 KBTriple(rel='caused', sbj='magnesium', obj='renin')
#      0.996 KBTriple(rel='caused', sbj='magnesium', obj='essential_hypertension')
#      0.996 KBTriple(rel='caused', sbj='essential_hypertension', obj='magnesium')
#      0.996 KBTriple(rel='caused', sbj='essential_hypertension', obj='thiazide')
#      0.996 KBTriple(rel='caused', sbj='thiazide', obj='essential_hypertension')
#      0.996 KBTriple(rel='caused', sbj='concomitant', obj='anxiety')
#      0.996 KBTriple(rel='caused', sbj='anxiety', obj='concomitant')
#      0.995 KBTriple(rel='caused', sbj='levobunolol', obj='ocular_hypertension')
#      0.995 KBTriple(rel='caused', sbj='ocular_hypertension', obj='levobunolol')
#      0.995 KBTriple(rel='caused', sbj='infection', obj='zidovudine')
#      0.995 KBTriple(rel='caused', sbj='zidovudine', obj='infection')
#      0.994 KBTriple(rel='caused', sbj='betaxolol', obj='intraocular_pressure')
#      0.994 KBTriple(rel='caused', sbj='intraocular_pressure', obj='betaxolol')
#      0.994 KBTriple(rel='caused', sbj='swelling', obj='diclofenac')
#      0.994 KBTriple(rel='caused', sbj='diclofenac', obj='swelling')
#      0.994 KBTriple(rel='caused', sbj='peritoneal_dialysis', obj='magnesium')
#      0.994 KBTriple(rel='caused', sbj='magnesium', obj='peritoneal_dialysis')
#      0.993 KBTriple(rel='caused', sbj='hypertrophy', obj='hydralazine')
#      0.993 KBTriple(rel='caused', sbj='hydralazine', obj='hypertrophy')
#      0.993 KBTriple(rel='caused', sbj='cimetidine', obj='pco2')
#      0.993 KBTriple(rel='caused', sbj='pco2', obj='cimetidine')
#      0.993 KBTriple(rel='caused', sbj='sodium', obj='venous_thrombosis')
#      0.993 KBTriple(rel='caused', sbj='venous_thrombosis', obj='sodium')
#      0.993 KBTriple(rel='caused', sbj='elective_surgery', obj='lidocaine')
#      0.993 KBTriple(rel='caused', sbj='lidocaine', obj='elective_surgery')
#      0.992 KBTriple(rel='caused', sbj='propranolol', obj='diuretic_therapy')
#      0.992 KBTriple(rel='caused', sbj='diuretic_therapy', obj='propranolol')
#      0.992 KBTriple(rel='caused', sbj='carnitine', obj='phenytoin')
#      0.992 KBTriple(rel='caused', sbj='phenytoin', obj='carnitine')
#      0.992 KBTriple(rel='caused', sbj='aluminium', obj='ulcer')
#      0.992 KBTriple(rel='caused', sbj='ulcer', obj='aluminium')
#      0.992 KBTriple(rel='caused', sbj='electrocardiogram', obj='thallium')
#      0.992 KBTriple(rel='caused', sbj='thallium', obj='electrocardiogram')
#      0.992 KBTriple(rel='caused', sbj='allantoin', obj='weight')
#      0.992 KBTriple(rel='caused', sbj='weight', obj='allantoin')
#      0.991 KBTriple(rel='caused', sbj='gastric_varices', obj='somatostatin')
#      0.991 KBTriple(rel='caused', sbj='somatostatin', obj='gastric_varices')
#      0.989 KBTriple(rel='caused', sbj='fracture', obj='magnesium')
#      0.989 KBTriple(rel='caused', sbj='magnesium', obj='fracture')
#      0.989 KBTriple(rel='caused', sbj='anaesthesia', obj='magnesium')
#      0.989 KBTriple(rel='caused', sbj='magnesium', obj='anaesthesia')
#      0.989 KBTriple(rel='caused', sbj='cell_death', obj='diltiazem')
#      0.989 KBTriple(rel='caused', sbj='diltiazem', obj='cell_death')
#      0.988 KBTriple(rel='caused', sbj='epinephrine', obj='magnesium')
#      0.988 KBTriple(rel='caused', sbj='magnesium', obj='epinephrine')
#      0.988 KBTriple(rel='caused', sbj='osteomalacia', obj='aluminium')
#      0.988 KBTriple(rel='caused', sbj='aluminium', obj='osteomalacia')
#      0.987 KBTriple(rel='caused', sbj='epinephrine', obj='clopidogrel')
#      0.987 KBTriple(rel='caused', sbj='clopidogrel', obj='epinephrine')
#      0.987 KBTriple(rel='caused', sbj='magnesium', obj='depression')
#      0.987 KBTriple(rel='caused', sbj='depression', obj='magnesium')
#      0.987 KBTriple(rel='caused', sbj='diflunisal', obj='necrosis')
#      0.987 KBTriple(rel='caused', sbj='necrosis', obj='diflunisal')
#      0.986 KBTriple(rel='caused', sbj='strontium', obj='osteolysis')
#      0.986 KBTriple(rel='caused', sbj='osteolysis', obj='strontium')
#      0.986 KBTriple(rel='caused', sbj='nausea', obj='methylprednisolone')
#      0.986 KBTriple(rel='caused', sbj='methylprednisolone', obj='nausea')
#      0.985 KBTriple(rel='caused', sbj='stress', obj='hydralazine')
#      0.985 KBTriple(rel='caused', sbj='hydralazine', obj='stress')
#      0.985 KBTriple(rel='caused', sbj='vomiting', obj='droperidol')
#      0.985 KBTriple(rel='caused', sbj='droperidol', obj='vomiting')
#
# Highest probability examples for relation changed:
#
#      0.602 KBTriple(rel='changed', sbj='pain', obj='gamma-globulin')
#      0.602 KBTriple(rel='changed', sbj='gamma-globulin', obj='pain')
#      0.458 KBTriple(rel='changed', sbj='gamma-globulin', obj='cholangitis')
#      0.458 KBTriple(rel='changed', sbj='cholangitis', obj='gamma-globulin')
#      0.302 KBTriple(rel='changed', sbj='carbon_dioxide', obj='methylprednisolone')
#      0.302 KBTriple(rel='changed', sbj='methylprednisolone', obj='carbon_dioxide')
#      0.256 KBTriple(rel='changed', sbj='cardiopulmonary_bypass', obj='fac')
#      0.256 KBTriple(rel='changed', sbj='fac', obj='cardiopulmonary_bypass')
#      0.239 KBTriple(rel='changed', sbj='indium', obj='neoplasm')
#      0.239 KBTriple(rel='changed', sbj='neoplasm', obj='indium')
#      0.212 KBTriple(rel='changed', sbj='fungal_infection', obj='gentamicin')
#      0.212 KBTriple(rel='changed', sbj='gentamicin', obj='fungal_infection')
#      0.202 KBTriple(rel='changed', sbj='sodium', obj='carbohydrate_intolerance')
#      0.202 KBTriple(rel='changed', sbj='carbohydrate_intolerance', obj='sodium')
#      0.164 KBTriple(rel='changed', sbj='gastric_fistula', obj='diazepam')
#      0.164 KBTriple(rel='changed', sbj='diazepam', obj='gastric_fistula')
#      0.162 KBTriple(rel='changed', sbj='nasal', obj='holoprosencephaly')
#      0.162 KBTriple(rel='changed', sbj='holoprosencephaly', obj='nasal')
#      0.148 KBTriple(rel='changed', sbj='concomitant', obj='borderline_personality_disorder')
#      0.148 KBTriple(rel='changed', sbj='borderline_personality_disorder', obj='concomitant')
#      0.146 KBTriple(rel='changed', sbj='lidocaine', obj='cerebral_artery_occlusion')
#      0.146 KBTriple(rel='changed', sbj='cerebral_artery_occlusion', obj='lidocaine')
#      0.129 KBTriple(rel='changed', sbj='arac', obj='hypersensitivity')
#      0.129 KBTriple(rel='changed', sbj='hypersensitivity', obj='arac')
#      0.117 KBTriple(rel='changed', sbj='paradox', obj='acidosis')
#      0.117 KBTriple(rel='changed', sbj='acidosis', obj='paradox')
#      0.117 KBTriple(rel='changed', sbj='lithiasis', obj='sodium')
#      0.117 KBTriple(rel='changed', sbj='sodium', obj='lithiasis')
#      0.113 KBTriple(rel='changed', sbj='paradox', obj='muscle_fatigue')
#      0.113 KBTriple(rel='changed', sbj='muscle_fatigue', obj='paradox')
#      0.107 KBTriple(rel='changed', sbj='solar_urticaria', obj='cimetidine')
#      0.107 KBTriple(rel='changed', sbj='cimetidine', obj='solar_urticaria')
#      0.105 KBTriple(rel='changed', sbj='pindolol', obj='fibrosis')
#      0.105 KBTriple(rel='changed', sbj='fibrosis', obj='pindolol')
#      0.104 KBTriple(rel='changed', sbj='investigation', obj='idoxuridine')
#      0.104 KBTriple(rel='changed', sbj='idoxuridine', obj='investigation')
#      0.099 KBTriple(rel='changed', sbj='flunitrazepam', obj='aortic_surgery')
#      0.099 KBTriple(rel='changed', sbj='aortic_surgery', obj='flunitrazepam')
#      0.095 KBTriple(rel='changed', sbj='oxyphenbutazone', obj='rheumatoid_arthritis')
#      0.095 KBTriple(rel='changed', sbj='arthritis', obj='oxyphenbutazone')
#      0.095 KBTriple(rel='changed', sbj='rheumatoid_arthritis', obj='oxyphenbutazone')
#      0.095 KBTriple(rel='changed', sbj='oxyphenbutazone', obj='arthritis')
#      0.095 KBTriple(rel='changed', sbj='azatadine', obj='rhinitis')
#      0.095 KBTriple(rel='changed', sbj='rhinitis', obj='azatadine')
#      0.094 KBTriple(rel='changed', sbj='teicoplanin', obj='intensive_care')
#      0.094 KBTriple(rel='changed', sbj='intensive_care', obj='teicoplanin')
#      0.094 KBTriple(rel='changed', sbj='propranolol', obj='craniotomy')
#      0.094 KBTriple(rel='changed', sbj='craniotomy', obj='propranolol')
#      0.093 KBTriple(rel='changed', sbj='osteochondrosis', obj='propranolol')
#      0.093 KBTriple(rel='changed', sbj='propranolol', obj='osteochondrosis')
#      0.085 KBTriple(rel='changed', sbj='cimetidine', obj='erosive_oesophagitis')
#      0.085 KBTriple(rel='changed', sbj='erosive_oesophagitis', obj='cimetidine')
#      0.085 KBTriple(rel='changed', sbj='hyperoxia', obj='tripeptide')
#      0.085 KBTriple(rel='changed', sbj='tripeptide', obj='hyperoxia')
#      0.083 KBTriple(rel='changed', sbj='concomitant', obj='stridor')
#      0.083 KBTriple(rel='changed', sbj='stridor', obj='concomitant')
#      0.082 KBTriple(rel='changed', sbj='angle_closure_glaucoma', obj='fluorouracil')
#      0.082 KBTriple(rel='changed', sbj='fluorouracil', obj='angle_closure_glaucoma')
#      0.082 KBTriple(rel='changed', sbj='lidocaine', obj='atopy')
#      0.082 KBTriple(rel='changed', sbj='atopy', obj='lidocaine')
#      0.081 KBTriple(rel='changed', sbj='cancer_pain', obj='diflunisal')
#      0.081 KBTriple(rel='changed', sbj='diflunisal', obj='cancer_pain')
#      0.081 KBTriple(rel='changed', sbj='ammonium', obj='loss_of_consciousness')
#      0.081 KBTriple(rel='changed', sbj='loss_of_consciousness', obj='ammonium')
#      0.081 KBTriple(rel='changed', sbj='lidocaine', obj='hysterectomy')
#      0.081 KBTriple(rel='changed', sbj='hysterectomy', obj='lidocaine')
#      0.081 KBTriple(rel='changed', sbj='b-cell_lymphoma', obj='acyclovir')
#      0.081 KBTriple(rel='changed', sbj='acyclovir', obj='b-cell_lymphoma')
#      0.080 KBTriple(rel='changed', sbj='foscavir', obj='necrosis')
#      0.080 KBTriple(rel='changed', sbj='necrosis', obj='foscavir')
#      0.079 KBTriple(rel='changed', sbj='gamma-globulin', obj='mean_arterial_pressure')
#      0.079 KBTriple(rel='changed', sbj='mean_arterial_pressure', obj='gamma-globulin')
#      0.078 KBTriple(rel='changed', sbj='renal_amyloidosis', obj='sodium')
#      0.078 KBTriple(rel='changed', sbj='sodium', obj='renal_amyloidosis')
#      0.075 KBTriple(rel='changed', sbj='surgery', obj='proparacaine')
#      0.075 KBTriple(rel='changed', sbj='proparacaine', obj='surgery')
#      0.074 KBTriple(rel='changed', sbj='hydralazine', obj='body_surface_area')
#      0.074 KBTriple(rel='changed', sbj='body_surface_area', obj='hydralazine')
#      0.072 KBTriple(rel='changed', sbj='mastocytoma', obj='amsacrine')
#      0.072 KBTriple(rel='changed', sbj='amsacrine', obj='mastocytoma')
#      0.069 KBTriple(rel='changed', sbj='allantoin', obj='anoxia')
#      0.069 KBTriple(rel='changed', sbj='anoxia', obj='allantoin')
#      0.069 KBTriple(rel='changed', sbj='diastolic_hypertension', obj='propranolol')
#      0.069 KBTriple(rel='changed', sbj='propranolol', obj='diastolic_hypertension')
#      0.067 KBTriple(rel='changed', sbj='hypocapnia', obj='lidocaine')
#      0.067 KBTriple(rel='changed', sbj='lidocaine', obj='hypocapnia')
#      0.065 KBTriple(rel='changed', sbj='gallium', obj='drug_resistance')
#      0.065 KBTriple(rel='changed', sbj='drug_resistance', obj='gallium')
#      0.063 KBTriple(rel='changed', sbj='human_chorionic_gonadotropin', obj='beta-carotene')
#      0.063 KBTriple(rel='changed', sbj='beta-carotene', obj='human_chorionic_gonadotropin')
#      0.062 KBTriple(rel='changed', sbj='insomnia', obj='zidovudine')
#      0.062 KBTriple(rel='changed', sbj='zidovudine', obj='insomnia')
#      0.062 KBTriple(rel='changed', sbj='myocardial_depression', obj='sotalol')
#      0.062 KBTriple(rel='changed', sbj='sotalol', obj='myocardial_depression')
#      0.061 KBTriple(rel='changed', sbj='azacytidine', obj='lymphoma')
#      0.061 KBTriple(rel='changed', sbj='lymphoma', obj='azacytidine')
#      0.060 KBTriple(rel='changed', sbj='gastrointestinal_toxicity', obj='sodium')
#      0.060 KBTriple(rel='changed', sbj='sodium', obj='gastrointestinal_toxicity')
#      0.059 KBTriple(rel='changed', sbj='cutaneous_vasculitis', obj='propranolol')
#      0.059 KBTriple(rel='changed', sbj='propranolol', obj='cutaneous_vasculitis')
#
# Highest probability examples for relation decreased:
#
#      1.000 KBTriple(rel='decreased', sbj='renin', obj='terazosin')
#      1.000 KBTriple(rel='decreased', sbj='terazosin', obj='renin')
#      1.000 KBTriple(rel='decreased', sbj='weight', obj='diltiazem')
#      1.000 KBTriple(rel='decreased', sbj='diltiazem', obj='weight')
#      1.000 KBTriple(rel='decreased', sbj='hypotension', obj='betaxolol')
#      1.000 KBTriple(rel='decreased', sbj='betaxolol', obj='hypotension')
#      1.000 KBTriple(rel='decreased', sbj='gentamicin', obj='mass')
#      1.000 KBTriple(rel='decreased', sbj='mass', obj='gentamicin')
#      1.000 KBTriple(rel='decreased', sbj='allantoin', obj='weight')
#      1.000 KBTriple(rel='decreased', sbj='weight', obj='allantoin')
#      0.999 KBTriple(rel='decreased', sbj='cardiac_index', obj='propranolol')
#      0.999 KBTriple(rel='decreased', sbj='propranolol', obj='cardiac_index')
#      0.998 KBTriple(rel='decreased', sbj='magnesium', obj='alanine_aminotransferase')
#      0.998 KBTriple(rel='decreased', sbj='alanine_aminotransferase', obj='magnesium')
#      0.997 KBTriple(rel='decreased', sbj='urine_flow', obj='ammonium')
#      0.997 KBTriple(rel='decreased', sbj='ammonium', obj='urine_flow')
#      0.996 KBTriple(rel='decreased', sbj='terazosin', obj='epinephrine')
#      0.996 KBTriple(rel='decreased', sbj='epinephrine', obj='terazosin')
#      0.996 KBTriple(rel='decreased', sbj='blood_pressure', obj='urapidil')
#      0.996 KBTriple(rel='decreased', sbj='urapidil', obj='blood_pressure')
#      0.994 KBTriple(rel='decreased', sbj='hydralazine', obj='cardiac_output')
#      0.994 KBTriple(rel='decreased', sbj='cardiac_output', obj='hydralazine')
#      0.994 KBTriple(rel='decreased', sbj='diltiazem', obj='oxygen_consumption')
#      0.994 KBTriple(rel='decreased', sbj='oxygen_consumption', obj='diltiazem')
#      0.991 KBTriple(rel='decreased', sbj='exercise_tolerance', obj='gallopamil')
#      0.991 KBTriple(rel='decreased', sbj='gallopamil', obj='exercise_tolerance')
#      0.989 KBTriple(rel='decreased', sbj='weight', obj='pyrantel')
#      0.989 KBTriple(rel='decreased', sbj='pyrantel', obj='weight')
#      0.986 KBTriple(rel='decreased', sbj='central_venous_pressure', obj='sodium')
#      0.986 KBTriple(rel='decreased', sbj='sodium', obj='central_venous_pressure')
#      0.982 KBTriple(rel='decreased', sbj='metformin', obj='fasting')
#      0.982 KBTriple(rel='decreased', sbj='fasting', obj='metformin')
#      0.980 KBTriple(rel='decreased', sbj='vital_capacity', obj='lidocaine')
#      0.980 KBTriple(rel='decreased', sbj='lidocaine', obj='vital_capacity')
#      0.980 KBTriple(rel='decreased', sbj='lipids', obj='fenofibrate')
#      0.980 KBTriple(rel='decreased', sbj='fenofibrate', obj='lipids')
#      0.977 KBTriple(rel='decreased', sbj='weight', obj='roxithromycin')
#      0.977 KBTriple(rel='decreased', sbj='roxithromycin', obj='weight')
#      0.975 KBTriple(rel='decreased', sbj='nasal', obj='urine_flow')
#      0.975 KBTriple(rel='decreased', sbj='urine_flow', obj='nasal')
#      0.975 KBTriple(rel='decreased', sbj='propranolol', obj='venous_pressure')
#      0.975 KBTriple(rel='decreased', sbj='venous_pressure', obj='propranolol')
#      0.974 KBTriple(rel='decreased', sbj='magnesium', obj='fasting')
#      0.974 KBTriple(rel='decreased', sbj='fasting', obj='magnesium')
#      0.972 KBTriple(rel='decreased', sbj='aluminium', obj='leukaemia')
#      0.972 KBTriple(rel='decreased', sbj='leukaemia', obj='aluminium')
#      0.971 KBTriple(rel='decreased', sbj='mean_arterial_pressure', obj='propranolol')
#      0.971 KBTriple(rel='decreased', sbj='propranolol', obj='mean_arterial_pressure')
#      0.963 KBTriple(rel='decreased', sbj='renin', obj='sulindac')
#      0.963 KBTriple(rel='decreased', sbj='sulindac', obj='renin')
#      0.960 KBTriple(rel='decreased', sbj='concomitant', obj='pco2')
#      0.960 KBTriple(rel='decreased', sbj='pco2', obj='concomitant')
#      0.959 KBTriple(rel='decreased', sbj='ejection_fraction', obj='cocaine')
#      0.959 KBTriple(rel='decreased', sbj='cocaine', obj='ejection_fraction')
#      0.957 KBTriple(rel='decreased', sbj='pindolol', obj='blood_pressure')
#      0.957 KBTriple(rel='decreased', sbj='blood_pressure', obj='pindolol')
#      0.951 KBTriple(rel='decreased', sbj='blood_pressure', obj='lacidipine')
#      0.951 KBTriple(rel='decreased', sbj='lacidipine', obj='blood_pressure')
#      0.951 KBTriple(rel='decreased', sbj='blood_pressure', obj='bepridil')
#      0.951 KBTriple(rel='decreased', sbj='bepridil', obj='blood_pressure')
#      0.951 KBTriple(rel='decreased', sbj='metabolic_alkalosis', obj='pac')
#      0.951 KBTriple(rel='decreased', sbj='pac', obj='metabolic_alkalosis')
#      0.950 KBTriple(rel='decreased', sbj='cimetidine', obj='forced_expiratory_volume')
#      0.950 KBTriple(rel='decreased', sbj='forced_expiratory_volume', obj='cimetidine')
#      0.949 KBTriple(rel='decreased', sbj='carbon_dioxide', obj='methylprednisolone')
#      0.949 KBTriple(rel='decreased', sbj='methylprednisolone', obj='carbon_dioxide')
#      0.949 KBTriple(rel='decreased', sbj='magnesium', obj='vitamin_a')
#      0.949 KBTriple(rel='decreased', sbj='vitamin_a', obj='magnesium')
#      0.947 KBTriple(rel='decreased', sbj='hydralazine', obj='oxygen_consumption')
#      0.947 KBTriple(rel='decreased', sbj='oxygen_consumption', obj='hydralazine')
#      0.940 KBTriple(rel='decreased', sbj='pulmonary_arterial_pressure', obj='molsidomine')
#      0.940 KBTriple(rel='decreased', sbj='molsidomine', obj='pulmonary_arterial_pressure')
#      0.940 KBTriple(rel='decreased', sbj='betaxolol', obj='intraocular_pressure')
#      0.940 KBTriple(rel='decreased', sbj='intraocular_pressure', obj='betaxolol')
#      0.927 KBTriple(rel='decreased', sbj='fall', obj='dapsone')
#      0.927 KBTriple(rel='decreased', sbj='dapsone', obj='fall')
#      0.926 KBTriple(rel='decreased', sbj='bisoprolol', obj='infusion')
#      0.926 KBTriple(rel='decreased', sbj='infusion', obj='bisoprolol')
#      0.922 KBTriple(rel='decreased', sbj='progesterone', obj='cocaine')
#      0.922 KBTriple(rel='decreased', sbj='cocaine', obj='progesterone')
#      0.921 KBTriple(rel='decreased', sbj='cimetidine', obj='pco2')
#      0.921 KBTriple(rel='decreased', sbj='pco2', obj='cimetidine')
#      0.916 KBTriple(rel='decreased', sbj='somatostatin', obj='thyroxine')
#      0.916 KBTriple(rel='decreased', sbj='thyroxine', obj='somatostatin')
#      0.916 KBTriple(rel='decreased', sbj='blood_ethanol', obj='cocaine')
#      0.916 KBTriple(rel='decreased', sbj='cocaine', obj='blood_ethanol')
#      0.899 KBTriple(rel='decreased', sbj='cardiac_output', obj='sotalol')
#      0.899 KBTriple(rel='decreased', sbj='sotalol', obj='cardiac_output')
#      0.896 KBTriple(rel='decreased', sbj='acyclovir', obj='weight')
#      0.896 KBTriple(rel='decreased', sbj='weight', obj='acyclovir')
#      0.894 KBTriple(rel='decreased', sbj='cimetidine', obj='forced_expiratory_flow')
#      0.894 KBTriple(rel='decreased', sbj='forced_expiratory_flow', obj='cimetidine')
#      0.884 KBTriple(rel='decreased', sbj='right_atrial_pressure', obj='pindolol')
#      0.884 KBTriple(rel='decreased', sbj='pindolol', obj='right_atrial_pressure')
#      0.879 KBTriple(rel='decreased', sbj='forced_expiratory_flow', obj='sodium')
#      0.879 KBTriple(rel='decreased', sbj='sodium', obj='forced_expiratory_flow')
#      0.869 KBTriple(rel='decreased', sbj='cortisol', obj='flumazenil')
#      0.869 KBTriple(rel='decreased', sbj='flumazenil', obj='cortisol')
#      0.862 KBTriple(rel='decreased', sbj='epinephrine', obj='diazepam')
#      0.862 KBTriple(rel='decreased', sbj='diazepam', obj='epinephrine')
#
# Highest probability examples for relation delayed:
#      0.154 KBTriple(rel='delayed', sbj='gamma-globulin', obj='cholangitis')
#      0.154 KBTriple(rel='delayed', sbj='cholangitis', obj='gamma-globulin')
#      0.133 KBTriple(rel='delayed', sbj='solar_urticaria', obj='cimetidine')
#      0.133 KBTriple(rel='delayed', sbj='cimetidine', obj='solar_urticaria')
#      0.107 KBTriple(rel='delayed', sbj='anaplastic_astrocytoma', obj='methylprednisolone')
#      0.107 KBTriple(rel='delayed', sbj='methylprednisolone', obj='astrocytoma')
#      0.107 KBTriple(rel='delayed', sbj='methylprednisolone', obj='anaplastic_astrocytoma')
#      0.107 KBTriple(rel='delayed', sbj='astrocytoma', obj='methylprednisolone')
#      0.091 KBTriple(rel='delayed', sbj='ejection_fraction', obj='gallopamil')
#      0.091 KBTriple(rel='delayed', sbj='gallopamil', obj='ejection_fraction')
#      0.087 KBTriple(rel='delayed', sbj='azatadine', obj='rhinitis')
#      0.087 KBTriple(rel='delayed', sbj='rhinitis', obj='azatadine')
#      0.083 KBTriple(rel='delayed', sbj='anoxia', obj='nadolol')
#      0.083 KBTriple(rel='delayed', sbj='nadolol', obj='anoxia')
#      0.080 KBTriple(rel='delayed', sbj='intranasal', obj='cachexia')
#      0.080 KBTriple(rel='delayed', sbj='cachexia', obj='intranasal')
#      0.070 KBTriple(rel='delayed', sbj='gamma-globulin', obj='skin_reaction')
#      0.070 KBTriple(rel='delayed', sbj='skin_reaction', obj='gamma-globulin')
#      0.070 KBTriple(rel='delayed', sbj='gastric_fistula', obj='diazepam')
#      0.070 KBTriple(rel='delayed', sbj='diazepam', obj='gastric_fistula')
#      0.067 KBTriple(rel='delayed', sbj='abdominal_abscess', obj='imipenem')
#      0.067 KBTriple(rel='delayed', sbj='imipenem', obj='abdominal_abscess')
#      0.064 KBTriple(rel='delayed', sbj='pain', obj='proparacaine')
#      0.064 KBTriple(rel='delayed', sbj='proparacaine', obj='pain')
#      0.058 KBTriple(rel='delayed', sbj='fungal_infection', obj='gentamicin')
#      0.058 KBTriple(rel='delayed', sbj='gentamicin', obj='fungal_infection')
#      0.057 KBTriple(rel='delayed', sbj='ejection_fraction', obj='molsidomine')
#      0.057 KBTriple(rel='delayed', sbj='molsidomine', obj='ejection_fraction')
#      0.052 KBTriple(rel='delayed', sbj='propranolol', obj='choanal_atresia')
#      0.052 KBTriple(rel='delayed', sbj='choanal_atresia', obj='propranolol')
#      0.052 KBTriple(rel='delayed', sbj='atrial_fibrillation', obj='celiprolol')
#      0.052 KBTriple(rel='delayed', sbj='celiprolol', obj='atrial_fibrillation')
#      0.050 KBTriple(rel='delayed', sbj='methylprednisolone', obj='hypocapnia')
#      0.050 KBTriple(rel='delayed', sbj='hypocapnia', obj='methylprednisolone')
#      0.048 KBTriple(rel='delayed', sbj='nasal', obj='stevens-johnson_syndrome')
#      0.048 KBTriple(rel='delayed', sbj='stevens-johnson_syndrome', obj='nasal')
#      0.042 KBTriple(rel='delayed', sbj='carbon_dioxide', obj='methylprednisolone')
#      0.042 KBTriple(rel='delayed', sbj='methylprednisolone', obj='carbon_dioxide')
#      0.041 KBTriple(rel='delayed', sbj='tanning', obj='sodium')
# ...
#      0.093 KBTriple(rel='reduced', sbj='hypertension', obj='rubidium')
#      0.093 KBTriple(rel='reduced', sbj='rubidium', obj='hypertension')
#      0.091 KBTriple(rel='reduced', sbj='phenylbutazone', obj='faeces')
#      0.091 KBTriple(rel='reduced', sbj='faeces', obj='phenylbutazone')
#      0.091 KBTriple(rel='reduced', sbj='magnesium', obj='renal_mass')
#      0.091 KBTriple(rel='reduced', sbj='renal_mass', obj='magnesium')
#      0.090 KBTriple(rel='reduced', sbj='nasal', obj='urine_flow')
#      0.090 KBTriple(rel='reduced', sbj='urine_flow', obj='nasal')
#
# Highest probability examples for relation ruptured:
#      0.861 KBTriple(rel='ruptured', sbj='strontium', obj='osteolysis')
#      0.861 KBTriple(rel='ruptured', sbj='osteolysis', obj='strontium')
#      0.238 KBTriple(rel='ruptured', sbj='renal_hypertrophy', obj='polypeptide')
#      0.238 KBTriple(rel='ruptured', sbj='polypeptide', obj='renal_hypertrophy')
#      0.104 KBTriple(rel='ruptured', sbj='econazole', obj='erythema')
#      0.104 KBTriple(rel='ruptured', sbj='erythema', obj='econazole')
#      0.069 KBTriple(rel='ruptured', sbj='immunglobulin', obj='transplant')
#      0.069 KBTriple(rel='ruptured', sbj='transplant', obj='immunglobulin')
#      0.058 KBTriple(rel='ruptured', sbj='coma', obj='methylprednisolone')
#      0.058 KBTriple(rel='ruptured', sbj='methylprednisolone', obj='coma')
#      0.049 KBTriple(rel='ruptured', sbj='acyclovir', obj='seizure')
#      0.049 KBTriple(rel='ruptured', sbj='seizure', obj='acyclovir')
#      0.045 KBTriple(rel='ruptured', sbj='enzyme_activity', obj='pindolol')
#      0.045 KBTriple(rel='ruptured', sbj='pindolol', obj='enzyme_activity')
#      0.043 KBTriple(rel='ruptured', sbj='concomitant', obj='congestive_cardiomyopathy')
#      0.043 KBTriple(rel='ruptured', sbj='congestive_cardiomyopathy', obj='concomitant')
#      0.040 KBTriple(rel='ruptured', sbj='hyperplasia', obj='budesonide')
#      0.040 KBTriple(rel='ruptured', sbj='budesonide', obj='hyperplasia')
#      0.040 KBTriple(rel='ruptured', sbj='ammonium', obj='proteinuria')
#      0.040 KBTriple(rel='ruptured', sbj='proteinuria', obj='ammonium')
#      0.038 KBTriple(rel='ruptured', sbj='concomitant', obj='carotid_artery_occlusion')
#      0.038 KBTriple(rel='ruptured', sbj='carotid_artery_occlusion', obj='concomitant')
#      0.038 KBTriple(rel='ruptured', sbj='concomitant', obj='hyperbilirubinaemia')
#      0.038 KBTriple(rel='ruptured', sbj='hyperbilirubinaemia', obj='concomitant')
#      0.038 KBTriple(rel='ruptured', sbj='metastasis', obj='intranasal')
#      0.038 KBTriple(rel='ruptured', sbj='intranasal', obj='metastasis')
#      0.037 KBTriple(rel='ruptured', sbj='ophthalmoplegia', obj='edrophonium')
#      0.037 KBTriple(rel='ruptured', sbj='edrophonium', obj='ophthalmoplegia')
#      0.035 KBTriple(rel='ruptured', sbj='pneumonectomy', obj='minocycline')
#      0.035 KBTriple(rel='ruptured', sbj='minocycline', obj='pneumonectomy')
#      0.032 KBTriple(rel='ruptured', sbj='acute_respiratory_failure', obj='sulindac')
#      0.032 KBTriple(rel='ruptured', sbj='sulindac', obj='acute_respiratory_failure')
#      0.031 KBTriple(rel='ruptured', sbj='concomitant', obj='hyperaemia')
#      0.031 KBTriple(rel='ruptured', sbj='hyperaemia', obj='concomitant')
#      0.030 KBTriple(rel='ruptured', sbj='econazole', obj='haemoglobin')
#      0.030 KBTriple(rel='ruptured', sbj='haemoglobin', obj='econazole')
#      0.029 KBTriple(rel='ruptured', sbj='infusion', obj='sulindac')
#      0.029 KBTriple(rel='ruptured', sbj='sulindac', obj='infusion')
#      0.027 KBTriple(rel='ruptured', sbj='thallium', obj='thyroiditis')
#      0.027 KBTriple(rel='ruptured', sbj='thyroiditis', obj='thallium')
#      0.026 KBTriple(rel='ruptured', sbj='enzyme_activity', obj='diclofenac')
#      0.026 KBTriple(rel='ruptured', sbj='diclofenac', obj='enzyme_activity')
#      0.025 KBTriple(rel='ruptured', sbj='tryptase', obj='concomitant')
#      0.025 KBTriple(rel='ruptured', sbj='concomitant', obj='tryptase')
#      0.024 KBTriple(rel='ruptured', sbj='hypertensive_crisis', obj='pindolol')
#      0.024 KBTriple(rel='ruptured', sbj='pindolol', obj='hypertensive_crisis')
#      0.024 KBTriple(rel='ruptured', sbj='urapidil', obj='weight')
#      0.024 KBTriple(rel='ruptured', sbj='weight', obj='urapidil')
#      0.021 KBTriple(rel='ruptured', sbj='hydralazine', obj='hypertensive_encephalopathy')
#      0.021 KBTriple(rel='ruptured', sbj='hypertensive_encephalopathy', obj='hydralazine')
#      0.021 KBTriple(rel='ruptured', sbj='molsidomine', obj='asthma')
#      0.021 KBTriple(rel='ruptured', sbj='cardiac_asthma', obj='molsidomine')
#      0.021 KBTriple(rel='ruptured', sbj='asthma', obj='molsidomine')
#      0.021 KBTriple(rel='ruptured', sbj='molsidomine', obj='cardiac_asthma')
#      0.021 KBTriple(rel='ruptured', sbj='concomitant', obj='oculogyric_crisis')
#      0.021 KBTriple(rel='ruptured', sbj='oculogyric_crisis', obj='concomitant')
#      0.021 KBTriple(rel='ruptured', sbj='cell_death', obj='propranolol')
#      0.021 KBTriple(rel='ruptured', sbj='propranolol', obj='cell_death')
#      0.020 KBTriple(rel='ruptured', sbj='concomitant', obj='barotrauma')
#      0.020 KBTriple(rel='ruptured', sbj='barotrauma', obj='concomitant')
#      0.020 KBTriple(rel='ruptured', sbj='magnesium', obj='metrorrhagia')
#      0.020 KBTriple(rel='ruptured', sbj='metrorrhagia', obj='magnesium')
#      0.019 KBTriple(rel='ruptured', sbj='graft_infection', obj='concomitant')
#      0.019 KBTriple(rel='ruptured', sbj='concomitant', obj='graft_infection')
#      0.019 KBTriple(rel='ruptured', sbj='ammonium', obj='salmonellosis')
#      0.019 KBTriple(rel='ruptured', sbj='salmonellosis', obj='ammonium')
#      0.018 KBTriple(rel='ruptured', sbj='immunosuppression', obj='tac')
#      0.018 KBTriple(rel='ruptured', sbj='tac', obj='immunosuppression')
#      0.018 KBTriple(rel='ruptured', sbj='hypoglycaemia', obj='cocaine')
#      0.018 KBTriple(rel='ruptured', sbj='cocaine', obj='hypoglycaemia')
#      0.018 KBTriple(rel='ruptured', sbj='gadolinium', obj='arteritis')
#      0.018 KBTriple(rel='ruptured', sbj='arteritis', obj='gadolinium')
#      0.017 KBTriple(rel='ruptured', sbj='fall', obj='strontium')
#      0.017 KBTriple(rel='ruptured', sbj='strontium', obj='fall')
#      0.017 KBTriple(rel='ruptured', sbj='roxithromycin', obj='transaminases')
#      0.017 KBTriple(rel='ruptured', sbj='transaminases', obj='roxithromycin')
#      0.017 KBTriple(rel='ruptured', sbj='fluid_imbalance', obj='ibuprofen')
#      0.017 KBTriple(rel='ruptured', sbj='ibuprofen', obj='fluid_imbalance')
#      0.017 KBTriple(rel='ruptured', sbj='concomitant', obj='hyperreflexia')
#      0.017 KBTriple(rel='ruptured', sbj='hyperreflexia', obj='concomitant')
#      0.017 KBTriple(rel='ruptured', sbj='perforation', obj='lidocaine')
#      0.017 KBTriple(rel='ruptured', sbj='lidocaine', obj='perforation')
#      0.017 KBTriple(rel='ruptured', sbj='sulindac', obj='colectomy')
#      0.017 KBTriple(rel='ruptured', sbj='colectomy', obj='sulindac')
#      0.017 KBTriple(rel='ruptured', sbj='demethylchlortetracycline', obj='nephrogenic_diabetes_insipidus')
#      0.017 KBTriple(rel='ruptured', sbj='nephrogenic_diabetes_insipidus', obj='demethylchlortetracycline')
#      0.016 KBTriple(rel='ruptured', sbj='adrenal_insufficiency', obj='somatostatin')
#      0.016 KBTriple(rel='ruptured', sbj='somatostatin', obj='adrenal_insufficiency')
#      0.016 KBTriple(rel='ruptured', sbj='diazepam', obj='central_venous_catheterisation')
#      0.016 KBTriple(rel='ruptured', sbj='central_venous_catheterisation', obj='diazepam')
#      0.016 KBTriple(rel='ruptured', sbj='polypeptide', obj='ganglioneuroma')
#      0.016 KBTriple(rel='ruptured', sbj='ganglioneuroma', obj='polypeptide')
#      0.016 KBTriple(rel='ruptured', sbj='corynebacterium', obj='haemodialysis')
#      0.016 KBTriple(rel='ruptured', sbj='haemodialysis', obj='corynebacterium')
#      0.016 KBTriple(rel='ruptured', sbj='octreotide', obj='seizure')
#      0.016 KBTriple(rel='ruptured', sbj='seizure', obj='octreotide')
#      0.016 KBTriple(rel='ruptured', sbj='euthyroid_sick_syndrome', obj='concomitant')
#      0.016 KBTriple(rel='ruptured', sbj='concomitant', obj='euthyroid_sick_syndrome')
#      0.016 KBTriple(rel='ruptured', sbj='halcinonide', obj='dermatitis')
#      0.016 KBTriple(rel='ruptured', sbj='dermatitis', obj='halcinonide')
#
# Highest probability examples for relation shortened:
#
#      0.980 KBTriple(rel='shortened', sbj='cystic_fibrosis', obj='roxithromycin')
#      0.980 KBTriple(rel='shortened', sbj='fibrosis', obj='roxithromycin')
#      0.980 KBTriple(rel='shortened', sbj='roxithromycin', obj='fibrosis')
#      0.980 KBTriple(rel='shortened', sbj='roxithromycin', obj='cystic_fibrosis')
#      0.935 KBTriple(rel='shortened', sbj='prothrombin_time', obj='magnesium')
#      0.935 KBTriple(rel='shortened', sbj='magnesium', obj='prothrombin_time')
#      0.931 KBTriple(rel='shortened', sbj='osteochondrosis', obj='propranolol')
#      0.931 KBTriple(rel='shortened', sbj='propranolol', obj='osteochondrosis')
#      0.919 KBTriple(rel='shortened', sbj='strontium', obj='salmonellosis')
#      0.919 KBTriple(rel='shortened', sbj='salmonellosis', obj='strontium')
#      0.866 KBTriple(rel='shortened', sbj='hydralazine', obj='body_surface_area')
#      0.866 KBTriple(rel='shortened', sbj='body_surface_area', obj='hydralazine')
#      0.813 KBTriple(rel='shortened', sbj='prazepam', obj='mood')
#      0.813 KBTriple(rel='shortened', sbj='mood', obj='prazepam')
#      0.767 KBTriple(rel='shortened', sbj='propranolol', obj='thrombin_time')
#      0.767 KBTriple(rel='shortened', sbj='thrombin_time', obj='propranolol')
#      0.754 KBTriple(rel='shortened', sbj='strontium', obj='food_poisoning')
#      0.754 KBTriple(rel='shortened', sbj='food_poisoning', obj='strontium')
#      0.753 KBTriple(rel='shortened', sbj='poisoning', obj='strontium')
#      0.753 KBTriple(rel='shortened', sbj='strontium', obj='poisoning')
#      0.715 KBTriple(rel='shortened', sbj='obsessive-compulsive_disorder', obj='intranasal')
#      0.715 KBTriple(rel='shortened', sbj='intranasal', obj='obsessive-compulsive_disorder')
#      0.709 KBTriple(rel='shortened', sbj='azatadine', obj='rhinitis')
#      0.709 KBTriple(rel='shortened', sbj='rhinitis', obj='azatadine')
#      0.561 KBTriple(rel='shortened', sbj='tension', obj='prazepam')
#      0.561 KBTriple(rel='shortened', sbj='prazepam', obj='tension')
#      0.480 KBTriple(rel='shortened', sbj='ammonium', obj='prothrombin_time')
#      0.480 KBTriple(rel='shortened', sbj='prothrombin_time', obj='ammonium')
#      0.452 KBTriple(rel='shortened', sbj='gamma-globulin', obj='flow_cytometry')
#      0.452 KBTriple(rel='shortened', sbj='flow_cytometry', obj='gamma-globulin')
#      0.437 KBTriple(rel='shortened', sbj='cocaine', obj='heart_rate_variability')
#      0.437 KBTriple(rel='shortened', sbj='heart_rate_variability', obj='cocaine')
#      0.429 KBTriple(rel='shortened', sbj='paradox', obj='acidosis')
#      0.429 KBTriple(rel='shortened', sbj='acidosis', obj='paradox')
#      0.414 KBTriple(rel='shortened', sbj='leprosy', obj='tac')
#      0.414 KBTriple(rel='shortened', sbj='tac', obj='leprosy')
#      0.413 KBTriple(rel='shortened', sbj='helium', obj='fasting')
#      0.413 KBTriple(rel='shortened', sbj='fasting', obj='helium')
#      0.400 KBTriple(rel='shortened', sbj='sodium', obj='carbohydrate_intolerance')
#      0.400 KBTriple(rel='shortened', sbj='carbohydrate_intolerance', obj='sodium')
#      0.397 KBTriple(rel='shortened', sbj='weight', obj='roxithromycin')
#      0.397 KBTriple(rel='shortened', sbj='roxithromycin', obj='weight')
#      0.388 KBTriple(rel='shortened', sbj='gastric_fistula', obj='diazepam')
#      0.388 KBTriple(rel='shortened', sbj='diazepam', obj='gastric_fistula')
#      0.335 KBTriple(rel='shortened', sbj='ciclosporin', obj='dialysis')
#      0.335 KBTriple(rel='shortened', sbj='dialysis', obj='ciclosporin')
#      0.324 KBTriple(rel='shortened', sbj='intranasal', obj='cachexia')
#      0.324 KBTriple(rel='shortened', sbj='cachexia', obj='intranasal')
#      0.323 KBTriple(rel='shortened', sbj='teicoplanin', obj='intensive_care')
#      0.323 KBTriple(rel='shortened', sbj='intensive_care', obj='teicoplanin')
#      0.316 KBTriple(rel='shortened', sbj='dehydroepiandrosterone', obj='cimetidine')
#      0.316 KBTriple(rel='shortened', sbj='cimetidine', obj='dehydroepiandrosterone')
#      0.310 KBTriple(rel='shortened', sbj='abdominal_abscess', obj='imipenem')
#      0.310 KBTriple(rel='shortened', sbj='imipenem', obj='abdominal_abscess')
#      0.300 KBTriple(rel='shortened', sbj='bepridil', obj='depression')
#      0.300 KBTriple(rel='shortened', sbj='depression', obj='bepridil')
#      0.295 KBTriple(rel='shortened', sbj='human_chorionic_gonadotropin', obj='beta-carotene')
#      0.295 KBTriple(rel='shortened', sbj='beta-carotene', obj='human_chorionic_gonadotropin')
#      0.268 KBTriple(rel='shortened', sbj='gamma-globulin', obj='cholangitis')
#      0.268 KBTriple(rel='shortened', sbj='cholangitis', obj='gamma-globulin')
#      0.261 KBTriple(rel='shortened', sbj='induration', obj='concomitant')
#      0.261 KBTriple(rel='shortened', sbj='concomitant', obj='induration')
#      0.243 KBTriple(rel='shortened', sbj='propanolol', obj='cardiac_output')
#      0.243 KBTriple(rel='shortened', sbj='cardiac_output', obj='propanolol')
#      0.241 KBTriple(rel='shortened', sbj='fungal_infection', obj='gentamicin')
#      0.241 KBTriple(rel='shortened', sbj='gentamicin', obj='fungal_infection')
#      0.238 KBTriple(rel='shortened', sbj='elective_surgery', obj='lidocaine')
#      0.238 KBTriple(rel='shortened', sbj='lidocaine', obj='elective_surgery')
#      0.237 KBTriple(rel='shortened', sbj='tanning', obj='sodium')
#      0.237 KBTriple(rel='shortened', sbj='sodium', obj='tanning')
#      0.235 KBTriple(rel='shortened', sbj='idoxuridine', obj='infection')
#      0.235 KBTriple(rel='shortened', sbj='infection', obj='idoxuridine')
#      0.225 KBTriple(rel='shortened', sbj='nasal', obj='holoprosencephaly')
#      0.225 KBTriple(rel='shortened', sbj='holoprosencephaly', obj='nasal')
#      0.225 KBTriple(rel='shortened', sbj='electric_shock', obj='flumazenil')
#      0.225 KBTriple(rel='shortened', sbj='flumazenil', obj='electric_shock')
#      0.222 KBTriple(rel='shortened', sbj='flumazenil', obj='pain_management')
#      0.222 KBTriple(rel='shortened', sbj='pain_management', obj='flumazenil')
#      0.218 KBTriple(rel='shortened', sbj='ibuprofen', obj='hepatic_enzyme')
#      0.218 KBTriple(rel='shortened', sbj='hepatic_enzyme', obj='ibuprofen')
#      0.212 KBTriple(rel='shortened', sbj='eosinophilia', obj='mebendazole')
#      0.212 KBTriple(rel='shortened', sbj='mebendazole', obj='eosinophilia')
#      0.208 KBTriple(rel='shortened', sbj='cardiopulmonary_bypass', obj='fac')
#      0.208 KBTriple(rel='shortened', sbj='fac', obj='cardiopulmonary_bypass')
#      0.201 KBTriple(rel='shortened', sbj='carbon_dioxide', obj='methylprednisolone')
#      0.201 KBTriple(rel='shortened', sbj='methylprednisolone', obj='carbon_dioxide')
#      0.200 KBTriple(rel='shortened', sbj='phagocytosis', obj='tripeptide')
#      0.200 KBTriple(rel='shortened', sbj='tripeptide', obj='phagocytosis')
#      0.190 KBTriple(rel='shortened', sbj='norfloxacin', obj='nosocomial_infection')
#      0.190 KBTriple(rel='shortened', sbj='nosocomial_infection', obj='norfloxacin')
#      0.182 KBTriple(rel='shortened', sbj='cancer_pain', obj='diflunisal')
#      0.182 KBTriple(rel='shortened', sbj='diflunisal', obj='cancer_pain')
#      0.175 KBTriple(rel='shortened', sbj='erythema_annulare', obj='dapsone')
#      0.175 KBTriple(rel='shortened', sbj='dapsone', obj='erythema_annulare')
#      0.175 KBTriple(rel='shortened', sbj='hypertension', obj='neostigmine')
#      0.175 KBTriple(rel='shortened', sbj='neostigmine', obj='hypertension')
#      0.169 KBTriple(rel='shortened', sbj='ovarian_hyperstimulation_syndrome', obj='menopausal')
#      0.169 KBTriple(rel='shortened', sbj='menopausal', obj='ovarian_hyperstimulation_syndrome')
#      0.157 KBTriple(rel='shortened', sbj='protein_deficiency', obj='diazepam')
#      0.157 KBTriple(rel='shortened', sbj='diazepam', obj='protein_deficiency')

# %%
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    '', 'examples', 'examples', 'examples'))
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    'relation', 'eval set', 'suggestions', 'intersection'))
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    '--------', '--------', '-------', '-------'))

for rel, instances in eval_relations.items():
    print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
        rel, str(len(instances)), 
        str(int(len(suggestions[rel])/2)), 
        str(len(instances.intersection(suggestions[rel])))))
# Out:
#                        examples        examples        examples
# relation               eval set     suggestions    intersection
# --------               --------         -------         -------
# accelerated                   1               0               0
# acquired                      9              50               0
# aggravated                  114              50               0
# altered                      29              50               0
# caused                    11426              50              15
# changed                      25              50               0
# decreased                   962              50               4
# delayed                      24              50               0
# discoloured                  40              50               1
# impaired                     16              50               0
# increased                  1031              50               7
# infected                      9              50               0
# prolonged                    30              50               1
# reduced                      18              50               0
# ruptured                      5              50               0
# shortened                    30              50               0

# %%
new_instances = get_new_relation_instances(
    dataset,
    featurizers=[simple_bag_of_words_featurizer],
    k=200
)

eval_relations = defaultdict(set)

for kb_triple in kb_eval:
    eval_relations[kb_triple.rel].add((kb_triple.rel, kb_triple.sbj, kb_triple.obj))
    
suggestions = defaultdict(set)

for rel, rel_inst in new_instances.items():
    for instance in rel_inst:
        suggestions[rel].add((instance[1].rel, instance[1].sbj, instance[1].obj))
# Out:
# WARNING: could not train model for improved
# train_x_rel = None
# train_y_rel = None
# Highest probability examples for relation acquired:
#
#      0.191 KBTriple(rel='acquired', sbj='corynebacterium', obj='faeces')
#      0.191 KBTriple(rel='acquired', sbj='faeces', obj='corynebacterium')
#      0.163 KBTriple(rel='acquired', sbj='tac', obj='toxoplasmosis')
#      0.163 KBTriple(rel='acquired', sbj='toxoplasmosis', obj='tac')
#      0.092 KBTriple(rel='acquired', sbj='microangiopathy', obj='somatostatin')
#      0.092 KBTriple(rel='acquired', sbj='somatostatin', obj='microangiopathy')
#      0.070 KBTriple(rel='acquired', sbj='tac', obj='progesterone')
#      0.070 KBTriple(rel='acquired', sbj='progesterone', obj='tac')
#      0.062 KBTriple(rel='acquired', sbj='stress', obj='ondansetron')
#      0.062 KBTriple(rel='acquired', sbj='ondansetron', obj='stress')
#      0.058 KBTriple(rel='acquired', sbj='econazole', obj='haemoglobin')
#      0.058 KBTriple(rel='acquired', sbj='haemoglobin', obj='econazole')
#      0.057 KBTriple(rel='acquired', sbj='ammonium', obj='nephrocalcinosis')
#      0.057 KBTriple(rel='acquired', sbj='nephrocalcinosis', obj='ammonium')
#      0.042 KBTriple(rel='acquired', sbj='diabetic_neuropathy', obj='cisapride')
#      0.042 KBTriple(rel='acquired', sbj='cisapride', obj='diabetic_neuropathy')
#      0.031 KBTriple(rel='acquired', sbj='pancreatectomy', obj='octreotide')
#      0.031 KBTriple(rel='acquired', sbj='octreotide', obj='pancreatectomy')
#      0.031 KBTriple(rel='acquired', sbj='tryptase', obj='polypeptide')
#      0.031 KBTriple(rel='acquired', sbj='polypeptide', obj='tryptase')
#      0.026 KBTriple(rel='acquired', sbj='ammonium', obj='salmonellosis')
#      0.026 KBTriple(rel='acquired', sbj='salmonellosis', obj='ammonium')
#      0.026 KBTriple(rel='acquired', sbj='head_injury', obj='cocaine')
#      0.026 KBTriple(rel='acquired', sbj='cocaine', obj='head_injury')
#      0.024 KBTriple(rel='acquired', sbj='laparotomy', obj='pac')
#      0.024 KBTriple(rel='acquired', sbj='pac', obj='laparotomy')
#      0.023 KBTriple(rel='acquired', sbj='droperidol', obj='ataxia')
#      0.023 KBTriple(rel='acquired', sbj='ataxia', obj='droperidol')
#      0.022 KBTriple(rel='acquired', sbj='clostridium', obj='systemic_lupus_erythematosus')
#      0.022 KBTriple(rel='acquired', sbj='systemic_lupus_erythematosus', obj='clostridium')
#      0.020 KBTriple(rel='acquired', sbj='corium', obj='panniculitis')
#      0.020 KBTriple(rel='acquired', sbj='panniculitis', obj='corium')
#      0.019 KBTriple(rel='acquired', sbj='dihydrotachysterol', obj='tetany')
#      0.019 KBTriple(rel='acquired', sbj='tetany', obj='dihydrotachysterol')
#      0.016 KBTriple(rel='acquired', sbj='polypeptide', obj='giardiasis')
#      0.016 KBTriple(rel='acquired', sbj='giardiasis', obj='polypeptide')
#      0.016 KBTriple(rel='acquired', sbj='diazepam', obj='prostatitis')
#      0.016 KBTriple(rel='acquired', sbj='prostatitis', obj='diazepam')
#      0.015 KBTriple(rel='acquired', sbj='propranolol', obj='gastric_lavage')
#      0.015 KBTriple(rel='acquired', sbj='gastric_lavage', obj='propranolol')
#      0.015 KBTriple(rel='acquired', sbj='concomitant', obj='lacrimation')
#      0.015 KBTriple(rel='acquired', sbj='lacrimation', obj='concomitant')
#      0.015 KBTriple(rel='acquired', sbj='ammonium', obj='dysentery')
#      0.015 KBTriple(rel='acquired', sbj='dysentery', obj='ammonium')
#      0.014 KBTriple(rel='acquired', sbj='ammonium', obj='proteinuria')
#      0.014 KBTriple(rel='acquired', sbj='proteinuria', obj='ammonium')
#      0.014 KBTriple(rel='acquired', sbj='anaplastic_astrocytoma', obj='methylprednisolone')
#      0.014 KBTriple(rel='acquired', sbj='methylprednisolone', obj='astrocytoma')
#      0.014 KBTriple(rel='acquired', sbj='methylprednisolone', obj='anaplastic_astrocytoma')
#      0.014 KBTriple(rel='acquired', sbj='astrocytoma', obj='methylprednisolone')
#      0.014 KBTriple(rel='acquired', sbj='hypertensive_crisis', obj='pindolol')
#      0.014 KBTriple(rel='acquired', sbj='pindolol', obj='hypertensive_crisis')
#      0.014 KBTriple(rel='acquired', sbj='norfloxacin', obj='pruritus')
#      0.014 KBTriple(rel='acquired', sbj='pruritus', obj='norfloxacin')
#      0.014 KBTriple(rel='acquired', sbj='adrenal_insufficiency', obj='somatostatin')
#      0.014 KBTriple(rel='acquired', sbj='somatostatin', obj='adrenal_insufficiency')
#      0.014 KBTriple(rel='acquired', sbj='progesterone', obj='nafarelin')
#      0.014 KBTriple(rel='acquired', sbj='nafarelin', obj='progesterone')
#      0.014 KBTriple(rel='acquired', sbj='concomitant', obj='ileus')
#      0.014 KBTriple(rel='acquired', sbj='ileus', obj='concomitant')
#      0.013 KBTriple(rel='acquired', sbj='buserelin', obj='investigation')
#      0.013 KBTriple(rel='acquired', sbj='investigation', obj='buserelin')
#      0.013 KBTriple(rel='acquired', sbj='phlebitis', obj='phenylbutazone')
#      0.013 KBTriple(rel='acquired', sbj='phenylbutazone', obj='phlebitis')
#      0.012 KBTriple(rel='acquired', sbj='concomitant', obj='aplastic_anaemia')
#      0.012 KBTriple(rel='acquired', sbj='aplastic_anaemia', obj='concomitant')
#      0.011 KBTriple(rel='acquired', sbj='halcinonide', obj='dermatitis')
#      0.011 KBTriple(rel='acquired', sbj='dermatitis', obj='halcinonide')
#      0.011 KBTriple(rel='acquired', sbj='natamycin', obj='eosinophilia')
#      0.011 KBTriple(rel='acquired', sbj='eosinophilia', obj='natamycin')
#      0.011 KBTriple(rel='acquired', sbj='supraventricular_tachyarrhythmia', obj='diltiazem')
#      0.011 KBTriple(rel='acquired', sbj='diltiazem', obj='supraventricular_tachyarrhythmia')
#      0.011 KBTriple(rel='acquired', sbj='fluorouracil', obj='aphakia')
#      0.011 KBTriple(rel='acquired', sbj='aphakia', obj='fluorouracil')
#      0.010 KBTriple(rel='acquired', sbj='condition', obj='radium')
#      0.010 KBTriple(rel='acquired', sbj='radium', obj='condition')
#      0.010 KBTriple(rel='acquired', sbj='dehydration', obj='pregnenolone')
#      0.010 KBTriple(rel='acquired', sbj='pregnenolone', obj='dehydration')
#      0.009 KBTriple(rel='acquired', sbj='brain_contusion', obj='magnesium')
#      0.009 KBTriple(rel='acquired', sbj='magnesium', obj='brain_contusion')
#      0.009 KBTriple(rel='acquired', sbj='quality_of_life', obj='betaxolol')
#      0.009 KBTriple(rel='acquired', sbj='betaxolol', obj='quality_of_life')
#      0.009 KBTriple(rel='acquired', sbj='cortisol', obj='buserelin')
#      0.009 KBTriple(rel='acquired', sbj='buserelin', obj='cortisol')
#      0.009 KBTriple(rel='acquired', sbj='acute_respiratory_failure', obj='sulindac')
#      0.009 KBTriple(rel='acquired', sbj='sulindac', obj='acute_respiratory_failure')
#      0.009 KBTriple(rel='acquired', sbj='graft_infection', obj='concomitant')
#      0.009 KBTriple(rel='acquired', sbj='concomitant', obj='graft_infection')
#      0.009 KBTriple(rel='acquired', sbj='adrenalectomy', obj='flunitrazepam')
#      0.009 KBTriple(rel='acquired', sbj='flunitrazepam', obj='adrenalectomy')
#      0.009 KBTriple(rel='acquired', sbj='stress_ulcer', obj='sodium')
#      0.009 KBTriple(rel='acquired', sbj='sodium', obj='stress_ulcer')
#      0.009 KBTriple(rel='acquired', sbj='mydriasis', obj='proparacaine')
#      0.009 KBTriple(rel='acquired', sbj='proparacaine', obj='mydriasis')
#      0.009 KBTriple(rel='acquired', sbj='nasal', obj='stevens-johnson_syndrome')
#      0.009 KBTriple(rel='acquired', sbj='stevens-johnson_syndrome', obj='nasal')
#      0.009 KBTriple(rel='acquired', sbj='lymphoma', obj='ovarium')
#      0.009 KBTriple(rel='acquired', sbj='ovarium', obj='lymphoma')
#      0.009 KBTriple(rel='acquired', sbj='hereditary_angioedema', obj='stanozolol')
#      0.009 KBTriple(rel='acquired', sbj='stanozolol', obj='hereditary_angioedema')
#      0.008 KBTriple(rel='acquired', sbj='acyclovir', obj='ataxia')
#      0.008 KBTriple(rel='acquired', sbj='ataxia', obj='acyclovir')
#      0.008 KBTriple(rel='acquired', sbj='cerebellar_ataxia', obj='acyclovir')
#      0.008 KBTriple(rel='acquired', sbj='acyclovir', obj='cerebellar_ataxia')
#      0.008 KBTriple(rel='acquired', sbj='nasal', obj='left_ventricular_dysfunction')
#      0.008 KBTriple(rel='acquired', sbj='left_ventricular_dysfunction', obj='nasal')
#      0.008 KBTriple(rel='acquired', sbj='ventricular_dysfunction', obj='nasal')
#      0.008 KBTriple(rel='acquired', sbj='nasal', obj='ventricular_dysfunction')
#      0.008 KBTriple(rel='acquired', sbj='concomitant', obj='periodontal_inflammation')
#      0.008 KBTriple(rel='acquired', sbj='periodontal_inflammation', obj='concomitant')
#      0.008 KBTriple(rel='acquired', sbj='acidosis', obj='celiprolol')
#      0.008 KBTriple(rel='acquired', sbj='celiprolol', obj='acidosis')
#      0.008 KBTriple(rel='acquired', sbj='cisapride', obj='discomfort')
#      0.008 KBTriple(rel='acquired', sbj='abdominal_discomfort', obj='cisapride')
#      0.008 KBTriple(rel='acquired', sbj='discomfort', obj='cisapride')
#      0.008 KBTriple(rel='acquired', sbj='cisapride', obj='abdominal_discomfort')
#      0.008 KBTriple(rel='acquired', sbj='ibuprofen', obj='dyspepsia')
#      0.008 KBTriple(rel='acquired', sbj='dyspepsia', obj='ibuprofen')
#      0.008 KBTriple(rel='acquired', sbj='overwork', obj='sodium')
#      0.008 KBTriple(rel='acquired', sbj='sodium', obj='overwork')
#      0.008 KBTriple(rel='acquired', sbj='gamma-globulin', obj='pneumoconiosis')
#      0.008 KBTriple(rel='acquired', sbj='pneumoconiosis', obj='gamma-globulin')
#      0.008 KBTriple(rel='acquired', sbj='cisapride', obj='spinal_cord_injury')
#      0.008 KBTriple(rel='acquired', sbj='spinal_cord_injury', obj='cisapride')
#      0.008 KBTriple(rel='acquired', sbj='paradox', obj='scar')
#      0.008 KBTriple(rel='acquired', sbj='scar', obj='paradox')
#      0.008 KBTriple(rel='acquired', sbj='thallium', obj='optic_neuritis')
#      0.008 KBTriple(rel='acquired', sbj='thallium', obj='neuritis')
#      0.008 KBTriple(rel='acquired', sbj='neuritis', obj='thallium')
#      0.008 KBTriple(rel='acquired', sbj='optic_neuritis', obj='thallium')
#      0.008 KBTriple(rel='acquired', sbj='methylprednisolone', obj='self-medication')
#      0.008 KBTriple(rel='acquired', sbj='self-medication', obj='methylprednisolone')
#      0.008 KBTriple(rel='acquired', sbj='urapidil', obj='weight')
#      0.008 KBTriple(rel='acquired', sbj='weight', obj='urapidil')
#      0.008 KBTriple(rel='acquired', sbj='flunitrazepam', obj='seizure')
#      0.008 KBTriple(rel='acquired', sbj='seizure', obj='flunitrazepam')
#      0.008 KBTriple(rel='acquired', sbj='effusion', obj='gentamicin')
#      0.008 KBTriple(rel='acquired', sbj='gentamicin', obj='effusion')
#      0.007 KBTriple(rel='acquired', sbj='hepatitis', obj='imunoglobulin')
#      0.007 KBTriple(rel='acquired', sbj='imunoglobulin', obj='hepatitis')
#      0.007 KBTriple(rel='acquired', sbj='enzyme_activity', obj='diclofenac')
#      0.007 KBTriple(rel='acquired', sbj='diclofenac', obj='enzyme_activity')
#      0.007 KBTriple(rel='acquired', sbj='corynebacterium', obj='impetigo')
#      0.007 KBTriple(rel='acquired', sbj='impetigo', obj='corynebacterium')
#      0.007 KBTriple(rel='acquired', sbj='aluminium', obj='dyspraxia')
#      0.007 KBTriple(rel='acquired', sbj='dyspraxia', obj='aluminium')
#      0.007 KBTriple(rel='acquired', sbj='diazepam', obj='central_cord_syndrome')
#      0.007 KBTriple(rel='acquired', sbj='central_cord_syndrome', obj='diazepam')
#      0.007 KBTriple(rel='acquired', sbj='sodium', obj='central_cord_syndrome')
#      0.007 KBTriple(rel='acquired', sbj='central_cord_syndrome', obj='sodium')
#      0.007 KBTriple(rel='acquired', sbj='fibrin', obj='propranolol')
#      0.007 KBTriple(rel='acquired', sbj='propranolol', obj='fibrin')
#      0.007 KBTriple(rel='acquired', sbj='concomitant', obj='atrioventricular_block')
#      0.007 KBTriple(rel='acquired', sbj='atrioventricular_block', obj='concomitant')
#      0.007 KBTriple(rel='acquired', sbj='nephrectomy', obj='acyclovir')
#      0.007 KBTriple(rel='acquired', sbj='acyclovir', obj='nephrectomy')
#      0.007 KBTriple(rel='acquired', sbj='dihydrotachysterol', obj='biopsy')
#      0.007 KBTriple(rel='acquired', sbj='biopsy', obj='dihydrotachysterol')
#      0.007 KBTriple(rel='acquired', sbj='breast_feeding', obj='diazepam')
#      0.007 KBTriple(rel='acquired', sbj='diazepam', obj='breast_feeding')
#      0.007 KBTriple(rel='acquired', sbj='concomitant', obj='holoprosencephaly')
#      0.007 KBTriple(rel='acquired', sbj='holoprosencephaly', obj='concomitant')
#      0.007 KBTriple(rel='acquired', sbj='phenytoin', obj='nephritis')
#      0.007 KBTriple(rel='acquired', sbj='nephritis', obj='phenytoin')
#      0.007 KBTriple(rel='acquired', sbj='corynebacterium', obj='drug_resistance')
#      0.007 KBTriple(rel='acquired', sbj='drug_resistance', obj='corynebacterium')
#      0.006 KBTriple(rel='acquired', sbj='nasal', obj='gingivitis')
#      0.006 KBTriple(rel='acquired', sbj='gingivitis', obj='nasal')
#      0.006 KBTriple(rel='acquired', sbj='lyme_disease', obj='belgium')
#      0.006 KBTriple(rel='acquired', sbj='belgium', obj='lyme_disease')
#      0.006 KBTriple(rel='acquired', sbj='phenytoin', obj='gastric_lavage')
#      0.006 KBTriple(rel='acquired', sbj='gastric_lavage', obj='phenytoin')
#      0.006 KBTriple(rel='acquired', sbj='cell_death', obj='propranolol')
#      0.006 KBTriple(rel='acquired', sbj='propranolol', obj='cell_death')
#      0.006 KBTriple(rel='acquired', sbj='dicoumarol', obj='venous_thrombosis')
#      0.006 KBTriple(rel='acquired', sbj='venous_thrombosis', obj='dicoumarol')
#      0.006 KBTriple(rel='acquired', sbj='disofenin', obj='cyst')
#      0.006 KBTriple(rel='acquired', sbj='cyst', obj='disofenin')
#      0.006 KBTriple(rel='acquired', sbj='histiocytosis', obj='nasal')
#      0.006 KBTriple(rel='acquired', sbj='nasal', obj='histiocytosis')
#      0.006 KBTriple(rel='acquired', sbj='imipenem', obj='aspiration')
#      0.006 KBTriple(rel='acquired', sbj='aspiration', obj='imipenem')
#      0.006 KBTriple(rel='acquired', sbj='concomitant', obj='joint_instability')
#      0.006 KBTriple(rel='acquired', sbj='joint_instability', obj='concomitant')
#      0.006 KBTriple(rel='acquired', sbj='venous_pressure', obj='fluorouracil')
#      0.006 KBTriple(rel='acquired', sbj='fluorouracil', obj='venous_pressure')
#      0.006 KBTriple(rel='acquired', sbj='nasal', obj='rheumatoid_factor')
#      0.006 KBTriple(rel='acquired', sbj='rheumatoid_factor', obj='nasal')
#      0.006 KBTriple(rel='acquired', sbj='concomitant', obj='thrombectomy')
#      0.006 KBTriple(rel='acquired', sbj='thrombectomy', obj='concomitant')
#      0.006 KBTriple(rel='acquired', sbj='biliary_colic', obj='octreotide')
#      0.006 KBTriple(rel='acquired', sbj='octreotide', obj='biliary_colic')
#      0.006 KBTriple(rel='acquired', sbj='irritability', obj='ibuprofen')
#      0.006 KBTriple(rel='acquired', sbj='ibuprofen', obj='irritability')
#      0.006 KBTriple(rel='acquired', sbj='osteopenia', obj='thiazide')
#      0.006 KBTriple(rel='acquired', sbj='thiazide', obj='osteopenia')
#      0.006 KBTriple(rel='acquired', sbj='osteogenesis_imperfecta', obj='peptide')
#      0.006 KBTriple(rel='acquired', sbj='peptide', obj='osteogenesis_imperfecta')
#      0.006 KBTriple(rel='acquired', sbj='thallium', obj='ataxia')
#      0.006 KBTriple(rel='acquired', sbj='ataxia', obj='thallium')
#
# Highest probability examples for relation aggravated:
#
#      0.999 KBTriple(rel='aggravated', sbj='cimetidine', obj='pco2')
#      0.999 KBTriple(rel='aggravated', sbj='pco2', obj='cimetidine')
#      0.979 KBTriple(rel='aggravated', sbj='diazepam', obj='tension')
#      0.979 KBTriple(rel='aggravated', sbj='tension', obj='diazepam')
#      0.887 KBTriple(rel='aggravated', sbj='somatostatin', obj='acidosis')
#      0.887 KBTriple(rel='aggravated', sbj='acidosis', obj='somatostatin')
#      0.886 KBTriple(rel='aggravated', sbj='droperidol', obj='visual_analogue_scale')
#      0.886 KBTriple(rel='aggravated', sbj='visual_analogue_scale', obj='droperidol')
#      0.850 KBTriple(rel='aggravated', sbj='coagulopathy', obj='corynebacterium')
#      0.850 KBTriple(rel='aggravated', sbj='corynebacterium', obj='coagulopathy')
#      0.842 KBTriple(rel='aggravated', sbj='phenytoin', obj='tension')
#      0.842 KBTriple(rel='aggravated', sbj='tension', obj='phenytoin')
#      0.832 KBTriple(rel='aggravated', sbj='metabolic_acidosis', obj='somatostatin')
#      0.832 KBTriple(rel='aggravated', sbj='somatostatin', obj='metabolic_acidosis')
#      0.740 KBTriple(rel='aggravated', sbj='ibuprofen', obj='vitamin_a')
#      0.740 KBTriple(rel='aggravated', sbj='vitamin_a', obj='ibuprofen')
#      0.736 KBTriple(rel='aggravated', sbj='rheumatoid_arthritis', obj='diazepam')
#      0.736 KBTriple(rel='aggravated', sbj='diazepam', obj='rheumatoid_arthritis')
#      0.731 KBTriple(rel='aggravated', sbj='condition', obj='viomycin')
#      0.731 KBTriple(rel='aggravated', sbj='viomycin', obj='condition')
#      0.719 KBTriple(rel='aggravated', sbj='forced_expiratory_flow', obj='sodium')
#      0.719 KBTriple(rel='aggravated', sbj='sodium', obj='forced_expiratory_flow')
#      0.701 KBTriple(rel='aggravated', sbj='debridement', obj='piperacillin')
#      0.701 KBTriple(rel='aggravated', sbj='piperacillin', obj='debridement')
#      0.679 KBTriple(rel='aggravated', sbj='teicoplanin', obj='growth')
#      0.679 KBTriple(rel='aggravated', sbj='growth', obj='teicoplanin')
#      0.652 KBTriple(rel='aggravated', sbj='hepatic_lesion', obj='cocaine')
#      0.652 KBTriple(rel='aggravated', sbj='cocaine', obj='hepatic_lesion')
#      0.651 KBTriple(rel='aggravated', sbj='idoxuridine', obj='infection')
#      0.651 KBTriple(rel='aggravated', sbj='infection', obj='idoxuridine')
#      0.617 KBTriple(rel='aggravated', sbj='accident', obj='molsidomine')
#      0.617 KBTriple(rel='aggravated', sbj='molsidomine', obj='accident')
#      0.601 KBTriple(rel='aggravated', sbj='fluid_imbalance', obj='ibuprofen')
#      0.601 KBTriple(rel='aggravated', sbj='ibuprofen', obj='fluid_imbalance')
#      0.600 KBTriple(rel='aggravated', sbj='muscle_mass', obj='bisoprolol')
#      0.600 KBTriple(rel='aggravated', sbj='bisoprolol', obj='muscle_mass')
#      0.594 KBTriple(rel='aggravated', sbj='pulmonary_function_test', obj='helium')
#      0.594 KBTriple(rel='aggravated', sbj='helium', obj='pulmonary_function_test')
#      0.589 KBTriple(rel='aggravated', sbj='concomitant', obj='grip_strength')
#      0.589 KBTriple(rel='aggravated', sbj='grip_strength', obj='concomitant')
#      0.587 KBTriple(rel='aggravated', sbj='neostigmine', obj='ischaemia')
#      0.587 KBTriple(rel='aggravated', sbj='ischaemia', obj='neostigmine')
#      0.582 KBTriple(rel='aggravated', sbj='pain', obj='paradox')
#      0.582 KBTriple(rel='aggravated', sbj='paradox', obj='pain')
#      0.542 KBTriple(rel='aggravated', sbj='alfentanil', obj='neuromuscular_block')
#      0.542 KBTriple(rel='aggravated', sbj='neuromuscular_block', obj='alfentanil')
#      0.528 KBTriple(rel='aggravated', sbj='magnesium', obj='metrorrhagia')
#      0.528 KBTriple(rel='aggravated', sbj='metrorrhagia', obj='magnesium')
#      0.520 KBTriple(rel='aggravated', sbj='sinus_rhythm', obj='terazosin')
#      0.520 KBTriple(rel='aggravated', sbj='terazosin', obj='sinus_rhythm')
#      0.518 KBTriple(rel='aggravated', sbj='intranasal', obj='glioma')
#      0.518 KBTriple(rel='aggravated', sbj='glioma', obj='intranasal')
#      0.503 KBTriple(rel='aggravated', sbj='teicoplanin', obj='vomiting')
#      0.503 KBTriple(rel='aggravated', sbj='vomiting', obj='teicoplanin')
#      0.491 KBTriple(rel='aggravated', sbj='cocaine', obj='oestradiol')
#      0.491 KBTriple(rel='aggravated', sbj='oestradiol', obj='cocaine')
#      0.489 KBTriple(rel='aggravated', sbj='peptide', obj='enteral_nutrition')
#      0.489 KBTriple(rel='aggravated', sbj='enteral_nutrition', obj='peptide')
#      0.488 KBTriple(rel='aggravated', sbj='diazepam', obj='central_cord_syndrome')
#      0.488 KBTriple(rel='aggravated', sbj='central_cord_syndrome', obj='diazepam')
#      0.474 KBTriple(rel='aggravated', sbj='tac', obj='t-cell_lymphoma')
#      0.474 KBTriple(rel='aggravated', sbj='t-cell_lymphoma', obj='tac')
#      0.467 KBTriple(rel='aggravated', sbj='muscle_mass', obj='diltiazem')
#      0.467 KBTriple(rel='aggravated', sbj='diltiazem', obj='muscle_mass')
#      0.466 KBTriple(rel='aggravated', sbj='epinephrine', obj='allantoin')
#      0.466 KBTriple(rel='aggravated', sbj='allantoin', obj='epinephrine')
#      0.461 KBTriple(rel='aggravated', sbj='amsacrine', obj='blast_cells')
#      0.461 KBTriple(rel='aggravated', sbj='blast_cells', obj='amsacrine')
#      0.459 KBTriple(rel='aggravated', sbj='vitamin_b12', obj='gentamicin')
#      0.459 KBTriple(rel='aggravated', sbj='gentamicin', obj='vitamin_b12')
#      0.454 KBTriple(rel='aggravated', sbj='gentamicin', obj='glomerulosclerosis')
#      0.454 KBTriple(rel='aggravated', sbj='glomerulosclerosis', obj='gentamicin')
#      0.452 KBTriple(rel='aggravated', sbj='sputum', obj='thiabendazole')
#      0.452 KBTriple(rel='aggravated', sbj='thiabendazole', obj='sputum')
#      0.451 KBTriple(rel='aggravated', sbj='ischaemia', obj='paradox')
#      0.451 KBTriple(rel='aggravated', sbj='paradox', obj='ischaemia')
#      0.449 KBTriple(rel='aggravated', sbj='hypometabolism', obj='cocaine')
#      0.449 KBTriple(rel='aggravated', sbj='cocaine', obj='hypometabolism')
#      0.448 KBTriple(rel='aggravated', sbj='piloerection', obj='sodium')
#      0.448 KBTriple(rel='aggravated', sbj='sodium', obj='piloerection')
#      0.441 KBTriple(rel='aggravated', sbj='sodium', obj='central_cord_syndrome')
#      0.441 KBTriple(rel='aggravated', sbj='central_cord_syndrome', obj='sodium')
#      0.437 KBTriple(rel='aggravated', sbj='aciclovir', obj='genital_herpes_simplex')
#      0.437 KBTriple(rel='aggravated', sbj='genital_herpes_simplex', obj='aciclovir')
#      0.430 KBTriple(rel='aggravated', sbj='sodium', obj='atrial_hypertrophy')
#      0.430 KBTriple(rel='aggravated', sbj='atrial_hypertrophy', obj='sodium')
#      0.429 KBTriple(rel='aggravated', sbj='hyperammonaemia', obj='sodium')
#      0.429 KBTriple(rel='aggravated', sbj='sodium', obj='hyperammonaemia')
#      0.427 KBTriple(rel='aggravated', sbj='azatadine', obj='rhinitis')
#      0.427 KBTriple(rel='aggravated', sbj='rhinitis', obj='azatadine')
#      0.420 KBTriple(rel='aggravated', sbj='bepridil', obj='troponin')
#      0.420 KBTriple(rel='aggravated', sbj='troponin', obj='bepridil')
#      0.403 KBTriple(rel='aggravated', sbj='polypeptide', obj='lactic_acidosis')
#      0.403 KBTriple(rel='aggravated', sbj='lactic_acidosis', obj='polypeptide')
#      0.403 KBTriple(rel='aggravated', sbj='diazepam', obj='chorea')
#      0.403 KBTriple(rel='aggravated', sbj='chorea', obj='diazepam')
#      0.401 KBTriple(rel='aggravated', sbj='celiprolol', obj='hypertrophy')
#      0.401 KBTriple(rel='aggravated', sbj='hypertrophy', obj='celiprolol')
#      0.397 KBTriple(rel='aggravated', sbj='somatostatin', obj='gastroduodenal_ulcer')
#      0.397 KBTriple(rel='aggravated', sbj='gastroduodenal_ulcer', obj='somatostatin')
#      0.393 KBTriple(rel='aggravated', sbj='nasal', obj='narcolepsy')
#      0.393 KBTriple(rel='aggravated', sbj='narcolepsy', obj='nasal')
#      0.391 KBTriple(rel='aggravated', sbj='hypersomnia', obj='concomitant')
#      0.391 KBTriple(rel='aggravated', sbj='concomitant', obj='hypersomnia')
#      0.388 KBTriple(rel='aggravated', sbj='pac', obj='delivery')
#      0.388 KBTriple(rel='aggravated', sbj='delivery', obj='pac')
#      0.385 KBTriple(rel='aggravated', sbj='propanolol', obj='acute_myocardial_infarction')
#      0.385 KBTriple(rel='aggravated', sbj='acute_myocardial_infarction', obj='propanolol')
#      0.378 KBTriple(rel='aggravated', sbj='dysphagia', obj='neostigmine')
#      0.378 KBTriple(rel='aggravated', sbj='neostigmine', obj='dysphagia')
#      0.375 KBTriple(rel='aggravated', sbj='tryptase', obj='concomitant')
#      0.375 KBTriple(rel='aggravated', sbj='concomitant', obj='tryptase')
#      0.375 KBTriple(rel='aggravated', sbj='propanolol', obj='shock')
#      0.375 KBTriple(rel='aggravated', sbj='shock', obj='propanolol')
#      0.375 KBTriple(rel='aggravated', sbj='cardiogenic_shock', obj='propanolol')
#      0.375 KBTriple(rel='aggravated', sbj='propanolol', obj='cardiogenic_shock')
#      0.372 KBTriple(rel='aggravated', sbj='macrophages', obj='tac')
#      0.372 KBTriple(rel='aggravated', sbj='tac', obj='macrophages')
#      0.370 KBTriple(rel='aggravated', sbj='neuromuscular_block', obj='diazepam')
#      0.370 KBTriple(rel='aggravated', sbj='diazepam', obj='neuromuscular_block')
#      0.368 KBTriple(rel='aggravated', sbj='myelopathy', obj='acyclovir')
#      0.368 KBTriple(rel='aggravated', sbj='acyclovir', obj='myelopathy')
#      0.365 KBTriple(rel='aggravated', sbj='strontium', obj='overdose')
#      0.365 KBTriple(rel='aggravated', sbj='overdose', obj='strontium')
#      0.361 KBTriple(rel='aggravated', sbj='vital_capacity', obj='cimetidine')
#      0.361 KBTriple(rel='aggravated', sbj='cimetidine', obj='vital_capacity')
#      0.361 KBTriple(rel='aggravated', sbj='cimetidine', obj='forced_vital_capacity')
#      0.361 KBTriple(rel='aggravated', sbj='forced_vital_capacity', obj='cimetidine')
#      0.361 KBTriple(rel='aggravated', sbj='azelastine', obj='tachyphylaxis')
#      0.361 KBTriple(rel='aggravated', sbj='tachyphylaxis', obj='azelastine')
#      0.355 KBTriple(rel='aggravated', sbj='nasal', obj='hypothyroidism')
#      0.355 KBTriple(rel='aggravated', sbj='hypothyroidism', obj='nasal')
#      0.355 KBTriple(rel='aggravated', sbj='polypeptide', obj='dysplasia')
#      0.355 KBTriple(rel='aggravated', sbj='dysplasia', obj='polypeptide')
#      0.354 KBTriple(rel='aggravated', sbj='magnesium', obj='cardiac_death')
#      0.354 KBTriple(rel='aggravated', sbj='cardiac_death', obj='magnesium')
#      0.349 KBTriple(rel='aggravated', sbj='somatostatin', obj='acquired_immunodeficiency_syndrome')
#      0.349 KBTriple(rel='aggravated', sbj='acquired_immunodeficiency_syndrome', obj='somatostatin')
#      0.341 KBTriple(rel='aggravated', sbj='diarrhoea', obj='pectin')
#      0.341 KBTriple(rel='aggravated', sbj='pectin', obj='diarrhoea')
#      0.341 KBTriple(rel='aggravated', sbj='condition', obj='helium')
#      0.341 KBTriple(rel='aggravated', sbj='helium', obj='condition')
#      0.338 KBTriple(rel='aggravated', sbj='infectious_mononucleosis', obj='polypeptide')
#      0.338 KBTriple(rel='aggravated', sbj='polypeptide', obj='infectious_mononucleosis')
#      0.329 KBTriple(rel='aggravated', sbj='diazepam', obj='hyperreflexia')
#      0.329 KBTriple(rel='aggravated', sbj='hyperreflexia', obj='diazepam')
#      0.329 KBTriple(rel='aggravated', sbj='bisoprolol', obj='epinephrine')
#      0.329 KBTriple(rel='aggravated', sbj='epinephrine', obj='bisoprolol')
#      0.328 KBTriple(rel='aggravated', sbj='myocardial_infarction', obj='propanolol')
#      0.328 KBTriple(rel='aggravated', sbj='propanolol', obj='myocardial_infarction')
#      0.325 KBTriple(rel='aggravated', sbj='paradox', obj='visual_acuity')
#      0.325 KBTriple(rel='aggravated', sbj='visual_acuity', obj='paradox')
#      0.325 KBTriple(rel='aggravated', sbj='sudden_cardiac_death', obj='magnesium')
#      0.325 KBTriple(rel='aggravated', sbj='magnesium', obj='sudden_cardiac_death')
#      0.320 KBTriple(rel='aggravated', sbj='sodium', obj='protein_bound_iodine')
#      0.320 KBTriple(rel='aggravated', sbj='protein_bound_iodine', obj='sodium')
#      0.317 KBTriple(rel='aggravated', sbj='scleritis', obj='dapsone')
#      0.317 KBTriple(rel='aggravated', sbj='dapsone', obj='scleritis')
#      0.315 KBTriple(rel='aggravated', sbj='acyclovir', obj='tuberculosis')
#      0.315 KBTriple(rel='aggravated', sbj='tuberculosis', obj='acyclovir')
#      0.313 KBTriple(rel='aggravated', sbj='aluminium', obj='calcium_deficiency')
#      0.313 KBTriple(rel='aggravated', sbj='calcium_deficiency', obj='aluminium')
#      0.313 KBTriple(rel='aggravated', sbj='polypeptide', obj='amputation')
#      0.313 KBTriple(rel='aggravated', sbj='amputation', obj='polypeptide')
#      0.309 KBTriple(rel='aggravated', sbj='cataract', obj='benzalkonium')
#      0.309 KBTriple(rel='aggravated', sbj='benzalkonium', obj='cataract')
#      0.307 KBTriple(rel='aggravated', sbj='propranolol', obj='accident')
#      0.307 KBTriple(rel='aggravated', sbj='accident', obj='propranolol')
#      0.306 KBTriple(rel='aggravated', sbj='energy', obj='miconazole')
#      0.306 KBTriple(rel='aggravated', sbj='miconazole', obj='energy')
#      0.304 KBTriple(rel='aggravated', sbj='hypotension', obj='betaxolol')
#      0.304 KBTriple(rel='aggravated', sbj='betaxolol', obj='hypotension')
#      0.302 KBTriple(rel='aggravated', sbj='gamma-globulin', obj='abscess')
#      0.302 KBTriple(rel='aggravated', sbj='abscess', obj='gamma-globulin')
#      0.298 KBTriple(rel='aggravated', sbj='ibuprofen', obj='aneurysm_repair')
#      0.298 KBTriple(rel='aggravated', sbj='aneurysm_repair', obj='ibuprofen')
#      0.298 KBTriple(rel='aggravated', sbj='aortic_aneurysm_repair', obj='ibuprofen')
#      0.298 KBTriple(rel='aggravated', sbj='ibuprofen', obj='aortic_aneurysm_repair')
#      0.297 KBTriple(rel='aggravated', sbj='death', obj='menopausal')
#      0.297 KBTriple(rel='aggravated', sbj='menopausal', obj='death')
#      0.297 KBTriple(rel='aggravated', sbj='gestational_hypertension', obj='concomitant')
#      0.297 KBTriple(rel='aggravated', sbj='concomitant', obj='gestational_hypertension')
#      0.296 KBTriple(rel='aggravated', sbj='forced_vital_capacity', obj='edrophonium')
#      0.296 KBTriple(rel='aggravated', sbj='edrophonium', obj='forced_vital_capacity')
#      0.296 KBTriple(rel='aggravated', sbj='vital_capacity', obj='edrophonium')
#      0.296 KBTriple(rel='aggravated', sbj='edrophonium', obj='vital_capacity')
#      0.292 KBTriple(rel='aggravated', sbj='osteonecrosis', obj='radium')
#      0.292 KBTriple(rel='aggravated', sbj='radium', obj='osteonecrosis')
#      0.289 KBTriple(rel='aggravated', sbj='dicoumarol', obj='coagulation_time')
#      0.289 KBTriple(rel='aggravated', sbj='coagulation_time', obj='dicoumarol')
#      0.289 KBTriple(rel='aggravated', sbj='osteitis', obj='polypeptide')
#      0.289 KBTriple(rel='aggravated', sbj='polypeptide', obj='osteitis')
#      0.287 KBTriple(rel='aggravated', sbj='concomitant', obj='transaminases')
#      0.287 KBTriple(rel='aggravated', sbj='transaminases', obj='concomitant')
#      0.283 KBTriple(rel='aggravated', sbj='sensitisation', obj='ammonium')
#      0.283 KBTriple(rel='aggravated', sbj='ammonium', obj='sensitisation')
#      0.281 KBTriple(rel='aggravated', sbj='immunodeficiency', obj='imipenem')
#      0.281 KBTriple(rel='aggravated', sbj='imipenem', obj='immunodeficiency')
#      0.281 KBTriple(rel='aggravated', sbj='tac', obj='tuberculosis')
#      0.281 KBTriple(rel='aggravated', sbj='tuberculosis', obj='tac')
#
# Highest probability examples for relation altered:
#
#      0.878 KBTriple(rel='altered', sbj='protein_c', obj='peptide')
#      0.878 KBTriple(rel='altered', sbj='peptide', obj='protein_c')
#      0.631 KBTriple(rel='altered', sbj='cimetidine', obj='forced_expiratory_volume')
#      0.631 KBTriple(rel='altered', sbj='forced_expiratory_volume', obj='cimetidine')
#      0.542 KBTriple(rel='altered', sbj='tinnitus', obj='phenylbutazone')
#      0.542 KBTriple(rel='altered', sbj='phenylbutazone', obj='tinnitus')
#      0.501 KBTriple(rel='altered', sbj='vital_capacity', obj='lidocaine')
#      0.501 KBTriple(rel='altered', sbj='lidocaine', obj='vital_capacity')
#      0.382 KBTriple(rel='altered', sbj='somatostatin', obj='blood_glucagon')
#      0.382 KBTriple(rel='altered', sbj='blood_glucagon', obj='somatostatin')
#      0.352 KBTriple(rel='altered', sbj='diazepam', obj='extubation')
#      0.352 KBTriple(rel='altered', sbj='extubation', obj='diazepam')
#      0.273 KBTriple(rel='altered', sbj='microangiopathy', obj='somatostatin')
#      0.273 KBTriple(rel='altered', sbj='somatostatin', obj='microangiopathy')
#      0.271 KBTriple(rel='altered', sbj='infusion', obj='betaxolol')
#      0.271 KBTriple(rel='altered', sbj='betaxolol', obj='infusion')
#      0.262 KBTriple(rel='altered', sbj='phenylbutazone', obj='urticaria')
#      0.262 KBTriple(rel='altered', sbj='urticaria', obj='phenylbutazone')
#      0.241 KBTriple(rel='altered', sbj='strontium', obj='salmonellosis')
#      0.241 KBTriple(rel='altered', sbj='salmonellosis', obj='strontium')
#      0.230 KBTriple(rel='altered', sbj='cimetidine', obj='forced_expiratory_flow')
#      0.230 KBTriple(rel='altered', sbj='forced_expiratory_flow', obj='cimetidine')
#      0.227 KBTriple(rel='altered', sbj='pindolol', obj='forced_expiratory_volume')
#      0.227 KBTriple(rel='altered', sbj='forced_expiratory_volume', obj='pindolol')
#      0.208 KBTriple(rel='altered', sbj='blood_bicarbonate', obj='ammonium')
#      0.208 KBTriple(rel='altered', sbj='ammonium', obj='blood_bicarbonate')
#      0.198 KBTriple(rel='altered', sbj='poisoning', obj='strontium')
#      0.198 KBTriple(rel='altered', sbj='strontium', obj='poisoning')
#      0.186 KBTriple(rel='altered', sbj='desipramine', obj='amylase')
#      0.186 KBTriple(rel='altered', sbj='amylase', obj='desipramine')
#      0.184 KBTriple(rel='altered', sbj='imipenem', obj='neurotoxicity')
#      0.184 KBTriple(rel='altered', sbj='neurotoxicity', obj='imipenem')
#      0.179 KBTriple(rel='altered', sbj='strontium', obj='food_poisoning')
#      0.179 KBTriple(rel='altered', sbj='food_poisoning', obj='strontium')
#      0.162 KBTriple(rel='altered', sbj='abdominal_pain', obj='magnesium')
#      0.162 KBTriple(rel='altered', sbj='magnesium', obj='abdominal_pain')
#      0.149 KBTriple(rel='altered', sbj='depressed_mood', obj='concomitant')
#      0.149 KBTriple(rel='altered', sbj='concomitant', obj='depressed_mood')
#      0.142 KBTriple(rel='altered', sbj='sneezing', obj='methylprednisolone')
#      0.142 KBTriple(rel='altered', sbj='methylprednisolone', obj='sneezing')
#      0.142 KBTriple(rel='altered', sbj='zidovudine', obj='saliva')
#      0.142 KBTriple(rel='altered', sbj='saliva', obj='zidovudine')
#      0.137 KBTriple(rel='altered', sbj='prazepam', obj='mood')
#      0.137 KBTriple(rel='altered', sbj='mood', obj='prazepam')
#      0.127 KBTriple(rel='altered', sbj='norfloxacin', obj='prothrombin_time')
#      0.127 KBTriple(rel='altered', sbj='prothrombin_time', obj='norfloxacin')
#      0.120 KBTriple(rel='altered', sbj='magnesium', obj='blood_cadmium')
#      0.120 KBTriple(rel='altered', sbj='blood_cadmium', obj='magnesium')
#      0.115 KBTriple(rel='altered', sbj='euthyroid_sick_syndrome', obj='concomitant')
#      0.115 KBTriple(rel='altered', sbj='concomitant', obj='euthyroid_sick_syndrome')
#      0.113 KBTriple(rel='altered', sbj='osteonecrosis', obj='radium')
#      0.113 KBTriple(rel='altered', sbj='radium', obj='osteonecrosis')
#      0.112 KBTriple(rel='altered', sbj='vital_capacity', obj='cimetidine')
#      0.112 KBTriple(rel='altered', sbj='cimetidine', obj='vital_capacity')
#      0.112 KBTriple(rel='altered', sbj='cimetidine', obj='forced_vital_capacity')
#      0.112 KBTriple(rel='altered', sbj='forced_vital_capacity', obj='cimetidine')
#      0.111 KBTriple(rel='altered', sbj='pindolol', obj='forced_vital_capacity')
#      0.111 KBTriple(rel='altered', sbj='pindolol', obj='vital_capacity')
#      0.111 KBTriple(rel='altered', sbj='vital_capacity', obj='pindolol')
#      0.111 KBTriple(rel='altered', sbj='forced_vital_capacity', obj='pindolol')
#      0.106 KBTriple(rel='altered', sbj='cutaneous_vasculitis', obj='propranolol')
#      0.106 KBTriple(rel='altered', sbj='propranolol', obj='cutaneous_vasculitis')
#      0.102 KBTriple(rel='altered', sbj='immunoglobulins', obj='zidovudine')
#      0.102 KBTriple(rel='altered', sbj='zidovudine', obj='immunoglobulins')
#      0.100 KBTriple(rel='altered', sbj='investigation', obj='idoxuridine')
#      0.100 KBTriple(rel='altered', sbj='idoxuridine', obj='investigation')
#      0.100 KBTriple(rel='altered', sbj='diltiazem', obj='mobility')
#      0.100 KBTriple(rel='altered', sbj='mobility', obj='diltiazem')
#      0.096 KBTriple(rel='altered', sbj='carotid_artery_occlusion', obj='bretylium')
#      0.096 KBTriple(rel='altered', sbj='bretylium', obj='carotid_artery_occlusion')
#      0.093 KBTriple(rel='altered', sbj='fatigue', obj='pindolol')
#      0.093 KBTriple(rel='altered', sbj='pindolol', obj='fatigue')
#      0.092 KBTriple(rel='altered', sbj='nasal', obj='urine_flow')
#      0.092 KBTriple(rel='altered', sbj='urine_flow', obj='nasal')
#      0.089 KBTriple(rel='altered', sbj='tension', obj='prazepam')
#      0.089 KBTriple(rel='altered', sbj='prazepam', obj='tension')
#      0.085 KBTriple(rel='altered', sbj='fasting', obj='nizatidine')
#      0.085 KBTriple(rel='altered', sbj='nizatidine', obj='fasting')
#      0.083 KBTriple(rel='altered', sbj='otitis_media', obj='xylometazoline')
#      0.083 KBTriple(rel='altered', sbj='xylometazoline', obj='otitis_media')
#      0.083 KBTriple(rel='altered', sbj='ammonium', obj='prothrombin_time')
#      0.083 KBTriple(rel='altered', sbj='prothrombin_time', obj='ammonium')
#      0.083 KBTriple(rel='altered', sbj='acyclovir', obj='sensory_disturbance')
#      0.083 KBTriple(rel='altered', sbj='sensory_disturbance', obj='acyclovir')
#      0.081 KBTriple(rel='altered', sbj='concomitant', obj='hypocalcaemia')
#      0.081 KBTriple(rel='altered', sbj='hypocalcaemia', obj='concomitant')
#      0.081 KBTriple(rel='altered', sbj='magnesium', obj='duodenal_obstruction')
#      0.081 KBTriple(rel='altered', sbj='duodenal_obstruction', obj='magnesium')
#      0.080 KBTriple(rel='altered', sbj='piperacillin', obj='prostatitis')
#      0.080 KBTriple(rel='altered', sbj='prostatitis', obj='piperacillin')
#      0.080 KBTriple(rel='altered', sbj='metabolic_acidosis', obj='somatostatin')
#      0.080 KBTriple(rel='altered', sbj='somatostatin', obj='metabolic_acidosis')
#      0.077 KBTriple(rel='altered', sbj='magnesium', obj='folate_deficiency')
#      0.077 KBTriple(rel='altered', sbj='folate_deficiency', obj='magnesium')
#      0.077 KBTriple(rel='altered', sbj='amoebiasis', obj='magnesium')
#      0.077 KBTriple(rel='altered', sbj='magnesium', obj='amoebiasis')
#      0.075 KBTriple(rel='altered', sbj='sodium', obj='gastroschisis')
#      0.075 KBTriple(rel='altered', sbj='gastroschisis', obj='sodium')
#      0.073 KBTriple(rel='altered', sbj='somatostatin', obj='acidosis')
#      0.073 KBTriple(rel='altered', sbj='acidosis', obj='somatostatin')
#      0.072 KBTriple(rel='altered', sbj='cocaine', obj='oestradiol')
#      0.072 KBTriple(rel='altered', sbj='oestradiol', obj='cocaine')
#      0.071 KBTriple(rel='altered', sbj='leprosy', obj='tac')
#      0.071 KBTriple(rel='altered', sbj='tac', obj='leprosy')
#      0.070 KBTriple(rel='altered', sbj='ammonia', obj='nadolol')
#      0.070 KBTriple(rel='altered', sbj='nadolol', obj='ammonia')
#      0.070 KBTriple(rel='altered', sbj='propranolol', obj='grip_strength')
#      0.070 KBTriple(rel='altered', sbj='grip_strength', obj='propranolol')
#      0.068 KBTriple(rel='altered', sbj='surgery', obj='pectin')
#      0.068 KBTriple(rel='altered', sbj='pectin', obj='surgery')
#      0.066 KBTriple(rel='altered', sbj='skin_irritation', obj='oxyphenbutazone')
#      0.066 KBTriple(rel='altered', sbj='oxyphenbutazone', obj='skin_irritation')
#      0.064 KBTriple(rel='altered', sbj='cyst', obj='pregnenolone')
#      0.064 KBTriple(rel='altered', sbj='pregnenolone', obj='cyst')
#      0.064 KBTriple(rel='altered', sbj='obstruction', obj='ammonium')
#      0.064 KBTriple(rel='altered', sbj='ammonium', obj='obstruction')
#      0.064 KBTriple(rel='altered', sbj='thallium', obj='ataxia')
#      0.064 KBTriple(rel='altered', sbj='ataxia', obj='thallium')
#      0.063 KBTriple(rel='altered', sbj='magnesium', obj='urine_uric_acid')
#      0.063 KBTriple(rel='altered', sbj='urine_uric_acid', obj='magnesium')
#      0.063 KBTriple(rel='altered', sbj='thallium', obj='tremor')
#      0.063 KBTriple(rel='altered', sbj='tremor', obj='thallium')
#      0.063 KBTriple(rel='altered', sbj='thallium', obj='coma')
#      0.063 KBTriple(rel='altered', sbj='coma', obj='thallium')
#      0.062 KBTriple(rel='altered', sbj='magnesium', obj='ejaculation')
#      0.062 KBTriple(rel='altered', sbj='ejaculation', obj='magnesium')
#      0.061 KBTriple(rel='altered', sbj='osteopenia', obj='thiazide')
#      0.061 KBTriple(rel='altered', sbj='thiazide', obj='osteopenia')
#      0.060 KBTriple(rel='altered', sbj='cell_death', obj='magnesium')
#      0.060 KBTriple(rel='altered', sbj='magnesium', obj='cell_death')
#      0.060 KBTriple(rel='altered', sbj='thallium', obj='thyroiditis')
#      0.060 KBTriple(rel='altered', sbj='thyroiditis', obj='thallium')
#      0.060 KBTriple(rel='altered', sbj='minocycline', obj='saliva')
#      0.060 KBTriple(rel='altered', sbj='saliva', obj='minocycline')
#      0.060 KBTriple(rel='altered', sbj='pindolol', obj='ammonia')
#      0.060 KBTriple(rel='altered', sbj='ammonia', obj='pindolol')
#      0.060 KBTriple(rel='altered', sbj='imipenem', obj='thoracotomy')
#      0.060 KBTriple(rel='altered', sbj='thoracotomy', obj='imipenem')
#      0.059 KBTriple(rel='altered', sbj='somatostatin', obj='tri-iodothyronine')
#      0.059 KBTriple(rel='altered', sbj='tri-iodothyronine', obj='somatostatin')
#      0.058 KBTriple(rel='altered', sbj='energy', obj='pac')
#      0.058 KBTriple(rel='altered', sbj='pac', obj='energy')
#      0.057 KBTriple(rel='altered', sbj='effusion', obj='xylometazoline')
#      0.057 KBTriple(rel='altered', sbj='xylometazoline', obj='effusion')
#      0.057 KBTriple(rel='altered', sbj='acyclovir', obj='ataxia')
#      0.057 KBTriple(rel='altered', sbj='ataxia', obj='acyclovir')
#      0.057 KBTriple(rel='altered', sbj='cerebellar_ataxia', obj='acyclovir')
#      0.057 KBTriple(rel='altered', sbj='acyclovir', obj='cerebellar_ataxia')
#      0.056 KBTriple(rel='altered', sbj='polypeptide', obj='gastric_fistula')
#      0.056 KBTriple(rel='altered', sbj='gastric_fistula', obj='polypeptide')
#      0.056 KBTriple(rel='altered', sbj='thiazide', obj='crystalluria')
#      0.056 KBTriple(rel='altered', sbj='crystalluria', obj='thiazide')
#      0.056 KBTriple(rel='altered', sbj='magnesium', obj='renal_mass')
#      0.056 KBTriple(rel='altered', sbj='renal_mass', obj='magnesium')
#      0.055 KBTriple(rel='altered', sbj='protein_deficiency', obj='diazepam')
#      0.055 KBTriple(rel='altered', sbj='diazepam', obj='protein_deficiency')
#      0.054 KBTriple(rel='altered', sbj='urine_flow', obj='sulindac')
#      0.054 KBTriple(rel='altered', sbj='sulindac', obj='urine_flow')
#      0.054 KBTriple(rel='altered', sbj='urinary_retention', obj='acyclovir')
#      0.054 KBTriple(rel='altered', sbj='acyclovir', obj='urinary_retention')
#      0.054 KBTriple(rel='altered', sbj='norfloxacin', obj='blister')
#      0.054 KBTriple(rel='altered', sbj='blister', obj='norfloxacin')
#      0.053 KBTriple(rel='altered', sbj='agitation', obj='nortriptyline')
#      0.053 KBTriple(rel='altered', sbj='nortriptyline', obj='agitation')
#      0.053 KBTriple(rel='altered', sbj='cimetidine', obj='prothrombin_time')
#      0.053 KBTriple(rel='altered', sbj='prothrombin_time', obj='cimetidine')
#      0.052 KBTriple(rel='altered', sbj='glomerular_filtration_rate', obj='pac')
#      0.052 KBTriple(rel='altered', sbj='pac', obj='glomerular_filtration_rate')
#      0.051 KBTriple(rel='altered', sbj='ejection_fraction', obj='molsidomine')
#      0.051 KBTriple(rel='altered', sbj='molsidomine', obj='ejection_fraction')
#      0.049 KBTriple(rel='altered', sbj='magnesium', obj='eosinopenia')
#      0.049 KBTriple(rel='altered', sbj='eosinopenia', obj='magnesium')
#      0.049 KBTriple(rel='altered', sbj='pectin', obj='ammonia')
#      0.049 KBTriple(rel='altered', sbj='ammonia', obj='pectin')
#      0.049 KBTriple(rel='altered', sbj='nafarelin', obj='bone_loss')
#      0.049 KBTriple(rel='altered', sbj='bone_loss', obj='nafarelin')
#      0.047 KBTriple(rel='altered', sbj='aluminium', obj='hypercalciuria')
#      0.047 KBTriple(rel='altered', sbj='hypercalciuria', obj='aluminium')
#      0.047 KBTriple(rel='altered', sbj='abdominal_pain', obj='acetorphan')
#      0.047 KBTriple(rel='altered', sbj='acetorphan', obj='abdominal_pain')
#      0.047 KBTriple(rel='altered', sbj='blood_sodium', obj='ammonium')
#      0.047 KBTriple(rel='altered', sbj='ammonium', obj='blood_sodium')
#      0.046 KBTriple(rel='altered', sbj='infant', obj='pregnenolone')
#      0.046 KBTriple(rel='altered', sbj='pregnenolone', obj='infant')
#      0.046 KBTriple(rel='altered', sbj='menopausal', obj='glucose_tolerance')
#      0.046 KBTriple(rel='altered', sbj='glucose_tolerance', obj='menopausal')
#      0.046 KBTriple(rel='altered', sbj='lidocaine', obj='forced_expiratory_flow')
#      0.046 KBTriple(rel='altered', sbj='forced_expiratory_flow', obj='lidocaine')
#      0.045 KBTriple(rel='altered', sbj='hypotension', obj='betaxolol')
#      0.045 KBTriple(rel='altered', sbj='betaxolol', obj='hypotension')
#      0.045 KBTriple(rel='altered', sbj='low_density_lipoprotein', obj='clenbuterol')
#      0.045 KBTriple(rel='altered', sbj='clenbuterol', obj='low_density_lipoprotein')
#      0.045 KBTriple(rel='altered', sbj='dipotassium', obj='sedation')
#      0.045 KBTriple(rel='altered', sbj='sedation', obj='dipotassium')
#      0.044 KBTriple(rel='altered', sbj='nadolol', obj='tri-iodothyronine')
#      0.044 KBTriple(rel='altered', sbj='tri-iodothyronine', obj='nadolol')
#      0.044 KBTriple(rel='altered', sbj='cocaine', obj='unemployment')
#      0.044 KBTriple(rel='altered', sbj='unemployment', obj='cocaine')
#      0.044 KBTriple(rel='altered', sbj='osteochondrosis', obj='propranolol')
#      0.044 KBTriple(rel='altered', sbj='propranolol', obj='osteochondrosis')
#
# Highest probability examples for relation caused:
#      1.000 KBTriple(rel='caused', sbj='fall', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='fall')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='blood_pressure')
#      1.000 KBTriple(rel='caused', sbj='blood_pressure', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='enzyme_activity', obj='pindolol')
#      1.000 KBTriple(rel='caused', sbj='pindolol', obj='enzyme_activity')
#      1.000 KBTriple(rel='caused', sbj='tachycardia', obj='propranolol')
#      1.000 KBTriple(rel='caused', sbj='propranolol', obj='tachycardia')
#      1.000 KBTriple(rel='caused', sbj='magnesium', obj='infusion')
#      1.000 KBTriple(rel='caused', sbj='infusion', obj='magnesium')
#      1.000 KBTriple(rel='caused', sbj='sodium', obj='hypercalciuria')
#      1.000 KBTriple(rel='caused', sbj='hypercalciuria', obj='sodium')
#      1.000 KBTriple(rel='caused', sbj='headache', obj='sumatriptan')
#      1.000 KBTriple(rel='caused', sbj='sumatriptan', obj='headache')
#      1.000 KBTriple(rel='caused', sbj='ventricular_tachycardia', obj='magnesium')
#      1.000 KBTriple(rel='caused', sbj='magnesium', obj='ventricular_tachycardia')
#      1.000 KBTriple(rel='caused', sbj='sodium', obj='thrombosis')
#      1.000 KBTriple(rel='caused', sbj='thrombosis', obj='sodium')
#      1.000 KBTriple(rel='caused', sbj='salpingitis', obj='gentamicin')
#      1.000 KBTriple(rel='caused', sbj='gentamicin', obj='salpingitis')
#      1.000 KBTriple(rel='caused', sbj='propranolol', obj='enzyme_activity')
#      1.000 KBTriple(rel='caused', sbj='enzyme_activity', obj='propranolol')
#      0.999 KBTriple(rel='caused', sbj='magnesium', obj='dialysis')
#      0.999 KBTriple(rel='caused', sbj='dialysis', obj='magnesium')
#      0.999 KBTriple(rel='caused', sbj='hypotension', obj='betaxolol')
#      0.999 KBTriple(rel='caused', sbj='betaxolol', obj='hypotension')
#      0.999 KBTriple(rel='caused', sbj='ulcer', obj='nizatidine')
#      0.999 KBTriple(rel='caused', sbj='nizatidine', obj='ulcer')
#      0.999 KBTriple(rel='caused', sbj='blood_ethanol', obj='cocaine')
#      0.999 KBTriple(rel='caused', sbj='cocaine', obj='blood_ethanol')
#      0.998 KBTriple(rel='caused', sbj='pectin', obj='weight')
#      0.998 KBTriple(rel='caused', sbj='weight', obj='pectin')
#      0.997 KBTriple(rel='caused', sbj='injury', obj='magnesium')
#      0.997 KBTriple(rel='caused', sbj='magnesium', obj='injury')
#      0.997 KBTriple(rel='caused', sbj='ondansetron', obj='radiotherapy')
#      0.997 KBTriple(rel='caused', sbj='radiotherapy', obj='ondansetron')
#      0.996 KBTriple(rel='caused', sbj='cocaine', obj='thrombosis')
#      0.996 KBTriple(rel='caused', sbj='thrombosis', obj='cocaine')
#      0.996 KBTriple(rel='caused', sbj='renin', obj='magnesium')
#      0.996 KBTriple(rel='caused', sbj='magnesium', obj='renin')
#      0.996 KBTriple(rel='caused', sbj='magnesium', obj='essential_hypertension')
#      0.996 KBTriple(rel='caused', sbj='essential_hypertension', obj='magnesium')
# ...
#      0.012 KBTriple(rel='ruptured', sbj='hydrocephalus', obj='methylprednisolone')
#      0.012 KBTriple(rel='ruptured', sbj='methylprednisolone', obj='hydrocephalus')
#      0.012 KBTriple(rel='ruptured', sbj='electric_shock', obj='propranolol')
#      0.012 KBTriple(rel='ruptured', sbj='propranolol', obj='electric_shock')
#      0.012 KBTriple(rel='ruptured', sbj='infarction', obj='paradox')
#      0.012 KBTriple(rel='ruptured', sbj='paradox', obj='infarction')
#
# Highest probability examples for relation shortened:
#
#      0.980 KBTriple(rel='shortened', sbj='cystic_fibrosis', obj='roxithromycin')
#      0.980 KBTriple(rel='shortened', sbj='fibrosis', obj='roxithromycin')
#      0.980 KBTriple(rel='shortened', sbj='roxithromycin', obj='fibrosis')
#      0.980 KBTriple(rel='shortened', sbj='roxithromycin', obj='cystic_fibrosis')
#      0.935 KBTriple(rel='shortened', sbj='prothrombin_time', obj='magnesium')
#      0.935 KBTriple(rel='shortened', sbj='magnesium', obj='prothrombin_time')
#      0.931 KBTriple(rel='shortened', sbj='osteochondrosis', obj='propranolol')
#      0.931 KBTriple(rel='shortened', sbj='propranolol', obj='osteochondrosis')
#      0.919 KBTriple(rel='shortened', sbj='strontium', obj='salmonellosis')
#      0.919 KBTriple(rel='shortened', sbj='salmonellosis', obj='strontium')
#      0.866 KBTriple(rel='shortened', sbj='hydralazine', obj='body_surface_area')
#      0.866 KBTriple(rel='shortened', sbj='body_surface_area', obj='hydralazine')
#      0.813 KBTriple(rel='shortened', sbj='prazepam', obj='mood')
#      0.813 KBTriple(rel='shortened', sbj='mood', obj='prazepam')
#      0.767 KBTriple(rel='shortened', sbj='propranolol', obj='thrombin_time')
#      0.767 KBTriple(rel='shortened', sbj='thrombin_time', obj='propranolol')
#      0.754 KBTriple(rel='shortened', sbj='strontium', obj='food_poisoning')
#      0.754 KBTriple(rel='shortened', sbj='food_poisoning', obj='strontium')
#      0.753 KBTriple(rel='shortened', sbj='poisoning', obj='strontium')
#      0.753 KBTriple(rel='shortened', sbj='strontium', obj='poisoning')
#      0.715 KBTriple(rel='shortened', sbj='obsessive-compulsive_disorder', obj='intranasal')
#      0.715 KBTriple(rel='shortened', sbj='intranasal', obj='obsessive-compulsive_disorder')
#      0.709 KBTriple(rel='shortened', sbj='azatadine', obj='rhinitis')
#      0.709 KBTriple(rel='shortened', sbj='rhinitis', obj='azatadine')
#      0.561 KBTriple(rel='shortened', sbj='tension', obj='prazepam')
#      0.561 KBTriple(rel='shortened', sbj='prazepam', obj='tension')
#      0.480 KBTriple(rel='shortened', sbj='ammonium', obj='prothrombin_time')
#      0.480 KBTriple(rel='shortened', sbj='prothrombin_time', obj='ammonium')
#      0.452 KBTriple(rel='shortened', sbj='gamma-globulin', obj='flow_cytometry')
#      0.452 KBTriple(rel='shortened', sbj='flow_cytometry', obj='gamma-globulin')
#      0.437 KBTriple(rel='shortened', sbj='cocaine', obj='heart_rate_variability')
#      0.437 KBTriple(rel='shortened', sbj='heart_rate_variability', obj='cocaine')
#      0.429 KBTriple(rel='shortened', sbj='paradox', obj='acidosis')
#      0.429 KBTriple(rel='shortened', sbj='acidosis', obj='paradox')
#      0.414 KBTriple(rel='shortened', sbj='leprosy', obj='tac')
#      0.414 KBTriple(rel='shortened', sbj='tac', obj='leprosy')
#      0.413 KBTriple(rel='shortened', sbj='helium', obj='fasting')
#      0.413 KBTriple(rel='shortened', sbj='fasting', obj='helium')
#      0.400 KBTriple(rel='shortened', sbj='sodium', obj='carbohydrate_intolerance')
#      0.400 KBTriple(rel='shortened', sbj='carbohydrate_intolerance', obj='sodium')
#      0.397 KBTriple(rel='shortened', sbj='weight', obj='roxithromycin')
#      0.397 KBTriple(rel='shortened', sbj='roxithromycin', obj='weight')
#      0.388 KBTriple(rel='shortened', sbj='gastric_fistula', obj='diazepam')
#      0.388 KBTriple(rel='shortened', sbj='diazepam', obj='gastric_fistula')
#      0.335 KBTriple(rel='shortened', sbj='ciclosporin', obj='dialysis')
#      0.335 KBTriple(rel='shortened', sbj='dialysis', obj='ciclosporin')
#      0.324 KBTriple(rel='shortened', sbj='intranasal', obj='cachexia')
#      0.324 KBTriple(rel='shortened', sbj='cachexia', obj='intranasal')
#      0.323 KBTriple(rel='shortened', sbj='teicoplanin', obj='intensive_care')
#      0.323 KBTriple(rel='shortened', sbj='intensive_care', obj='teicoplanin')
#      0.316 KBTriple(rel='shortened', sbj='dehydroepiandrosterone', obj='cimetidine')
#      0.316 KBTriple(rel='shortened', sbj='cimetidine', obj='dehydroepiandrosterone')
#      0.310 KBTriple(rel='shortened', sbj='abdominal_abscess', obj='imipenem')
#      0.310 KBTriple(rel='shortened', sbj='imipenem', obj='abdominal_abscess')
#      0.300 KBTriple(rel='shortened', sbj='bepridil', obj='depression')
#      0.300 KBTriple(rel='shortened', sbj='depression', obj='bepridil')
#      0.295 KBTriple(rel='shortened', sbj='human_chorionic_gonadotropin', obj='beta-carotene')
#      0.295 KBTriple(rel='shortened', sbj='beta-carotene', obj='human_chorionic_gonadotropin')
#      0.268 KBTriple(rel='shortened', sbj='gamma-globulin', obj='cholangitis')
#      0.268 KBTriple(rel='shortened', sbj='cholangitis', obj='gamma-globulin')
#      0.261 KBTriple(rel='shortened', sbj='induration', obj='concomitant')
#      0.261 KBTriple(rel='shortened', sbj='concomitant', obj='induration')
#      0.243 KBTriple(rel='shortened', sbj='propanolol', obj='cardiac_output')
#      0.243 KBTriple(rel='shortened', sbj='cardiac_output', obj='propanolol')
#      0.241 KBTriple(rel='shortened', sbj='fungal_infection', obj='gentamicin')
#      0.241 KBTriple(rel='shortened', sbj='gentamicin', obj='fungal_infection')
#      0.238 KBTriple(rel='shortened', sbj='elective_surgery', obj='lidocaine')
#      0.238 KBTriple(rel='shortened', sbj='lidocaine', obj='elective_surgery')
#      0.237 KBTriple(rel='shortened', sbj='tanning', obj='sodium')
#      0.237 KBTriple(rel='shortened', sbj='sodium', obj='tanning')
#      0.235 KBTriple(rel='shortened', sbj='idoxuridine', obj='infection')
#      0.235 KBTriple(rel='shortened', sbj='infection', obj='idoxuridine')
#      0.225 KBTriple(rel='shortened', sbj='nasal', obj='holoprosencephaly')
#      0.225 KBTriple(rel='shortened', sbj='holoprosencephaly', obj='nasal')
#      0.225 KBTriple(rel='shortened', sbj='electric_shock', obj='flumazenil')
#      0.225 KBTriple(rel='shortened', sbj='flumazenil', obj='electric_shock')
#      0.222 KBTriple(rel='shortened', sbj='flumazenil', obj='pain_management')
#      0.222 KBTriple(rel='shortened', sbj='pain_management', obj='flumazenil')
#      0.218 KBTriple(rel='shortened', sbj='ibuprofen', obj='hepatic_enzyme')
#      0.218 KBTriple(rel='shortened', sbj='hepatic_enzyme', obj='ibuprofen')
#      0.212 KBTriple(rel='shortened', sbj='eosinophilia', obj='mebendazole')
#      0.212 KBTriple(rel='shortened', sbj='mebendazole', obj='eosinophilia')
#      0.208 KBTriple(rel='shortened', sbj='cardiopulmonary_bypass', obj='fac')
#      0.208 KBTriple(rel='shortened', sbj='fac', obj='cardiopulmonary_bypass')
#      0.201 KBTriple(rel='shortened', sbj='carbon_dioxide', obj='methylprednisolone')
#      0.201 KBTriple(rel='shortened', sbj='methylprednisolone', obj='carbon_dioxide')
#      0.200 KBTriple(rel='shortened', sbj='phagocytosis', obj='tripeptide')
#      0.200 KBTriple(rel='shortened', sbj='tripeptide', obj='phagocytosis')
#      0.190 KBTriple(rel='shortened', sbj='norfloxacin', obj='nosocomial_infection')
#      0.190 KBTriple(rel='shortened', sbj='nosocomial_infection', obj='norfloxacin')
#      0.182 KBTriple(rel='shortened', sbj='cancer_pain', obj='diflunisal')
#      0.182 KBTriple(rel='shortened', sbj='diflunisal', obj='cancer_pain')
#      0.175 KBTriple(rel='shortened', sbj='erythema_annulare', obj='dapsone')
#      0.175 KBTriple(rel='shortened', sbj='dapsone', obj='erythema_annulare')
#      0.175 KBTriple(rel='shortened', sbj='hypertension', obj='neostigmine')
#      0.175 KBTriple(rel='shortened', sbj='neostigmine', obj='hypertension')
#      0.169 KBTriple(rel='shortened', sbj='ovarian_hyperstimulation_syndrome', obj='menopausal')
#      0.169 KBTriple(rel='shortened', sbj='menopausal', obj='ovarian_hyperstimulation_syndrome')
#      0.157 KBTriple(rel='shortened', sbj='protein_deficiency', obj='diazepam')
#      0.157 KBTriple(rel='shortened', sbj='diazepam', obj='protein_deficiency')
#      0.154 KBTriple(rel='shortened', sbj='amenorrhoea', obj='gemeprost')
#      0.154 KBTriple(rel='shortened', sbj='gemeprost', obj='amenorrhoea')
#      0.153 KBTriple(rel='shortened', sbj='stress', obj='piperacillin')
#      0.153 KBTriple(rel='shortened', sbj='piperacillin', obj='stress')
#      0.153 KBTriple(rel='shortened', sbj='visual_impairment', obj='concomitant')
#      0.153 KBTriple(rel='shortened', sbj='concomitant', obj='visual_impairment')
#      0.150 KBTriple(rel='shortened', sbj='nasal', obj='cardiomyopathy')
#      0.150 KBTriple(rel='shortened', sbj='cardiomyopathy', obj='nasal')
#      0.150 KBTriple(rel='shortened', sbj='premenstrual_syndrome', obj='concomitant')
#      0.150 KBTriple(rel='shortened', sbj='concomitant', obj='premenstrual_syndrome')
#      0.150 KBTriple(rel='shortened', sbj='indium', obj='neoplasm')
#      0.150 KBTriple(rel='shortened', sbj='neoplasm', obj='indium')
#      0.150 KBTriple(rel='shortened', sbj='thrombotic_thrombocytopenic_purpura', obj='gamma-globulin')
#      0.150 KBTriple(rel='shortened', sbj='gamma-globulin', obj='thrombotic_thrombocytopenic_purpura')
#      0.139 KBTriple(rel='shortened', sbj='propranolol', obj='choanal_atresia')
#      0.139 KBTriple(rel='shortened', sbj='choanal_atresia', obj='propranolol')
#      0.136 KBTriple(rel='shortened', sbj='ejection_fraction', obj='gallopamil')
#      0.136 KBTriple(rel='shortened', sbj='gallopamil', obj='ejection_fraction')
#      0.134 KBTriple(rel='shortened', sbj='coma', obj='gamma-globulin')
#      0.134 KBTriple(rel='shortened', sbj='gamma-globulin', obj='coma')
#      0.134 KBTriple(rel='shortened', sbj='gamma-globulin', obj='delirium')
#      0.134 KBTriple(rel='shortened', sbj='delirium', obj='gamma-globulin')
#      0.134 KBTriple(rel='shortened', sbj='mobility', obj='pac')
#      0.134 KBTriple(rel='shortened', sbj='pac', obj='mobility')
#      0.134 KBTriple(rel='shortened', sbj='investigation', obj='idoxuridine')
#      0.134 KBTriple(rel='shortened', sbj='idoxuridine', obj='investigation')
#      0.131 KBTriple(rel='shortened', sbj='cutaneous_vasculitis', obj='propranolol')
#      0.131 KBTriple(rel='shortened', sbj='propranolol', obj='cutaneous_vasculitis')
#      0.129 KBTriple(rel='shortened', sbj='concomitant', obj='stridor')
#      0.129 KBTriple(rel='shortened', sbj='stridor', obj='concomitant')
#      0.129 KBTriple(rel='shortened', sbj='cocaine', obj='angiotensin_converting_enzyme')
#      0.129 KBTriple(rel='shortened', sbj='angiotensin_converting_enzyme', obj='cocaine')
#      0.128 KBTriple(rel='shortened', sbj='concomitant', obj='general_physical_condition')
#      0.128 KBTriple(rel='shortened', sbj='general_physical_condition', obj='concomitant')
#      0.127 KBTriple(rel='shortened', sbj='lidocaine', obj='cerebral_artery_occlusion')
#      0.127 KBTriple(rel='shortened', sbj='cerebral_artery_occlusion', obj='lidocaine')
#      0.124 KBTriple(rel='shortened', sbj='cimetidine', obj='erosive_oesophagitis')
#      0.124 KBTriple(rel='shortened', sbj='erosive_oesophagitis', obj='cimetidine')
#      0.120 KBTriple(rel='shortened', sbj='allantoin', obj='anoxia')
#      0.120 KBTriple(rel='shortened', sbj='anoxia', obj='allantoin')
#      0.120 KBTriple(rel='shortened', sbj='cisapride', obj='urinary_retention')
#      0.120 KBTriple(rel='shortened', sbj='urinary_retention', obj='cisapride')
#      0.119 KBTriple(rel='shortened', sbj='immunglobulin', obj='transplant')
#      0.119 KBTriple(rel='shortened', sbj='transplant', obj='immunglobulin')
#      0.117 KBTriple(rel='shortened', sbj='gentamicin', obj='urine_calcium')
#      0.117 KBTriple(rel='shortened', sbj='urine_calcium', obj='gentamicin')
#      0.117 KBTriple(rel='shortened', sbj='polydipsia', obj='desipramine')
#      0.117 KBTriple(rel='shortened', sbj='desipramine', obj='polydipsia')
#      0.116 KBTriple(rel='shortened', sbj='gestational_diabetes', obj='somatostatin')
#      0.116 KBTriple(rel='shortened', sbj='somatostatin', obj='gestational_diabetes')
#      0.115 KBTriple(rel='shortened', sbj='hypocapnia', obj='helium')
#      0.115 KBTriple(rel='shortened', sbj='helium', obj='hypocapnia')
#      0.113 KBTriple(rel='shortened', sbj='arac', obj='hypersensitivity')
#      0.113 KBTriple(rel='shortened', sbj='hypersensitivity', obj='arac')
#      0.110 KBTriple(rel='shortened', sbj='sulindac', obj='dysplasia')
#      0.110 KBTriple(rel='shortened', sbj='dysplasia', obj='sulindac')
#      0.108 KBTriple(rel='shortened', sbj='cystitis', obj='gentamicin')
#      0.108 KBTriple(rel='shortened', sbj='gentamicin', obj='cystitis')
#      0.108 KBTriple(rel='shortened', sbj='hookworm_infection', obj='albendazole')
#      0.108 KBTriple(rel='shortened', sbj='albendazole', obj='hookworm_infection')
#      0.106 KBTriple(rel='shortened', sbj='gallium', obj='angiogram')
#      0.106 KBTriple(rel='shortened', sbj='angiogram', obj='gallium')
#      0.104 KBTriple(rel='shortened', sbj='pectin', obj='amino_acid_level')
#      0.104 KBTriple(rel='shortened', sbj='amino_acid_level', obj='pectin')
#      0.103 KBTriple(rel='shortened', sbj='cholera', obj='norfloxacin')
#      0.103 KBTriple(rel='shortened', sbj='norfloxacin', obj='cholera')
#      0.103 KBTriple(rel='shortened', sbj='sodium', obj='anticipatory_anxiety')
#      0.103 KBTriple(rel='shortened', sbj='anticipatory_anxiety', obj='sodium')
#      0.103 KBTriple(rel='shortened', sbj='nasal', obj='histoplasmosis')
#      0.103 KBTriple(rel='shortened', sbj='histoplasmosis', obj='nasal')
#      0.102 KBTriple(rel='shortened', sbj='pain', obj='gamma-globulin')
#      0.102 KBTriple(rel='shortened', sbj='gamma-globulin', obj='pain')
#      0.102 KBTriple(rel='shortened', sbj='elective_surgery', obj='ibuprofen')
#      0.102 KBTriple(rel='shortened', sbj='ibuprofen', obj='elective_surgery')
#      0.100 KBTriple(rel='shortened', sbj='gamma-globulin', obj='skin_reaction')
#      0.100 KBTriple(rel='shortened', sbj='skin_reaction', obj='gamma-globulin')
#      0.099 KBTriple(rel='shortened', sbj='solar_urticaria', obj='cimetidine')
#      0.099 KBTriple(rel='shortened', sbj='cimetidine', obj='solar_urticaria')
#      0.099 KBTriple(rel='shortened', sbj='angle_closure_glaucoma', obj='fluorouracil')
#      0.099 KBTriple(rel='shortened', sbj='fluorouracil', obj='angle_closure_glaucoma')
#      0.098 KBTriple(rel='shortened', sbj='investigation', obj='budesonide')
#      0.098 KBTriple(rel='shortened', sbj='budesonide', obj='investigation')
#      0.096 KBTriple(rel='shortened', sbj='tenoxicam', obj='discomfort')
#      0.096 KBTriple(rel='shortened', sbj='discomfort', obj='tenoxicam')
#      0.096 KBTriple(rel='shortened', sbj='tenoxicam', obj='epigastric_discomfort')
#      0.096 KBTriple(rel='shortened', sbj='epigastric_discomfort', obj='tenoxicam')
#      0.096 KBTriple(rel='shortened', sbj='propranolol', obj='beta_2_microglobulin')
#      0.096 KBTriple(rel='shortened', sbj='beta_2_microglobulin', obj='propranolol')
#      0.096 KBTriple(rel='shortened', sbj='liver_injury', obj='thiabendazole')
#      0.096 KBTriple(rel='shortened', sbj='thiabendazole', obj='liver_injury')
#      0.093 KBTriple(rel='shortened', sbj='magnesium', obj='ejaculation')
#      0.093 KBTriple(rel='shortened', sbj='ejaculation', obj='magnesium')
#      0.093 KBTriple(rel='shortened', sbj='lidocaine', obj='atopy')
#      0.093 KBTriple(rel='shortened', sbj='atopy', obj='lidocaine')
#      0.093 KBTriple(rel='shortened', sbj='supraventricular_tachyarrhythmia', obj='diltiazem')
#      0.093 KBTriple(rel='shortened', sbj='diltiazem', obj='supraventricular_tachyarrhythmia')
#      0.091 KBTriple(rel='shortened', sbj='lymphocytic_leukaemia', obj='ondansetron')
#      0.091 KBTriple(rel='shortened', sbj='leukaemia', obj='ondansetron')
#      0.091 KBTriple(rel='shortened', sbj='ondansetron', obj='acute_lymphocytic_leukaemia')
#      0.091 KBTriple(rel='shortened', sbj='ondansetron', obj='leukaemia')

# %%
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    '', 'examples', 'examples', 'examples'))
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    'relation', 'eval set', 'suggestions', 'intersection'))
print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
    '--------', '--------', '-------', '-------'))

for rel, instances in eval_relations.items():
    print('{:15s} {:>15s} {:>15s} {:>15s}'.format(
        rel, str(len(instances)), 
        str(int(len(suggestions[rel])/2)), 
        str(len(instances.intersection(suggestions[rel])))))
# Out:
#                        examples        examples        examples
# relation               eval set     suggestions    intersection
# --------               --------         -------         -------
# accelerated                   1               0               0
# acquired                      9             100               0
# aggravated                  114             100               0
# altered                      29             100               0
# caused                    11426             100              26
# changed                      25             100               0
# decreased                   962             100               8
# delayed                      24             100               0
# discoloured                  40             100               1
# impaired                     16             100               0
# increased                  1031             100               9
# infected                      9             100               0
# prolonged                    30             100               1
# reduced                      18             100               0
# ruptured                      5             100               0
# shortened                    30             100               0
