# %%
import os

import pandas as pd

import dist_sup_lib.utils as utils
import dist_sup_lib.rel_ext as rel_ext

from dist_sup_lib.rel_ext import RelSetup

from src.utils import read_json_examples
from src.utils import read_kb_triples
from src.utils import read_kb_triples_json

from src.rel_extract_extend.data import DatasetExt
from src.rel_extract_extend.kfold import make_kfold_val

from src.rel_extract_extend.featurizers import start_bag_of_words_featurizer
from src.rel_extract_extend.featurizers import middle_bag_of_words_featurizer
from src.rel_extract_extend.featurizers import end_bag_of_words_featurizer

# %%
utils.fix_random_seeds()
rel_ext_data_sents = os.path.join('data', 'featurized_sentences')
rel_ext_data_kb = os.path.join("data", "knowledge_base")

example_data = []

for index in range(1, 200):
    s_i = str(index)
    zeros = "0" * (4 - len(s_i))
    # Files updated constantly and the names changes by year
    # for files downloaded in 2021 file_naming has to be changed to
    # featurized_sents_pubmed21n
    tagged_sent_file = f"featurized_sents_pubmed20n{zeros + s_i}.json"
    file_path = os.path.join(rel_ext_data_sents, tagged_sent_file)
    example_data.extend(read_json_examples(file_path))

kb_triples = read_kb_triples_json(os.path.join(rel_ext_data_kb, "rel_drug_react_triple_occ_all.json"))
kb = rel_ext.KB(kb_triples)

corpus = rel_ext.Corpus(example_data)
dataset = DatasetExt(corpus, kb)

# %%
k = 5

results, train_setups, test_setups = make_kfold_val(
    dataset, 
    [
        start_bag_of_words_featurizer, 
        middle_bag_of_words_featurizer, 
        end_bag_of_words_featurizer
    ],
    avg_results=False,
    k=k,
    sampling_rate=0.5
)
# Out:
# {'0': Corpus with 135,453 examples; KB with 10,700 triples, '1': Corpus with 146,804 examples; KB with 9,650 triples, '2': Corpus with 108,424 examples; KB with 11,019 triples, '3': Corpus with 249,476 examples; KB with 10,295 triples, '4': Corpus with 244,064 examples; KB with 13,403 triples, 'all': Corpus with 884,221 examples; KB with 55,067 triples}
# /home/gerhard/.local/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      1.000      1.000          3       2133
# aggravated                0.455      0.163      0.240         92       2222
# altered                   0.250      0.043      0.074         23       2153
# caused                    0.820      0.982      0.894       8924      11054
# changed                   0.933      0.609      0.737         23       2153
# decreased                 0.545      0.124      0.202        734       2864
# delayed                   1.000      0.692      0.818         13       2143
# discoloured               0.885      0.821      0.852         28       2158
# impaired                  0.650      0.867      0.743         15       2145
# increased                 0.630      0.089      0.156        765       2895
# infected                  0.000      0.000      0.000         12       2142
# lowered                   0.000      0.000      0.000          1       2131
# prolonged                 0.778      0.737      0.757         19       2149
# reduced                   0.909      0.714      0.800         14       2144
# ruptured                  0.000      0.000      0.000          5       2135
# shortened                 0.808      0.724      0.764         29       2159
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.604      0.473      0.502      10700      44780
# /home/gerhard/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      0.500      0.667          2       2121
# aggravated                0.797      0.718      0.756         71       2190
# altered                   0.600      0.167      0.261         18       2137
# caused                    0.808      0.980      0.886       8117      10236
# changed                   0.867      0.765      0.812         17       2136
# decreased                 0.686      0.165      0.267        659       2778
# delayed                   1.000      1.000      1.000          8       2127
# discoloured               0.667      0.609      0.636         23       2142
# impaired                  0.692      0.643      0.667         14       2133
# increased                 0.765      0.138      0.234        659       2778
# infected                  0.000      0.000      0.000          3       2122
# prolonged                 1.000      0.706      0.828         17       2136
# reduced                   0.786      0.688      0.733         16       2135
# ruptured                  0.000      0.000      0.000          2       2121
# shortened                 0.773      0.708      0.739         24       2143
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.696      0.519      0.566       9650      41435
# WARNING: could not train model for improved
# train_x_rel = None
# train_y_rel = None
# WARNING: No entries for 'improved
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      1.000      1.000          1       2289
# aggravated                0.774      0.714      0.743         91       2379
# altered                   0.900      0.643      0.750         28       2316
# caused                    0.815      0.977      0.889       9176      11464
# changed                   0.750      0.474      0.581         19       2307
# decreased                 0.551      0.197      0.290        767       3055
# delayed                   1.000      0.889      0.941          9       2297
# discoloured               0.880      0.537      0.667         41       2329
# impaired                  0.900      0.720      0.800         25       2313
# increased                 0.673      0.147      0.242        781       3069
# infected                  0.000      0.000      0.000          3       2291
# prolonged                 0.944      0.680      0.791         25       2313
# reduced                   0.765      0.812      0.788         16       2304
# ruptured                  0.000      0.000      0.000          1       2289
# shortened                 0.815      0.629      0.710         35       2323
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.718      0.561      0.613      11018      45338
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      0.800      0.889          5       2071
# aggravated                0.875      0.786      0.828         98       2164
# altered                   0.333      0.033      0.061         30       2096
# caused                    0.825      0.982      0.897       8535      10601
# changed                   0.909      0.526      0.667         19       2085
# decreased                 0.609      0.211      0.314        729       2795
# delayed                   1.000      0.727      0.842         11       2077
# discoloured               0.808      0.750      0.778         28       2094
# impaired                  0.692      0.529      0.600         17       2083
# increased                 0.752      0.137      0.232        750       2816
# infected                  0.000      0.000      0.000          4       2070
# prolonged                 0.933      0.700      0.800         20       2086
# reduced                   0.923      0.800      0.857         15       2081
# ruptured                  0.000      0.000      0.000          2       2068
# shortened                 0.917      0.688      0.786         32       2098
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.705      0.511      0.570      10295      41285
# WARNING: could not train model for accelerated
# train_x_rel = None
# train_y_rel = None
# WARNING: No entries for 'accelerated
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# acquired                  1.000      0.867      0.929         15       2094
# aggravated                0.870      0.714      0.784         84       2163
# altered                   0.625      0.185      0.286         27       2106
# caused                    0.855      0.947      0.899      11275      13354
# changed                   1.000      0.588      0.741         17       2096
# decreased                 0.812      0.713      0.760        893       2972
# delayed                   1.000      0.308      0.471         13       2092
# discoloured               0.692      0.529      0.600         34       2113
# impaired                  0.818      0.562      0.667         16       2095
# increased                 0.650      0.214      0.322        922       3001
# infected                  0.667      0.200      0.308         10       2089
# lowered                   0.000      0.000      0.000          1       2080
# prolonged                 0.765      0.382      0.510         34       2113
# reduced                   0.900      0.450      0.600         20       2099
# ruptured                  1.000      0.222      0.364          9       2088
# shortened                 0.850      0.531      0.654         32       2111
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.782      0.463      0.556      13402      46666

# %%
print(results)
# Out:
# [{'acquired': [1.0, 1.0, 1.0, 3, 2133], 'aggravated': [0.45454545454545453, 0.16304347826086957, 0.24000000000000002, 92, 2222], 'altered': [0.25, 0.043478260869565216, 0.07407407407407408, 23, 2153], 'caused': [0.8203256597417181, 0.9822949350067235, 0.8940336562978073, 8924, 11054], 'changed': [0.9333333333333333, 0.6086956521739131, 0.7368421052631579, 23, 2153], 'decreased': [0.5449101796407185, 0.12397820163487738, 0.20199778024417314, 734, 2864], 'delayed': [1.0, 0.6923076923076923, 0.8181818181818181, 13, 2143], 'discoloured': [0.8846153846153846, 0.8214285714285714, 0.8518518518518519, 28, 2158], 'impaired': [0.65, 0.8666666666666667, 0.7428571428571429, 15, 2145], 'increased': [0.6296296296296297, 0.08888888888888889, 0.15578465063001146, 765, 2895], 'infected': [0.0, 0.0, 0.0, 12, 2142], 'lowered': [0.0, 0.0, 0.0, 1, 2131], 'prolonged': [0.7777777777777778, 0.7368421052631579, 0.7567567567567567, 19, 2149], 'reduced': [0.9090909090909091, 0.7142857142857143, 0.8, 14, 2144], 'ruptured': [0.0, 0.0, 0.0, 5, 2135], 'shortened': [0.8076923076923077, 0.7241379310344828, 0.7636363636363636, 29, 2159], 'avg_result': [0.6038700397542022, 0.47287800611382025, 0.5022510124870723, 10700, 44780]}, {'acquired': [1.0, 0.5, 0.6666666666666666, 2, 2121], 'aggravated': [0.796875, 0.7183098591549296, 0.7555555555555555, 71, 2190], 'altered': [0.6, 0.16666666666666666, 0.2608695652173913, 18, 2137], 'caused': [0.8084738874212558, 0.9802882838487126, 0.8861295172336989, 8117, 10236], 'changed': [0.8666666666666667, 0.7647058823529411, 0.8125, 17, 2136], 'decreased': [0.6855345911949685, 0.165402124430956, 0.2665036674816626, 659, 2778], 'delayed': [1.0, 1.0, 1.0, 8, 2127], 'discoloured': [0.6666666666666666, 0.6086956521739131, 0.6363636363636365, 23, 2142], 'impaired': [0.6923076923076923, 0.6428571428571429, 0.6666666666666666, 14, 2133], 'increased': [0.7647058823529411, 0.13808801213960548, 0.23393316195372751, 659, 2778], 'infected': [0.0, 0.0, 0.0, 3, 2122], 'prolonged': [1.0, 0.7058823529411765, 0.8275862068965517, 17, 2136], 'reduced': [0.7857142857142857, 0.6875, 0.7333333333333334, 16, 2135], 'ruptured': [0.0, 0.0, 0.0, 2, 2121], 'shortened': [0.7727272727272727, 0.7083333333333334, 0.7391304347826088, 24, 2143], 'avg_result': [0.6959781296701167, 0.5191152873266252, 0.5656825608100999, 9650, 41435]}, {'acquired': [1.0, 1.0, 1.0, 1, 2289], 'aggravated': [0.7738095238095238, 0.7142857142857143, 0.7428571428571429, 91, 2379], 'altered': [0.9, 0.6428571428571429, 0.75, 28, 2316], 'caused': [0.8147205815538392, 0.9771142109851787, 0.8885585451662456, 9176, 11464], 'changed': [0.75, 0.47368421052631576, 0.5806451612903226, 19, 2307], 'decreased': [0.551094890510949, 0.196870925684485, 0.29010566762728146, 767, 3055], 'delayed': [1.0, 0.8888888888888888, 0.9411764705882353, 9, 2297], 'discoloured': [0.88, 0.5365853658536586, 0.6666666666666667, 41, 2329], 'impaired': [0.9, 0.72, 0.7999999999999999, 25, 2313], 'increased': [0.672514619883041, 0.147247119078105, 0.24159663865546216, 781, 3069], 'infected': [0.0, 0.0, 0.0, 3, 2291], 'prolonged': [0.9444444444444444, 0.68, 0.7906976744186047, 25, 2313], 'reduced': [0.7647058823529411, 0.8125, 0.787878787878788, 16, 2304], 'ruptured': [0.0, 0.0, 0.0, 1, 2289], 'shortened': [0.8148148148148148, 0.6285714285714286, 0.7096774193548386, 35, 2323], 'avg_result': [0.7177403171579702, 0.5612403337820612, 0.6126573449669057, 11018, 45338]}, {'acquired': [1.0, 0.8, 0.888888888888889, 5, 2071], 'aggravated': [0.875, 0.7857142857142857, 0.8279569892473119, 98, 2164], 'altered': [0.3333333333333333, 0.03333333333333333, 0.0606060606060606, 30, 2096], 'caused': [0.8252905259011227, 0.9818394844756884, 0.8967842046123388, 8535, 10601], 'changed': [0.9090909090909091, 0.5263157894736842, 0.6666666666666666, 19, 2085], 'decreased': [0.6086956521739131, 0.2112482853223594, 0.31364562118126277, 729, 2795], 'delayed': [1.0, 0.7272727272727273, 0.8421052631578948, 11, 2077], 'discoloured': [0.807692307692307 ...

# %%
columns = ["precision", "recall", "f-score", "support", "size"]
total_results = {}



for key in kb.all_relations:
    rel_res = []
    for part_result in results:
        res = part_result.get(key)
        if res:
            rel_res.append(part_result[key])
        else:
            rel_res.append([0] * 5)
    total_results[key] = pd.DataFrame(data=rel_res, columns=columns)

# %%
avg_vals = {rel: {} for rel in total_results.keys()}
for rel in total_results.keys():
    avg_precision = total_results[rel].precision.mean()
    avg_recall = total_results[rel].recall.mean()
    avg_vals[rel]["avg_precision"] = avg_precision
    avg_vals[rel]["avg_recall"] = avg_recall
    avg_vals[rel]["avg_fscore"] = (
        2 * avg_precision * avg_recall/(avg_precision + avg_recall)
        if avg_precision and avg_recall else 0
    )

# %%
prec_vals = []
rec_vals = []
fscore_vals = []

prec_zeros = 0
rec_zeros = 0
fscore_zeros = 0

for res in avg_vals.values():
    prec_vals.append(res["avg_precision"])
    rec_vals.append(res["avg_recall"])
    fscore_vals.append(res["avg_fscore"])
    if prec_vals[-1] == 0:
        prec_zeros += 1
    if rec_vals[-1] == 0:
        rec_zeros += 1
    if fscore_vals[-1] == 0:
        fscore_zeros += 1

# %%
macro_avg = {}
macro_avg_zeros_excluded = {}

zero_vals = min(prec_zeros, rec_zeros, fscore_zeros)

macro_avg["precision"] = sum(prec_vals)/len(prec_vals)
macro_avg["recall"] = sum(rec_vals)/len(rec_vals)
macro_avg["fscore"] = sum(fscore_vals)/len(fscore_vals)

macro_avg_zeros_excluded["precision"] = sum(prec_vals)/(len(prec_vals) - zero_vals)
macro_avg_zeros_excluded["recall"] = sum(rec_vals)/(len(rec_vals) - zero_vals)
macro_avg_zeros_excluded["fscore"] = sum(fscore_vals)/(len(fscore_vals) - zero_vals)

# %%
print(macro_avg)
# Out:
# {'precision': 0.5994241584083685, 'recall': 0.4317253890575059, 'fscore': 0.4869623830321482}

# %%
prec_vals
# Out:
# [0.0,
#  1.0,
#  0.7539590391492565,
#  0.5416666666666667,
#  0.8247766236772105,
#  0.8918181818181818,
#  0.6405470627041099,
#  1.0,
#  0.7862564102564102,
#  0.7505594405594407,
#  0.0,
#  0.693767993177102,
#  0.13333333333333333,
#  0.0,
#  0.8840522875816994,
#  0.8565176000470119,
#  0.2,
#  0.8323802123802123]

# %%
print(macro_avg_zeros_excluded)
# Out:
# {'precision': 0.7193089900900421, 'recall': 0.518070466869007, 'fscore': 0.5843548596385779}

# %%
print('{:20s} {:>10s} {:>10s} {:>10s}'.format(
        'relation', 'precision', 'recall', 'f-score'))
print('{:20s} {:>10s} {:>10s} {:>10s}'.format(
        '-' * 18, '-' * 9, '-' * 9, '-' * 9))

for rel, precision, recall, fscore in zip(total_results.keys(), prec_vals, rec_vals, fscore_vals):
    print('{:20s} {:10.3f} {:10.3f} {:10.3f}'.format(rel, precision, recall, fscore))
print('{:20s} {:>10s} {:>10s} {:>10s}'.format(
        '-' * 18, '-' * 9, '-' * 9, '-' * 9))
print('{:20s} {:10.3f} {:10.3f} {:10.3f}'.format(
    "macro avg", macro_avg["precision"], macro_avg["recall"], macro_avg["fscore"]))
print('{:20s} {:10.3f} {:10.3f} {:10.3f}'.format(
    "macro avg (-0 vals)", macro_avg_zeros_excluded["precision"], 
    macro_avg_zeros_excluded["recall"], macro_avg_zeros_excluded["fscore"])
     )
# Out:
# relation              precision     recall    f-score
# ------------------    ---------  ---------  ---------
# accelerated               0.000      0.000      0.000
# acquired                  1.000      0.833      0.909
# aggravated                0.754      0.619      0.680
# altered                   0.542      0.214      0.307
# caused                    0.825      0.974      0.893
# changed                   0.892      0.592      0.712
# decreased                 0.641      0.282      0.392
# delayed                   1.000      0.723      0.839
# discoloured               0.786      0.649      0.711
# impaired                  0.751      0.664      0.705
# improved                  0.000      0.000      0.000
# increased                 0.694      0.145      0.240
# infected                  0.133      0.040      0.062
# lowered                   0.000      0.000      0.000
# prolonged                 0.884      0.641      0.743
# reduced                   0.857      0.693      0.766
# ruptured                  0.200      0.044      0.073
# shortened                 0.832      0.656      0.734
# ------------------    ---------  ---------  ---------
# macro avg                 0.599      0.432      0.487
# macro avg (-0 vals)       0.719      0.518      0.584

# %%
all_relations = set(dataset.kb.all_relations)

print("number setups:", len(train_setups))
print("#################")

for i, setup in enumerate(train_setups):
    print("-------------------------")
    set_relations = set([x.relation for x in setup])
    for relation in all_relations.difference(set_relations):
        setup.append(RelSetup(relation, 0, 0))
    setup.sort()
    print(f"setup {i}, number setups:", len(setup))
# Out:
# number setups: 5
# #################
# -------------------------
# setup 0, number setups: 18
# -------------------------
# setup 1, number setups: 18
# -------------------------
# setup 2, number setups: 18
# -------------------------
# setup 3, number setups: 18
# -------------------------
# setup 4, number setups: 18

# %%
columns = ["relation", "pos_examples", "neg_examples"]
train_setup_table = pd.DataFrame(data=train_setups)
train_setup_table
# Out:
#                        0                     1                        2   \
# 0  (accelerated, 1, 8154)  (acquired, 23, 8154)  (aggravated, 344, 8154)
# 1  (accelerated, 1, 8168)  (acquired, 24, 8168)  (aggravated, 365, 8168)
# 2  (accelerated, 1, 7993)  (acquired, 25, 7993)  (aggravated, 345, 7993)
# 3  (accelerated, 1, 8209)  (acquired, 21, 8209)  (aggravated, 338, 8209)
# 4     (accelerated, 0, 0)  (acquired, 11, 8202)  (aggravated, 352, 8202)
#
#                      3                      4                    5   \
# 0  (altered, 103, 8154)  (caused, 37103, 8154)  (changed, 72, 8154)
# 1  (altered, 108, 8168)  (caused, 37910, 8168)  (changed, 78, 8168)
# 2   (altered, 98, 7993)  (caused, 36851, 7993)  (changed, 76, 7993)
# 3   (altered, 96, 8209)  (caused, 37492, 8209)  (changed, 76, 8209)
# 4   (altered, 99, 8202)  (caused, 34752, 8202)  (changed, 78, 8202)
#
#                         6                    7                         8   \
# 0  (decreased, 3048, 8154)  (delayed, 41, 8154)  (discoloured, 126, 8154)
# 1  (decreased, 3123, 8168)  (delayed, 46, 8168)  (discoloured, 131, 8168)
# 2  (decreased, 3015, 7993)  (delayed, 45, 7993)  (discoloured, 113, 7993)
# 3  (decreased, 3053, 8209)  (delayed, 43, 8209)  (discoloured, 126, 8209)
# 4  (decreased, 2889, 8202)  (delayed, 41, 8202)  (discoloured, 120, 8202)
#
#                      9                    10                       11  \
# 0  (impaired, 72, 8154)  (improved, 1, 8154)  (increased, 3112, 8154)
# 1  (impaired, 73, 8168)  (improved, 1, 8168)  (increased, 3218, 8168)
# 2  (impaired, 62, 7993)     (improved, 0, 0)  (increased, 3096, 7993)
# 3  (impaired, 70, 8209)  (improved, 1, 8209)  (increased, 3127, 8209)
# 4  (impaired, 71, 8202)  (improved, 1, 8202)  (increased, 2955, 8202)
#
#                      12                  13                     14  \
# 0  (infected, 20, 8154)  (lowered, 1, 8154)  (prolonged, 96, 8154)
# 1  (infected, 29, 8168)  (lowered, 2, 8168)  (prolonged, 98, 8168)
# 2  (infected, 29, 7993)  (lowered, 2, 7993)  (prolonged, 90, 7993)
# 3  (infected, 28, 8209)  (lowered, 2, 8209)  (prolonged, 95, 8209)
# 4  (infected, 22, 8202)  (lowered, 1, 8202)  (prolonged, 81, 8202)
#
#                     15                    16                      17
# 0  (reduced, 67, 8154)  (ruptured, 14, 8154)  (shortened, 123, 8154)
# 1  (reduced, 65, 8168)  (ruptured, 17, 8168)  (shortened, 128, 8168)
# 2  (reduced, 65, 7993)  (ruptured, 18, 7993)  (shortened, 117, 7993)
# 3  (reduced, 66, 8209)  (ruptured, 17, 8209)  (shortened, 120, 8209)
# 4  (reduced, 61, 8202)  (ruptured, 10, 8202)  (shortened, 120, 8202)

# %%
all_relations = set(dataset.kb.all_relations)

print("number setups:", len(test_setups))
print("#################")

for i, setup in enumerate(test_setups):
    print("-------------------------")
    set_relations = set([x.relation for x in setup])
    for relation in all_relations.difference(set_relations):
        setup.append(RelSetup(relation, 0, 0))
    setup.sort()
    print(f"setup {i}, number setups:", len(setup))
# Out:
# number setups: 5
# #################
# -------------------------
# setup 0, number setups: 18
# -------------------------
# setup 1, number setups: 18
# -------------------------
# setup 2, number setups: 18
# -------------------------
# setup 3, number setups: 18
# -------------------------
# setup 4, number setups: 18

# %%
columns = ["relation", "pos_examples", "neg_examples"]
test_setup_table = pd.DataFrame(data=test_setups)
test_setup_table
# Out:
#                        0                     1                       2   \
# 0     (accelerated, 0, 0)   (acquired, 3, 2130)  (aggravated, 92, 2130)
# 1     (accelerated, 0, 0)   (acquired, 2, 2119)  (aggravated, 71, 2119)
# 2     (accelerated, 0, 0)   (acquired, 1, 2288)  (aggravated, 91, 2288)
# 3     (accelerated, 0, 0)   (acquired, 5, 2066)  (aggravated, 98, 2066)
# 4  (accelerated, 1, 2079)  (acquired, 15, 2079)  (aggravated, 84, 2079)
#
#                     3                      4                    5   \
# 0  (altered, 23, 2130)   (caused, 8924, 2130)  (changed, 23, 2130)
# 1  (altered, 18, 2119)   (caused, 8117, 2119)  (changed, 17, 2119)
# 2  (altered, 28, 2288)   (caused, 9176, 2288)  (changed, 19, 2288)
# 3  (altered, 30, 2066)   (caused, 8535, 2066)  (changed, 19, 2066)
# 4  (altered, 27, 2079)  (caused, 11275, 2079)  (changed, 17, 2079)
#
#                        6                    7                        8   \
# 0  (decreased, 734, 2130)  (delayed, 13, 2130)  (discoloured, 28, 2130)
# 1  (decreased, 659, 2119)   (delayed, 8, 2119)  (discoloured, 23, 2119)
# 2  (decreased, 767, 2288)   (delayed, 9, 2288)  (discoloured, 41, 2288)
# 3  (decreased, 729, 2066)  (delayed, 11, 2066)  (discoloured, 28, 2066)
# 4  (decreased, 893, 2079)  (delayed, 13, 2079)  (discoloured, 34, 2079)
#
#                      9                    10                      11  \
# 0  (impaired, 15, 2130)     (improved, 0, 0)  (increased, 765, 2130)
# 1  (impaired, 14, 2119)     (improved, 0, 0)  (increased, 659, 2119)
# 2  (impaired, 25, 2288)  (improved, 1, 2288)  (increased, 781, 2288)
# 3  (impaired, 17, 2066)     (improved, 0, 0)  (increased, 750, 2066)
# 4  (impaired, 16, 2079)     (improved, 0, 0)  (increased, 922, 2079)
#
#                      12                  13                     14  \
# 0  (infected, 12, 2130)  (lowered, 1, 2130)  (prolonged, 19, 2130)
# 1   (infected, 3, 2119)     (lowered, 0, 0)  (prolonged, 17, 2119)
# 2   (infected, 3, 2288)     (lowered, 0, 0)  (prolonged, 25, 2288)
# 3   (infected, 4, 2066)     (lowered, 0, 0)  (prolonged, 20, 2066)
# 4  (infected, 10, 2079)  (lowered, 1, 2079)  (prolonged, 34, 2079)
#
#                     15                   16                     17
# 0  (reduced, 14, 2130)  (ruptured, 5, 2130)  (shortened, 29, 2130)
# 1  (reduced, 16, 2119)  (ruptured, 2, 2119)  (shortened, 24, 2119)
# 2  (reduced, 16, 2288)  (ruptured, 1, 2288)  (shortened, 35, 2288)
# 3  (reduced, 15, 2066)  (ruptured, 2, 2066)  (shortened, 32, 2066)
# 4  (reduced, 20, 2079)  (ruptured, 9, 2079)  (shortened, 32, 2079)
